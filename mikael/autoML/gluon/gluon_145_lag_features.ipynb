# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from autogluon.tabular import TabularDataset, TabularPredictor
import pandas as pd
import numpy as np

# %%
# %autoreload
from pipeline_lag_features import Pipeline
pipin = Pipeline()

# %%
DEFAULT_PATH = f"ag_145_lag_features"

# %%
df1_0 = pipin.get_data("A")
df2_0 = pipin.get_data("B")
df3_0 = pipin.get_data("C")

# %%
# remove_consecutive_measurments
df1_0 = pipin.remove_consecutive_measurments(df1_0, 400, 25)
df2_0 = pipin.remove_consecutive_measurments(df2_0, 400, 25)
df3_0 = pipin.remove_consecutive_measurments(df3_0, 400, 25)

# %%
df1_0.head()
# Out:
#    absolute_humidity_2m:gm3  air_density_2m:kgm3  ceiling_height_agl:m  \
# 0                     7.700              1.22825           1728.949951
# 1                     7.700              1.22350           1689.824951
# 2                     7.875              1.21975           1563.224976
# 3                     8.425              1.21800           1283.425049
# 4                     8.950              1.21800           1003.500000
#
#    clear_sky_energy_1h:J  clear_sky_rad:W  cloud_base_agl:m  dew_or_rime:idx  \
# 0               0.000000             0.00       1728.949951              0.0
# 1               0.000000             0.00       1689.824951              0.0
# 2               0.000000             0.00       1563.224976              0.0
# 3             208.649994             0.75       1283.425049              0.0
# 4           32468.150391            23.10       1003.500000              0.0
#
#    dew_point_2m:K  diffuse_rad:W  diffuse_rad_1h:J  ...  \
# 0      280.299988          0.000          0.000000  ...
# 1      280.299988          0.000          0.000000  ...
# 2      280.649994          0.000          0.000000  ...
# 3      281.674988          0.300        526.775024  ...
# 4      282.500000         11.975      22068.949219  ...
#
#    wind_speed_w_1000hPa:ms  estimated  observed  day_of_year  hour  \
# 0                      0.0        0.0       1.0        153.0  22.0
# 1                      0.0        0.0       1.0        153.0  23.0
# 2                      0.0        0.0       1.0        154.0   0.0
# 3                      0.0        0.0       1.0        154.0   1.0
# 4                      0.0        0.0       1.0        154.0   2.0
#
#    clear_sky_energy_1h:J_lag_2  diffuse_rad_1h:J_lag_2  direct_rad_1h:J_lag_2  \
# 0                          NaN                     NaN                    NaN
# 1                          NaN                     NaN                    NaN
# 2                          0.0                     0.0                    0.0
# 3                          0.0                     0.0                    0.0
# 4                          0.0                     0.0                    0.0
#
#    fresh_snow_1h:cm_lag_2  pv_measurement
# 0                     NaN            0.00
# 1                     NaN            0.00
# 2                     0.0            0.00
# 3                     0.0            0.00
# 4                     0.0           19.36
#
# [5 rows x 54 columns]

# %%
train1 = TabularDataset(df1_0)
train2 = TabularDataset(df2_0)
train3 = TabularDataset(df3_0)

# %%
predictor1 = TabularPredictor(label="pv_measurement",
                              eval_metric='mean_absolute_error',
                              path= DEFAULT_PATH+"A"
                              ).fit(
    train1,
    time_limit=3600,
    # hyperparameters='extrme', 
    presets='experimental_zeroshot_hpo_hybrid', 
    # tuning_data = tuning1,
    # use_bag_holdout=True,
    # num_bag_folds= 6,
    # refit_full = True,
    # auto_stack = True,
    # num_bag_sets= 10,
    # set_best_to_refit_full= True,
    # num_stack_levels = 2,
    # verbosity = 3
    )
# Out:
# Presets specified: ['best_quality']
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/core/utils/utils.py:564: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Beginning AutoGluon training ...
# AutoGluon will save models to "ag_145_lag_featuresA"
# AutoGluon Version:  0.8.2
# Python Version:     3.10.12
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 23.0.0: Fri Sep 15 14:41:43 PDT 2023; root:xnu-10002.1.13~1/RELEASE_ARM64_T6000
# Disk Space Avail:   228.80 GB / 494.38 GB (46.3%)
# Train Data Rows:    19853
# Train Data Columns: 53
# Label Column: pv_measurement
# Preprocessing data ...
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/core/utils/utils.py:564: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (5733.42, 0.0, 1082.6485, 1358.08613)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/learner/default_learner.py:215: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    4302.12 MB
# 	Train Data (Original)  Memory Usage: 4.53 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 3 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Unused Original Features (Count: 1): ['snow_drift:idx']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('float', []) : 1 | ['snow_drift:idx']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 52 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 50 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 		('int', ['bool']) :  2 | ['elevation:m', 'snow_density:kgm3']
# 	3.5s = Fit runtime
# 	52 features in original data used to generate 52 features in processed data.
# 	Train Data (Processed) Memory Usage: 4.33 MB (0.1% of available memory)
# Data preprocessing and feature engineering runtime = 4.33s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ...
# 	-384.5416	 = Validation score   (-mean_absolute_error)
# 	0.02s	 = Training   runtime
# 	1.99s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ...
# 	-384.0107	 = Validation score   (-mean_absolute_error)
# 	0.21s	 = Training   runtime
# 	1.93s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-259.7062	 = Validation score   (-mean_absolute_error)
# 	170.5s	 = Training   runtime
# 	122.37s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-272.9814	 = Validation score   (-mean_absolute_error)
# 	270.29s	 = Training   runtime
# 	130.18s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ...
# 	-310.7248	 = Validation score   (-mean_absolute_error)
# 	130.13s	 = Training   runtime
# 	4.45s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-278.7811	 = Validation score   (-mean_absolute_error)
# 	834.75s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ...
# 	-310.066	 = Validation score   (-mean_absolute_error)
# 	16.02s	 = Training   runtime
# 	3.57s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-304.9654	 = Validation score   (-mean_absolute_error)
# 	65.32s	 = Training   runtime
# 	0.83s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-288.8076	 = Validation score   (-mean_absolute_error)
# 	440.64s	 = Training   runtime
# 	29.15s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-293.2446	 = Validation score   (-mean_absolute_error)
# 	105.83s	 = Training   runtime
# 	0.5s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-271.1995	 = Validation score   (-mean_absolute_error)
# 	242.28s	 = Training   runtime
# 	502.21s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-256.2728	 = Validation score   (-mean_absolute_error)
# 	0.93s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 9 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-258.2787	 = Validation score   (-mean_absolute_error)
# 	11.6s	 = Training   runtime
# 	1.46s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-255.9625	 = Validation score   (-mean_absolute_error)
# 	10.26s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ...
# 	-256.6691	 = Validation score   (-mean_absolute_error)
# 	84.2s	 = Training   runtime
# 	3.39s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-254.8722	 = Validation score   (-mean_absolute_error)
# 	39.13s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ...
# 	-253.4918	 = Validation score   (-mean_absolute_error)
# 	19.61s	 = Training   runtime
# 	2.75s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-255.2476	 = Validation score   (-mean_absolute_error)
# 	51.12s	 = Training   runtime
# 	0.65s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-255.415	 = Validation score   (-mean_absolute_error)
# 	40.89s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-254.0166	 = Validation score   (-mean_absolute_error)
# 	105.82s	 = Training   runtime
# 	0.71s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-258.8145	 = Validation score   (-mean_absolute_error)
# 	27.96s	 = Training   runtime
# 	1.36s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ...
# 	-249.459	 = Validation score   (-mean_absolute_error)
# 	1.09s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 2890.55s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("ag_145_lag_featuresA")

# %%
predictor2 = TabularPredictor(label="pv_measurement", 
                              eval_metric='mean_absolute_error',
                              path= DEFAULT_PATH+"B"
                              ).fit(
    train2,
    time_limit=3600,
    presets='experimental_zeroshot_hpo_hybrid', 
    # hyperparameters='very_large', 
    # tuning_data = tuning2,
    # use_bag_holdout=True,
    # num_bag_folds= 6,
    # refit_full = True,
    # auto_stack = True,
    # num_bag_sets= 10,
    # set_best_to_refit_full= True,
    # num_stack_levels = 2,
    # verbosity = 3
    )

# tuning_data
# num bag holdout 6
# bag_holdout
# Out:
# Presets specified: ['best_quality']
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/core/utils/utils.py:564: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Beginning AutoGluon training ...
# AutoGluon will save models to "ag_145_lag_featuresB"
# AutoGluon Version:  0.8.2
# Python Version:     3.10.12
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 23.0.0: Fri Sep 15 14:41:43 PDT 2023; root:xnu-10002.1.13~1/RELEASE_ARM64_T6000
# Disk Space Avail:   215.05 GB / 494.38 GB (43.5%)
# Train Data Rows:    13632
# Train Data Columns: 53
# Label Column: pv_measurement
# Preprocessing data ...
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/core/utils/utils.py:564: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (1152.3, 0.0, 203.67563, 257.36859)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/learner/default_learner.py:215: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    6029.45 MB
# 	Train Data (Original)  Memory Usage: 3.11 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 3 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Unused Original Features (Count: 1): ['snow_drift:idx']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('float', []) : 1 | ['snow_drift:idx']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 52 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 50 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 		('int', ['bool']) :  2 | ['elevation:m', 'snow_density:kgm3']
# 	0.9s = Fit runtime
# 	52 features in original data used to generate 52 features in processed data.
# 	Train Data (Processed) Memory Usage: 2.97 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 1.08s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ...
# 	-62.887	 = Validation score   (-mean_absolute_error)
# 	0.08s	 = Training   runtime
# 	0.54s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ...
# 	-62.6383	 = Validation score   (-mean_absolute_error)
# 	0.05s	 = Training   runtime
# 	0.54s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-41.5085	 = Validation score   (-mean_absolute_error)
# 	68.33s	 = Training   runtime
# 	57.5s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-43.946	 = Validation score   (-mean_absolute_error)
# 	301.85s	 = Training   runtime
# 	122.62s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ...
# 	-50.0941	 = Validation score   (-mean_absolute_error)
# 	50.65s	 = Training   runtime
# 	2.35s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/miksx/GitHub/Forest-Gump/mikael/autoML/gluon/gluon_145_lag_features.ipynb Cell 10 line 1
# ----> <a href='vscode-notebook-cell:/Users/miksx/GitHub/Forest-Gump/mikael/autoML/gluon/gluon_145_lag_features.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> predictor2 = TabularPredictor(label="pv_measurement",
#       <a href='vscode-notebook-cell:/Users/miksx/GitHub/Forest-Gump/mikael/autoML/gluon/gluon_145_lag_features.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a>                               eval_metric='mean_absolute_error',
#       <a href='vscode-notebook-cell:/Users/miksx/GitHub/Forest-Gump/mikael/autoML/gluon/gluon_145_lag_features.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a>                               path= DEFAULT_PATH+"B"
#       <a href='vscode-notebook-cell:/Users/miksx/GitHub/Forest-Gump/mikael/autoML/gluon/gluon_145_lag_features.ipynb#X11sZmlsZQ%3D%3D?line=3'>4</a>                               ).fit(
#       <a href='vscode-notebook-cell:/Users/miksx/GitHub/Forest-Gump/mikael/autoML/gluon/gluon_145_lag_features.ipynb#X11sZmlsZQ%3D%3D?line=4'>5</a>     train2,
#       <a href='vscode-notebook-cell:/Users/miksx/GitHub/Forest-Gump/mikael/autoML/gluon/gluon_145_lag_features.ipynb#X11sZmlsZQ%3D%3D?line=5'>6</a>
#       <a href='vscode-notebook-cell:/Users/miksx/GitHub/Forest-Gump/mikael/autoML/gluon/gluon_145_lag_features.ipynb#X11sZmlsZQ%3D%3D?line=6'>7</a>     presets='best_quality',
#       <a href='vscode-notebook-cell:/Users/miksx/GitHub/Forest-Gump/mikael/autoML/gluon/gluon_145_lag_features.ipynb#X11sZmlsZQ%3D%3D?line=7'>8</a>     # hyperparameters='very_large',
#       <a href='vscode-notebook-cell:/Users/miksx/GitHub/Forest-Gump/mikael/autoML/gluon/gluon_145_lag_features.ipynb#X11sZmlsZQ%3D%3D?line=8'>9</a>     # time_limit=6000,
#      <a href='vscode-notebook-cell:/Users/miksx/GitHub/Forest-Gump/mikael/autoML/gluon/gluon_145_lag_features.ipynb#X11sZmlsZQ%3D%3D?line=9'>10</a>     # tuning_data = tuning2,
#      <a href='vscode-notebook-cell:/Users/miksx/GitHub/Forest-Gump/mikael/autoML/gluon/gluon_145_lag_features.ipynb#X11sZmlsZQ%3D%3D?line=10'>11</a>     # use_bag_holdout=True,
#      <a href='vscode-notebook-cell:/Users/miksx/GitHub/Forest-Gump/mikael/autoML/gluon/gluon_145_lag_features.ipynb#X11sZmlsZQ%3D%3D?line=11'>12</a>     # num_bag_folds= 6,
#      <a href='vscode-notebook-cell:/Users/miksx/GitHub/Forest-Gump/mikael/autoML/gluon/gluon_145_lag_features.ipynb#X11sZmlsZQ%3D%3D?line=12'>13</a>     # refit_full = True,
#      <a href='vscode-notebook-cell:/Users/miksx/GitHub/Forest-Gump/mikael/autoML/gluon/gluon_145_lag_features.ipynb#X11sZmlsZQ%3D%3D?line=13'>14</a>     # auto_stack = True,
#      <a href='vscode-notebook-cell:/Users/miksx/GitHub/Forest-Gump/mikael/autoML/gluon/gluon_145_lag_features.ipynb#X11sZmlsZQ%3D%3D?line=14'>15</a>     # num_bag_sets= 10,
#      <a href='vscode-notebook-cell:/Users/miksx/GitHub/Forest-Gump/mikael/autoML/gluon/gluon_145_lag_features.ipynb#X11sZmlsZQ%3D%3D?line=15'>16</a>     # set_best_to_refit_full= True,
#      <a href='vscode-notebook-cell:/Users/miksx/GitHub/Forest-Gump/mikael/autoML/gluon/gluon_145_lag_features.ipynb#X11sZmlsZQ%3D%3D?line=16'>17</a>     # num_stack_levels = 2,
#      <a href='vscode-notebook-cell:/Users/miksx/GitHub/Forest-Gump/mikael/autoML/gluon/gluon_145_lag_features.ipynb#X11sZmlsZQ%3D%3D?line=17'>18</a>     # verbosity = 3
#      <a href='vscode-notebook-cell:/Users/miksx/GitHub/Forest-Gump/mikael/autoML/gluon/gluon_145_lag_features.ipynb#X11sZmlsZQ%3D%3D?line=18'>19</a>     )
#
# File ~/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/core/utils/decorators.py:31, in unpack.<locals>._unpack_inner.<locals>._call(*args, **kwargs)
#      28 @functools.wraps(f)
#      29 def _call(*args, **kwargs):
#      30     gargs, gkwargs = g(*other_args, *args, **kwargs)
# ---> 31     return f(*gargs, **gkwargs)
#
# File ~/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/predictor/predictor.py:986, in TabularPredictor.fit(self, train_data, tuning_data, time_limit, presets, hyperparameters, feature_metadata, infer_limit, infer_limit_batch_size, fit_weighted_ensemble, calibrate_decision_threshold, num_cpus, num_gpus, **kwargs)
#     984     aux_kwargs["fit_weighted_ensemble"] = False
#     985 self.save(silent=True)  # Save predictor to disk to enable prediction and training after interrupt
# --> 986 self._learner.fit(
#     987     X=train_data,
#     988     X_val=tuning_data,
#     989     X_unlabeled=unlabeled_data,
#     990     holdout_frac=holdout_frac,
#     991     num_bag_folds=num_bag_folds,
#     992     num_bag_sets=num_bag_sets,
#     993     num_stack_levels=num_stack_levels,
#     994     hyperparameters=hyperparameters,
#     995     core_kwargs=core_kwargs,
#     996     aux_kwargs=aux_kwargs,
#     997     time_limit=time_limit,
#     998     infer_limit=infer_limit,
#     999     infer_limit_batch_size=infer_limit_batch_size,
#    1000     verbosity=verbosity,
#    1001     use_bag_holdout=use_bag_holdout,
#    1002 )
#    1003 self._set_post_fit_vars()
#    1005 self._post_fit(
#    1006     keep_only_best=kwargs["keep_only_best"],
#    1007     refit_full=kwargs["refit_full"],
#    (...)
#    1012     infer_limit=infer_limit,
#    1013 )
#
# File ~/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/learner/abstract_learner.py:159, in AbstractTabularLearner.fit(self, X, X_val, **kwargs)
#     157     raise AssertionError("Learner is already fit.")
#     158 self._validate_fit_input(X=X, X_val=X_val, **kwargs)
# --> 159 return self._fit(X=X, X_val=X_val, **kwargs)
#
# File ~/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/learner/default_learner.py:157, in DefaultLearner._fit(self, X, X_val, X_unlabeled, holdout_frac, num_bag_folds, num_bag_sets, time_limit, infer_limit, infer_limit_batch_size, verbosity, **trainer_fit_kwargs)
#     154     self.eval_metric = trainer.eval_metric
#     156 self.save()
# --> 157 trainer.fit(
#     158     X=X,
#     159     y=y,
#     160     X_val=X_val,
#     161     y_val=y_val,
#     162     X_unlabeled=X_unlabeled,
#     163     holdout_frac=holdout_frac,
#     164     time_limit=time_limit_trainer,
#     165     infer_limit=infer_limit,
#     166     infer_limit_batch_size=infer_limit_batch_size,
#     167     groups=groups,
#     168     **trainer_fit_kwargs,
#     169 )
#     170 self.save_trainer(trainer=trainer)
#     171 time_end = time.time()
#
# File ~/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/trainer/auto_trainer.py:114, in AutoTrainer.fit(self, X, y, hyperparameters, X_val, y_val, X_unlabeled, holdout_frac, num_stack_levels, core_kwargs, aux_kwargs, time_limit, infer_limit, infer_limit_batch_size, use_bag_holdout, groups, **kwargs)
#     111 log_str += "}"
#     112 logger.log(20, log_str)
# --> 114 self._train_multi_and_ensemble(
#     115     X=X,
#     116     y=y,
#     117     X_val=X_val,
#     118     y_val=y_val,
#     119     X_unlabeled=X_unlabeled,
#     120     hyperparameters=hyperparameters,
#     121     num_stack_levels=num_stack_levels,
#     122     time_limit=time_limit,
#     123     core_kwargs=core_kwargs,
#     124     aux_kwargs=aux_kwargs,
#     125     infer_limit=infer_limit,
#     126     infer_limit_batch_size=infer_limit_batch_size,
#     127     groups=groups,
#     128 )
#
# File ~/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/core/trainer/abstract_trainer.py:2419, in AbstractTrainer._train_multi_and_ensemble(self, X, y, X_val, y_val, hyperparameters, X_unlabeled, num_stack_levels, time_limit, groups, **kwargs)
#    2417     self._num_rows_val = len(X_val)
#    2418 self._num_cols_train = len(list(X.columns))
# -> 2419 model_names_fit = self.train_multi_levels(
#    2420     X,
#    2421     y,
#    2422     hyperparameters=hyperparameters,
#    2423     X_val=X_val,
#    2424     y_val=y_val,
#    2425     X_unlabeled=X_unlabeled,
#    2426     level_start=1,
#    2427     level_end=num_stack_levels + 1,
#    2428     time_limit=time_limit,
#    2429     **kwargs,
#    2430 )
#    2431 if len(self.get_model_names()) == 0:
#    2432     raise ValueError("AutoGluon did not successfully train any models")
#
# File ~/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/core/trainer/abstract_trainer.py:383, in AbstractTrainer.train_multi_levels(self, X, y, hyperparameters, X_val, y_val, X_unlabeled, base_model_names, core_kwargs, aux_kwargs, level_start, level_end, time_limit, name_suffix, relative_stack, level_time_modifier, infer_limit, infer_limit_batch_size)
#     381         core_kwargs_level["time_limit"] = core_kwargs_level.get("time_limit", time_limit_core)
#     382         aux_kwargs_level["time_limit"] = aux_kwargs_level.get("time_limit", time_limit_aux)
# --> 383     base_model_names, aux_models = self.stack_new_level(
#     384         X=X,
#     385         y=y,
#     386         X_val=X_val,
#     387         y_val=y_val,
#     388         X_unlabeled=X_unlabeled,
#     389         models=hyperparameters,
#     390         level=level,
#     391         base_model_names=base_model_names,
#     392         core_kwargs=core_kwargs_level,
#     393         aux_kwargs=aux_kwargs_level,
#     394         name_suffix=name_suffix,
#     395         infer_limit=infer_limit,
#     396         infer_limit_batch_size=infer_limit_batch_size,
#     397     )
#     398     model_names_fit += base_model_names + aux_models
#     399 if self.model_best is None and len(model_names_fit) != 0:
#
# File ~/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/core/trainer/abstract_trainer.py:527, in AbstractTrainer.stack_new_level(self, X, y, models, X_val, y_val, X_unlabeled, level, base_model_names, core_kwargs, aux_kwargs, name_suffix, infer_limit, infer_limit_batch_size)
#     525     core_kwargs["name_suffix"] = core_kwargs.get("name_suffix", "") + name_suffix
#     526     aux_kwargs["name_suffix"] = aux_kwargs.get("name_suffix", "") + name_suffix
# --> 527 core_models = self.stack_new_level_core(
#     528     X=X,
#     529     y=y,
#     530     X_val=X_val,
#     531     y_val=y_val,
#     532     X_unlabeled=X_unlabeled,
#     533     models=models,
#     534     level=level,
#     535     infer_limit=infer_limit,
#     536     infer_limit_batch_size=infer_limit_batch_size,
#     537     base_model_names=base_model_names,
#     538     **core_kwargs,
#     539 )
#     541 if X_val is None:
#     542     aux_models = self.stack_new_level_aux(
#     543         X=X, y=y, base_model_names=core_models, level=level + 1, infer_limit=infer_limit, infer_limit_batch_size=infer_limit_batch_size, **aux_kwargs
#     544     )
#
# File ~/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/core/trainer/abstract_trainer.py:661, in AbstractTrainer.stack_new_level_core(self, X, y, models, X_val, y_val, X_unlabeled, level, base_model_names, stack_name, ag_args, ag_args_fit, ag_args_ensemble, included_model_types, excluded_model_types, ensemble_type, name_suffix, get_models_func, refit_full, infer_limit, infer_limit_batch_size, **kwargs)
#     658 fit_kwargs = dict(num_classes=self.num_classes)
#     660 # FIXME: TODO: v0.1 X_unlabeled isn't cached so it won't be available during refit_full or fit_extra.
# --> 661 return self._train_multi(
#     662     X=X_init,
#     663     y=y,
#     664     X_val=X_val,
#     665     y_val=y_val,
#     666     X_unlabeled=X_unlabeled,
#     667     models=models,
#     668     level=level,
#     669     stack_name=stack_name,
#     670     compute_score=compute_score,
#     671     fit_kwargs=fit_kwargs,
#     672     **kwargs,
#     673 )
#
# File ~/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/core/trainer/abstract_trainer.py:2369, in AbstractTrainer._train_multi(self, X, y, models, hyperparameter_tune_kwargs, feature_prune_kwargs, k_fold, n_repeats, n_repeat_start, time_limit, **kwargs)
#    2367 if n_repeat_start == 0:
#    2368     time_start = time.time()
# -> 2369     model_names_trained = self._train_multi_initial(
#    2370         X=X,
#    2371         y=y,
#    2372         models=models,
#    2373         k_fold=k_fold,
#    2374         n_repeats=n_repeats_initial,
#    2375         hyperparameter_tune_kwargs=hyperparameter_tune_kwargs,
#    2376         feature_prune_kwargs=feature_prune_kwargs,
#    2377         time_limit=time_limit,
#    2378         **kwargs,
#    2379     )
#    2380     n_repeat_start = n_repeats_initial
#    2381     if time_limit is not None:
#
# File ~/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/core/trainer/abstract_trainer.py:2218, in AbstractTrainer._train_multi_initial(self, X, y, models, k_fold, n_repeats, hyperparameter_tune_kwargs, time_limit, feature_prune_kwargs, **kwargs)
#    2216 else:
#    2217     time_ratio = hpo_time_ratio if hpo_enabled else 1
# -> 2218     models = self._train_multi_fold(
#    2219         models=models,
#    2220         hyperparameter_tune_kwargs=hyperparameter_tune_kwargs,
#    2221         k_fold_start=0,
#    2222         k_fold_end=k_fold,
#    2223         n_repeats=n_repeats,
#    2224         n_repeat_start=0,
#    2225         time_limit=time_limit,
#    2226         time_split=time_split,
#    2227         time_ratio=time_ratio,
#    2228         **fit_args,
#    2229     )
#    2231 multi_fold_time_elapsed = time.time() - multi_fold_time_start
#    2232 if time_limit is not None:
#
# File ~/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/core/trainer/abstract_trainer.py:2326, in AbstractTrainer._train_multi_fold(self, X, y, models, time_limit, time_split, time_ratio, hyperparameter_tune_kwargs, **kwargs)
#    2324         time_start_model = time.time()
#    2325         time_left = time_limit - (time_start_model - time_start)
# -> 2326 model_name_trained_lst = self._train_single_full(
#    2327     X, y, model, time_limit=time_left, hyperparameter_tune_kwargs=hyperparameter_tune_kwargs_model, **kwargs
#    2328 )
#    2330 if self.low_memory:
#    2331     del model
#
# File ~/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/core/trainer/abstract_trainer.py:2099, in AbstractTrainer._train_single_full(self, X, y, model, X_unlabeled, X_val, y_val, X_pseudo, y_pseudo, feature_prune, hyperparameter_tune_kwargs, stack_name, k_fold, k_fold_start, k_fold_end, n_repeats, n_repeat_start, level, time_limit, fit_kwargs, compute_score, total_resources, **kwargs)
#    2095         bagged_model_fit_kwargs = self._get_bagged_model_fit_kwargs(
#    2096             k_fold=k_fold, k_fold_start=k_fold_start, k_fold_end=k_fold_end, n_repeats=n_repeats, n_repeat_start=n_repeat_start
#    2097         )
#    2098         model_fit_kwargs.update(bagged_model_fit_kwargs)
# -> 2099     model_names_trained = self._train_and_save(
#    2100         X=X,
#    2101         y=y,
#    2102         model=model,
#    2103         X_val=X_val,
#    2104         y_val=y_val,
#    2105         X_unlabeled=X_unlabeled,
#    2106         stack_name=stack_name,
#    2107         level=level,
#    2108         compute_score=compute_score,
#    2109         total_resources=total_resources,
#    2110         **model_fit_kwargs,
#    2111     )
#    2112 self.save()
#    2113 return model_names_trained
#
# File ~/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/core/trainer/abstract_trainer.py:1761, in AbstractTrainer._train_and_save(self, X, y, model, X_val, y_val, stack_name, level, compute_score, total_resources, **model_fit_kwargs)
#    1759     model = self._train_single(X_w_pseudo, y_w_pseudo, model, X_val, y_val, **model_fit_kwargs)
#    1760 else:
# -> 1761     model = self._train_single(X, y, model, X_val, y_val, total_resources=total_resources, **model_fit_kwargs)
#    1763 fit_end_time = time.time()
#    1764 if self.weight_evaluation:
#
# File ~/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/core/trainer/abstract_trainer.py:1712, in AbstractTrainer._train_single(self, X, y, model, X_val, y_val, total_resources, **model_fit_kwargs)
#    1707 def _train_single(self, X, y, model: AbstractModel, X_val=None, y_val=None, total_resources=None, **model_fit_kwargs) -> AbstractModel:
#    1708     """
#    1709     Trains model but does not add the trained model to this Trainer.
#    1710     Returns trained model object.
#    1711     """
# -> 1712     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, total_resources=total_resources, **model_fit_kwargs)
#    1713     return model
#
# File ~/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py:838, in AbstractModel.fit(self, **kwargs)
#     836 self.validate_fit_resources(**kwargs)
#     837 self._validate_fit_memory_usage(**kwargs)
# --> 838 out = self._fit(**kwargs)
#     839 if out is None:
#     840     out = self
#
# File ~/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/core/models/ensemble/stacker_ensemble_model.py:165, in StackerEnsembleModel._fit(self, X, y, compute_base_preds, time_limit, **kwargs)
#     163 if time_limit is not None:
#     164     time_limit = time_limit - (time.time() - start_time)
# --> 165 return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#
# File ~/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py:266, in BaggedEnsembleModel._fit(self, X, y, X_val, y_val, X_pseudo, y_pseudo, k_fold, k_fold_start, k_fold_end, n_repeats, n_repeat_start, groups, _skip_oof, **kwargs)
#     264         # Reserve time for final refit model
#     265         kwargs["time_limit"] = kwargs["time_limit"] * folds_to_fit / (folds_to_fit + 1.2)
# --> 266 self._fit_folds(
#     267     X=X,
#     268     y=y,
#     269     model_base=model_base,
#     270     X_pseudo=X_pseudo,
#     271     y_pseudo=y_pseudo,
#     272     k_fold=k_fold,
#     273     k_fold_start=k_fold_start,
#     274     k_fold_end=k_fold_end,
#     275     n_repeats=n_repeats,
#     276     n_repeat_start=n_repeat_start,
#     277     save_folds=save_bag_folds,
#     278     groups=groups,
#     279     **kwargs,
#     280 )
#     281 # FIXME: Cleanup self
#     282 # FIXME: Support `can_refit_full=False` models
#     283 if refit_folds:
#
# File ~/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py:592, in BaggedEnsembleModel._fit_folds(self, X, y, model_base, X_pseudo, y_pseudo, k_fold, k_fold_start, k_fold_end, n_repeats, n_repeat_start, time_limit, sample_weight, save_folds, groups, num_cpus, num_gpus, **kwargs)
#     590 for fold_fit_args in fold_fit_args_list:
#     591     fold_fitting_strategy.schedule_fold_model_fit(**fold_fit_args)
# --> 592 fold_fitting_strategy.after_all_folds_scheduled()
#     594 for model in models:
#     595     # No need to add child times or save child here as this already occurred in the fold_fitting_strategy
#     596     self.add_child(model=model, add_child_times=False)
#
# File ~/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py:538, in ParallelFoldFittingStrategy.after_all_folds_scheduled(self)
#     536 unfinished = job_refs
#     537 while unfinished:
# --> 538     finished, unfinished = self.ray.wait(unfinished, num_returns=1)
#     539     finished = finished[0]
#     540     try:
#
# File ~/anaconda3/envs/TDT4173/lib/python3.10/site-packages/ray/_private/auto_init_hook.py:24, in wrap_auto_init.<locals>.auto_init_wrapper(*args, **kwargs)
#      21 @wraps(fn)
#      22 def auto_init_wrapper(*args, **kwargs):
#      23     auto_init_ray()
# ---> 24     return fn(*args, **kwargs)
#
# File ~/anaconda3/envs/TDT4173/lib/python3.10/site-packages/ray/_private/client_mode_hook.py:103, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     101     if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     102         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 103 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/TDT4173/lib/python3.10/site-packages/ray/_private/worker.py:2732, in wait(object_refs, num_returns, timeout, fetch_local)
#    2730 timeout = timeout if timeout is not None else 10**6
#    2731 timeout_milliseconds = int(timeout * 1000)
# -> 2732 ready_ids, remaining_ids = worker.core_worker.wait(
#    2733     object_refs,
#    2734     num_returns,
#    2735     timeout_milliseconds,
#    2736     worker.current_task_id,
#    2737     fetch_local,
#    2738 )
#    2739 return ready_ids, remaining_ids
#
# File python/ray/_raylet.pyx:3012, in ray._raylet.CoreWorker.wait()
#
# File python/ray/_raylet.pyx:400, in ray._raylet.check_status()
#
# KeyboardInterrupt:

# %%
predictor3 = TabularPredictor(label="pv_measurement", 
                              eval_metric='mean_absolute_error',
                              path= DEFAULT_PATH+"C"
                              ).fit(
    train3,
    time_limit=3600,
    presets='experimental_zeroshot_hpo_hybrid', 
    # hyperparameters='very_large', 
    # tuning_data = tuning3,
    # use_bag_holdout=True,
    # num_bag_folds= 6,
    # refit_full = True,
    # auto_stack = True,
    # num_bag_sets= 10,
    # set_best_to_refit_full= True,
    # num_stack_levels = 2,
    # verbosity = 3
    )
# Out:
# Presets specified: ['best_quality']
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/core/utils/utils.py:564: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Beginning AutoGluon training ...
# AutoGluon will save models to "ag_148_lag_featuresC"
# AutoGluon Version:  0.8.2
# Python Version:     3.10.12
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 23.0.0: Fri Sep 15 14:41:43 PDT 2023; root:xnu-10002.1.13~1/RELEASE_ARM64_T6000
# Disk Space Avail:   24.24 GB / 494.38 GB (4.9%)
# Train Data Rows:    26095
# Train Data Columns: 53
# Label Column: pv_measurement
# Preprocessing data ...
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/core/utils/utils.py:564: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and label-values can't be converted to int).
# 	Label info (max, min, mean, stddev): (999.6, 0.0, 77.63106, 165.81688)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/learner/default_learner.py:215: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    6583.16 MB
# 	Train Data (Original)  Memory Usage: 5.95 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 3 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Unused Original Features (Count: 1): ['snow_drift:idx']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('float', []) : 1 | ['snow_drift:idx']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 52 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 50 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 		('int', ['bool']) :  2 | ['elevation:m', 'snow_density:kgm3']
# 	0.4s = Fit runtime
# 	52 features in original data used to generate 52 features in processed data.
# 	Train Data (Processed) Memory Usage: 5.69 MB (0.1% of available memory)
# Data preprocessing and feature engineering runtime = 0.45s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ...
# 	-27.1293	 = Validation score   (-mean_absolute_error)
# 	0.02s	 = Training   runtime
# 	0.78s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ...
# 	-27.0609	 = Validation score   (-mean_absolute_error)
# 	0.02s	 = Training   runtime
# 	0.86s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-16.647	 = Validation score   (-mean_absolute_error)
# 	81.37s	 = Training   runtime
# 	78.61s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-17.6608	 = Validation score   (-mean_absolute_error)
# 	66.48s	 = Training   runtime
# 	108.63s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ...
# 	-19.8841	 = Validation score   (-mean_absolute_error)
# 	42.13s	 = Training   runtime
# 	0.65s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-18.328	 = Validation score   (-mean_absolute_error)
# 	425.41s	 = Training   runtime
# 	0.37s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ...
# 	-19.8047	 = Validation score   (-mean_absolute_error)
# 	6.14s	 = Training   runtime
# 	0.73s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-20.2594	 = Validation score   (-mean_absolute_error)
# 	34.92s	 = Training   runtime
# 	0.55s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-18.6375	 = Validation score   (-mean_absolute_error)
# 	276.84s	 = Training   runtime
# 	46.84s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-18.6601	 = Validation score   (-mean_absolute_error)
# 	79.21s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-17.3535	 = Validation score   (-mean_absolute_error)
# 	164.87s	 = Training   runtime
# 	189.94s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-16.3525	 = Validation score   (-mean_absolute_error)
# 	0.33s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 9 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-16.8402	 = Validation score   (-mean_absolute_error)
# 	4.27s	 = Training   runtime
# 	0.64s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-16.6548	 = Validation score   (-mean_absolute_error)
# 	3.69s	 = Training   runtime
# 	0.29s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ...
# 	-16.3037	 = Validation score   (-mean_absolute_error)
# 	42.26s	 = Training   runtime
# 	0.74s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-16.7495	 = Validation score   (-mean_absolute_error)
# 	22.78s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ...
# 	-16.216	 = Validation score   (-mean_absolute_error)
# 	6.1s	 = Training   runtime
# 	0.7s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-16.3901	 = Validation score   (-mean_absolute_error)
# 	32.67s	 = Training   runtime
# 	0.47s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-16.524	 = Validation score   (-mean_absolute_error)
# 	7.91s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-16.5278	 = Validation score   (-mean_absolute_error)
# 	49.26s	 = Training   runtime
# 	0.4s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-16.6196	 = Validation score   (-mean_absolute_error)
# 	11.44s	 = Training   runtime
# 	0.91s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ...
# 	-15.9746	 = Validation score   (-mean_absolute_error)
# 	0.32s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 1455.29s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("ag_148_lag_featuresC")

# %%
test1 = pipin.get_test_data("A")
test2 = pipin.get_test_data("B")
test3 = pipin.get_test_data("C")

# %%
test_data1 = TabularDataset(test1)
test_data2 = TabularDataset(test2)
test_data3 = TabularDataset(test3)

pred1 = pd.DataFrame(predictor1.predict(test_data1))
pred2 = pd.DataFrame(predictor2.predict(test_data2))
pred3 = pd.DataFrame(predictor3.predict(test_data3))

negatives_pred1 = pred1[pred1["pv_measurement"] < 0]
negatives_pred2 = pred2[pred2["pv_measurement"] < 0]
negatives_pred3 = pred3[pred3["pv_measurement"] < 0]
neg = pd.concat([negatives_pred1, negatives_pred2, negatives_pred3])
neg.shape
# Out:
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# (119, 1)

# %%
pred = pd.concat([pred1, pred2, pred3])
final_prediction = pipin.post_processing(pred, prediction_column="pv_measurement")
final_prediction.to_csv('submissions/gluon_145_lag_features.csv')

# %%
diff = pipin.compare_mae(final_prediction)
diff
# Out:
# 60.79858378164785

# %%
# predictor.evaluate(df1, silent=True)
