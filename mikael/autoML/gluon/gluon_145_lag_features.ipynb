# %%
# %load_ext autoreload

# %%
from autogluon.tabular import TabularDataset, TabularPredictor
import pandas as pd
import numpy as np

# %%
# %autoreload
from pipeline_lag_features import Pipeline
pipin = Pipeline()
# Out:
# Current working directory: /Users/miksx/GitHub/Forest-Gump/mikael/autoML/gluon

# %%
DEFAULT_PATH = f"ag_145_lag_features"

# %%
df1_0 = pipin.get_data("A")
df2_0 = pipin.get_data("B")
df3_0 = pipin.get_data("C")

# %%
# remove_consecutive_measurments
df1_0 = pipin.remove_consecutive_measurments(df1_0, 400, 25)
df2_0 = pipin.remove_consecutive_measurments(df2_0, 400, 25)
df3_0 = pipin.remove_consecutive_measurments(df3_0, 400, 25)

# %%
df1_0.head()
# Out:
#    absolute_humidity_2m:gm3  air_density_2m:kgm3  ceiling_height_agl:m  \
# 0                     7.700              1.22825           1728.949951
# 1                     7.700              1.22350           1689.824951
# 2                     7.875              1.21975           1563.224976
# 3                     8.425              1.21800           1283.425049
# 4                     8.950              1.21800           1003.500000
#
#    clear_sky_energy_1h:J  clear_sky_rad:W  cloud_base_agl:m  dew_or_rime:idx  \
# 0               0.000000             0.00       1728.949951              0.0
# 1               0.000000             0.00       1689.824951              0.0
# 2               0.000000             0.00       1563.224976              0.0
# 3             208.649994             0.75       1283.425049              0.0
# 4           32468.150391            23.10       1003.500000              0.0
#
#    dew_point_2m:K  diffuse_rad:W  diffuse_rad_1h:J  ...  \
# 0      280.299988          0.000          0.000000  ...
# 1      280.299988          0.000          0.000000  ...
# 2      280.649994          0.000          0.000000  ...
# 3      281.674988          0.300        526.775024  ...
# 4      282.500000         11.975      22068.949219  ...
#
#    wind_speed_w_1000hPa:ms  estimated  observed  day_of_year  hour  \
# 0                      0.0        0.0       1.0        153.0  22.0
# 1                      0.0        0.0       1.0        153.0  23.0
# 2                      0.0        0.0       1.0        154.0   0.0
# 3                      0.0        0.0       1.0        154.0   1.0
# 4                      0.0        0.0       1.0        154.0   2.0
#
#    clear_sky_energy_1h:J_lag_2  diffuse_rad_1h:J_lag_2  direct_rad_1h:J_lag_2  \
# 0                          NaN                     NaN                    NaN
# 1                          NaN                     NaN                    NaN
# 2                          0.0                     0.0                    0.0
# 3                          0.0                     0.0                    0.0
# 4                          0.0                     0.0                    0.0
#
#    fresh_snow_1h:cm_lag_2  pv_measurement
# 0                     NaN            0.00
# 1                     NaN            0.00
# 2                     0.0            0.00
# 3                     0.0            0.00
# 4                     0.0           19.36
#
# [5 rows x 54 columns]

# %%
train1 = TabularDataset(df1_0)
train2 = TabularDataset(df2_0)
train3 = TabularDataset(df3_0)

# %%
predictor1 = TabularPredictor(label="pv_measurement",
                              eval_metric='mean_absolute_error',
                              path= DEFAULT_PATH+"A"
                              ).fit(
    train1,
    time_limit=3600,
    # hyperparameters='extrme', 
    presets='experimental_zeroshot_hpo_hybrid', 
    # tuning_data = tuning1,
    # use_bag_holdout=True,
    # num_bag_folds= 6,
    # refit_full = True,
    # auto_stack = True,
    # num_bag_sets= 10,
    # set_best_to_refit_full= True,
    # num_stack_levels = 2,
    # verbosity = 3
    )
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="ag_145_lag_featuresA"
# Presets specified: ['experimental_zeroshot_hpo_hybrid']
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/core/utils/utils.py:564: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=20
# Beginning AutoGluon training ... Time limit = 3600s
# AutoGluon will save models to "ag_145_lag_featuresA"
# AutoGluon Version:  0.8.2
# Python Version:     3.10.12
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 23.0.0: Fri Sep 15 14:41:43 PDT 2023; root:xnu-10002.1.13~1/RELEASE_ARM64_T6000
# Disk Space Avail:   212.85 GB / 494.38 GB (43.1%)
# Train Data Rows:    34043
# Train Data Columns: 53
# Label Column: pv_measurement
# Preprocessing data ...
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/core/utils/utils.py:564: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (5733.42, 0.0, 631.37269, 1166.41088)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/learner/default_learner.py:215: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    5186.78 MB
# 	Train Data (Original)  Memory Usage: 7.76 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 3 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Unused Original Features (Count: 1): ['snow_drift:idx']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('float', []) : 1 | ['snow_drift:idx']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 52 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 50 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 		('int', ['bool']) :  2 | ['elevation:m', 'snow_density:kgm3']
# 	1.0s = Fit runtime
# 	52 features in original data used to generate 52 features in processed data.
# 	Train Data (Processed) Memory Usage: 7.42 MB (0.1% of available memory)
# Data preprocessing and feature engineering runtime = 1.08s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}, {'min_samples_leaf': 1, 'max_leaf_nodes': 15000, 'max_features': 0.5, 'ag_args': {'name_suffix': '_r19', 'priority': 20}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}, {'min_samples_leaf': 5, 'max_leaf_nodes': 50000, 'max_features': 0.5, 'ag_args': {'name_suffix': '_r5', 'priority': 19}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge', {'extra_trees': False, 'feature_fraction': 0.7248284762542815, 'learning_rate': 0.07947286942946127, 'min_data_in_leaf': 50, 'num_leaves': 89, 'ag_args': {'name_suffix': '_r158', 'priority': 18}}, {'extra_trees': True, 'feature_fraction': 0.7832570544199176, 'learning_rate': 0.021720607471727896, 'min_data_in_leaf': 3, 'num_leaves': 21, 'ag_args': {'name_suffix': '_r118', 'priority': 17}}, {'extra_trees': True, 'feature_fraction': 0.7113010892989156, 'learning_rate': 0.012535427424259274, 'min_data_in_leaf': 16, 'num_leaves': 48, 'ag_args': {'name_suffix': '_r97', 'priority': 16}}, {'extra_trees': True, 'feature_fraction': 0.45555769907110816, 'learning_rate': 0.009591347321206594, 'min_data_in_leaf': 50, 'num_leaves': 110, 'ag_args': {'name_suffix': '_r71', 'priority': 15}}, {'extra_trees': False, 'feature_fraction': 0.40979710161022476, 'learning_rate': 0.008708890211023034, 'min_data_in_leaf': 3, 'num_leaves': 80, 'ag_args': {'name_suffix': '_r111', 'priority': 14}}],
# 	'XGB': {},
# 	'FASTAI': [{}, {'bs': 1024, 'emb_drop': 0.6167722379778131, 'epochs': 44, 'layers': [200, 100, 50], 'lr': 0.053440377855629266, 'ps': 0.48477211305443607, 'ag_args': {'name_suffix': '_r25', 'priority': 13}}, {'bs': 1024, 'emb_drop': 0.6046989241462619, 'epochs': 48, 'layers': [200, 100, 50], 'lr': 0.00775309042164966, 'ps': 0.09244767444160731, 'ag_args': {'name_suffix': '_r51', 'priority': 12}}, {'bs': 512, 'emb_drop': 0.6557225316526186, 'epochs': 49, 'layers': [200, 100], 'lr': 0.023627682025564638, 'ps': 0.519566584552178, 'ag_args': {'name_suffix': '_r82', 'priority': 11}}, {'bs': 2048, 'emb_drop': 0.4066210919034579, 'epochs': 43, 'layers': [400, 200], 'lr': 0.0029598312717673434, 'ps': 0.4378695797438974, 'ag_args': {'name_suffix': '_r121', 'priority': 10}}, {'bs': 128, 'emb_drop': 0.44339037504795686, 'epochs': 31, 'layers': [400, 200, 100], 'lr': 0.008615195908919904, 'ps': 0.19220253419114286, 'ag_args': {'name_suffix': '_r145', 'priority': 9}}, {'bs': 128, 'emb_drop': 0.12106594798980945, 'epochs': 38, 'layers': [200, 100, 50], 'lr': 0.037991970245029975, 'ps': 0.33120008492595093, 'ag_args': {'name_suffix': '_r173', 'priority': 8}}, {'bs': 128, 'emb_drop': 0.4599138419358, 'epochs': 47, 'layers': [200, 100], 'lr': 0.03888383281136287, 'ps': 0.28193673177122863, 'ag_args': {'name_suffix': '_r128', 'priority': 7}}],
# 	'CAT': [{}, {'depth': 5, 'l2_leaf_reg': 4.774992314058497, 'learning_rate': 0.038551267822920274, 'ag_args': {'name_suffix': '_r16', 'priority': 6}}, {'depth': 4, 'l2_leaf_reg': 1.9950125740798321, 'learning_rate': 0.028091050379971633, 'ag_args': {'name_suffix': '_r42', 'priority': 5}}, {'depth': 6, 'l2_leaf_reg': 1.8298803017644376, 'learning_rate': 0.017844259810823604, 'ag_args': {'name_suffix': '_r93', 'priority': 4}}, {'depth': 7, 'l2_leaf_reg': 4.81099604606794, 'learning_rate': 0.019085060180573103, 'ag_args': {'name_suffix': '_r44', 'priority': 3}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 29 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 2398.68s of the 3598.91s of remaining time.
# 	-226.5165	 = Validation score   (-mean_absolute_error)
# 	0.13s	 = Training   runtime
# 	2.21s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 2394.07s of the 3594.3s of remaining time.
# 	-226.1671	 = Validation score   (-mean_absolute_error)
# 	0.09s	 = Training   runtime
# 	2.1s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 2391.6s of the 3591.84s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-154.3646	 = Validation score   (-mean_absolute_error)
# 	102.87s	 = Training   runtime
# 	87.02s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 2264.97s of the 3465.21s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-163.0697	 = Validation score   (-mean_absolute_error)
# 	259.17s	 = Training   runtime
# 	474.32s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 1963.84s of the 3164.08s of remaining time.
# 	-181.4603	 = Validation score   (-mean_absolute_error)
# 	135.87s	 = Training   runtime
# 	1.93s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 1825.54s of the 3025.77s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-168.5311	 = Validation score   (-mean_absolute_error)
# 	508.93s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 1314.07s of the 2514.31s of remaining time.
# 	-181.8351	 = Validation score   (-mean_absolute_error)
# 	8.54s	 = Training   runtime
# 	1.2s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 1303.88s of the 2504.12s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-186.1663	 = Validation score   (-mean_absolute_error)
# 	43.6s	 = Training   runtime
# 	0.83s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 1257.78s of the 2458.01s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-173.2338	 = Validation score   (-mean_absolute_error)
# 	315.48s	 = Training   runtime
# 	6.03s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 932.19s of the 2132.43s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-171.6396	 = Validation score   (-mean_absolute_error)
# 	113.94s	 = Training   runtime
# 	0.4s	 = Validation runtime
# Fitting model: ExtraTrees_r19_BAG_L1 ... Training model for up to 816.2s of the 2016.44s of remaining time.
# 	-182.2637	 = Validation score   (-mean_absolute_error)
# 	3.35s	 = Training   runtime
# 	1.02s	 = Validation runtime
# Fitting model: RandomForest_r5_BAG_L1 ... Training model for up to 811.48s of the 2011.71s of remaining time.
# 	-183.1315	 = Validation score   (-mean_absolute_error)
# 	15.9s	 = Training   runtime
# 	0.91s	 = Validation runtime
# Fitting model: LightGBM_r158_BAG_L1 ... Training model for up to 794.49s of the 1994.73s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-165.4872	 = Validation score   (-mean_absolute_error)
# 	132.44s	 = Training   runtime
# 	1834.98s	 = Validation runtime
# Fitting model: LightGBM_r118_BAG_L1 ... Training model for up to 219.49s of the 1419.73s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-157.3193	 = Validation score   (-mean_absolute_error)
# 	104.69s	 = Training   runtime
# 	48.08s	 = Validation runtime
# Fitting model: LightGBM_r97_BAG_L1 ... Training model for up to 109.32s of the 1309.56s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-159.0783	 = Validation score   (-mean_absolute_error)
# 	629.82s	 = Training   runtime
# 	85.18s	 = Validation runtime
# Completed 1/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 664.93s of remaining time.
# 	-151.9514	 = Validation score   (-mean_absolute_error)
# 	0.66s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 27 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 664.25s of the 664.2s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-153.8442	 = Validation score   (-mean_absolute_error)
# 	5.21s	 = Training   runtime
# 	0.68s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 657.03s of the 656.99s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-151.1129	 = Validation score   (-mean_absolute_error)
# 	3.01s	 = Training   runtime
# 	0.22s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ... Training model for up to 652.03s of the 651.99s of remaining time.
# 	-150.4886	 = Validation score   (-mean_absolute_error)
# 	1542.35s	 = Training   runtime
# 	1.32s	 = Validation runtime
# Completed 1/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the -892.3s of remaining time.
# 	-149.7507	 = Validation score   (-mean_absolute_error)
# 	0.25s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 4492.59s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("ag_145_lag_featuresA")

# %%
predictor2 = TabularPredictor(label="pv_measurement", 
                              eval_metric='mean_absolute_error',
                              path= DEFAULT_PATH+"B"
                              ).fit(
    train2,
    time_limit=3600,
    presets='experimental_zeroshot_hpo_hybrid', 
    # hyperparameters='very_large', 
    # tuning_data = tuning2,
    # use_bag_holdout=True,
    # num_bag_folds= 6,
    # refit_full = True,
    # auto_stack = True,
    # num_bag_sets= 10,
    # set_best_to_refit_full= True,
    # num_stack_levels = 2,
    # verbosity = 3
    )

# tuning_data
# num bag holdout 6
# bag_holdout
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="ag_145_lag_featuresB"
# Presets specified: ['experimental_zeroshot_hpo_hybrid']
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/core/utils/utils.py:564: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=20
# Beginning AutoGluon training ... Time limit = 3600s
# AutoGluon will save models to "ag_145_lag_featuresB"
# AutoGluon Version:  0.8.2
# Python Version:     3.10.12
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 23.0.0: Fri Sep 15 14:41:43 PDT 2023; root:xnu-10002.1.13~1/RELEASE_ARM64_T6000
# Disk Space Avail:   212.25 GB / 494.38 GB (42.9%)
# Train Data Rows:    27618
# Train Data Columns: 53
# Label Column: pv_measurement
# Preprocessing data ...
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/core/utils/utils.py:564: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (1152.3, 0.0, 107.66861, 207.32975)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/learner/default_learner.py:215: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    5180.82 MB
# 	Train Data (Original)  Memory Usage: 6.3 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 2 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 53 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 51 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 		('int', ['bool']) :  2 | ['elevation:m', 'snow_density:kgm3']
# 	0.2s = Fit runtime
# 	53 features in original data used to generate 53 features in processed data.
# 	Train Data (Processed) Memory Usage: 6.13 MB (0.1% of available memory)
# Data preprocessing and feature engineering runtime = 0.24s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}, {'min_samples_leaf': 1, 'max_leaf_nodes': 15000, 'max_features': 0.5, 'ag_args': {'name_suffix': '_r19', 'priority': 20}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}, {'min_samples_leaf': 5, 'max_leaf_nodes': 50000, 'max_features': 0.5, 'ag_args': {'name_suffix': '_r5', 'priority': 19}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge', {'extra_trees': False, 'feature_fraction': 0.7248284762542815, 'learning_rate': 0.07947286942946127, 'min_data_in_leaf': 50, 'num_leaves': 89, 'ag_args': {'name_suffix': '_r158', 'priority': 18}}, {'extra_trees': True, 'feature_fraction': 0.7832570544199176, 'learning_rate': 0.021720607471727896, 'min_data_in_leaf': 3, 'num_leaves': 21, 'ag_args': {'name_suffix': '_r118', 'priority': 17}}, {'extra_trees': True, 'feature_fraction': 0.7113010892989156, 'learning_rate': 0.012535427424259274, 'min_data_in_leaf': 16, 'num_leaves': 48, 'ag_args': {'name_suffix': '_r97', 'priority': 16}}, {'extra_trees': True, 'feature_fraction': 0.45555769907110816, 'learning_rate': 0.009591347321206594, 'min_data_in_leaf': 50, 'num_leaves': 110, 'ag_args': {'name_suffix': '_r71', 'priority': 15}}, {'extra_trees': False, 'feature_fraction': 0.40979710161022476, 'learning_rate': 0.008708890211023034, 'min_data_in_leaf': 3, 'num_leaves': 80, 'ag_args': {'name_suffix': '_r111', 'priority': 14}}],
# 	'XGB': {},
# 	'FASTAI': [{}, {'bs': 1024, 'emb_drop': 0.6167722379778131, 'epochs': 44, 'layers': [200, 100, 50], 'lr': 0.053440377855629266, 'ps': 0.48477211305443607, 'ag_args': {'name_suffix': '_r25', 'priority': 13}}, {'bs': 1024, 'emb_drop': 0.6046989241462619, 'epochs': 48, 'layers': [200, 100, 50], 'lr': 0.00775309042164966, 'ps': 0.09244767444160731, 'ag_args': {'name_suffix': '_r51', 'priority': 12}}, {'bs': 512, 'emb_drop': 0.6557225316526186, 'epochs': 49, 'layers': [200, 100], 'lr': 0.023627682025564638, 'ps': 0.519566584552178, 'ag_args': {'name_suffix': '_r82', 'priority': 11}}, {'bs': 2048, 'emb_drop': 0.4066210919034579, 'epochs': 43, 'layers': [400, 200], 'lr': 0.0029598312717673434, 'ps': 0.4378695797438974, 'ag_args': {'name_suffix': '_r121', 'priority': 10}}, {'bs': 128, 'emb_drop': 0.44339037504795686, 'epochs': 31, 'layers': [400, 200, 100], 'lr': 0.008615195908919904, 'ps': 0.19220253419114286, 'ag_args': {'name_suffix': '_r145', 'priority': 9}}, {'bs': 128, 'emb_drop': 0.12106594798980945, 'epochs': 38, 'layers': [200, 100, 50], 'lr': 0.037991970245029975, 'ps': 0.33120008492595093, 'ag_args': {'name_suffix': '_r173', 'priority': 8}}, {'bs': 128, 'emb_drop': 0.4599138419358, 'epochs': 47, 'layers': [200, 100], 'lr': 0.03888383281136287, 'ps': 0.28193673177122863, 'ag_args': {'name_suffix': '_r128', 'priority': 7}}],
# 	'CAT': [{}, {'depth': 5, 'l2_leaf_reg': 4.774992314058497, 'learning_rate': 0.038551267822920274, 'ag_args': {'name_suffix': '_r16', 'priority': 6}}, {'depth': 4, 'l2_leaf_reg': 1.9950125740798321, 'learning_rate': 0.028091050379971633, 'ag_args': {'name_suffix': '_r42', 'priority': 5}}, {'depth': 6, 'l2_leaf_reg': 1.8298803017644376, 'learning_rate': 0.017844259810823604, 'ag_args': {'name_suffix': '_r93', 'priority': 4}}, {'depth': 7, 'l2_leaf_reg': 4.81099604606794, 'learning_rate': 0.019085060180573103, 'ag_args': {'name_suffix': '_r44', 'priority': 3}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 29 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 2399.23s of the 3599.75s of remaining time.
# 	-41.4881	 = Validation score   (-mean_absolute_error)
# 	0.03s	 = Training   runtime
# 	0.83s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 2398.14s of the 3598.66s of remaining time.
# 	-41.3174	 = Validation score   (-mean_absolute_error)
# 	0.03s	 = Training   runtime
# 	0.79s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 2397.05s of the 3597.56s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-26.3859	 = Validation score   (-mean_absolute_error)
# 	33.96s	 = Training   runtime
# 	69.78s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 2350.11s of the 3550.62s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-26.6462	 = Validation score   (-mean_absolute_error)
# 	52.8s	 = Training   runtime
# 	84.53s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 2282.53s of the 3483.04s of remaining time.
# 	-30.7176	 = Validation score   (-mean_absolute_error)
# 	42.79s	 = Training   runtime
# 	0.79s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 2238.59s of the 3439.11s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-27.724	 = Validation score   (-mean_absolute_error)
# 	333.68s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 1902.94s of the 3103.45s of remaining time.
# 	-31.4395	 = Validation score   (-mean_absolute_error)
# 	5.87s	 = Training   runtime
# 	0.77s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 1895.87s of the 3096.38s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-33.826	 = Validation score   (-mean_absolute_error)
# 	27.23s	 = Training   runtime
# 	0.51s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 1866.62s of the 3067.13s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-29.1425	 = Validation score   (-mean_absolute_error)
# 	253.23s	 = Training   runtime
# 	83.58s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 1601.85s of the 2802.36s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-29.9832	 = Validation score   (-mean_absolute_error)
# 	92.65s	 = Training   runtime
# 	0.22s	 = Validation runtime
# Fitting model: ExtraTrees_r19_BAG_L1 ... Training model for up to 1507.47s of the 2707.98s of remaining time.
# 	-31.9485	 = Validation score   (-mean_absolute_error)
# 	1.95s	 = Training   runtime
# 	0.63s	 = Validation runtime
# Fitting model: RandomForest_r5_BAG_L1 ... Training model for up to 1504.63s of the 2705.15s of remaining time.
# 	-31.7489	 = Validation score   (-mean_absolute_error)
# 	12.77s	 = Training   runtime
# 	0.62s	 = Validation runtime
# Fitting model: LightGBM_r158_BAG_L1 ... Training model for up to 1491.05s of the 2691.57s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-27.8783	 = Validation score   (-mean_absolute_error)
# 	114.81s	 = Training   runtime
# 	221.9s	 = Validation runtime
# Fitting model: LightGBM_r118_BAG_L1 ... Training model for up to 1337.48s of the 2537.99s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-27.3778	 = Validation score   (-mean_absolute_error)
# 	27.04s	 = Training   runtime
# 	34.53s	 = Validation runtime
# Fitting model: LightGBM_r97_BAG_L1 ... Training model for up to 1303.2s of the 2503.71s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-27.192	 = Validation score   (-mean_absolute_error)
# 	48.42s	 = Training   runtime
# 	119.0s	 = Validation runtime
# Fitting model: LightGBM_r71_BAG_L1 ... Training model for up to 1234.45s of the 2434.96s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-28.9196	 = Validation score   (-mean_absolute_error)
# 	92.03s	 = Training   runtime
# 	269.04s	 = Validation runtime
# Fitting model: LightGBM_r111_BAG_L1 ... Training model for up to 1101.07s of the 2301.58s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-25.5879	 = Validation score   (-mean_absolute_error)
# 	82.21s	 = Training   runtime
# 	178.14s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r25_BAG_L1 ... Training model for up to 989.85s of the 2190.36s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-34.8256	 = Validation score   (-mean_absolute_error)
# 	24.28s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r51_BAG_L1 ... Training model for up to 963.75s of the 2164.27s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-31.0032	 = Validation score   (-mean_absolute_error)
# 	26.11s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r82_BAG_L1 ... Training model for up to 935.67s of the 2136.19s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-35.6702	 = Validation score   (-mean_absolute_error)
# 	30.4s	 = Training   runtime
# 	0.29s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r121_BAG_L1 ... Training model for up to 903.26s of the 2103.78s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-36.9632	 = Validation score   (-mean_absolute_error)
# 	38.1s	 = Training   runtime
# 	0.48s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r145_BAG_L1 ... Training model for up to 863.17s of the 2063.68s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-34.5767	 = Validation score   (-mean_absolute_error)
# 	70.45s	 = Training   runtime
# 	0.73s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r173_BAG_L1 ... Training model for up to 790.4s of the 1990.91s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-38.301	 = Validation score   (-mean_absolute_error)
# 	52.27s	 = Training   runtime
# 	0.5s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r128_BAG_L1 ... Training model for up to 735.98s of the 1936.5s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-38.3413	 = Validation score   (-mean_absolute_error)
# 	47.85s	 = Training   runtime
# 	0.41s	 = Validation runtime
# Fitting model: CatBoost_r16_BAG_L1 ... Training model for up to 686.04s of the 1886.56s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-29.5975	 = Validation score   (-mean_absolute_error)
# 	261.56s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting model: CatBoost_r42_BAG_L1 ... Training model for up to 423.11s of the 1623.62s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-31.5392	 = Validation score   (-mean_absolute_error)
# 	225.09s	 = Training   runtime
# 	0.32s	 = Validation runtime
# Fitting model: CatBoost_r93_BAG_L1 ... Training model for up to 196.24s of the 1396.76s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-29.7781	 = Validation score   (-mean_absolute_error)
# 	157.91s	 = Training   runtime
# 	0.24s	 = Validation runtime
# Fitting model: CatBoost_r44_BAG_L1 ... Training model for up to 36.42s of the 1236.93s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-33.3142	 = Validation score   (-mean_absolute_error)
# 	29.75s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 4.87s of the 1205.39s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-27.7296	 = Validation score   (-mean_absolute_error)
# 	4.75s	 = Training   runtime
# 	0.76s	 = Validation runtime
# Completed 1/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 1198.86s of remaining time.
# 	-25.2444	 = Validation score   (-mean_absolute_error)
# 	0.51s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 27 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 1198.34s of the 1198.31s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-24.0062	 = Validation score   (-mean_absolute_error)
# 	3.52s	 = Training   runtime
# 	0.54s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 1193.7s of the 1193.67s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-23.4816	 = Validation score   (-mean_absolute_error)
# 	2.68s	 = Training   runtime
# 	0.24s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ... Training model for up to 1189.96s of the 1189.93s of remaining time.
# 	-22.6494	 = Validation score   (-mean_absolute_error)
# 	49.53s	 = Training   runtime
# 	0.67s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 1139.51s of the 1139.48s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-23.6797	 = Validation score   (-mean_absolute_error)
# 	27.35s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ... Training model for up to 1111.16s of the 1111.13s of remaining time.
# 	-22.612	 = Validation score   (-mean_absolute_error)
# 	5.16s	 = Training   runtime
# 	0.72s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 1105.04s of the 1105.0s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.7591	 = Validation score   (-mean_absolute_error)
# 	15.1s	 = Training   runtime
# 	0.27s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 1088.84s of the 1088.81s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-23.0648	 = Validation score   (-mean_absolute_error)
# 	5.1s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 1082.33s of the 1082.3s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-23.4785	 = Validation score   (-mean_absolute_error)
# 	30.97s	 = Training   runtime
# 	0.33s	 = Validation runtime
# Fitting model: ExtraTrees_r19_BAG_L2 ... Training model for up to 1050.38s of the 1050.35s of remaining time.
# 	-22.6742	 = Validation score   (-mean_absolute_error)
# 	2.88s	 = Training   runtime
# 	0.7s	 = Validation runtime
# Fitting model: RandomForest_r5_BAG_L2 ... Training model for up to 1046.53s of the 1046.5s of remaining time.
# 	-22.455	 = Validation score   (-mean_absolute_error)
# 	20.65s	 = Training   runtime
# 	0.58s	 = Validation runtime
# Fitting model: LightGBM_r158_BAG_L2 ... Training model for up to 1025.19s of the 1025.16s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-23.5343	 = Validation score   (-mean_absolute_error)
# 	3.08s	 = Training   runtime
# 	0.32s	 = Validation runtime
# Fitting model: LightGBM_r118_BAG_L2 ... Training model for up to 1021.0s of the 1020.96s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-23.4945	 = Validation score   (-mean_absolute_error)
# 	20.26s	 = Training   runtime
# 	10.22s	 = Validation runtime
# Fitting model: LightGBM_r97_BAG_L2 ... Training model for up to 996.62s of the 996.59s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-23.7187	 = Validation score   (-mean_absolute_error)
# 	30.96s	 = Training   runtime
# 	27.32s	 = Validation runtime
# Fitting model: LightGBM_r71_BAG_L2 ... Training model for up to 957.26s of the 957.23s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-23.9336	 = Validation score   (-mean_absolute_error)
# 	37.53s	 = Training   runtime
# 	14.98s	 = Validation runtime
# Fitting model: LightGBM_r111_BAG_L2 ... Training model for up to 914.06s of the 914.03s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.9009	 = Validation score   (-mean_absolute_error)
# 	69.14s	 = Training   runtime
# 	35.37s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r25_BAG_L2 ... Training model for up to 832.67s of the 832.64s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-23.8005	 = Validation score   (-mean_absolute_error)
# 	13.33s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r51_BAG_L2 ... Training model for up to 817.99s of the 817.96s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.7622	 = Validation score   (-mean_absolute_error)
# 	14.54s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r82_BAG_L2 ... Training model for up to 801.8s of the 801.76s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-23.4422	 = Validation score   (-mean_absolute_error)
# 	16.64s	 = Training   runtime
# 	0.19s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r121_BAG_L2 ... Training model for up to 783.62s of the 783.59s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-24.8877	 = Validation score   (-mean_absolute_error)
# 	20.32s	 = Training   runtime
# 	0.29s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r145_BAG_L2 ... Training model for up to 761.79s of the 761.75s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-23.3592	 = Validation score   (-mean_absolute_error)
# 	35.18s	 = Training   runtime
# 	0.45s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r173_BAG_L2 ... Training model for up to 724.92s of the 724.89s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-25.1697	 = Validation score   (-mean_absolute_error)
# 	28.7s	 = Training   runtime
# 	0.32s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r128_BAG_L2 ... Training model for up to 694.7s of the 694.66s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-26.6278	 = Validation score   (-mean_absolute_error)
# 	29.79s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: CatBoost_r16_BAG_L2 ... Training model for up to 663.86s of the 663.82s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-23.5412	 = Validation score   (-mean_absolute_error)
# 	35.08s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: CatBoost_r42_BAG_L2 ... Training model for up to 627.78s of the 627.74s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-23.6676	 = Validation score   (-mean_absolute_error)
# 	32.17s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: CatBoost_r93_BAG_L2 ... Training model for up to 594.56s of the 594.53s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-23.4048	 = Validation score   (-mean_absolute_error)
# 	94.66s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: CatBoost_r44_BAG_L2 ... Training model for up to 498.59s of the 498.55s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-23.4409	 = Validation score   (-mean_absolute_error)
# 	212.09s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 284.83s of the 284.8s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-23.1398	 = Validation score   (-mean_absolute_error)
# 	33.16s	 = Training   runtime
# 	1.82s	 = Validation runtime
# Completed 1/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the 249.25s of remaining time.
# 	-22.081	 = Validation score   (-mean_absolute_error)
# 	0.48s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 3351.26s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("ag_145_lag_featuresB")

# %%
predictor3 = TabularPredictor(label="pv_measurement", 
                              eval_metric='mean_absolute_error',
                              path= DEFAULT_PATH+"C"
                              ).fit(
    train3,
    time_limit=3600,
    presets='experimental_zeroshot_hpo_hybrid', 
    # hyperparameters='very_large', 
    # tuning_data = tuning3,
    # use_bag_holdout=True,
    # num_bag_folds= 6,
    # refit_full = True,
    # auto_stack = True,
    # num_bag_sets= 10,
    # set_best_to_refit_full= True,
    # num_stack_levels = 2,
    # verbosity = 3
    )
# Out:
# Presets specified: ['experimental_zeroshot_hpo_hybrid']
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/core/utils/utils.py:564: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=20
# Beginning AutoGluon training ... Time limit = 3600s
# AutoGluon will save models to "ag_145_lag_featuresC"
# AutoGluon Version:  0.8.2
# Python Version:     3.10.12
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 23.0.0: Fri Sep 15 14:41:43 PDT 2023; root:xnu-10002.1.13~1/RELEASE_ARM64_T6000
# Disk Space Avail:   204.05 GB / 494.38 GB (41.3%)
# Train Data Rows:    21169
# Train Data Columns: 53
# Label Column: pv_measurement
# Preprocessing data ...
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/core/utils/utils.py:564: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and label-values can't be converted to int).
# 	Label info (max, min, mean, stddev): (999.6, 0.0, 95.69571, 179.34563)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/learner/default_learner.py:215: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    6937.39 MB
# 	Train Data (Original)  Memory Usage: 4.83 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 3 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Unused Original Features (Count: 1): ['snow_drift:idx']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('float', []) : 1 | ['snow_drift:idx']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 52 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 50 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 		('int', ['bool']) :  2 | ['elevation:m', 'snow_density:kgm3']
# 	0.2s = Fit runtime
# 	52 features in original data used to generate 52 features in processed data.
# 	Train Data (Processed) Memory Usage: 4.61 MB (0.1% of available memory)
# Data preprocessing and feature engineering runtime = 0.24s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}, {'min_samples_leaf': 1, 'max_leaf_nodes': 15000, 'max_features': 0.5, 'ag_args': {'name_suffix': '_r19', 'priority': 20}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}, {'min_samples_leaf': 5, 'max_leaf_nodes': 50000, 'max_features': 0.5, 'ag_args': {'name_suffix': '_r5', 'priority': 19}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge', {'extra_trees': False, 'feature_fraction': 0.7248284762542815, 'learning_rate': 0.07947286942946127, 'min_data_in_leaf': 50, 'num_leaves': 89, 'ag_args': {'name_suffix': '_r158', 'priority': 18}}, {'extra_trees': True, 'feature_fraction': 0.7832570544199176, 'learning_rate': 0.021720607471727896, 'min_data_in_leaf': 3, 'num_leaves': 21, 'ag_args': {'name_suffix': '_r118', 'priority': 17}}, {'extra_trees': True, 'feature_fraction': 0.7113010892989156, 'learning_rate': 0.012535427424259274, 'min_data_in_leaf': 16, 'num_leaves': 48, 'ag_args': {'name_suffix': '_r97', 'priority': 16}}, {'extra_trees': True, 'feature_fraction': 0.45555769907110816, 'learning_rate': 0.009591347321206594, 'min_data_in_leaf': 50, 'num_leaves': 110, 'ag_args': {'name_suffix': '_r71', 'priority': 15}}, {'extra_trees': False, 'feature_fraction': 0.40979710161022476, 'learning_rate': 0.008708890211023034, 'min_data_in_leaf': 3, 'num_leaves': 80, 'ag_args': {'name_suffix': '_r111', 'priority': 14}}],
# 	'XGB': {},
# 	'FASTAI': [{}, {'bs': 1024, 'emb_drop': 0.6167722379778131, 'epochs': 44, 'layers': [200, 100, 50], 'lr': 0.053440377855629266, 'ps': 0.48477211305443607, 'ag_args': {'name_suffix': '_r25', 'priority': 13}}, {'bs': 1024, 'emb_drop': 0.6046989241462619, 'epochs': 48, 'layers': [200, 100, 50], 'lr': 0.00775309042164966, 'ps': 0.09244767444160731, 'ag_args': {'name_suffix': '_r51', 'priority': 12}}, {'bs': 512, 'emb_drop': 0.6557225316526186, 'epochs': 49, 'layers': [200, 100], 'lr': 0.023627682025564638, 'ps': 0.519566584552178, 'ag_args': {'name_suffix': '_r82', 'priority': 11}}, {'bs': 2048, 'emb_drop': 0.4066210919034579, 'epochs': 43, 'layers': [400, 200], 'lr': 0.0029598312717673434, 'ps': 0.4378695797438974, 'ag_args': {'name_suffix': '_r121', 'priority': 10}}, {'bs': 128, 'emb_drop': 0.44339037504795686, 'epochs': 31, 'layers': [400, 200, 100], 'lr': 0.008615195908919904, 'ps': 0.19220253419114286, 'ag_args': {'name_suffix': '_r145', 'priority': 9}}, {'bs': 128, 'emb_drop': 0.12106594798980945, 'epochs': 38, 'layers': [200, 100, 50], 'lr': 0.037991970245029975, 'ps': 0.33120008492595093, 'ag_args': {'name_suffix': '_r173', 'priority': 8}}, {'bs': 128, 'emb_drop': 0.4599138419358, 'epochs': 47, 'layers': [200, 100], 'lr': 0.03888383281136287, 'ps': 0.28193673177122863, 'ag_args': {'name_suffix': '_r128', 'priority': 7}}],
# 	'CAT': [{}, {'depth': 5, 'l2_leaf_reg': 4.774992314058497, 'learning_rate': 0.038551267822920274, 'ag_args': {'name_suffix': '_r16', 'priority': 6}}, {'depth': 4, 'l2_leaf_reg': 1.9950125740798321, 'learning_rate': 0.028091050379971633, 'ag_args': {'name_suffix': '_r42', 'priority': 5}}, {'depth': 6, 'l2_leaf_reg': 1.8298803017644376, 'learning_rate': 0.017844259810823604, 'ag_args': {'name_suffix': '_r93', 'priority': 4}}, {'depth': 7, 'l2_leaf_reg': 4.81099604606794, 'learning_rate': 0.019085060180573103, 'ag_args': {'name_suffix': '_r44', 'priority': 3}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 29 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 2399.24s of the 3599.75s of remaining time.
# 	-30.4218	 = Validation score   (-mean_absolute_error)
# 	0.02s	 = Training   runtime
# 	0.29s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 2398.9s of the 3599.42s of remaining time.
# 	-30.3691	 = Validation score   (-mean_absolute_error)
# 	0.02s	 = Training   runtime
# 	0.27s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 2398.58s of the 3599.1s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.7509	 = Validation score   (-mean_absolute_error)
# 	19.49s	 = Training   runtime
# 	39.9s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 2372.33s of the 3572.84s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-20.9719	 = Validation score   (-mean_absolute_error)
# 	29.97s	 = Training   runtime
# 	43.49s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 2333.56s of the 3534.08s of remaining time.
# 	-23.7747	 = Validation score   (-mean_absolute_error)
# 	23.59s	 = Training   runtime
# 	0.55s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 2309.05s of the 3509.57s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.2247	 = Validation score   (-mean_absolute_error)
# 	273.5s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 2033.61s of the 3234.13s of remaining time.
# 	-23.5518	 = Validation score   (-mean_absolute_error)
# 	3.87s	 = Training   runtime
# 	0.57s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 2028.86s of the 3229.38s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-23.8395	 = Validation score   (-mean_absolute_error)
# 	23.06s	 = Training   runtime
# 	0.29s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 2003.81s of the 3204.32s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.9957	 = Validation score   (-mean_absolute_error)
# 	205.74s	 = Training   runtime
# 	24.91s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 1792.62s of the 2993.13s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.9979	 = Validation score   (-mean_absolute_error)
# 	60.49s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: ExtraTrees_r19_BAG_L1 ... Training model for up to 1730.16s of the 2930.67s of remaining time.
# 	-23.5107	 = Validation score   (-mean_absolute_error)
# 	2.06s	 = Training   runtime
# 	0.48s	 = Validation runtime
# Fitting model: RandomForest_r5_BAG_L1 ... Training model for up to 1727.41s of the 2927.93s of remaining time.
# 	-24.2045	 = Validation score   (-mean_absolute_error)
# 	8.95s	 = Training   runtime
# 	0.43s	 = Validation runtime
# Fitting model: LightGBM_r158_BAG_L1 ... Training model for up to 1717.95s of the 2918.46s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.4507	 = Validation score   (-mean_absolute_error)
# 	79.38s	 = Training   runtime
# 	78.13s	 = Validation runtime
# Fitting model: LightGBM_r118_BAG_L1 ... Training model for up to 1613.97s of the 2814.48s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.7252	 = Validation score   (-mean_absolute_error)
# 	23.16s	 = Training   runtime
# 	32.61s	 = Validation runtime
# Fitting model: LightGBM_r97_BAG_L1 ... Training model for up to 1583.82s of the 2784.33s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.5984	 = Validation score   (-mean_absolute_error)
# 	30.78s	 = Training   runtime
# 	71.73s	 = Validation runtime
# Fitting model: LightGBM_r71_BAG_L1 ... Training model for up to 1540.43s of the 2740.95s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-20.8868	 = Validation score   (-mean_absolute_error)
# 	77.04s	 = Training   runtime
# 	273.42s	 = Validation runtime
# Fitting model: LightGBM_r111_BAG_L1 ... Training model for up to 1420.45s of the 2620.97s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-20.2805	 = Validation score   (-mean_absolute_error)
# 	83.74s	 = Training   runtime
# 	155.78s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r25_BAG_L1 ... Training model for up to 1311.57s of the 2512.09s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-25.0883	 = Validation score   (-mean_absolute_error)
# 	18.48s	 = Training   runtime
# 	0.36s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r51_BAG_L1 ... Training model for up to 1291.03s of the 2491.54s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.347	 = Validation score   (-mean_absolute_error)
# 	20.89s	 = Training   runtime
# 	0.24s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r82_BAG_L1 ... Training model for up to 1268.1s of the 2468.62s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-24.6979	 = Validation score   (-mean_absolute_error)
# 	24.27s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r121_BAG_L1 ... Training model for up to 1241.67s of the 2442.19s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-25.8869	 = Validation score   (-mean_absolute_error)
# 	30.75s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r145_BAG_L1 ... Training model for up to 1208.87s of the 2409.39s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-24.2843	 = Validation score   (-mean_absolute_error)
# 	51.46s	 = Training   runtime
# 	0.69s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r173_BAG_L1 ... Training model for up to 1154.9s of the 2355.42s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-27.0298	 = Validation score   (-mean_absolute_error)
# 	43.15s	 = Training   runtime
# 	0.48s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r128_BAG_L1 ... Training model for up to 1109.23s of the 2309.74s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-27.2855	 = Validation score   (-mean_absolute_error)
# 	43.86s	 = Training   runtime
# 	0.4s	 = Validation runtime
# Fitting model: CatBoost_r16_BAG_L1 ... Training model for up to 1063.23s of the 2263.75s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.9858	 = Validation score   (-mean_absolute_error)
# 	249.69s	 = Training   runtime
# 	0.33s	 = Validation runtime
# Fitting model: CatBoost_r42_BAG_L1 ... Training model for up to 811.52s of the 2012.04s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.849	 = Validation score   (-mean_absolute_error)
# 	215.33s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: CatBoost_r93_BAG_L1 ... Training model for up to 594.46s of the 1794.97s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.6495	 = Validation score   (-mean_absolute_error)
# 	356.2s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: CatBoost_r44_BAG_L1 ... Training model for up to 236.21s of the 1436.73s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.8538	 = Validation score   (-mean_absolute_error)
# 	189.92s	 = Training   runtime
# 	0.39s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 44.57s of the 1245.08s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-20.8943	 = Validation score   (-mean_absolute_error)
# 	39.37s	 = Training   runtime
# 	20.9s	 = Validation runtime
# Completed 1/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 1198.99s of remaining time.
# 	-19.2963	 = Validation score   (-mean_absolute_error)
# 	0.77s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 27 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 1198.2s of the 1198.15s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.6966	 = Validation score   (-mean_absolute_error)
# 	5.74s	 = Training   runtime
# 	0.65s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 1190.34s of the 1190.29s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.5119	 = Validation score   (-mean_absolute_error)
# 	7.34s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ... Training model for up to 1180.81s of the 1180.76s of remaining time.
# 	-19.1622	 = Validation score   (-mean_absolute_error)
# 	64.57s	 = Training   runtime
# 	0.76s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 1115.12s of the 1115.07s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.6639	 = Validation score   (-mean_absolute_error)
# 	30.57s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ... Training model for up to 1082.36s of the 1082.31s of remaining time.
# 	-19.0077	 = Validation score   (-mean_absolute_error)
# 	8.24s	 = Training   runtime
# 	0.85s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 1072.97s of the 1072.92s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.0271	 = Validation score   (-mean_absolute_error)
# 	29.68s	 = Training   runtime
# 	0.6s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 1040.9s of the 1040.85s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.4114	 = Validation score   (-mean_absolute_error)
# 	10.83s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 1027.41s of the 1027.36s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.5328	 = Validation score   (-mean_absolute_error)
# 	47.4s	 = Training   runtime
# 	0.64s	 = Validation runtime
# Fitting model: ExtraTrees_r19_BAG_L2 ... Training model for up to 977.87s of the 977.82s of remaining time.
# 	-19.1097	 = Validation score   (-mean_absolute_error)
# 	6.44s	 = Training   runtime
# 	1.04s	 = Validation runtime
# Fitting model: RandomForest_r5_BAG_L2 ... Training model for up to 970.0s of the 969.95s of remaining time.
# 	-18.9489	 = Validation score   (-mean_absolute_error)
# 	37.31s	 = Training   runtime
# 	0.71s	 = Validation runtime
# Fitting model: LightGBM_r158_BAG_L2 ... Training model for up to 931.79s of the 931.73s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.6793	 = Validation score   (-mean_absolute_error)
# 	11.36s	 = Training   runtime
# 	0.96s	 = Validation runtime
# Fitting model: LightGBM_r118_BAG_L2 ... Training model for up to 917.47s of the 917.42s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.5282	 = Validation score   (-mean_absolute_error)
# 	20.41s	 = Training   runtime
# 	3.79s	 = Validation runtime
# Fitting model: LightGBM_r97_BAG_L2 ... Training model for up to 892.84s of the 892.79s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.6794	 = Validation score   (-mean_absolute_error)
# 	35.08s	 = Training   runtime
# 	11.47s	 = Validation runtime
# Fitting model: LightGBM_r71_BAG_L2 ... Training model for up to 851.95s of the 851.89s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.8296	 = Validation score   (-mean_absolute_error)
# 	85.88s	 = Training   runtime
# 	43.08s	 = Validation runtime
# Fitting model: LightGBM_r111_BAG_L2 ... Training model for up to 755.32s of the 755.26s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.2949	 = Validation score   (-mean_absolute_error)
# 	46.33s	 = Training   runtime
# 	5.22s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r25_BAG_L2 ... Training model for up to 704.13s of the 704.08s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.7627	 = Validation score   (-mean_absolute_error)
# 	41.11s	 = Training   runtime
# 	0.46s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r51_BAG_L2 ... Training model for up to 659.9s of the 659.85s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.5232	 = Validation score   (-mean_absolute_error)
# 	35.02s	 = Training   runtime
# 	0.42s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r82_BAG_L2 ... Training model for up to 622.49s of the 622.43s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.5356	 = Validation score   (-mean_absolute_error)
# 	39.09s	 = Training   runtime
# 	0.53s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r121_BAG_L2 ... Training model for up to 580.61s of the 580.55s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-20.2888	 = Validation score   (-mean_absolute_error)
# 	47.64s	 = Training   runtime
# 	0.77s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r145_BAG_L2 ... Training model for up to 530.24s of the 530.19s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.3077	 = Validation score   (-mean_absolute_error)
# 	79.79s	 = Training   runtime
# 	0.73s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r173_BAG_L2 ... Training model for up to 448.14s of the 448.09s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.2217	 = Validation score   (-mean_absolute_error)
# 	66.54s	 = Training   runtime
# 	0.83s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r128_BAG_L2 ... Training model for up to 379.11s of the 379.06s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.228	 = Validation score   (-mean_absolute_error)
# 	49.89s	 = Training   runtime
# 	0.64s	 = Validation runtime
# Fitting model: CatBoost_r16_BAG_L2 ... Training model for up to 326.87s of the 326.82s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.6603	 = Validation score   (-mean_absolute_error)
# 	47.43s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: CatBoost_r42_BAG_L2 ... Training model for up to 277.06s of the 277.01s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.6838	 = Validation score   (-mean_absolute_error)
# 	47.5s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: CatBoost_r93_BAG_L2 ... Training model for up to 227.04s of the 226.99s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.5942	 = Validation score   (-mean_absolute_error)
# 	103.3s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: CatBoost_r44_BAG_L2 ... Training model for up to 121.32s of the 121.27s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.6246	 = Validation score   (-mean_absolute_error)
# 	99.35s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 18.57s of the 18.52s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.6386	 = Validation score   (-mean_absolute_error)
# 	13.92s	 = Training   runtime
# 	0.71s	 = Validation runtime
# Completed 1/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the 2.48s of remaining time.
# 	-18.7136	 = Validation score   (-mean_absolute_error)
# 	0.48s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 3598.02s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("ag_145_lag_featuresC")

# %%
test1 = pipin.get_test_data("A")
test2 = pipin.get_test_data("B")
test3 = pipin.get_test_data("C")

# %%
test_data1 = TabularDataset(test1)
test_data2 = TabularDataset(test2)
test_data3 = TabularDataset(test3)

pred1 = pd.DataFrame(predictor1.predict(test_data1))
pred2 = pd.DataFrame(predictor2.predict(test_data2))
pred3 = pd.DataFrame(predictor3.predict(test_data3))

negatives_pred1 = pred1[pred1["pv_measurement"] < 0]
negatives_pred2 = pred2[pred2["pv_measurement"] < 0]
negatives_pred3 = pred3[pred3["pv_measurement"] < 0]
neg = pd.concat([negatives_pred1, negatives_pred2, negatives_pred3])
neg.shape
# Out:
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
# ...
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# (74, 1)

# %%
pred = pd.concat([pred1, pred2, pred3])
final_prediction = pipin.post_processing(pred, prediction_column="pv_measurement")
final_prediction.to_csv('submissions/gluon_145_lag_features.csv')

# %%
diff = pipin.compare_mae(final_prediction)
diff
# Out:
# 66.64465321641909

# %%
# predictor.evaluate(df1, silent=True)
