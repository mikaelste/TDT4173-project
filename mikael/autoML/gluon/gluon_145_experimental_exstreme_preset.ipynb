# %% [markdown]
# <h3> Henning skal teste å fjerne consecutives.</h3>
# <p> yee<p>

# %%
# %load_ext autoreload

# %%
from autogluon.tabular import TabularDataset, TabularPredictor
import pandas as pd
import numpy as np

# %%
# %autoreload
from pipeline_145_preset import Pipeline
pipin = Pipeline()
# Out:
# Current working directory: /Users/miksx/GitHub/Forest-Gump/mikael/autoML/gluon

# %%
DEFAULT_PATH = f"ag_145_experimental_exstreme_preset"

# %%
df1_0 = pipin.get_data("A")
df2_0 = pipin.get_data("B")
df3_0 = pipin.get_data("C")

# %%
# remove_consecutive_measurments
df1_0 = pipin.remove_consecutive_measurments(df1_0, 3, 24)
df2_0 = pipin.remove_consecutive_measurments(df2_0, 3, 24)
df3_0 = pipin.remove_consecutive_measurments(df3_0, 3, 24)

# %%
df1_0.head()
# Out:
#    absolute_humidity_2m:gm3  air_density_2m:kgm3  ceiling_height_agl:m  \
# 0                     7.700              1.22825           1728.949951
# 1                     7.700              1.22350           1689.824951
# 2                     7.875              1.21975           1563.224976
# 3                     8.425              1.21800           1283.425049
# 4                     8.950              1.21800           1003.500000
#
#    clear_sky_energy_1h:J  clear_sky_rad:W  cloud_base_agl:m  dew_or_rime:idx  \
# 0               0.000000             0.00       1728.949951              0.0
# 1               0.000000             0.00       1689.824951              0.0
# 2               0.000000             0.00       1563.224976              0.0
# 3             208.649994             0.75       1283.425049              0.0
# 4           32468.150391            23.10       1003.500000              0.0
#
#    dew_point_2m:K  diffuse_rad:W  diffuse_rad_1h:J  ...  visibility:m  \
# 0      280.299988          0.000          0.000000  ...  40386.476562
# 1      280.299988          0.000          0.000000  ...  33770.648438
# 2      280.649994          0.000          0.000000  ...  13595.500000
# 3      281.674988          0.300        526.775024  ...   2321.850098
# 4      282.500000         11.975      22068.949219  ...  11634.799805
#
#    wind_speed_10m:ms  wind_speed_u_10m:ms  wind_speed_v_10m:ms  \
# 0              3.600                3.575                0.500
# 1              3.350                3.350                0.275
# 2              3.050                2.950                0.750
# 3              2.725                2.600                0.875
# 4              2.550                2.350                0.925
#
#    wind_speed_w_1000hPa:ms  estimated  observed  day_of_year  hour  \
# 0                      0.0        0.0       1.0        153.0  22.0
# 1                      0.0        0.0       1.0        153.0  23.0
# 2                      0.0        0.0       1.0        154.0   0.0
# 3                      0.0        0.0       1.0        154.0   1.0
# 4                      0.0        0.0       1.0        154.0   2.0
#
#    pv_measurement
# 0            0.00
# 1            0.00
# 2            0.00
# 3            0.00
# 4           19.36
#
# [5 rows x 50 columns]

# %%
train1 = TabularDataset(df1_0)
train2 = TabularDataset(df2_0)
train3 = TabularDataset(df3_0)

# %%
predictor1 = TabularPredictor(label="pv_measurement",
                              eval_metric='mean_absolute_error',
                              path= DEFAULT_PATH+"A"
                              ).fit(
    train1,
    # time_limit=6000,
    # hyperparameters='extrme', 
    presets='experimental_extreme_quality', 
    # tuning_data = tuning1,
    # use_bag_holdout=True,
    # num_bag_folds= 6,
    # refit_full = True,
    # auto_stack = True,
    # num_bag_sets= 10,
    # set_best_to_refit_full= True,
    # num_stack_levels = 2,
    # verbosity = 3
    )
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="ag_145_experimental_exstreme_presetA"
# Presets specified: ['experimental_extreme_quality']
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/core/utils/utils.py:564: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Beginning AutoGluon training ...
# AutoGluon will save models to "ag_145_experimental_exstreme_presetA"
# AutoGluon Version:  0.8.2
# Python Version:     3.10.12
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 23.0.0: Fri Sep 15 14:41:43 PDT 2023; root:xnu-10002.1.13~1/RELEASE_ARM64_T6000
# Disk Space Avail:   221.91 GB / 494.38 GB (44.9%)
# Train Data Rows:    19853
# Train Data Columns: 49
# Label Column: pv_measurement
# Preprocessing data ...
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/core/utils/utils.py:564: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (5733.42, 0.0, 1082.6485, 1358.08613)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/learner/default_learner.py:215: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    3666.97 MB
# 	Train Data (Original)  Memory Usage: 4.21 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 3 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Unused Original Features (Count: 1): ['snow_drift:idx']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('float', []) : 1 | ['snow_drift:idx']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 48 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 46 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 		('int', ['bool']) :  2 | ['elevation:m', 'snow_density:kgm3']
# 	1.4s = Fit runtime
# 	48 features in original data used to generate 48 features in processed data.
# 	Train Data (Processed) Memory Usage: 4.01 MB (0.1% of available memory)
# Data preprocessing and feature engineering runtime = 1.51s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'TABPFN': {'N_ensemble_configurations': 8},
# 	'FT_TRANSFORMER': {},
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 12 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ...
# 	-453.8266	 = Validation score   (-mean_absolute_error)
# 	0.02s	 = Training   runtime
# 	0.82s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ...
# 	-455.2582	 = Validation score   (-mean_absolute_error)
# 	0.09s	 = Training   runtime
# 	0.71s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-258.4436	 = Validation score   (-mean_absolute_error)
# 	84.53s	 = Training   runtime
# 	109.29s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-271.7405	 = Validation score   (-mean_absolute_error)
# 	132.94s	 = Training   runtime
# 	97.12s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ...
# 	-309.7828	 = Validation score   (-mean_absolute_error)
# 	81.16s	 = Training   runtime
# 	3.3s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-277.5229	 = Validation score   (-mean_absolute_error)
# 	592.91s	 = Training   runtime
# 	0.33s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ...
# 	-309.8548	 = Validation score   (-mean_absolute_error)
# 	16.64s	 = Training   runtime
# 	2.68s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-306.6593	 = Validation score   (-mean_absolute_error)
# 	81.05s	 = Training   runtime
# 	0.62s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-287.4556	 = Validation score   (-mean_absolute_error)
# 	334.75s	 = Training   runtime
# 	48.33s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-293.3246	 = Validation score   (-mean_absolute_error)
# 	147.24s	 = Training   runtime
# 	0.38s	 = Validation runtime
# Fitting model: FTTransformer_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	Warning: Exception caused FTTransformer_BAG_L1 to fail during training (ImportError)... Skipping this model.
# 		ray::_ray_fit() (pid=29169, ip=127.0.0.1)
#   File "/Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/multimodal/__init__.py", line 6, in <module>
#     from . import constants, data, models, optimization, predictor, problem_types, utils
#   File "/Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/multimodal/predictor.py", line 34, in <module>
#     from autogluon.multimodal.utils.log import get_fit_complete_message, get_fit_start_message
#   File "/Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/multimodal/utils/__init__.py", line 58, in <module>
#     from .metric import compute_ranking_score, compute_score, get_minmax_mode, get_stopping_threshold, infer_metrics
#   File "/Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/multimodal/utils/metric.py", line 7, in <module>
#     import evaluate
#   File "/Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/evaluate/__init__.py", line 29, in <module>
#     from .evaluation_suite import EvaluationSuite
#   File "/Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/evaluate/evaluation_suite/__init__.py", line 7, in <module>
#     from datasets import Dataset, DownloadConfig, DownloadMode, load_dataset
#   File "/Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/datasets/__init__.py", line 22, in <module>
#     from .arrow_dataset import Dataset
#   File "/Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/datasets/arrow_dataset.py", line 66, in <module>
#     from .arrow_reader import ArrowReader
#   File "/Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/datasets/arrow_reader.py", line 28, in <module>
#     import pyarrow.parquet as pq
#   File "/Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/pyarrow/parquet/__init__.py", line 34, in <module>
#     import pyarrow._parquet as _parquet
# ImportError: dlopen(/Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/pyarrow/_parquet.cpython-310-darwin.so, 0x0002): Library not loaded: @rpath/libssl.1.1.dylib
#   Referenced from: <B5E6545D-91E6-3B05-AD42-0BC24850FDB4> /Users/miksx/anaconda3/envs/TDT4173/lib/libthrift.0.13.0.dylib
#   Reason: tried: '/Users/miksx/anaconda3/envs/TDT4173/lib/libssl.1.1.dylib' (no such file), '/Users/miksx/anaconda3/envs/TDT4173/lib/libssl.1.1.dylib' (no such file), '/Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/pyarrow/../../../libssl.1.1.dylib' (no such file), '/Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/pyarrow/../../../libssl.1.1.dylib' (no such file), '/Users/miksx/anaconda3/envs/TDT4173/bin/../lib/libssl.1.1.dylib' (no such file), '/Users/miksx/anaconda3/envs/TDT4173/bin/../lib/libssl.1.1.dylib' (no such file), '/usr/local/lib/libssl.1.1.dylib' (no such file), '/usr/lib/libssl.1.1.dylib' (no such file, not in dyld cache)
#
# During handling of the above exception, another exception occurred:
#
# ray::_ray_fit() (pid=29169, ip=127.0.0.1)
#   File "/Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 402, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 838, in fit
#     out = self._fit(**kwargs)
#   File "/Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/automm/ft_transformer.py", line 53, in _fit
#     super()._fit(X, num_gpus=num_gpus, **kwargs)
#   File "/Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/automm/automm_model.py", line 141, in _fit
#     try_import_autogluon_multimodal()
#   File "/Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/common/utils/try_import.py", line 140, in try_import_autogluon_multimodal
#     raise ImportError("`import autogluon.multimodal` failed.\n" f"A quick tip is to install via `pip install autogluon.multimodal=={__version__}`.\n")
# ImportError: `import autogluon.multimodal` failed.
# A quick tip is to install via `pip install autogluon.multimodal==0.8.2`.
# Fitting model: LightGBMLarge_BAG_L1 ...
# 2023-11-07 15:54:35,002	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-07 15:54:35,006	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-07 15:54:35,007	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-07 15:54:35,008	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-07 15:54:35,009	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-07 15:54:35,011	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 2023-11-07 15:54:35,033	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	-269.0078	 = Validation score   (-mean_absolute_error)
# 	292.86s	 = Training   runtime
# 	372.23s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-255.0663	 = Validation score   (-mean_absolute_error)
# 	2.19s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 9 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-257.2929	 = Validation score   (-mean_absolute_error)
# 	16.92s	 = Training   runtime
# 	2.36s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-253.942	 = Validation score   (-mean_absolute_error)
# 	17.95s	 = Training   runtime
# 	1.4s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ...
# 	-252.9166	 = Validation score   (-mean_absolute_error)
# 	130.43s	 = Training   runtime
# 	3.01s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-253.2403	 = Validation score   (-mean_absolute_error)
# 	37.74s	 = Training   runtime
# 	0.39s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ...
# 	-252.6906	 = Validation score   (-mean_absolute_error)
# 	17.48s	 = Training   runtime
# 	2.51s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-253.1447	 = Validation score   (-mean_absolute_error)
# 	48.89s	 = Training   runtime
# 	0.94s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-253.9995	 = Validation score   (-mean_absolute_error)
# 	10.29s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-252.5266	 = Validation score   (-mean_absolute_error)
# 	50.36s	 = Training   runtime
# 	0.57s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-256.5926	 = Validation score   (-mean_absolute_error)
# 	14.47s	 = Training   runtime
# 	1.06s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ...
# 	-247.8911	 = Validation score   (-mean_absolute_error)
# 	0.34s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 2319.43s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("ag_145_experimental_exstreme_presetA")

# %%
predictor2 = TabularPredictor(label="pv_measurement",
                              eval_metric='mean_absolute_error',
                              path= DEFAULT_PATH+"B"
                              ).fit(
    train2,
    # time_limit=6000,
    # hyperparameters='extrme', 
    presets='experimental_extreme_quality', 
    # tuning_data = tuning1,
    # use_bag_holdout=True,
    # num_bag_folds= 6,
    # refit_full = True,
    # auto_stack = True,
    # num_bag_sets= 10,
    # set_best_to_refit_full= True,
    # num_stack_levels = 2,
    # verbosity = 3
    )

# tuning_data
# num bag holdout 6
# bag_holdout
# Out:
# Presets specified: ['experimental_extreme_quality']
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/core/utils/utils.py:564: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Beginning AutoGluon training ...
# AutoGluon will save models to "ag_145_experimental_exstreme_presetB"
# AutoGluon Version:  0.8.2
# Python Version:     3.10.12
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 23.0.0: Fri Sep 15 14:41:43 PDT 2023; root:xnu-10002.1.13~1/RELEASE_ARM64_T6000
# Disk Space Avail:   229.26 GB / 494.38 GB (46.4%)
# Train Data Rows:    13632
# Train Data Columns: 49
# Label Column: pv_measurement
# Preprocessing data ...
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/core/utils/utils.py:564: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (1152.3, 0.0, 203.67563, 257.36859)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/learner/default_learner.py:215: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    5817.78 MB
# 	Train Data (Original)  Memory Usage: 2.89 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 3 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Unused Original Features (Count: 1): ['snow_drift:idx']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('float', []) : 1 | ['snow_drift:idx']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 48 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 46 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 		('int', ['bool']) :  2 | ['elevation:m', 'snow_density:kgm3']
# 	0.6s = Fit runtime
# 	48 features in original data used to generate 48 features in processed data.
# 	Train Data (Processed) Memory Usage: 2.75 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.65s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'TABPFN': {'N_ensemble_configurations': 8},
# 	'FT_TRANSFORMER': {},
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 12 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ...
# 	-77.0431	 = Validation score   (-mean_absolute_error)
# 	0.01s	 = Training   runtime
# 	0.39s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ...
# 	-77.2804	 = Validation score   (-mean_absolute_error)
# 	0.01s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-41.1818	 = Validation score   (-mean_absolute_error)
# 	47.48s	 = Training   runtime
# 	47.36s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-44.0708	 = Validation score   (-mean_absolute_error)
# 	135.32s	 = Training   runtime
# 	51.07s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ...
# 	-49.9611	 = Validation score   (-mean_absolute_error)
# 	67.17s	 = Training   runtime
# 	2.28s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy

# %%
predictor3 = TabularPredictor(label="pv_measurement",
                              eval_metric='mean_absolute_error',
                              path= DEFAULT_PATH+"C"
                              ).fit(
    train3,
    # time_limit=6000,
    # hyperparameters='extrme', 
    presets='experimental_extreme_quality', 
    # tuning_data = tuning1,
    # use_bag_holdout=True,
    # num_bag_folds= 6,
    # refit_full = True,
    # auto_stack = True,
    # num_bag_sets= 10,
    # set_best_to_refit_full= True,
    # num_stack_levels = 2,
    # verbosity = 3
    )
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20231107_001926/"
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20231107_001926/"
# AutoGluon Version:  0.8.2
# Python Version:     3.10.13
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 22.5.0: Thu Jun  8 22:22:20 PDT 2023; root:xnu-8796.121.3~7/RELEASE_ARM64_T6000
# Disk Space Avail:   655.49 GB / 994.66 GB (65.9%)
# Train Data Rows:    26095
# Train Data Columns: 49
# Label Column: pv_measurement
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and label-values can't be converted to int).
# 	Label info (max, min, mean, stddev): (999.6, -0.0, 77.63106, 165.81688)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    12692.78 MB
# 	Train Data (Original)  Memory Usage: 5.53 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 3 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Unused Original Features (Count: 1): ['snow_drift:idx']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('float', []) : 1 | ['snow_drift:idx']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 48 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 46 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 		('int', ['bool']) :  2 | ['elevation:m', 'snow_density:kgm3']
# 	0.5s = Fit runtime
# 	48 features in original data used to generate 48 features in processed data.
# 	Train Data (Processed) Memory Usage: 5.27 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.67s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ...
# 	-29.1151	 = Validation score   (-mean_absolute_error)
# 	0.02s	 = Training   runtime
# 	1.76s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ...
# 	-29.0905	 = Validation score   (-mean_absolute_error)
# 	0.02s	 = Training   runtime
# 	1.92s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-16.4497	 = Validation score   (-mean_absolute_error)
# 	90.88s	 = Training   runtime
# 	93.55s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-17.346	 = Validation score   (-mean_absolute_error)
# 	127.96s	 = Training   runtime
# 	214.89s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ...
# 	-19.7427	 = Validation score   (-mean_absolute_error)
# 	35.43s	 = Training   runtime
# 	1.27s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-17.9658	 = Validation score   (-mean_absolute_error)
# 	821.54s	 = Training   runtime
# 	0.8s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ...
# 	-19.7181	 = Validation score   (-mean_absolute_error)
# 	7.03s	 = Training   runtime
# 	1.69s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-20.2476	 = Validation score   (-mean_absolute_error)
# 	58.27s	 = Training   runtime
# 	1.07s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-18.43	 = Validation score   (-mean_absolute_error)
# 	388.65s	 = Training   runtime
# 	204.27s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-17.9975	 = Validation score   (-mean_absolute_error)
# 	231.24s	 = Training   runtime
# 	0.87s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-17.0576	 = Validation score   (-mean_absolute_error)
# 	313.34s	 = Training   runtime
# 	403.48s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-16.017	 = Validation score   (-mean_absolute_error)
# 	0.97s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 9 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-16.5143	 = Validation score   (-mean_absolute_error)
# 	8.75s	 = Training   runtime
# 	1.11s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-16.2631	 = Validation score   (-mean_absolute_error)
# 	7.04s	 = Training   runtime
# 	0.59s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ...
# 	-15.8638	 = Validation score   (-mean_absolute_error)
# 	56.93s	 = Training   runtime
# 	2.01s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-16.4443	 = Validation score   (-mean_absolute_error)
# 	32.38s	 = Training   runtime
# 	0.45s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ...
# 	-15.8232	 = Validation score   (-mean_absolute_error)
# 	9.56s	 = Training   runtime
# 	2.25s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-16.0857	 = Validation score   (-mean_absolute_error)
# 	60.7s	 = Training   runtime
# 	1.13s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-16.1754	 = Validation score   (-mean_absolute_error)
# 	9.11s	 = Training   runtime
# 	0.22s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-16.2449	 = Validation score   (-mean_absolute_error)
# 	85.91s	 = Training   runtime
# 	0.59s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-16.3502	 = Validation score   (-mean_absolute_error)
# 	45.31s	 = Training   runtime
# 	1.92s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ...
# 	-15.6089	 = Validation score   (-mean_absolute_error)
# 	0.65s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 2647.99s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20231107_001926/")

# %%
test1 = pipin.get_test_data("A")
test2 = pipin.get_test_data("B")
test3 = pipin.get_test_data("C")

# %%
test_data1 = TabularDataset(test1)
test_data2 = TabularDataset(test2)
test_data3 = TabularDataset(test3)

pred1 = pd.DataFrame(predictor1.predict(test_data1))
pred2 = pd.DataFrame(predictor2.predict(test_data2))
pred3 = pd.DataFrame(predictor3.predict(test_data3))

negatives_pred1 = pred1[pred1["pv_measurement"] < 0]
negatives_pred2 = pred2[pred2["pv_measurement"] < 0]
negatives_pred3 = pred3[pred3["pv_measurement"] < 0]
neg = pd.concat([negatives_pred1, negatives_pred2, negatives_pred3])
neg.shape
# Out:
# (71, 1)

# %%
pred = pd.concat([pred1, pred2, pred3])
final_prediction = pipin.post_processing(pred, prediction_column="pv_measurement")
final_prediction.to_csv('gluon_145_experimental_exstreme_preset.csv')

# %%
diff = pipin.compare_mae(final_prediction)
diff
# Out:
# 50.67033104400012

# %%
# predictor.evaluate(df1, silent=True)
