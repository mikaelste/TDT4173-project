# %%
import pipeline as pipe
from feature_engine.selection import DropCorrelatedFeatures
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Current working directory: /Users/miksx/GitHub/Forest-Gump/mikael/autoML/gluon

# %%
pipeline = pipe.Pipeline()

# %%
data_a = pipeline.get_data("A")

# %%
data_a
# Out:
#        absolute_humidity_2m:gm3  air_density_2m:kgm3  ceiling_height_agl:m  \
# 0                           7.7                1.230           1744.900024
# 1                           7.7                1.225           1703.599976
# 2                           7.7                1.221           1668.099976
# 3                           8.2                1.218           1388.400024
# 4                           8.8                1.219           1108.500000
# ...                         ...                  ...                   ...
# 34080                       4.6                1.275           1633.000000
# 34081                       4.5                1.279           1742.900024
# 34082                       4.5                1.281           1794.900024
# 34083                       4.5                1.281           1532.900024
# 34084                       4.5                1.281           1054.199951
#
#        clear_sky_energy_1h:J  clear_sky_rad:W  cloud_base_agl:m  \
# ...

# %%
data = pipeline.get_data("A")

# %%
# data_a = pipeline.remove_consecutive_measurments(data_a, 4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/miksx/GitHub/Forest-Gump/mikael/autoML/gluon/data_analysis.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/Users/miksx/GitHub/Forest-Gump/mikael/autoML/gluon/data_analysis.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> data_a = pipeline.remove_consecutive_measurments(data_a, 4)
#
# AttributeError: 'Pipeline' object has no attribute 'remove_consecutive_measurments'

# %%
# Split the dataset into features and target
X = data_a.drop(columns=["pv_measurement"])
y = data_a["pv_measurement"]

# %%
X.describe()
# Out:
#        absolute_humidity_2m:gm3  air_density_2m:kgm3  ceiling_height_agl:m  \
# count              20293.000000         20293.000000          16271.000000
# mean                   7.133427             1.241340           3130.423340
# std                    2.856283             0.034508           2662.231934
# min                    0.700000             1.145000             27.849998
# 25%                    4.800000             1.217750           1185.812500
# 50%                    7.150000             1.238500           2072.899902
# 75%                    9.100000             1.264000           4432.649902
# max                   17.350000             1.426250          12042.525391
#
#        clear_sky_energy_1h:J  clear_sky_rad:W  cloud_base_agl:m  \
# count           2.029300e+04     20293.000000      18794.000000
# mean            9.264022e+05       257.321381       1791.566284
# std             9.272698e+05       258.477142       1877.248169
# ...

# %%
tr = DropCorrelatedFeatures(variables=None, method="pearson", threshold=0.98)
X_pearson = tr.fit_transform(X)

# %%
X_pearson.describe()
# Out:
#        absolute_humidity_2m:gm3  air_density_2m:kgm3  ceiling_height_agl:m  \
# count              20293.000000         20293.000000          16271.000000
# mean                   7.133427             1.241340           3130.423340
# std                    2.856283             0.034508           2662.231934
# min                    0.700000             1.145000             27.849998
# 25%                    4.800000             1.217750           1185.812500
# 50%                    7.150000             1.238500           2072.899902
# 75%                    9.100000             1.264000           4432.649902
# max                   17.350000             1.426250          12042.525391
#
#        clear_sky_energy_1h:J  cloud_base_agl:m  dew_or_rime:idx  \
# count           2.029300e+04      18794.000000     20293.000000
# mean            9.264022e+05       1791.566284         0.010940
# std             9.272698e+05       1877.248169         0.096687
# ...

# %%
tr = DropCorrelatedFeatures(variables=None, method="spearman", threshold=0.98)
X_spearman = tr.fit_transform(X)

# %%
X_spearman.describe()
# Out:
#        absolute_humidity_2m:gm3  air_density_2m:kgm3  ceiling_height_agl:m  \
# count              20293.000000         20293.000000          16271.000000
# mean                   7.133427             1.241340           3130.423340
# std                    2.856283             0.034508           2662.231934
# min                    0.700000             1.145000             27.849998
# 25%                    4.800000             1.217750           1185.812500
# 50%                    7.150000             1.238500           2072.899902
# 75%                    9.100000             1.264000           4432.649902
# max                   17.350000             1.426250          12042.525391
#
#        clear_sky_energy_1h:J  cloud_base_agl:m  dew_or_rime:idx  \
# count           2.029300e+04      18794.000000     20293.000000
# mean            9.264022e+05       1791.566284         0.010940
# std             9.272698e+05       1877.248169         0.096687
# ...

# %%
X.describe()
# Out:
#        absolute_humidity_2m:gm3  air_density_2m:kgm3  ceiling_height_agl:m  \
# count              20293.000000         20293.000000          16271.000000
# mean                   7.133427             1.241340           3130.423340
# std                    2.856283             0.034508           2662.231934
# min                    0.700000             1.145000             27.849998
# 25%                    4.800000             1.217750           1185.812500
# 50%                    7.150000             1.238500           2072.899902
# 75%                    9.100000             1.264000           4432.649902
# max                   17.350000             1.426250          12042.525391
#
#        clear_sky_energy_1h:J  clear_sky_rad:W  cloud_base_agl:m  \
# count           2.029300e+04     20293.000000      18794.000000
# mean            9.264022e+05       257.321381       1791.566284
# std             9.272698e+05       258.477142       1877.248169
# ...

# %%
tr = DropCorrelatedFeatures(variables=None, method="kendall", threshold=0.9)
X_kendall = tr.fit_transform(X)

# %%
X_kendall.describe()
# Out:
#        absolute_humidity_2m:gm3  air_density_2m:kgm3  ceiling_height_agl:m  \
# count              20293.000000         20293.000000          16271.000000
# mean                   7.133427             1.241340           3130.423340
# std                    2.856283             0.034508           2662.231934
# min                    0.700000             1.145000             27.849998
# 25%                    4.800000             1.217750           1185.812500
# 50%                    7.150000             1.238500           2072.899902
# 75%                    9.100000             1.264000           4432.649902
# max                   17.350000             1.426250          12042.525391
#
#        clear_sky_energy_1h:J  clear_sky_rad:W  cloud_base_agl:m  \
# count           2.029300e+04     20293.000000      18794.000000
# mean            9.264022e+05       257.321381       1791.566284
# std             9.272698e+05       258.477142       1877.248169
# ...

# %% [markdown]
# # Lag features
