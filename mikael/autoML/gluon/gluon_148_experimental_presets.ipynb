# %%
# %load_ext autoreload

# %%
from autogluon.tabular import TabularDataset, TabularPredictor
import pandas as pd
import numpy as np

# %%
# %autoreload
from pipeline_experimental_presets import Pipeline
pipin = Pipeline()
# Out:
# Current working directory: /Users/miksx/GitHub/Forest-Gump/mikael/autoML/gluon

# %%
DEFAULT_PATH = f"ag_148_one_hot_experimental"

# %%
df1_0 = pipin.get_data("A")
df2_0 = pipin.get_data("B")
df3_0 = pipin.get_data("C")

# %%
df1_0.head()
# Out:
#    absolute_humidity_2m:gm3  air_density_2m:kgm3  ceiling_height_agl:m  \
# 0                     7.700              1.22825           1728.949951
# 1                     7.700              1.22350           1689.824951
# 2                     7.875              1.21975           1563.224976
# 3                     8.425              1.21800           1283.425049
# 4                     8.950              1.21800           1003.500000
#
#    clear_sky_energy_1h:J  clear_sky_rad:W  cloud_base_agl:m  dew_or_rime:idx  \
# 0               0.000000             0.00       1728.949951              0.0
# 1               0.000000             0.00       1689.824951              0.0
# 2               0.000000             0.00       1563.224976              0.0
# 3             208.649994             0.75       1283.425049              0.0
# 4           32468.150391            23.10       1003.500000              0.0
#
#    dew_point_2m:K  diffuse_rad:W  diffuse_rad_1h:J  ...  visibility:m  \
# 0      280.299988          0.000          0.000000  ...  40386.476562
# 1      280.299988          0.000          0.000000  ...  33770.648438
# 2      280.649994          0.000          0.000000  ...  13595.500000
# 3      281.674988          0.300        526.775024  ...   2321.850098
# 4      282.500000         11.975      22068.949219  ...  11634.799805
#
#    wind_speed_10m:ms  wind_speed_u_10m:ms  wind_speed_v_10m:ms  \
# 0              3.600                3.575                0.500
# 1              3.350                3.350                0.275
# 2              3.050                2.950                0.750
# 3              2.725                2.600                0.875
# 4              2.550                2.350                0.925
#
#    wind_speed_w_1000hPa:ms  estimated  observed  day_of_year  hour  \
# 0                      0.0        0.0       1.0        153.0  22.0
# 1                      0.0        0.0       1.0        153.0  23.0
# 2                      0.0        0.0       1.0        154.0   0.0
# 3                      0.0        0.0       1.0        154.0   1.0
# 4                      0.0        0.0       1.0        154.0   2.0
#
#    pv_measurement
# 0            0.00
# 1            0.00
# 2            0.00
# 3            0.00
# 4           19.36
#
# [5 rows x 50 columns]

# %%
train1 = TabularDataset(df1_0)
train2 = TabularDataset(df2_0)
train3 = TabularDataset(df3_0)

# %%
predictor1 = TabularPredictor(label="pv_measurement",
                              eval_metric='mean_absolute_error',
                              path= DEFAULT_PATH+"A"
                              ).fit(
    train1,
    # time_limit=6000,
    # hyperparameters='extrme', 
    presets='experimental_zeroshot_hpo_hybrid', 
    # tuning_data = tuning1,
    # use_bag_holdout=True,
    # num_bag_folds= 6,
    # refit_full = True,
    # auto_stack = True,
    # num_bag_sets= 10,
    # set_best_to_refit_full= True,
    # num_stack_levels = 2,
    # verbosity = 3
    )
# Out:
# Presets specified: ['experimental_zeroshot_hpo_hybrid']
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/core/utils/utils.py:564: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Beginning AutoGluon training ...
# AutoGluon will save models to "ag_148_one_hot_experimentalA"
# AutoGluon Version:  0.8.2
# Python Version:     3.10.12
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 23.0.0: Fri Sep 15 14:41:43 PDT 2023; root:xnu-10002.1.13~1/RELEASE_ARM64_T6000
# Disk Space Avail:   49.04 GB / 494.38 GB (9.9%)
# Train Data Rows:    34085
# Train Data Columns: 49
# Label Column: pv_measurement
# Preprocessing data ...
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/core/utils/utils.py:564: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (5733.42, 0.0, 630.59471, 1165.90242)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/learner/default_learner.py:215: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    4389.27 MB
# 	Train Data (Original)  Memory Usage: 7.23 MB (0.2% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 3 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Unused Original Features (Count: 1): ['snow_drift:idx']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('float', []) : 1 | ['snow_drift:idx']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 48 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 46 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 		('int', ['bool']) :  2 | ['elevation:m', 'snow_density:kgm3']
# 	0.5s = Fit runtime
# 	48 features in original data used to generate 48 features in processed data.
# 	Train Data (Processed) Memory Usage: 6.89 MB (0.2% of available memory)
# Data preprocessing and feature engineering runtime = 0.54s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}, {'min_samples_leaf': 1, 'max_leaf_nodes': 15000, 'max_features': 0.5, 'ag_args': {'name_suffix': '_r19', 'priority': 20}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}, {'min_samples_leaf': 5, 'max_leaf_nodes': 50000, 'max_features': 0.5, 'ag_args': {'name_suffix': '_r5', 'priority': 19}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge', {'extra_trees': False, 'feature_fraction': 0.7248284762542815, 'learning_rate': 0.07947286942946127, 'min_data_in_leaf': 50, 'num_leaves': 89, 'ag_args': {'name_suffix': '_r158', 'priority': 18}}, {'extra_trees': True, 'feature_fraction': 0.7832570544199176, 'learning_rate': 0.021720607471727896, 'min_data_in_leaf': 3, 'num_leaves': 21, 'ag_args': {'name_suffix': '_r118', 'priority': 17}}, {'extra_trees': True, 'feature_fraction': 0.7113010892989156, 'learning_rate': 0.012535427424259274, 'min_data_in_leaf': 16, 'num_leaves': 48, 'ag_args': {'name_suffix': '_r97', 'priority': 16}}, {'extra_trees': True, 'feature_fraction': 0.45555769907110816, 'learning_rate': 0.009591347321206594, 'min_data_in_leaf': 50, 'num_leaves': 110, 'ag_args': {'name_suffix': '_r71', 'priority': 15}}, {'extra_trees': False, 'feature_fraction': 0.40979710161022476, 'learning_rate': 0.008708890211023034, 'min_data_in_leaf': 3, 'num_leaves': 80, 'ag_args': {'name_suffix': '_r111', 'priority': 14}}],
# 	'XGB': {},
# 	'FASTAI': [{}, {'bs': 1024, 'emb_drop': 0.6167722379778131, 'epochs': 44, 'layers': [200, 100, 50], 'lr': 0.053440377855629266, 'ps': 0.48477211305443607, 'ag_args': {'name_suffix': '_r25', 'priority': 13}}, {'bs': 1024, 'emb_drop': 0.6046989241462619, 'epochs': 48, 'layers': [200, 100, 50], 'lr': 0.00775309042164966, 'ps': 0.09244767444160731, 'ag_args': {'name_suffix': '_r51', 'priority': 12}}, {'bs': 512, 'emb_drop': 0.6557225316526186, 'epochs': 49, 'layers': [200, 100], 'lr': 0.023627682025564638, 'ps': 0.519566584552178, 'ag_args': {'name_suffix': '_r82', 'priority': 11}}, {'bs': 2048, 'emb_drop': 0.4066210919034579, 'epochs': 43, 'layers': [400, 200], 'lr': 0.0029598312717673434, 'ps': 0.4378695797438974, 'ag_args': {'name_suffix': '_r121', 'priority': 10}}, {'bs': 128, 'emb_drop': 0.44339037504795686, 'epochs': 31, 'layers': [400, 200, 100], 'lr': 0.008615195908919904, 'ps': 0.19220253419114286, 'ag_args': {'name_suffix': '_r145', 'priority': 9}}, {'bs': 128, 'emb_drop': 0.12106594798980945, 'epochs': 38, 'layers': [200, 100, 50], 'lr': 0.037991970245029975, 'ps': 0.33120008492595093, 'ag_args': {'name_suffix': '_r173', 'priority': 8}}, {'bs': 128, 'emb_drop': 0.4599138419358, 'epochs': 47, 'layers': [200, 100], 'lr': 0.03888383281136287, 'ps': 0.28193673177122863, 'ag_args': {'name_suffix': '_r128', 'priority': 7}}],
# 	'CAT': [{}, {'depth': 5, 'l2_leaf_reg': 4.774992314058497, 'learning_rate': 0.038551267822920274, 'ag_args': {'name_suffix': '_r16', 'priority': 6}}, {'depth': 4, 'l2_leaf_reg': 1.9950125740798321, 'learning_rate': 0.028091050379971633, 'ag_args': {'name_suffix': '_r42', 'priority': 5}}, {'depth': 6, 'l2_leaf_reg': 1.8298803017644376, 'learning_rate': 0.017844259810823604, 'ag_args': {'name_suffix': '_r93', 'priority': 4}}, {'depth': 7, 'l2_leaf_reg': 4.81099604606794, 'learning_rate': 0.019085060180573103, 'ag_args': {'name_suffix': '_r44', 'priority': 3}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 29 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ...
# 	-266.2618	 = Validation score   (-mean_absolute_error)
# 	0.03s	 = Training   runtime
# 	1.25s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ...
# 	-266.9747	 = Validation score   (-mean_absolute_error)
# 	0.03s	 = Training   runtime
# 	1.21s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-155.1211	 = Validation score   (-mean_absolute_error)
# 	68.69s	 = Training   runtime
# 	93.04s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-162.8397	 = Validation score   (-mean_absolute_error)
# 	94.64s	 = Training   runtime
# 	118.32s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ...
# 	-181.546	 = Validation score   (-mean_absolute_error)
# 	47.02s	 = Training   runtime
# 	1.52s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-169.7986	 = Validation score   (-mean_absolute_error)
# 	425.68s	 = Training   runtime
# 	0.29s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ...
# 	-181.7482	 = Validation score   (-mean_absolute_error)
# 	8.64s	 = Training   runtime
# 	1.37s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-185.89	 = Validation score   (-mean_absolute_error)
# 	50.24s	 = Training   runtime
# 	0.75s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-172.662	 = Validation score   (-mean_absolute_error)
# 	313.06s	 = Training   runtime
# 	114.07s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-171.0935	 = Validation score   (-mean_absolute_error)
# 	165.74s	 = Training   runtime
# 	0.45s	 = Validation runtime
# Fitting model: ExtraTrees_r19_BAG_L1 ...
# 	-181.5691	 = Validation score   (-mean_absolute_error)
# 	7.14s	 = Training   runtime
# 	2.07s	 = Validation runtime
# Fitting model: RandomForest_r5_BAG_L1 ...
# 	-182.7223	 = Validation score   (-mean_absolute_error)
# 	23.56s	 = Training   runtime
# 	1.44s	 = Validation runtime
# Fitting model: LightGBM_r158_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-165.8054	 = Validation score   (-mean_absolute_error)
# 	101.55s	 = Training   runtime
# 	284.59s	 = Validation runtime
# Fitting model: LightGBM_r118_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-156.9157	 = Validation score   (-mean_absolute_error)
# 	31.89s	 = Training   runtime
# 	49.7s	 = Validation runtime
# Fitting model: LightGBM_r97_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-155.6785	 = Validation score   (-mean_absolute_error)
# 	54.78s	 = Training   runtime
# 	154.68s	 = Validation runtime
# Fitting model: LightGBM_r71_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-163.3427	 = Validation score   (-mean_absolute_error)
# 	121.59s	 = Training   runtime
# 	383.12s	 = Validation runtime
# Fitting model: LightGBM_r111_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-157.4893	 = Validation score   (-mean_absolute_error)
# 	94.8s	 = Training   runtime
# 	138.44s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r25_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-191.0219	 = Validation score   (-mean_absolute_error)
# 	26.95s	 = Training   runtime
# 	0.32s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r51_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-174.7367	 = Validation score   (-mean_absolute_error)
# 	29.21s	 = Training   runtime
# 	0.46s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r82_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-193.1284	 = Validation score   (-mean_absolute_error)
# 	51.16s	 = Training   runtime
# 	0.84s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r121_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-200.5909	 = Validation score   (-mean_absolute_error)
# 	63.5s	 = Training   runtime
# 	0.53s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r145_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-184.4551	 = Validation score   (-mean_absolute_error)
# 	125.32s	 = Training   runtime
# 	0.94s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r173_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-193.2359	 = Validation score   (-mean_absolute_error)
# 	125.85s	 = Training   runtime
# 	1.5s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r128_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-195.0036	 = Validation score   (-mean_absolute_error)
# 	124.17s	 = Training   runtime
# 	1.72s	 = Validation runtime
# Fitting model: CatBoost_r16_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-174.7286	 = Validation score   (-mean_absolute_error)
# 	448.1s	 = Training   runtime
# 	0.41s	 = Validation runtime
# Fitting model: CatBoost_r42_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-181.0501	 = Validation score   (-mean_absolute_error)
# 	349.69s	 = Training   runtime
# 	0.34s	 = Validation runtime
# Fitting model: CatBoost_r93_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-172.0806	 = Validation score   (-mean_absolute_error)
# 	398.79s	 = Training   runtime
# 	0.4s	 = Validation runtime
# Fitting model: CatBoost_r44_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-169.0984	 = Validation score   (-mean_absolute_error)
# 	655.41s	 = Training   runtime
# 	0.34s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-159.6058	 = Validation score   (-mean_absolute_error)
# 	172.49s	 = Training   runtime
# 	332.58s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-152.0055	 = Validation score   (-mean_absolute_error)
# 	0.7s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 27 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-152.8517	 = Validation score   (-mean_absolute_error)
# 	9.36s	 = Training   runtime
# 	1.36s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-150.4013	 = Validation score   (-mean_absolute_error)
# 	8.74s	 = Training   runtime
# 	0.91s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ...
# 	-148.9217	 = Validation score   (-mean_absolute_error)
# 	144.1s	 = Training   runtime
# 	1.56s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-150.856	 = Validation score   (-mean_absolute_error)
# 	46.63s	 = Training   runtime
# 	0.34s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ...
# 	-148.6735	 = Validation score   (-mean_absolute_error)
# 	26.92s	 = Training   runtime
# 	2.09s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-147.8429	 = Validation score   (-mean_absolute_error)
# 	64.2s	 = Training   runtime
# 	0.92s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-149.3748	 = Validation score   (-mean_absolute_error)
# 	17.83s	 = Training   runtime
# 	0.27s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-149.7117	 = Validation score   (-mean_absolute_error)
# 	77.08s	 = Training   runtime
# 	0.78s	 = Validation runtime
# Fitting model: ExtraTrees_r19_BAG_L2 ...
# 	-148.6098	 = Validation score   (-mean_absolute_error)
# 	11.76s	 = Training   runtime
# 	1.76s	 = Validation runtime
# Fitting model: RandomForest_r5_BAG_L2 ...
# 	-147.3598	 = Validation score   (-mean_absolute_error)
# 	65.62s	 = Training   runtime
# 	1.37s	 = Validation runtime
# Fitting model: LightGBM_r158_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-152.2775	 = Validation score   (-mean_absolute_error)
# 	7.24s	 = Training   runtime
# 	0.63s	 = Validation runtime
# Fitting model: LightGBM_r118_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-151.4116	 = Validation score   (-mean_absolute_error)
# 	22.66s	 = Training   runtime
# 	3.59s	 = Validation runtime
# Fitting model: LightGBM_r97_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-152.933	 = Validation score   (-mean_absolute_error)
# 	25.14s	 = Training   runtime
# 	4.93s	 = Validation runtime
# Fitting model: LightGBM_r71_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-153.7799	 = Validation score   (-mean_absolute_error)
# 	60.56s	 = Training   runtime
# 	37.49s	 = Validation runtime
# Fitting model: LightGBM_r111_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-149.4732	 = Validation score   (-mean_absolute_error)
# 	37.88s	 = Training   runtime
# 	5.03s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r25_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-153.5627	 = Validation score   (-mean_absolute_error)
# 	40.3s	 = Training   runtime
# 	0.59s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r51_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-148.9158	 = Validation score   (-mean_absolute_error)
# 	39.18s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r82_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-150.8271	 = Validation score   (-mean_absolute_error)
# 	50.12s	 = Training   runtime
# 	0.27s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r121_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-154.0346	 = Validation score   (-mean_absolute_error)
# 	51.18s	 = Training   runtime
# 	0.61s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r145_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-151.6749	 = Validation score   (-mean_absolute_error)
# 	90.42s	 = Training   runtime
# 	0.93s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r173_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-155.6299	 = Validation score   (-mean_absolute_error)
# 	76.49s	 = Training   runtime
# 	0.81s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r128_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-158.1718	 = Validation score   (-mean_absolute_error)
# 	102.91s	 = Training   runtime
# 	0.76s	 = Validation runtime
# Fitting model: CatBoost_r16_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-151.3029	 = Validation score   (-mean_absolute_error)
# 	52.12s	 = Training   runtime
# 	0.24s	 = Validation runtime
# Fitting model: CatBoost_r42_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-150.8428	 = Validation score   (-mean_absolute_error)
# 	52.22s	 = Training   runtime
# 	0.37s	 = Validation runtime
# Fitting model: CatBoost_r93_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-150.3327	 = Validation score   (-mean_absolute_error)
# 	189.1s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: CatBoost_r44_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-151.02	 = Validation score   (-mean_absolute_error)
# 	167.18s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-150.0968	 = Validation score   (-mean_absolute_error)
# 	13.5s	 = Training   runtime
# 	1.14s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ...
# 	-144.7578	 = Validation score   (-mean_absolute_error)
# 	0.67s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 6133.97s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("ag_148_one_hot_experimentalA")

# %%
predictor2 = TabularPredictor(label="pv_measurement", 
                              eval_metric='mean_absolute_error',
                              path= DEFAULT_PATH+"B"
                              ).fit(
    train2,

    presets='experimental_zeroshot_hpo_hybrid', 
    # hyperparameters='very_large', 
    # time_limit=6000,
    # tuning_data = tuning2,
    # use_bag_holdout=True,
    # num_bag_folds= 6,
    # refit_full = True,
    # auto_stack = True,
    # num_bag_sets= 10,
    # set_best_to_refit_full= True,
    # num_stack_levels = 2,
    # verbosity = 3
    )

# tuning_data
# num bag holdout 6
# bag_holdout
# Out:
# Presets specified: ['experimental_zeroshot_hpo_hybrid']
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/core/utils/utils.py:564: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Beginning AutoGluon training ...
# AutoGluon will save models to "ag_148_one_hot_experimentalB"
# AutoGluon Version:  0.8.2
# Python Version:     3.10.12
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 23.0.0: Fri Sep 15 14:41:43 PDT 2023; root:xnu-10002.1.13~1/RELEASE_ARM64_T6000
# Disk Space Avail:   21.57 GB / 494.38 GB (4.4%)
# Train Data Rows:    32844
# Train Data Columns: 49
# Label Column: pv_measurement
# Preprocessing data ...
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/core/utils/utils.py:564: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (1152.3, 0.0, 96.82478, 193.94649)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/learner/default_learner.py:215: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    7074.22 MB
# 	Train Data (Original)  Memory Usage: 6.96 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 2 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 49 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 47 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 		('int', ['bool']) :  2 | ['elevation:m', 'snow_density:kgm3']
# 	0.2s = Fit runtime
# 	49 features in original data used to generate 49 features in processed data.
# 	Train Data (Processed) Memory Usage: 6.77 MB (0.1% of available memory)
# Data preprocessing and feature engineering runtime = 0.24s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}, {'min_samples_leaf': 1, 'max_leaf_nodes': 15000, 'max_features': 0.5, 'ag_args': {'name_suffix': '_r19', 'priority': 20}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}, {'min_samples_leaf': 5, 'max_leaf_nodes': 50000, 'max_features': 0.5, 'ag_args': {'name_suffix': '_r5', 'priority': 19}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge', {'extra_trees': False, 'feature_fraction': 0.7248284762542815, 'learning_rate': 0.07947286942946127, 'min_data_in_leaf': 50, 'num_leaves': 89, 'ag_args': {'name_suffix': '_r158', 'priority': 18}}, {'extra_trees': True, 'feature_fraction': 0.7832570544199176, 'learning_rate': 0.021720607471727896, 'min_data_in_leaf': 3, 'num_leaves': 21, 'ag_args': {'name_suffix': '_r118', 'priority': 17}}, {'extra_trees': True, 'feature_fraction': 0.7113010892989156, 'learning_rate': 0.012535427424259274, 'min_data_in_leaf': 16, 'num_leaves': 48, 'ag_args': {'name_suffix': '_r97', 'priority': 16}}, {'extra_trees': True, 'feature_fraction': 0.45555769907110816, 'learning_rate': 0.009591347321206594, 'min_data_in_leaf': 50, 'num_leaves': 110, 'ag_args': {'name_suffix': '_r71', 'priority': 15}}, {'extra_trees': False, 'feature_fraction': 0.40979710161022476, 'learning_rate': 0.008708890211023034, 'min_data_in_leaf': 3, 'num_leaves': 80, 'ag_args': {'name_suffix': '_r111', 'priority': 14}}],
# 	'XGB': {},
# 	'FASTAI': [{}, {'bs': 1024, 'emb_drop': 0.6167722379778131, 'epochs': 44, 'layers': [200, 100, 50], 'lr': 0.053440377855629266, 'ps': 0.48477211305443607, 'ag_args': {'name_suffix': '_r25', 'priority': 13}}, {'bs': 1024, 'emb_drop': 0.6046989241462619, 'epochs': 48, 'layers': [200, 100, 50], 'lr': 0.00775309042164966, 'ps': 0.09244767444160731, 'ag_args': {'name_suffix': '_r51', 'priority': 12}}, {'bs': 512, 'emb_drop': 0.6557225316526186, 'epochs': 49, 'layers': [200, 100], 'lr': 0.023627682025564638, 'ps': 0.519566584552178, 'ag_args': {'name_suffix': '_r82', 'priority': 11}}, {'bs': 2048, 'emb_drop': 0.4066210919034579, 'epochs': 43, 'layers': [400, 200], 'lr': 0.0029598312717673434, 'ps': 0.4378695797438974, 'ag_args': {'name_suffix': '_r121', 'priority': 10}}, {'bs': 128, 'emb_drop': 0.44339037504795686, 'epochs': 31, 'layers': [400, 200, 100], 'lr': 0.008615195908919904, 'ps': 0.19220253419114286, 'ag_args': {'name_suffix': '_r145', 'priority': 9}}, {'bs': 128, 'emb_drop': 0.12106594798980945, 'epochs': 38, 'layers': [200, 100, 50], 'lr': 0.037991970245029975, 'ps': 0.33120008492595093, 'ag_args': {'name_suffix': '_r173', 'priority': 8}}, {'bs': 128, 'emb_drop': 0.4599138419358, 'epochs': 47, 'layers': [200, 100], 'lr': 0.03888383281136287, 'ps': 0.28193673177122863, 'ag_args': {'name_suffix': '_r128', 'priority': 7}}],
# 	'CAT': [{}, {'depth': 5, 'l2_leaf_reg': 4.774992314058497, 'learning_rate': 0.038551267822920274, 'ag_args': {'name_suffix': '_r16', 'priority': 6}}, {'depth': 4, 'l2_leaf_reg': 1.9950125740798321, 'learning_rate': 0.028091050379971633, 'ag_args': {'name_suffix': '_r42', 'priority': 5}}, {'depth': 6, 'l2_leaf_reg': 1.8298803017644376, 'learning_rate': 0.017844259810823604, 'ag_args': {'name_suffix': '_r93', 'priority': 4}}, {'depth': 7, 'l2_leaf_reg': 4.81099604606794, 'learning_rate': 0.019085060180573103, 'ag_args': {'name_suffix': '_r44', 'priority': 3}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 29 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ...
# 	-52.0461	 = Validation score   (-mean_absolute_error)
# 	0.02s	 = Training   runtime
# 	1.1s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ...
# 	-51.9444	 = Validation score   (-mean_absolute_error)
# 	0.02s	 = Training   runtime
# 	1.3s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-26.7658	 = Validation score   (-mean_absolute_error)
# 	42.9s	 = Training   runtime
# 	86.66s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-26.7858	 = Validation score   (-mean_absolute_error)
# 	59.3s	 = Training   runtime
# 	86.42s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ...
# 	-30.9165	 = Validation score   (-mean_absolute_error)
# 	44.13s	 = Training   runtime
# 	0.91s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-28.3125	 = Validation score   (-mean_absolute_error)
# 	315.89s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ...
# 	-32.9862	 = Validation score   (-mean_absolute_error)
# 	6.81s	 = Training   runtime
# 	1.01s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-36.3366	 = Validation score   (-mean_absolute_error)
# 	33.77s	 = Training   runtime
# 	0.52s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-29.5025	 = Validation score   (-mean_absolute_error)
# 	305.06s	 = Training   runtime
# 	81.32s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-31.1171	 = Validation score   (-mean_absolute_error)
# 	108.79s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: ExtraTrees_r19_BAG_L1 ...
# 	-33.9815	 = Validation score   (-mean_absolute_error)
# 	2.41s	 = Training   runtime
# 	0.89s	 = Validation runtime
# Fitting model: RandomForest_r5_BAG_L1 ...
# 	-33.0964	 = Validation score   (-mean_absolute_error)
# 	10.42s	 = Training   runtime
# 	0.73s	 = Validation runtime
# Fitting model: LightGBM_r158_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-27.3308	 = Validation score   (-mean_absolute_error)
# 	64.64s	 = Training   runtime
# 	242.94s	 = Validation runtime
# Fitting model: LightGBM_r118_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-28.762	 = Validation score   (-mean_absolute_error)
# 	20.96s	 = Training   runtime
# 	37.35s	 = Validation runtime
# Fitting model: LightGBM_r97_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-28.3083	 = Validation score   (-mean_absolute_error)
# 	30.27s	 = Training   runtime
# 	98.18s	 = Validation runtime
# Fitting model: LightGBM_r71_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-29.9758	 = Validation score   (-mean_absolute_error)
# 	61.7s	 = Training   runtime
# 	269.1s	 = Validation runtime
# Fitting model: LightGBM_r111_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-25.9197	 = Validation score   (-mean_absolute_error)
# 	50.51s	 = Training   runtime
# 	134.43s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r25_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-38.7085	 = Validation score   (-mean_absolute_error)
# 	15.64s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r51_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-32.1292	 = Validation score   (-mean_absolute_error)
# 	16.99s	 = Training   runtime
# 	0.22s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r82_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-39.4462	 = Validation score   (-mean_absolute_error)
# 	20.29s	 = Training   runtime
# 	0.22s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r121_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-41.2237	 = Validation score   (-mean_absolute_error)
# 	28.5s	 = Training   runtime
# 	0.32s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r145_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-35.6366	 = Validation score   (-mean_absolute_error)
# 	49.05s	 = Training   runtime
# 	0.58s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r173_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-38.9698	 = Validation score   (-mean_absolute_error)
# 	40.12s	 = Training   runtime
# 	0.42s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r128_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-41.001	 = Validation score   (-mean_absolute_error)
# 	46.47s	 = Training   runtime
# 	0.39s	 = Validation runtime
# Fitting model: CatBoost_r16_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-30.6773	 = Validation score   (-mean_absolute_error)
# 	171.37s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: CatBoost_r42_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-33.5453	 = Validation score   (-mean_absolute_error)
# 	146.16s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: CatBoost_r93_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-30.0244	 = Validation score   (-mean_absolute_error)
# 	211.34s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: CatBoost_r44_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-28.5123	 = Validation score   (-mean_absolute_error)
# 	343.18s	 = Training   runtime
# 	0.39s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-25.2206	 = Validation score   (-mean_absolute_error)
# 	138.78s	 = Training   runtime
# 	266.6s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-25.0048	 = Validation score   (-mean_absolute_error)
# 	0.79s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 27 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.4241	 = Validation score   (-mean_absolute_error)
# 	22.92s	 = Training   runtime
# 	3.11s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.9679	 = Validation score   (-mean_absolute_error)
# 	11.4s	 = Training   runtime
# 	0.81s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ...
# 	-20.99	 = Validation score   (-mean_absolute_error)
# 	130.05s	 = Training   runtime
# 	1.17s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.1999	 = Validation score   (-mean_absolute_error)
# 	78.52s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ...
# 	-21.0349	 = Validation score   (-mean_absolute_error)
# 	11.5s	 = Training   runtime
# 	1.23s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.3485	 = Validation score   (-mean_absolute_error)
# 	31.85s	 = Training   runtime
# 	0.48s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.6449	 = Validation score   (-mean_absolute_error)
# 	8.9s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.4839	 = Validation score   (-mean_absolute_error)
# 	80.55s	 = Training   runtime
# 	0.68s	 = Validation runtime
# Fitting model: ExtraTrees_r19_BAG_L2 ...
# 	-21.2287	 = Validation score   (-mean_absolute_error)
# 	5.13s	 = Training   runtime
# 	1.0s	 = Validation runtime
# Fitting model: RandomForest_r5_BAG_L2 ...
# 	-20.8062	 = Validation score   (-mean_absolute_error)
# 	38.73s	 = Training   runtime
# 	1.04s	 = Validation runtime
# Fitting model: LightGBM_r158_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.9524	 = Validation score   (-mean_absolute_error)
# 	5.6s	 = Training   runtime
# 	0.65s	 = Validation runtime
# Fitting model: LightGBM_r118_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.9781	 = Validation score   (-mean_absolute_error)
# 	36.69s	 = Training   runtime
# 	21.47s	 = Validation runtime
# Fitting model: LightGBM_r97_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.2559	 = Validation score   (-mean_absolute_error)
# 	41.59s	 = Training   runtime
# 	53.86s	 = Validation runtime
# Fitting model: LightGBM_r71_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.4838	 = Validation score   (-mean_absolute_error)
# 	112.03s	 = Training   runtime
# 	111.62s	 = Validation runtime
# Fitting model: LightGBM_r111_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.247	 = Validation score   (-mean_absolute_error)
# 	172.1s	 = Training   runtime
# 	264.8s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r25_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.9683	 = Validation score   (-mean_absolute_error)
# 	48.87s	 = Training   runtime
# 	0.73s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r51_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.0298	 = Validation score   (-mean_absolute_error)
# 	53.86s	 = Training   runtime
# 	0.73s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r82_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.5834	 = Validation score   (-mean_absolute_error)
# 	62.21s	 = Training   runtime
# 	0.8s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r121_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-23.5802	 = Validation score   (-mean_absolute_error)
# 	74.45s	 = Training   runtime
# 	0.81s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r145_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.1652	 = Validation score   (-mean_absolute_error)
# 	130.4s	 = Training   runtime
# 	1.66s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r173_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-23.9172	 = Validation score   (-mean_absolute_error)
# 	108.22s	 = Training   runtime
# 	1.19s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r128_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-24.5821	 = Validation score   (-mean_absolute_error)
# 	108.99s	 = Training   runtime
# 	1.04s	 = Validation runtime
# Fitting model: CatBoost_r16_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.2904	 = Validation score   (-mean_absolute_error)
# 	214.21s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: CatBoost_r42_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.4317	 = Validation score   (-mean_absolute_error)
# 	179.58s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: CatBoost_r93_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.0461	 = Validation score   (-mean_absolute_error)
# 	463.61s	 = Training   runtime
# 	0.36s	 = Validation runtime
# Fitting model: CatBoost_r44_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.9623	 = Validation score   (-mean_absolute_error)
# 	689.08s	 = Training   runtime
# 	0.4s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.4604	 = Validation score   (-mean_absolute_error)
# 	156.42s	 = Training   runtime
# 	38.76s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ...
# 	-20.3871	 = Validation score   (-mean_absolute_error)
# 	0.76s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 5892.9s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("ag_148_one_hot_experimentalB")

# %%
predictor3 = TabularPredictor(label="pv_measurement", 
                              eval_metric='mean_absolute_error',
                              path= DEFAULT_PATH+"C"
                              ).fit(
    train3,

    presets='experimental_zeroshot_hpo_hybrid', 
    # hyperparameters='very_large', 
    # time_limit=6000,
    # tuning_data = tuning3,
    # use_bag_holdout=True,
    # num_bag_folds= 6,
    # refit_full = True,
    # auto_stack = True,
    # num_bag_sets= 10,
    # set_best_to_refit_full= True,
    # num_stack_levels = 2,
    # verbosity = 3
    )
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="ag_148_one_hot_experimentalC"
# Presets specified: ['experimental_zeroshot_hpo_hybrid']
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/core/utils/utils.py:564: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Beginning AutoGluon training ...
# AutoGluon will save models to "ag_148_one_hot_experimentalC"
# AutoGluon Version:  0.8.2
# Python Version:     3.10.12
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 23.0.0: Fri Sep 15 14:41:43 PDT 2023; root:xnu-10002.1.13~1/RELEASE_ARM64_T6000
# Disk Space Avail:   2.34 GB / 494.38 GB (0.5%)
# 	WARNING: Available disk space is low and there is a risk that AutoGluon will run out of disk during fit, causing an exception.
# 	We recommend a minimum available disk space of 10 GB, and large datasets may require more.
# Train Data Rows:    26095
# Train Data Columns: 49
# Label Column: pv_measurement
# Preprocessing data ...
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/core/utils/utils.py:564: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and label-values can't be converted to int).
# 	Label info (max, min, mean, stddev): (999.6, 0.0, 77.63106, 165.81688)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/learner/default_learner.py:215: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    6229.73 MB
# 	Train Data (Original)  Memory Usage: 5.53 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 3 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Unused Original Features (Count: 1): ['snow_drift:idx']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('float', []) : 1 | ['snow_drift:idx']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 48 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 46 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 		('int', ['bool']) :  2 | ['elevation:m', 'snow_density:kgm3']
# 	0.5s = Fit runtime
# 	48 features in original data used to generate 48 features in processed data.
# 	Train Data (Processed) Memory Usage: 5.27 MB (0.1% of available memory)
# Data preprocessing and feature engineering runtime = 0.53s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}, {'min_samples_leaf': 1, 'max_leaf_nodes': 15000, 'max_features': 0.5, 'ag_args': {'name_suffix': '_r19', 'priority': 20}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}, {'min_samples_leaf': 5, 'max_leaf_nodes': 50000, 'max_features': 0.5, 'ag_args': {'name_suffix': '_r5', 'priority': 19}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge', {'extra_trees': False, 'feature_fraction': 0.7248284762542815, 'learning_rate': 0.07947286942946127, 'min_data_in_leaf': 50, 'num_leaves': 89, 'ag_args': {'name_suffix': '_r158', 'priority': 18}}, {'extra_trees': True, 'feature_fraction': 0.7832570544199176, 'learning_rate': 0.021720607471727896, 'min_data_in_leaf': 3, 'num_leaves': 21, 'ag_args': {'name_suffix': '_r118', 'priority': 17}}, {'extra_trees': True, 'feature_fraction': 0.7113010892989156, 'learning_rate': 0.012535427424259274, 'min_data_in_leaf': 16, 'num_leaves': 48, 'ag_args': {'name_suffix': '_r97', 'priority': 16}}, {'extra_trees': True, 'feature_fraction': 0.45555769907110816, 'learning_rate': 0.009591347321206594, 'min_data_in_leaf': 50, 'num_leaves': 110, 'ag_args': {'name_suffix': '_r71', 'priority': 15}}, {'extra_trees': False, 'feature_fraction': 0.40979710161022476, 'learning_rate': 0.008708890211023034, 'min_data_in_leaf': 3, 'num_leaves': 80, 'ag_args': {'name_suffix': '_r111', 'priority': 14}}],
# 	'XGB': {},
# 	'FASTAI': [{}, {'bs': 1024, 'emb_drop': 0.6167722379778131, 'epochs': 44, 'layers': [200, 100, 50], 'lr': 0.053440377855629266, 'ps': 0.48477211305443607, 'ag_args': {'name_suffix': '_r25', 'priority': 13}}, {'bs': 1024, 'emb_drop': 0.6046989241462619, 'epochs': 48, 'layers': [200, 100, 50], 'lr': 0.00775309042164966, 'ps': 0.09244767444160731, 'ag_args': {'name_suffix': '_r51', 'priority': 12}}, {'bs': 512, 'emb_drop': 0.6557225316526186, 'epochs': 49, 'layers': [200, 100], 'lr': 0.023627682025564638, 'ps': 0.519566584552178, 'ag_args': {'name_suffix': '_r82', 'priority': 11}}, {'bs': 2048, 'emb_drop': 0.4066210919034579, 'epochs': 43, 'layers': [400, 200], 'lr': 0.0029598312717673434, 'ps': 0.4378695797438974, 'ag_args': {'name_suffix': '_r121', 'priority': 10}}, {'bs': 128, 'emb_drop': 0.44339037504795686, 'epochs': 31, 'layers': [400, 200, 100], 'lr': 0.008615195908919904, 'ps': 0.19220253419114286, 'ag_args': {'name_suffix': '_r145', 'priority': 9}}, {'bs': 128, 'emb_drop': 0.12106594798980945, 'epochs': 38, 'layers': [200, 100, 50], 'lr': 0.037991970245029975, 'ps': 0.33120008492595093, 'ag_args': {'name_suffix': '_r173', 'priority': 8}}, {'bs': 128, 'emb_drop': 0.4599138419358, 'epochs': 47, 'layers': [200, 100], 'lr': 0.03888383281136287, 'ps': 0.28193673177122863, 'ag_args': {'name_suffix': '_r128', 'priority': 7}}],
# 	'CAT': [{}, {'depth': 5, 'l2_leaf_reg': 4.774992314058497, 'learning_rate': 0.038551267822920274, 'ag_args': {'name_suffix': '_r16', 'priority': 6}}, {'depth': 4, 'l2_leaf_reg': 1.9950125740798321, 'learning_rate': 0.028091050379971633, 'ag_args': {'name_suffix': '_r42', 'priority': 5}}, {'depth': 6, 'l2_leaf_reg': 1.8298803017644376, 'learning_rate': 0.017844259810823604, 'ag_args': {'name_suffix': '_r93', 'priority': 4}}, {'depth': 7, 'l2_leaf_reg': 4.81099604606794, 'learning_rate': 0.019085060180573103, 'ag_args': {'name_suffix': '_r44', 'priority': 3}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 29 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ...
# 	-29.1151	 = Validation score   (-mean_absolute_error)
# 	0.02s	 = Training   runtime
# 	1.0s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ...
# 	-29.0905	 = Validation score   (-mean_absolute_error)
# 	0.02s	 = Training   runtime
# 	1.04s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-16.5668	 = Validation score   (-mean_absolute_error)
# 	53.79s	 = Training   runtime
# 	105.3s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-17.5549	 = Validation score   (-mean_absolute_error)
# 	82.56s	 = Training   runtime
# 	103.54s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ...
# 	-19.7979	 = Validation score   (-mean_absolute_error)
# 	44.51s	 = Training   runtime
# 	1.59s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-18.2756	 = Validation score   (-mean_absolute_error)
# 	507.22s	 = Training   runtime
# 	0.45s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ...
# 	-19.7701	 = Validation score   (-mean_absolute_error)
# 	6.11s	 = Training   runtime
# 	1.23s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-20.2577	 = Validation score   (-mean_absolute_error)
# 	40.48s	 = Training   runtime
# 	0.63s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-18.6633	 = Validation score   (-mean_absolute_error)
# 	379.55s	 = Training   runtime
# 	56.12s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-18.4022	 = Validation score   (-mean_absolute_error)
# 	86.25s	 = Training   runtime
# 	0.42s	 = Validation runtime
# Fitting model: ExtraTrees_r19_BAG_L1 ...
# 	-19.8225	 = Validation score   (-mean_absolute_error)
# 	3.11s	 = Training   runtime
# 	0.91s	 = Validation runtime
# Fitting model: RandomForest_r5_BAG_L1 ...
# 	-20.2592	 = Validation score   (-mean_absolute_error)
# 	14.57s	 = Training   runtime
# 	0.78s	 = Validation runtime
# Fitting model: LightGBM_r158_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-18.9786	 = Validation score   (-mean_absolute_error)
# 	103.85s	 = Training   runtime
# 	121.64s	 = Validation runtime
# Fitting model: LightGBM_r118_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-16.7052	 = Validation score   (-mean_absolute_error)
# 	59.38s	 = Training   runtime
# 	51.79s	 = Validation runtime
# Fitting model: LightGBM_r97_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-16.532	 = Validation score   (-mean_absolute_error)
# 	91.08s	 = Training   runtime
# 	109.84s	 = Validation runtime
# Fitting model: LightGBM_r71_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-17.77	 = Validation score   (-mean_absolute_error)
# 	152.32s	 = Training   runtime
# 	501.33s	 = Validation runtime
# Fitting model: LightGBM_r111_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-16.8703	 = Validation score   (-mean_absolute_error)
# 	179.01s	 = Training   runtime
# 	301.91s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r25_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.5499	 = Validation score   (-mean_absolute_error)
# 	49.47s	 = Training   runtime
# 	0.56s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r51_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.2278	 = Validation score   (-mean_absolute_error)
# 	78.48s	 = Training   runtime
# 	0.72s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r82_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.4307	 = Validation score   (-mean_absolute_error)
# 	75.97s	 = Training   runtime
# 	1.3s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r121_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.8239	 = Validation score   (-mean_absolute_error)
# 	92.62s	 = Training   runtime
# 	0.72s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r145_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-20.3027	 = Validation score   (-mean_absolute_error)
# 	110.24s	 = Training   runtime
# 	1.41s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r173_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.6989	 = Validation score   (-mean_absolute_error)
# 	102.04s	 = Training   runtime
# 	0.88s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r128_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-23.0095	 = Validation score   (-mean_absolute_error)
# 	113.13s	 = Training   runtime
# 	1.39s	 = Validation runtime
# Fitting model: CatBoost_r16_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-18.9365	 = Validation score   (-mean_absolute_error)
# 	555.73s	 = Training   runtime
# 	0.32s	 = Validation runtime
# Fitting model: CatBoost_r42_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.8467	 = Validation score   (-mean_absolute_error)
# 	469.02s	 = Training   runtime
# 	0.63s	 = Validation runtime
# Fitting model: CatBoost_r93_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-18.5379	 = Validation score   (-mean_absolute_error)
# 	622.56s	 = Training   runtime
# 	0.76s	 = Validation runtime
# Fitting model: CatBoost_r44_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy

# %%
test1 = pipin.get_test_data("A")
test2 = pipin.get_test_data("B")
test3 = pipin.get_test_data("C")

# %%
test_data1 = TabularDataset(test1)
test_data2 = TabularDataset(test2)
test_data3 = TabularDataset(test3)

pred1 = pd.DataFrame(predictor1.predict(test_data1))
pred2 = pd.DataFrame(predictor2.predict(test_data2))
pred3 = pd.DataFrame(predictor3.predict(test_data3))

negatives_pred1 = pred1[pred1["pv_measurement"] < 0]
negatives_pred2 = pred2[pred2["pv_measurement"] < 0]
negatives_pred3 = pred3[pred3["pv_measurement"] < 0]
neg = pd.concat([negatives_pred1, negatives_pred2, negatives_pred3])
neg.shape
# Out:
# (71, 1)

# %%
pred = pd.concat([pred1, pred2, pred3])
final_prediction = pipin.post_processing(pred, prediction_column="pv_measurement")
final_prediction.to_csv('gluon_148_experimental_presets.csv')

# %%
diff = pipin.compare_mae(final_prediction)
diff
# Out:
# 50.67033104400012

# %%
# predictor.evaluate(df1, silent=True)
