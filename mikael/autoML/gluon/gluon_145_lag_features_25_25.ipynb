# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from autogluon.tabular import TabularDataset, TabularPredictor
import pandas as pd
import numpy as np

# %%
# %autoreload
from pipeline_lag_features import Pipeline
pipin = Pipeline()

# %%
DEFAULT_PATH = f"ag_145_lag_features_25_25"

# %%
df1_0 = pipin.get_data("A")
df2_0 = pipin.get_data("B")
df3_0 = pipin.get_data("C")

# %%
# remove_consecutive_measurments
df1_0 = pipin.remove_consecutive_measurments(df1_0, 25, 25)
df2_0 = pipin.remove_consecutive_measurments(df2_0, 25, 25)
df3_0 = pipin.remove_consecutive_measurments(df3_0, 25, 25)

# %%
df1_0.head()
# Out:
#    absolute_humidity_2m:gm3  air_density_2m:kgm3  ceiling_height_agl:m  \
# 0                     7.700              1.22825           1728.949951
# 1                     7.700              1.22350           1689.824951
# 2                     7.875              1.21975           1563.224976
# 3                     8.425              1.21800           1283.425049
# 4                     8.950              1.21800           1003.500000
#
#    clear_sky_energy_1h:J  clear_sky_rad:W  cloud_base_agl:m  dew_or_rime:idx  \
# 0               0.000000             0.00       1728.949951              0.0
# 1               0.000000             0.00       1689.824951              0.0
# 2               0.000000             0.00       1563.224976              0.0
# 3             208.649994             0.75       1283.425049              0.0
# 4           32468.150391            23.10       1003.500000              0.0
#
#    dew_point_2m:K  diffuse_rad:W  diffuse_rad_1h:J  ...  \
# 0      280.299988          0.000          0.000000  ...
# 1      280.299988          0.000          0.000000  ...
# 2      280.649994          0.000          0.000000  ...
# 3      281.674988          0.300        526.775024  ...
# 4      282.500000         11.975      22068.949219  ...
#
#    wind_speed_w_1000hPa:ms  estimated  observed  day_of_year  hour  \
# 0                      0.0        0.0       1.0        153.0  22.0
# 1                      0.0        0.0       1.0        153.0  23.0
# 2                      0.0        0.0       1.0        154.0   0.0
# 3                      0.0        0.0       1.0        154.0   1.0
# 4                      0.0        0.0       1.0        154.0   2.0
#
#    clear_sky_energy_1h:J_lag_1  diffuse_rad_1h:J_lag_1  direct_rad_1h:J_lag_1  \
# 0                          NaN                     NaN                    NaN
# 1                     0.000000                0.000000                    0.0
# 2                     0.000000                0.000000                    0.0
# 3                     0.000000                0.000000                    0.0
# 4                   208.649994              526.775024                    0.0
#
#    fresh_snow_1h:cm_lag_1  pv_measurement
# 0                     NaN            0.00
# 1                     0.0            0.00
# 2                     0.0            0.00
# 3                     0.0            0.00
# 4                     0.0           19.36
#
# [5 rows x 54 columns]

# %%
train1 = TabularDataset(df1_0)
train2 = TabularDataset(df2_0)
train3 = TabularDataset(df3_0)

# %%
predictor1 = TabularPredictor(label="pv_measurement",
                              eval_metric='mean_absolute_error',
                              path= DEFAULT_PATH+"A"
                              ).fit(
    train1,
    # time_limit=3600,
    # hyperparameters='extrme', 
    presets='experimental_zeroshot_hpo_hybrid', 
    # tuning_data = tuning1,
    # use_bag_holdout=True,
    # num_bag_folds= 6,
    # refit_full = True,
    # auto_stack = True,
    # num_bag_sets= 10,
    # set_best_to_refit_full= True,
    # num_stack_levels = 2,
    # verbosity = 3
    )
# Out:
# Presets specified: ['experimental_zeroshot_hpo_hybrid']
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/core/utils/utils.py:564: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Beginning AutoGluon training ...
# AutoGluon will save models to "ag_145_lag_features_25_25A"
# AutoGluon Version:  0.8.2
# Python Version:     3.10.12
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 23.0.0: Fri Sep 15 14:41:43 PDT 2023; root:xnu-10002.1.13~1/RELEASE_ARM64_T6000
# Disk Space Avail:   205.10 GB / 494.38 GB (41.5%)
# Train Data Rows:    34043
# Train Data Columns: 53
# Label Column: pv_measurement
# Preprocessing data ...
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/core/utils/utils.py:564: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (5733.42, 0.0, 631.37269, 1166.41088)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/learner/default_learner.py:215: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    4665.45 MB
# 	Train Data (Original)  Memory Usage: 7.76 MB (0.2% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 3 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Unused Original Features (Count: 1): ['snow_drift:idx']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('float', []) : 1 | ['snow_drift:idx']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 52 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 50 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 		('int', ['bool']) :  2 | ['elevation:m', 'snow_density:kgm3']
# 	0.4s = Fit runtime
# 	52 features in original data used to generate 52 features in processed data.
# 	Train Data (Processed) Memory Usage: 7.42 MB (0.2% of available memory)
# Data preprocessing and feature engineering runtime = 0.44s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}, {'min_samples_leaf': 1, 'max_leaf_nodes': 15000, 'max_features': 0.5, 'ag_args': {'name_suffix': '_r19', 'priority': 20}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}, {'min_samples_leaf': 5, 'max_leaf_nodes': 50000, 'max_features': 0.5, 'ag_args': {'name_suffix': '_r5', 'priority': 19}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge', {'extra_trees': False, 'feature_fraction': 0.7248284762542815, 'learning_rate': 0.07947286942946127, 'min_data_in_leaf': 50, 'num_leaves': 89, 'ag_args': {'name_suffix': '_r158', 'priority': 18}}, {'extra_trees': True, 'feature_fraction': 0.7832570544199176, 'learning_rate': 0.021720607471727896, 'min_data_in_leaf': 3, 'num_leaves': 21, 'ag_args': {'name_suffix': '_r118', 'priority': 17}}, {'extra_trees': True, 'feature_fraction': 0.7113010892989156, 'learning_rate': 0.012535427424259274, 'min_data_in_leaf': 16, 'num_leaves': 48, 'ag_args': {'name_suffix': '_r97', 'priority': 16}}, {'extra_trees': True, 'feature_fraction': 0.45555769907110816, 'learning_rate': 0.009591347321206594, 'min_data_in_leaf': 50, 'num_leaves': 110, 'ag_args': {'name_suffix': '_r71', 'priority': 15}}, {'extra_trees': False, 'feature_fraction': 0.40979710161022476, 'learning_rate': 0.008708890211023034, 'min_data_in_leaf': 3, 'num_leaves': 80, 'ag_args': {'name_suffix': '_r111', 'priority': 14}}],
# 	'XGB': {},
# 	'FASTAI': [{}, {'bs': 1024, 'emb_drop': 0.6167722379778131, 'epochs': 44, 'layers': [200, 100, 50], 'lr': 0.053440377855629266, 'ps': 0.48477211305443607, 'ag_args': {'name_suffix': '_r25', 'priority': 13}}, {'bs': 1024, 'emb_drop': 0.6046989241462619, 'epochs': 48, 'layers': [200, 100, 50], 'lr': 0.00775309042164966, 'ps': 0.09244767444160731, 'ag_args': {'name_suffix': '_r51', 'priority': 12}}, {'bs': 512, 'emb_drop': 0.6557225316526186, 'epochs': 49, 'layers': [200, 100], 'lr': 0.023627682025564638, 'ps': 0.519566584552178, 'ag_args': {'name_suffix': '_r82', 'priority': 11}}, {'bs': 2048, 'emb_drop': 0.4066210919034579, 'epochs': 43, 'layers': [400, 200], 'lr': 0.0029598312717673434, 'ps': 0.4378695797438974, 'ag_args': {'name_suffix': '_r121', 'priority': 10}}, {'bs': 128, 'emb_drop': 0.44339037504795686, 'epochs': 31, 'layers': [400, 200, 100], 'lr': 0.008615195908919904, 'ps': 0.19220253419114286, 'ag_args': {'name_suffix': '_r145', 'priority': 9}}, {'bs': 128, 'emb_drop': 0.12106594798980945, 'epochs': 38, 'layers': [200, 100, 50], 'lr': 0.037991970245029975, 'ps': 0.33120008492595093, 'ag_args': {'name_suffix': '_r173', 'priority': 8}}, {'bs': 128, 'emb_drop': 0.4599138419358, 'epochs': 47, 'layers': [200, 100], 'lr': 0.03888383281136287, 'ps': 0.28193673177122863, 'ag_args': {'name_suffix': '_r128', 'priority': 7}}],
# 	'CAT': [{}, {'depth': 5, 'l2_leaf_reg': 4.774992314058497, 'learning_rate': 0.038551267822920274, 'ag_args': {'name_suffix': '_r16', 'priority': 6}}, {'depth': 4, 'l2_leaf_reg': 1.9950125740798321, 'learning_rate': 0.028091050379971633, 'ag_args': {'name_suffix': '_r42', 'priority': 5}}, {'depth': 6, 'l2_leaf_reg': 1.8298803017644376, 'learning_rate': 0.017844259810823604, 'ag_args': {'name_suffix': '_r93', 'priority': 4}}, {'depth': 7, 'l2_leaf_reg': 4.81099604606794, 'learning_rate': 0.019085060180573103, 'ag_args': {'name_suffix': '_r44', 'priority': 3}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 29 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ...
# 	-225.3575	 = Validation score   (-mean_absolute_error)
# 	0.02s	 = Training   runtime
# 	1.05s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ...
# 	-225.3998	 = Validation score   (-mean_absolute_error)
# 	0.02s	 = Training   runtime
# 	1.09s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-154.9427	 = Validation score   (-mean_absolute_error)
# 	41.77s	 = Training   runtime
# 	7106.2s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-163.4463	 = Validation score   (-mean_absolute_error)
# 	70.11s	 = Training   runtime
# 	100.94s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ...
# 	-181.9974	 = Validation score   (-mean_absolute_error)
# 	61.22s	 = Training   runtime
# 	1.47s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-169.8041	 = Validation score   (-mean_absolute_error)
# 	529.87s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ...
# 	-182.045	 = Validation score   (-mean_absolute_error)
# 	8.52s	 = Training   runtime
# 	1.4s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-186.0604	 = Validation score   (-mean_absolute_error)
# 	55.09s	 = Training   runtime
# 	0.83s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-172.767	 = Validation score   (-mean_absolute_error)
# 	515.71s	 = Training   runtime
# 	87.23s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-171.6224	 = Validation score   (-mean_absolute_error)
# 	197.6s	 = Training   runtime
# 	0.93s	 = Validation runtime
# Fitting model: ExtraTrees_r19_BAG_L1 ...
# 	-182.8486	 = Validation score   (-mean_absolute_error)
# 	7.98s	 = Training   runtime
# 	2.14s	 = Validation runtime
# Fitting model: RandomForest_r5_BAG_L1 ...
# 	-183.4546	 = Validation score   (-mean_absolute_error)
# 	35.08s	 = Training   runtime
# 	1.9s	 = Validation runtime
# Fitting model: LightGBM_r158_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-165.7654	 = Validation score   (-mean_absolute_error)
# 	268.47s	 = Training   runtime
# 	333.23s	 = Validation runtime
# Fitting model: LightGBM_r118_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-157.5423	 = Validation score   (-mean_absolute_error)
# 	63.26s	 = Training   runtime
# 	71.83s	 = Validation runtime
# Fitting model: LightGBM_r97_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-155.9707	 = Validation score   (-mean_absolute_error)
# 	133.83s	 = Training   runtime
# 	162.12s	 = Validation runtime
# Fitting model: LightGBM_r71_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-163.2928	 = Validation score   (-mean_absolute_error)
# 	207.46s	 = Training   runtime
# 	415.89s	 = Validation runtime
# Fitting model: LightGBM_r111_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-158.3538	 = Validation score   (-mean_absolute_error)
# 	191.06s	 = Training   runtime
# 	206.34s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r25_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-189.4676	 = Validation score   (-mean_absolute_error)
# 	61.91s	 = Training   runtime
# 	0.68s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r51_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-174.5808	 = Validation score   (-mean_absolute_error)
# 	66.64s	 = Training   runtime
# 	0.72s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r82_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-190.6352	 = Validation score   (-mean_absolute_error)
# 	75.15s	 = Training   runtime
# 	0.81s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r121_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-197.3969	 = Validation score   (-mean_absolute_error)
# 	95.6s	 = Training   runtime
# 	0.96s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r145_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-186.0437	 = Validation score   (-mean_absolute_error)
# 	171.65s	 = Training   runtime
# 	2.12s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r173_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-191.1131	 = Validation score   (-mean_absolute_error)
# 	151.27s	 = Training   runtime
# 	1.47s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r128_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-194.0123	 = Validation score   (-mean_absolute_error)
# 	167.35s	 = Training   runtime
# 	1.56s	 = Validation runtime
# Fitting model: CatBoost_r16_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-175.4939	 = Validation score   (-mean_absolute_error)
# 	644.35s	 = Training   runtime
# 	0.39s	 = Validation runtime
# Fitting model: CatBoost_r42_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-181.2895	 = Validation score   (-mean_absolute_error)
# 	552.97s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: CatBoost_r93_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-172.455	 = Validation score   (-mean_absolute_error)
# 	807.69s	 = Training   runtime
# 	0.44s	 = Validation runtime
# Fitting model: CatBoost_r44_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-169.3029	 = Validation score   (-mean_absolute_error)
# 	1001.21s	 = Training   runtime
# 	0.62s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-159.5014	 = Validation score   (-mean_absolute_error)
# 	378.96s	 = Training   runtime
# 	340.63s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-151.8656	 = Validation score   (-mean_absolute_error)
# 	1.64s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 27 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-152.0914	 = Validation score   (-mean_absolute_error)
# 	12.15s	 = Training   runtime
# 	1.72s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-149.8358	 = Validation score   (-mean_absolute_error)
# 	12.35s	 = Training   runtime
# 	0.99s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ...
# 	-148.5831	 = Validation score   (-mean_absolute_error)
# 	231.83s	 = Training   runtime
# 	2.44s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-150.6487	 = Validation score   (-mean_absolute_error)
# 	51.86s	 = Training   runtime
# 	0.22s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ...
# 	-148.5508	 = Validation score   (-mean_absolute_error)
# 	26.39s	 = Training   runtime
# 	2.56s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-146.917	 = Validation score   (-mean_absolute_error)
# 	80.28s	 = Training   runtime
# 	1.44s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-150.0558	 = Validation score   (-mean_absolute_error)
# 	20.83s	 = Training   runtime
# 	0.46s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-149.363	 = Validation score   (-mean_absolute_error)
# 	147.24s	 = Training   runtime
# 	1.37s	 = Validation runtime
# Fitting model: ExtraTrees_r19_BAG_L2 ...
# 	-149.0555	 = Validation score   (-mean_absolute_error)
# 	13.71s	 = Training   runtime
# 	2.41s	 = Validation runtime
# Fitting model: RandomForest_r5_BAG_L2 ...
# 	-146.7789	 = Validation score   (-mean_absolute_error)
# 	65.83s	 = Training   runtime
# 	2.14s	 = Validation runtime
# Fitting model: LightGBM_r158_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-151.6212	 = Validation score   (-mean_absolute_error)
# 	11.93s	 = Training   runtime
# 	0.98s	 = Validation runtime
# Fitting model: LightGBM_r118_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-150.9204	 = Validation score   (-mean_absolute_error)
# 	27.36s	 = Training   runtime
# 	5.07s	 = Validation runtime
# Fitting model: LightGBM_r97_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-152.6335	 = Validation score   (-mean_absolute_error)
# 	34.83s	 = Training   runtime
# 	7.12s	 = Validation runtime
# Fitting model: LightGBM_r71_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-153.6409	 = Validation score   (-mean_absolute_error)
# 	84.97s	 = Training   runtime
# 	31.31s	 = Validation runtime
# Fitting model: LightGBM_r111_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-149.2474	 = Validation score   (-mean_absolute_error)
# 	39.61s	 = Training   runtime
# 	4.56s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r25_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-149.7366	 = Validation score   (-mean_absolute_error)
# 	998.37s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r51_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-149.2741	 = Validation score   (-mean_absolute_error)
# 	19.91s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r82_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-148.634	 = Validation score   (-mean_absolute_error)
# 	43.77s	 = Training   runtime
# 	0.47s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r121_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-155.3044	 = Validation score   (-mean_absolute_error)
# 	68.35s	 = Training   runtime
# 	0.89s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r145_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-150.5064	 = Validation score   (-mean_absolute_error)
# 	137.37s	 = Training   runtime
# 	1.82s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r173_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-155.8451	 = Validation score   (-mean_absolute_error)
# 	119.1s	 = Training   runtime
# 	1.26s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r128_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-157.9527	 = Validation score   (-mean_absolute_error)
# 	139.69s	 = Training   runtime
# 	1.29s	 = Validation runtime
# Fitting model: CatBoost_r16_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-150.5577	 = Validation score   (-mean_absolute_error)
# 	52.01s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: CatBoost_r42_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-150.3679	 = Validation score   (-mean_absolute_error)
# 	55.88s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: CatBoost_r93_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-149.7934	 = Validation score   (-mean_absolute_error)
# 	177.79s	 = Training   runtime
# 	0.22s	 = Validation runtime
# Fitting model: CatBoost_r44_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-150.1585	 = Validation score   (-mean_absolute_error)
# 	181.29s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-150.0986	 = Validation score   (-mean_absolute_error)
# 	24.78s	 = Training   runtime
# 	2.0s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ...
# 	-144.661	 = Validation score   (-mean_absolute_error)
# 	1.14s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 10772.57s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("ag_145_lag_features_25_25A")

# %%
predictor2 = TabularPredictor(label="pv_measurement", 
                              eval_metric='mean_absolute_error',
                              path= DEFAULT_PATH+"B"
                              ).fit(
    train2,
    # time_limit=3600,
    presets='experimental_zeroshot_hpo_hybrid', 
    # hyperparameters='very_large', 
    # tuning_data = tuning2,
    # use_bag_holdout=True,
    # num_bag_folds= 6,
    # refit_full = True,
    # auto_stack = True,
    # num_bag_sets= 10,
    # set_best_to_refit_full= True,
    # num_stack_levels = 2,
    # verbosity = 3
    )

# tuning_data
# num bag holdout 6
# bag_holdout
# Out:
# Presets specified: ['experimental_zeroshot_hpo_hybrid']
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/core/utils/utils.py:564: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Beginning AutoGluon training ...
# AutoGluon will save models to "ag_145_lag_features_25_25B"
# AutoGluon Version:  0.8.2
# Python Version:     3.10.12
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 23.0.0: Fri Sep 15 14:41:43 PDT 2023; root:xnu-10002.1.13~1/RELEASE_ARM64_T6000
# Disk Space Avail:   184.58 GB / 494.38 GB (37.3%)
# Train Data Rows:    26004
# Train Data Columns: 53
# Label Column: pv_measurement
# Preprocessing data ...
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/core/utils/utils.py:564: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (1152.3, 0.0, 106.84408, 212.27073)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/learner/default_learner.py:215: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    6629.05 MB
# 	Train Data (Original)  Memory Usage: 5.93 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 2 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 53 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 51 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 		('int', ['bool']) :  2 | ['elevation:m', 'snow_density:kgm3']
# 	0.3s = Fit runtime
# 	53 features in original data used to generate 53 features in processed data.
# 	Train Data (Processed) Memory Usage: 5.77 MB (0.1% of available memory)
# Data preprocessing and feature engineering runtime = 0.36s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}, {'min_samples_leaf': 1, 'max_leaf_nodes': 15000, 'max_features': 0.5, 'ag_args': {'name_suffix': '_r19', 'priority': 20}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}, {'min_samples_leaf': 5, 'max_leaf_nodes': 50000, 'max_features': 0.5, 'ag_args': {'name_suffix': '_r5', 'priority': 19}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge', {'extra_trees': False, 'feature_fraction': 0.7248284762542815, 'learning_rate': 0.07947286942946127, 'min_data_in_leaf': 50, 'num_leaves': 89, 'ag_args': {'name_suffix': '_r158', 'priority': 18}}, {'extra_trees': True, 'feature_fraction': 0.7832570544199176, 'learning_rate': 0.021720607471727896, 'min_data_in_leaf': 3, 'num_leaves': 21, 'ag_args': {'name_suffix': '_r118', 'priority': 17}}, {'extra_trees': True, 'feature_fraction': 0.7113010892989156, 'learning_rate': 0.012535427424259274, 'min_data_in_leaf': 16, 'num_leaves': 48, 'ag_args': {'name_suffix': '_r97', 'priority': 16}}, {'extra_trees': True, 'feature_fraction': 0.45555769907110816, 'learning_rate': 0.009591347321206594, 'min_data_in_leaf': 50, 'num_leaves': 110, 'ag_args': {'name_suffix': '_r71', 'priority': 15}}, {'extra_trees': False, 'feature_fraction': 0.40979710161022476, 'learning_rate': 0.008708890211023034, 'min_data_in_leaf': 3, 'num_leaves': 80, 'ag_args': {'name_suffix': '_r111', 'priority': 14}}],
# 	'XGB': {},
# 	'FASTAI': [{}, {'bs': 1024, 'emb_drop': 0.6167722379778131, 'epochs': 44, 'layers': [200, 100, 50], 'lr': 0.053440377855629266, 'ps': 0.48477211305443607, 'ag_args': {'name_suffix': '_r25', 'priority': 13}}, {'bs': 1024, 'emb_drop': 0.6046989241462619, 'epochs': 48, 'layers': [200, 100, 50], 'lr': 0.00775309042164966, 'ps': 0.09244767444160731, 'ag_args': {'name_suffix': '_r51', 'priority': 12}}, {'bs': 512, 'emb_drop': 0.6557225316526186, 'epochs': 49, 'layers': [200, 100], 'lr': 0.023627682025564638, 'ps': 0.519566584552178, 'ag_args': {'name_suffix': '_r82', 'priority': 11}}, {'bs': 2048, 'emb_drop': 0.4066210919034579, 'epochs': 43, 'layers': [400, 200], 'lr': 0.0029598312717673434, 'ps': 0.4378695797438974, 'ag_args': {'name_suffix': '_r121', 'priority': 10}}, {'bs': 128, 'emb_drop': 0.44339037504795686, 'epochs': 31, 'layers': [400, 200, 100], 'lr': 0.008615195908919904, 'ps': 0.19220253419114286, 'ag_args': {'name_suffix': '_r145', 'priority': 9}}, {'bs': 128, 'emb_drop': 0.12106594798980945, 'epochs': 38, 'layers': [200, 100, 50], 'lr': 0.037991970245029975, 'ps': 0.33120008492595093, 'ag_args': {'name_suffix': '_r173', 'priority': 8}}, {'bs': 128, 'emb_drop': 0.4599138419358, 'epochs': 47, 'layers': [200, 100], 'lr': 0.03888383281136287, 'ps': 0.28193673177122863, 'ag_args': {'name_suffix': '_r128', 'priority': 7}}],
# 	'CAT': [{}, {'depth': 5, 'l2_leaf_reg': 4.774992314058497, 'learning_rate': 0.038551267822920274, 'ag_args': {'name_suffix': '_r16', 'priority': 6}}, {'depth': 4, 'l2_leaf_reg': 1.9950125740798321, 'learning_rate': 0.028091050379971633, 'ag_args': {'name_suffix': '_r42', 'priority': 5}}, {'depth': 6, 'l2_leaf_reg': 1.8298803017644376, 'learning_rate': 0.017844259810823604, 'ag_args': {'name_suffix': '_r93', 'priority': 4}}, {'depth': 7, 'l2_leaf_reg': 4.81099604606794, 'learning_rate': 0.019085060180573103, 'ag_args': {'name_suffix': '_r44', 'priority': 3}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 29 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ...
# 	-33.4213	 = Validation score   (-mean_absolute_error)
# 	0.04s	 = Training   runtime
# 	1.25s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ...
# 	-33.331	 = Validation score   (-mean_absolute_error)
# 	0.03s	 = Training   runtime
# 	1.3s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.2807	 = Validation score   (-mean_absolute_error)
# 	73.12s	 = Training   runtime
# 	89.0s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-23.7361	 = Validation score   (-mean_absolute_error)
# 	1040.15s	 = Training   runtime
# 	51.12s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ...
# 	-26.6687	 = Validation score   (-mean_absolute_error)
# 	51.42s	 = Training   runtime
# 	0.95s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-24.3294	 = Validation score   (-mean_absolute_error)
# 	567.98s	 = Training   runtime
# 	0.44s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ...
# 	-26.4675	 = Validation score   (-mean_absolute_error)
# 	9.5s	 = Training   runtime
# 	1.28s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-26.8872	 = Validation score   (-mean_absolute_error)
# 	50.11s	 = Training   runtime
# 	0.87s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-24.9112	 = Validation score   (-mean_absolute_error)
# 	465.76s	 = Training   runtime
# 	57.21s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-25.2429	 = Validation score   (-mean_absolute_error)
# 	145.36s	 = Training   runtime
# 	0.56s	 = Validation runtime
# Fitting model: ExtraTrees_r19_BAG_L1 ...
# 	-26.5891	 = Validation score   (-mean_absolute_error)
# 	5.29s	 = Training   runtime
# 	1.24s	 = Validation runtime
# Fitting model: RandomForest_r5_BAG_L1 ...
# 	-26.9139	 = Validation score   (-mean_absolute_error)
# 	27.26s	 = Training   runtime
# 	1.07s	 = Validation runtime
# Fitting model: LightGBM_r158_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-25.2142	 = Validation score   (-mean_absolute_error)
# 	66.42s	 = Training   runtime
# 	28.4s	 = Validation runtime
# Fitting model: LightGBM_r118_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.3781	 = Validation score   (-mean_absolute_error)
# 	46.98s	 = Training   runtime
# 	39.53s	 = Validation runtime
# Fitting model: LightGBM_r97_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.2146	 = Validation score   (-mean_absolute_error)
# 	87.99s	 = Training   runtime
# 	137.38s	 = Validation runtime
# Fitting model: LightGBM_r71_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-23.5519	 = Validation score   (-mean_absolute_error)
# 	187.65s	 = Training   runtime
# 	346.31s	 = Validation runtime
# Fitting model: LightGBM_r111_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.7477	 = Validation score   (-mean_absolute_error)
# 	188.77s	 = Training   runtime
# 	202.25s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r25_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-28.6885	 = Validation score   (-mean_absolute_error)
# 	57.36s	 = Training   runtime
# 	0.84s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r51_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-25.025	 = Validation score   (-mean_absolute_error)
# 	64.22s	 = Training   runtime
# 	0.93s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r82_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-29.1903	 = Validation score   (-mean_absolute_error)
# 	67.95s	 = Training   runtime
# 	0.71s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r121_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-30.0233	 = Validation score   (-mean_absolute_error)
# 	90.87s	 = Training   runtime
# 	0.84s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r145_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-28.3215	 = Validation score   (-mean_absolute_error)
# 	119.21s	 = Training   runtime
# 	1.16s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r173_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-29.9586	 = Validation score   (-mean_absolute_error)
# 	106.67s	 = Training   runtime
# 	0.88s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r128_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-31.8688	 = Validation score   (-mean_absolute_error)
# 	107.32s	 = Training   runtime
# 	1.14s	 = Validation runtime
# Fitting model: CatBoost_r16_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-25.0836	 = Validation score   (-mean_absolute_error)
# 	536.79s	 = Training   runtime
# 	0.41s	 = Validation runtime
# Fitting model: CatBoost_r42_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-26.0864	 = Validation score   (-mean_absolute_error)
# 	513.39s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: CatBoost_r93_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-24.6618	 = Validation score   (-mean_absolute_error)
# 	1419.16s	 = Training   runtime
# 	0.38s	 = Validation runtime
# Fitting model: CatBoost_r44_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-24.2468	 = Validation score   (-mean_absolute_error)
# 	777.57s	 = Training   runtime
# 	0.37s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-23.4438	 = Validation score   (-mean_absolute_error)
# 	311.52s	 = Training   runtime
# 	204.09s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-21.773	 = Validation score   (-mean_absolute_error)
# 	1.46s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 27 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.2143	 = Validation score   (-mean_absolute_error)
# 	9.21s	 = Training   runtime
# 	1.02s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.843	 = Validation score   (-mean_absolute_error)
# 	8.28s	 = Training   runtime
# 	0.63s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ...
# 	-21.4999	 = Validation score   (-mean_absolute_error)
# 	149.8s	 = Training   runtime
# 	1.53s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.026	 = Validation score   (-mean_absolute_error)
# 	994.78s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ...
# 	-21.4329	 = Validation score   (-mean_absolute_error)
# 	9.62s	 = Training   runtime
# 	0.97s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.272	 = Validation score   (-mean_absolute_error)
# 	28.39s	 = Training   runtime
# 	0.46s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.6856	 = Validation score   (-mean_absolute_error)
# 	8.86s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.0057	 = Validation score   (-mean_absolute_error)
# 	47.29s	 = Training   runtime
# 	0.74s	 = Validation runtime
# Fitting model: ExtraTrees_r19_BAG_L2 ...
# 	-21.4747	 = Validation score   (-mean_absolute_error)
# 	6.85s	 = Training   runtime
# 	1.15s	 = Validation runtime
# Fitting model: RandomForest_r5_BAG_L2 ...
# 	-21.3156	 = Validation score   (-mean_absolute_error)
# 	47.65s	 = Training   runtime
# 	1.06s	 = Validation runtime
# Fitting model: LightGBM_r158_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.1391	 = Validation score   (-mean_absolute_error)
# 	9.0s	 = Training   runtime
# 	0.93s	 = Validation runtime
# Fitting model: LightGBM_r118_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.9876	 = Validation score   (-mean_absolute_error)
# 	19.79s	 = Training   runtime
# 	3.11s	 = Validation runtime
# Fitting model: LightGBM_r97_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.1417	 = Validation score   (-mean_absolute_error)
# 	1041.27s	 = Training   runtime
# 	8.65s	 = Validation runtime
# Fitting model: LightGBM_r71_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.3691	 = Validation score   (-mean_absolute_error)
# 	48.55s	 = Training   runtime
# 	25.6s	 = Validation runtime
# Fitting model: LightGBM_r111_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.5924	 = Validation score   (-mean_absolute_error)
# 	41.2s	 = Training   runtime
# 	4.87s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r25_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.0429	 = Validation score   (-mean_absolute_error)
# 	40.24s	 = Training   runtime
# 	0.67s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r51_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.8657	 = Validation score   (-mean_absolute_error)
# 	46.45s	 = Training   runtime
# 	0.64s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r82_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.9181	 = Validation score   (-mean_absolute_error)
# 	53.59s	 = Training   runtime
# 	0.61s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r121_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.559	 = Validation score   (-mean_absolute_error)
# 	75.45s	 = Training   runtime
# 	0.72s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r145_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.6123	 = Validation score   (-mean_absolute_error)
# 	112.91s	 = Training   runtime
# 	1.37s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r173_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-23.0353	 = Validation score   (-mean_absolute_error)
# 	83.45s	 = Training   runtime
# 	0.86s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r128_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-23.9996	 = Validation score   (-mean_absolute_error)
# 	83.27s	 = Training   runtime
# 	0.76s	 = Validation runtime
# Fitting model: CatBoost_r16_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.0019	 = Validation score   (-mean_absolute_error)
# 	61.49s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: CatBoost_r42_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.9666	 = Validation score   (-mean_absolute_error)
# 	40.55s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: CatBoost_r93_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.8896	 = Validation score   (-mean_absolute_error)
# 	194.28s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: CatBoost_r44_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.0121	 = Validation score   (-mean_absolute_error)
# 	164.72s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.8276	 = Validation score   (-mean_absolute_error)
# 	26.46s	 = Training   runtime
# 	1.59s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ...
# 	-20.8735	 = Validation score   (-mean_absolute_error)
# 	1.19s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 11014.23s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("ag_145_lag_features_25_25B")

# %%
predictor3 = TabularPredictor(label="pv_measurement", 
                              eval_metric='mean_absolute_error',
                              path= DEFAULT_PATH+"C"
                              ).fit(
    train3,
    # time_limit=3600,
    presets='experimental_zeroshot_hpo_hybrid', 
    # hyperparameters='very_large', 
    # tuning_data = tuning3,
    # use_bag_holdout=True,
    # num_bag_folds= 6,
    # refit_full = True,
    # auto_stack = True,
    # num_bag_sets= 10,
    # set_best_to_refit_full= True,
    # num_stack_levels = 2,
    # verbosity = 3
    )
# Out:
# Presets specified: ['experimental_zeroshot_hpo_hybrid']
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/core/utils/utils.py:564: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Beginning AutoGluon training ...
# AutoGluon will save models to "ag_145_lag_features_25_25C"
# AutoGluon Version:  0.8.2
# Python Version:     3.10.12
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 23.0.0: Fri Sep 15 14:41:43 PDT 2023; root:xnu-10002.1.13~1/RELEASE_ARM64_T6000
# Disk Space Avail:   169.50 GB / 494.38 GB (34.3%)
# Train Data Rows:    21169
# Train Data Columns: 53
# Label Column: pv_measurement
# Preprocessing data ...
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/core/utils/utils.py:564: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and label-values can't be converted to int).
# 	Label info (max, min, mean, stddev): (999.6, 0.0, 95.69571, 179.34563)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/learner/default_learner.py:215: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    6164.87 MB
# 	Train Data (Original)  Memory Usage: 4.83 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 3 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Unused Original Features (Count: 1): ['snow_drift:idx']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('float', []) : 1 | ['snow_drift:idx']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 52 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 50 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 		('int', ['bool']) :  2 | ['elevation:m', 'snow_density:kgm3']
# 	0.7s = Fit runtime
# 	52 features in original data used to generate 52 features in processed data.
# 	Train Data (Processed) Memory Usage: 4.61 MB (0.1% of available memory)
# Data preprocessing and feature engineering runtime = 0.74s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}, {'min_samples_leaf': 1, 'max_leaf_nodes': 15000, 'max_features': 0.5, 'ag_args': {'name_suffix': '_r19', 'priority': 20}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}, {'min_samples_leaf': 5, 'max_leaf_nodes': 50000, 'max_features': 0.5, 'ag_args': {'name_suffix': '_r5', 'priority': 19}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge', {'extra_trees': False, 'feature_fraction': 0.7248284762542815, 'learning_rate': 0.07947286942946127, 'min_data_in_leaf': 50, 'num_leaves': 89, 'ag_args': {'name_suffix': '_r158', 'priority': 18}}, {'extra_trees': True, 'feature_fraction': 0.7832570544199176, 'learning_rate': 0.021720607471727896, 'min_data_in_leaf': 3, 'num_leaves': 21, 'ag_args': {'name_suffix': '_r118', 'priority': 17}}, {'extra_trees': True, 'feature_fraction': 0.7113010892989156, 'learning_rate': 0.012535427424259274, 'min_data_in_leaf': 16, 'num_leaves': 48, 'ag_args': {'name_suffix': '_r97', 'priority': 16}}, {'extra_trees': True, 'feature_fraction': 0.45555769907110816, 'learning_rate': 0.009591347321206594, 'min_data_in_leaf': 50, 'num_leaves': 110, 'ag_args': {'name_suffix': '_r71', 'priority': 15}}, {'extra_trees': False, 'feature_fraction': 0.40979710161022476, 'learning_rate': 0.008708890211023034, 'min_data_in_leaf': 3, 'num_leaves': 80, 'ag_args': {'name_suffix': '_r111', 'priority': 14}}],
# 	'XGB': {},
# 	'FASTAI': [{}, {'bs': 1024, 'emb_drop': 0.6167722379778131, 'epochs': 44, 'layers': [200, 100, 50], 'lr': 0.053440377855629266, 'ps': 0.48477211305443607, 'ag_args': {'name_suffix': '_r25', 'priority': 13}}, {'bs': 1024, 'emb_drop': 0.6046989241462619, 'epochs': 48, 'layers': [200, 100, 50], 'lr': 0.00775309042164966, 'ps': 0.09244767444160731, 'ag_args': {'name_suffix': '_r51', 'priority': 12}}, {'bs': 512, 'emb_drop': 0.6557225316526186, 'epochs': 49, 'layers': [200, 100], 'lr': 0.023627682025564638, 'ps': 0.519566584552178, 'ag_args': {'name_suffix': '_r82', 'priority': 11}}, {'bs': 2048, 'emb_drop': 0.4066210919034579, 'epochs': 43, 'layers': [400, 200], 'lr': 0.0029598312717673434, 'ps': 0.4378695797438974, 'ag_args': {'name_suffix': '_r121', 'priority': 10}}, {'bs': 128, 'emb_drop': 0.44339037504795686, 'epochs': 31, 'layers': [400, 200, 100], 'lr': 0.008615195908919904, 'ps': 0.19220253419114286, 'ag_args': {'name_suffix': '_r145', 'priority': 9}}, {'bs': 128, 'emb_drop': 0.12106594798980945, 'epochs': 38, 'layers': [200, 100, 50], 'lr': 0.037991970245029975, 'ps': 0.33120008492595093, 'ag_args': {'name_suffix': '_r173', 'priority': 8}}, {'bs': 128, 'emb_drop': 0.4599138419358, 'epochs': 47, 'layers': [200, 100], 'lr': 0.03888383281136287, 'ps': 0.28193673177122863, 'ag_args': {'name_suffix': '_r128', 'priority': 7}}],
# 	'CAT': [{}, {'depth': 5, 'l2_leaf_reg': 4.774992314058497, 'learning_rate': 0.038551267822920274, 'ag_args': {'name_suffix': '_r16', 'priority': 6}}, {'depth': 4, 'l2_leaf_reg': 1.9950125740798321, 'learning_rate': 0.028091050379971633, 'ag_args': {'name_suffix': '_r42', 'priority': 5}}, {'depth': 6, 'l2_leaf_reg': 1.8298803017644376, 'learning_rate': 0.017844259810823604, 'ag_args': {'name_suffix': '_r93', 'priority': 4}}, {'depth': 7, 'l2_leaf_reg': 4.81099604606794, 'learning_rate': 0.019085060180573103, 'ag_args': {'name_suffix': '_r44', 'priority': 3}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 29 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ...
# 	-30.4818	 = Validation score   (-mean_absolute_error)
# 	0.04s	 = Training   runtime
# 	0.92s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ...
# 	-30.4427	 = Validation score   (-mean_absolute_error)
# 	0.04s	 = Training   runtime
# 	0.89s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.7946	 = Validation score   (-mean_absolute_error)
# 	59.51s	 = Training   runtime
# 	48.99s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.0228	 = Validation score   (-mean_absolute_error)
# 	85.59s	 = Training   runtime
# 	74.75s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ...
# 	-23.7968	 = Validation score   (-mean_absolute_error)
# 	37.85s	 = Training   runtime
# 	0.76s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.4628	 = Validation score   (-mean_absolute_error)
# 	1596.92s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ...
# 	-23.4792	 = Validation score   (-mean_absolute_error)
# 	3.45s	 = Training   runtime
# 	0.5s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-23.7564	 = Validation score   (-mean_absolute_error)
# 	19.14s	 = Training   runtime
# 	0.22s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.9559	 = Validation score   (-mean_absolute_error)
# 	155.55s	 = Training   runtime
# 	31.64s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.1295	 = Validation score   (-mean_absolute_error)
# 	35.34s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: ExtraTrees_r19_BAG_L1 ...
# 	-23.5741	 = Validation score   (-mean_absolute_error)
# 	1.12s	 = Training   runtime
# 	0.44s	 = Validation runtime
# Fitting model: RandomForest_r5_BAG_L1 ...
# 	-24.2272	 = Validation score   (-mean_absolute_error)
# 	5.12s	 = Training   runtime
# 	0.37s	 = Validation runtime
# Fitting model: LightGBM_r158_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.4214	 = Validation score   (-mean_absolute_error)
# 	62.54s	 = Training   runtime
# 	72.41s	 = Validation runtime
# Fitting model: LightGBM_r118_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.6665	 = Validation score   (-mean_absolute_error)
# 	12.65s	 = Training   runtime
# 	25.04s	 = Validation runtime
# Fitting model: LightGBM_r97_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.6655	 = Validation score   (-mean_absolute_error)
# 	21.87s	 = Training   runtime
# 	57.43s	 = Validation runtime
# Fitting model: LightGBM_r71_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-20.9446	 = Validation score   (-mean_absolute_error)
# 	45.57s	 = Training   runtime
# 	166.59s	 = Validation runtime
# Fitting model: LightGBM_r111_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-20.3552	 = Validation score   (-mean_absolute_error)
# 	42.92s	 = Training   runtime
# 	93.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r25_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-24.9258	 = Validation score   (-mean_absolute_error)
# 	9.87s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r51_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.4289	 = Validation score   (-mean_absolute_error)
# 	10.69s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r82_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-24.748	 = Validation score   (-mean_absolute_error)
# 	12.25s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r121_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-26.0044	 = Validation score   (-mean_absolute_error)
# 	15.55s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r145_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-24.1647	 = Validation score   (-mean_absolute_error)
# 	26.03s	 = Training   runtime
# 	0.33s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r173_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-26.9251	 = Validation score   (-mean_absolute_error)
# 	21.95s	 = Training   runtime
# 	0.24s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r128_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-27.8704	 = Validation score   (-mean_absolute_error)
# 	23.46s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: CatBoost_r16_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.1422	 = Validation score   (-mean_absolute_error)
# 	131.73s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: CatBoost_r42_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-23.0513	 = Validation score   (-mean_absolute_error)
# 	112.82s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: CatBoost_r93_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.7953	 = Validation score   (-mean_absolute_error)
# 	161.77s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: CatBoost_r44_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.4411	 = Validation score   (-mean_absolute_error)
# 	214.59s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-20.8206	 = Validation score   (-mean_absolute_error)
# 	83.32s	 = Training   runtime
# 	98.43s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-19.348	 = Validation score   (-mean_absolute_error)
# 	0.44s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 27 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.8161	 = Validation score   (-mean_absolute_error)
# 	2.4s	 = Training   runtime
# 	0.27s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.731	 = Validation score   (-mean_absolute_error)
# 	2.3s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ...
# 	-19.2583	 = Validation score   (-mean_absolute_error)
# 	28.32s	 = Training   runtime
# 	0.51s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.8215	 = Validation score   (-mean_absolute_error)
# 	16.46s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ...
# 	-19.2287	 = Validation score   (-mean_absolute_error)
# 	3.12s	 = Training   runtime
# 	0.53s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-18.9645	 = Validation score   (-mean_absolute_error)
# 	11.74s	 = Training   runtime
# 	0.19s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.5318	 = Validation score   (-mean_absolute_error)
# 	4.32s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.5456	 = Validation score   (-mean_absolute_error)
# 	20.24s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: ExtraTrees_r19_BAG_L2 ...
# 	-19.1784	 = Validation score   (-mean_absolute_error)
# 	1.76s	 = Training   runtime
# 	0.52s	 = Validation runtime
# Fitting model: RandomForest_r5_BAG_L2 ...
# 	-18.9816	 = Validation score   (-mean_absolute_error)
# 	11.64s	 = Training   runtime
# 	0.41s	 = Validation runtime
# Fitting model: LightGBM_r158_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.8007	 = Validation score   (-mean_absolute_error)
# 	3.21s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Fitting model: LightGBM_r118_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.6155	 = Validation score   (-mean_absolute_error)
# 	11.54s	 = Training   runtime
# 	1.07s	 = Validation runtime
# Fitting model: LightGBM_r97_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.7864	 = Validation score   (-mean_absolute_error)
# 	9.33s	 = Training   runtime
# 	1.5s	 = Validation runtime
# Fitting model: LightGBM_r71_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.9195	 = Validation score   (-mean_absolute_error)
# 	26.79s	 = Training   runtime
# 	8.13s	 = Validation runtime
# Fitting model: LightGBM_r111_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.4029	 = Validation score   (-mean_absolute_error)
# 	15.66s	 = Training   runtime
# 	1.55s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r25_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.9307	 = Validation score   (-mean_absolute_error)
# 	10.77s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r51_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.6326	 = Validation score   (-mean_absolute_error)
# 	11.5s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r82_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.612	 = Validation score   (-mean_absolute_error)
# 	13.07s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r121_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-20.3993	 = Validation score   (-mean_absolute_error)
# 	16.75s	 = Training   runtime
# 	0.22s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r145_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.414	 = Validation score   (-mean_absolute_error)
# 	27.0s	 = Training   runtime
# 	0.34s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r173_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-20.433	 = Validation score   (-mean_absolute_error)
# 	22.22s	 = Training   runtime
# 	0.24s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r128_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.1714	 = Validation score   (-mean_absolute_error)
# 	19.23s	 = Training   runtime
# 	0.24s	 = Validation runtime
# Fitting model: CatBoost_r16_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.7512	 = Validation score   (-mean_absolute_error)
# 	34.06s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: CatBoost_r42_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.7512	 = Validation score   (-mean_absolute_error)
# 	37.45s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: CatBoost_r93_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.7272	 = Validation score   (-mean_absolute_error)
# 	73.26s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: CatBoost_r44_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.7103	 = Validation score   (-mean_absolute_error)
# 	215.69s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.7367	 = Validation score   (-mean_absolute_error)
# 	7.96s	 = Training   runtime
# 	0.53s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ...
# 	-18.7205	 = Validation score   (-mean_absolute_error)
# 	0.44s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 3854.69s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("ag_145_lag_features_25_25C")

# %%
test1 = pipin.get_test_data("A")
test2 = pipin.get_test_data("B")
test3 = pipin.get_test_data("C")

# %%
test_data1 = TabularDataset(test1)
test_data2 = TabularDataset(test2)
test_data3 = TabularDataset(test3)

pred1 = pd.DataFrame(predictor1.predict(test_data1))
pred2 = pd.DataFrame(predictor2.predict(test_data2))
pred3 = pd.DataFrame(predictor3.predict(test_data3))

negatives_pred1 = pred1[pred1["pv_measurement"] < 0]
negatives_pred2 = pred2[pred2["pv_measurement"] < 0]
negatives_pred3 = pred3[pred3["pv_measurement"] < 0]
neg = pd.concat([negatives_pred1, negatives_pred2, negatives_pred3])
neg.shape
# Out:
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
# ...
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/miksx/anaconda3/envs/TDT4173/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:192: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# (194, 1)

# %%
pred = pd.concat([pred1, pred2, pred3])
final_prediction = pipin.post_processing(pred, prediction_column="pv_measurement")
final_prediction.to_csv('submissions/gluon_145_lag_features_25_25.csv')

# %%
diff = pipin.compare_mae(final_prediction)
diff
# Out:
# 63.61518464723095

# %%
# predictor.evaluate(df1, silent=True)
