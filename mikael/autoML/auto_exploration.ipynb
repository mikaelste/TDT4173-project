# %%
from DataExplore import Data
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data_a = Data("A")
data_b = Data("B")
data_c = Data("C")

# %%
data_a.frame.columns #.frame.isna().sum()
# Out:
# Index(['date_forecast', 'absolute_humidity_2m:gm3', 'air_density_2m:kgm3',
#        'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W',
#        'cloud_base_agl:m', 'dew_or_rime:idx', 'dew_point_2m:K',
#        'diffuse_rad:W', 'diffuse_rad_1h:J', 'direct_rad:W', 'direct_rad_1h:J',
#        'effective_cloud_cover:p', 'elevation:m', 'fresh_snow_12h:cm',
#        'fresh_snow_1h:cm', 'fresh_snow_24h:cm', 'fresh_snow_3h:cm',
#        'fresh_snow_6h:cm', 'is_day:idx', 'is_in_shadow:idx',
#        'msl_pressure:hPa', 'precip_5min:mm', 'precip_type_5min:idx',
#        'pressure_100m:hPa', 'pressure_50m:hPa', 'prob_rime:p',
#        'rain_water:kgm2', 'relative_humidity_1000hPa:p', 'sfc_pressure:hPa',
#        'snow_density:kgm3', 'snow_depth:cm', 'snow_drift:idx',
#        'snow_melt_10min:mm', 'snow_water:kgm2', 'sun_azimuth:d',
#        'sun_elevation:d', 'super_cooled_liquid_water:kgm2', 't_1000hPa:K',
#        'total_cloud_cover:p', 'visibility:m', 'wind_speed_10m:ms',
# ...

# %%
data_b.frame.isna().sum()
# Out:
# date_forecast                         0
# absolute_humidity_2m:gm3              8
# air_density_2m:kgm3                   8
# ceiling_height_agl:m               2546
# clear_sky_energy_1h:J                 8
# clear_sky_rad:W                       8
# cloud_base_agl:m                   1087
# dew_or_rime:idx                       8
# dew_point_2m:K                        8
# diffuse_rad:W                         8
# diffuse_rad_1h:J                      8
# direct_rad:W                          8
# direct_rad_1h:J                       8
# effective_cloud_cover:p               8
# elevation:m                           8
# fresh_snow_12h:cm                     8
# fresh_snow_1h:cm                      8
# fresh_snow_24h:cm                     8
# fresh_snow_3h:cm                      8
# fresh_snow_6h:cm                      8
# is_day:idx                            8
# is_in_shadow:idx                      8
# msl_pressure:hPa                      8
# ...

# %%
data_c.frame.isna().sum()
# Out:
# date_forecast                         0
# absolute_humidity_2m:gm3              8
# air_density_2m:kgm3                   8
# ceiling_height_agl:m               3170
# clear_sky_energy_1h:J                 8
# clear_sky_rad:W                       8
# cloud_base_agl:m                   1428
# dew_or_rime:idx                       8
# dew_point_2m:K                        8
# diffuse_rad:W                         8
# diffuse_rad_1h:J                      8
# direct_rad:W                          8
# direct_rad_1h:J                       8
# effective_cloud_cover:p               8
# elevation:m                           8
# fresh_snow_12h:cm                     8
# fresh_snow_1h:cm                      8
# fresh_snow_24h:cm                     8
# fresh_snow_3h:cm                      8
# fresh_snow_6h:cm                      8
# is_day:idx                            8
# is_in_shadow:idx                      8
# msl_pressure:hPa                      8
# ...

# %% [markdown]
# # Location A

# %%
frame_a = data_a.frame.copy().groupby(pd.Grouper(key="date_forecast", freq="1H")).mean()
frame_a.dropna(axis=1, inplace=True)
frame_a
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
data_a.frame.dropna(axis=1, inplace=True)
data_a.frame
# Out:
#             date_forecast  pv_measurement
# 0     2019-06-02 22:00:00            0.00
# 1     2019-06-02 23:00:00            0.00
# 2     2019-06-03 00:00:00            0.00
# 3     2019-06-03 01:00:00            0.00
# 4     2019-06-03 02:00:00           19.36
# ...                   ...             ...
# 21285 2023-04-30 19:00:00            9.02
# 21286 2023-04-30 20:00:00            0.00
# 21287 2023-04-30 21:00:00            0.00
# 21288 2023-04-30 22:00:00            0.00
# 21289 2023-04-30 23:00:00            0.00
#
# [21290 rows x 2 columns]

# %%
frame_na = data_a.frame.isna().sum()
frame_na
# Out:
# date_forecast     0
# pv_measurement    0
# dtype: int64

# %%
data_a.drop_consequtives(4)
data_a.frame = data_a.frame.loc[data_a.frame["pv_measurement"].notna()]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/miksx/GitHub/Forest-Gump/mikael/autoML/auto_exploration.ipynb Cell 10 line 1
# ----> <a href='vscode-notebook-cell:/Users/miksx/GitHub/Forest-Gump/mikael/autoML/auto_exploration.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> data_a.drop_consequtives(4)
#       <a href='vscode-notebook-cell:/Users/miksx/GitHub/Forest-Gump/mikael/autoML/auto_exploration.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a> data_a.frame = data_a.frame.loc[data_a.frame["pv_measurement"].notna()]
#
# AttributeError: 'Data' object has no attribute 'drop_consequtives'

# %%
data_a.frame.describe()
# Out:
#                        date_forecast  absolute_humidity_2m:gm3  \
# count                          20293              20293.000000
# mean   2021-04-23 15:40:01.478342144                  7.129079
# min              2019-06-02 22:00:00                  0.700000
# 25%              2020-05-25 21:00:00                  4.800000
# 50%              2021-05-15 23:00:00                  7.100000
# 75%              2022-05-07 02:00:00                  9.100000
# max              2023-04-30 23:00:00                 17.500000
# std                              NaN                  2.860024
#
#        air_density_2m:kgm3  clear_sky_energy_1h:J  clear_sky_rad:W  \
# count         20293.000000           2.029300e+04     20293.000000
# mean              1.241436           9.263658e+05       257.350220
# min               1.145000           0.000000e+00         0.000000
# 25%               1.218000           7.704120e+04        20.600000
# ...

# %%
data_a.tune_data.describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/miksx/GitHub/Forest-Gump/mikael/autoML/auto_exploration.ipynb Cell 9 line 1
# ----> <a href='vscode-notebook-cell:/Users/miksx/GitHub/Forest-Gump/mikael/autoML/auto_exploration.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> data_a.tune_data.describe()
#
# AttributeError: 'NoneType' object has no attribute 'describe'

# %% [markdown]
# # Location B

# %%
data_b.frame.describe()
# Out:
#                        date_forecast  absolute_humidity_2m:gm3  \
# count                          14252              14252.000000
# mean   2020-10-15 22:04:52.253719040                  6.828088
# min              2019-01-01 00:00:00                  0.700000
# 25%              2019-08-24 18:45:00                  4.700000
# 50%              2020-07-04 16:30:00                  6.500000
# 75%              2021-08-01 16:15:00                  8.700000
# max              2023-04-30 23:00:00                 17.500000
# std                              NaN                  2.742365
#
#        air_density_2m:kgm3  ceiling_height_agl:m  clear_sky_energy_1h:J  \
# count         14252.000000          11197.000000           1.425200e+04
# mean              1.243872           2853.725098           9.554300e+05
# min               1.151000             27.799999           0.000000e+00
# 25%               1.221000           1151.400024           1.159937e+05
# ...

# %%
data_b.drop_consequtives(5)

# %%
frame_na_b = data_b.frame.isna().sum()
frame_na_b
# Out:
# date_forecast                         0
# absolute_humidity_2m:gm3              0
# air_density_2m:kgm3                   0
# ceiling_height_agl:m               3042
# clear_sky_energy_1h:J                 0
# clear_sky_rad:W                       0
# cloud_base_agl:m                   1321
# dew_or_rime:idx                       0
# dew_point_2m:K                        0
# diffuse_rad:W                         0
# diffuse_rad_1h:J                      0
# direct_rad:W                          0
# direct_rad_1h:J                       0
# effective_cloud_cover:p               0
# elevation:m                           0
# fresh_snow_12h:cm                     0
# fresh_snow_1h:cm                      0
# fresh_snow_24h:cm                     0
# fresh_snow_3h:cm                      0
# fresh_snow_6h:cm                      0
# is_day:idx                            0
# is_in_shadow:idx                      0
# msl_pressure:hPa                      0
# ...

# %%
data_b.frame.describe()
# Out:
#                        date_forecast  absolute_humidity_2m:gm3  \
# count                          14238              14238.000000
# mean   2020-10-15 17:39:21.567635968                  6.832210
# min              2019-01-01 00:00:00                  0.700000
# 25%              2019-08-24 15:15:00                  4.700000
# 50%              2020-07-04 09:30:00                  6.500000
# 75%              2021-08-01 16:45:00                  8.700000
# max              2023-04-30 23:00:00                 17.500000
# std                              NaN                  2.739921
#
#        air_density_2m:kgm3  ceiling_height_agl:m  clear_sky_energy_1h:J  \
# count         14238.000000          11191.000000           1.423800e+04
# mean              1.243786           2854.545654           9.561951e+05
# min               1.151000             27.799999           0.000000e+00
# 25%               1.221000           1152.149902           1.162337e+05
# ...

# %%
data_b.tune_data.describe()
# Out:
#                        date_forecast  absolute_humidity_2m:gm3  \
# count                           2263               2263.000000
# mean   2021-06-27 11:37:23.040212224                  8.937561
# min              2021-05-01 22:00:00                  3.000000
# 25%              2021-05-29 01:30:00                  7.500000
# 50%              2021-06-27 18:00:00                  8.800000
# 75%              2021-07-25 15:30:00                 10.500000
# max              2021-08-25 22:00:00                 15.400000
# std                              NaN                  2.326164
#
#        air_density_2m:kgm3  ceiling_height_agl:m  clear_sky_energy_1h:J  \
# count          2263.000000           1609.000000           2.263000e+03
# mean              1.221719           4032.118164           1.296638e+06
# min               1.151000             30.400000           0.000000e+00
# 25%               1.208000           1306.800049           1.753344e+05
# ...

# %% [markdown]
# # Location C

# %%
data_c.frame.describe()
# Out:
#                        date_forecast  absolute_humidity_2m:gm3  \
# count                          32130              32130.000000
# mean   2020-11-20 04:16:18.039215872                  5.871992
# min              2019-01-01 00:00:00                  0.500000
# 25%              2019-12-01 18:15:00                  3.900000
# 50%              2020-10-31 12:30:00                  5.300000
# 75%              2021-10-01 04:45:00                  7.600000
# max              2023-04-30 23:00:00                 18.900000
# std                              NaN                  2.737951
#
#        air_density_2m:kgm3  ceiling_height_agl:m  clear_sky_energy_1h:J  \
# count         32130.000000          25317.000000           3.213000e+04
# mean              1.255162           2603.363037           5.208732e+05
# min               1.139000             27.799999           0.000000e+00
# 25%               1.230000            958.200012           0.000000e+00
# ...

# %%
data_c.drop_consequtives(5)
data_c.frame = data_c.frame.loc[data_c.frame["pv_measurement"].notna()]
# data_c.tune_data = self.tune_data.loc[self.tune_data["pv_measurement"].notna()]
# data_c.frame_without_tuning_data = self.frame_without_tuning_data.loc[self.frame_without_tuning_data["pv_measurement"].notna()]

# data_c.set_neg_to_zero()
# data_c.set_dtypes()
# data_c.drop_index()
# data_c.frame = data_a.frame.loc[data_a.frame["pv_measurement"].notna()]
data_c.exstract_tuning_data('2021-04-01', '2021-06-15')

# %%
data_c.frame.describe()
# Out:
#                        date_forecast  absolute_humidity_2m:gm3  \
# count                          17638              17638.000000
# mean   2020-08-01 13:53:37.507653632                  6.820881
# min              2019-01-01 00:00:00                  1.100000
# 25%              2019-07-03 17:15:00                  4.600000
# 50%              2020-06-18 20:30:00                  6.500000
# 75%              2021-06-20 14:45:00                  8.800000
# max              2023-04-30 23:00:00                 18.900000
# std                              NaN                  2.844172
#
#        air_density_2m:kgm3  ceiling_height_agl:m  clear_sky_energy_1h:J  \
# count         17638.000000          13868.000000           1.763800e+04
# mean              1.241627           2589.639404           9.160203e+05
# min               1.139000             28.500000           0.000000e+00
# 25%               1.217000            970.575012           5.411577e+04
# ...

# %%
data_c.frame_without_tuning_data.describe()
# Out:
#                        date_forecast  absolute_humidity_2m:gm3  \
# count                          15140              15140.000000
# mean   2020-06-07 22:22:50.805812480                  6.480509
# min              2019-01-01 00:00:00                  1.100000
# 25%              2019-06-07 16:45:00                  4.400000
# 50%              2020-04-18 07:30:00                  6.000000
# 75%              2021-02-21 12:15:00                  8.300000
# max              2023-04-30 23:00:00                 18.900000
# std                              NaN                  2.779394
#
#        air_density_2m:kgm3  ceiling_height_agl:m  clear_sky_energy_1h:J  \
# count         15140.000000          12219.000000           1.514000e+04
# mean              1.245699           2418.574463           8.483969e+05
# min               1.139000             28.500000           0.000000e+00
# 25%               1.222000            945.150024           3.974237e+04
# ...

# %%
data_c.tune_data.describe()
# Out:
#                        date_forecast  absolute_humidity_2m:gm3  \
# count                           2498               2498.000000
# mean   2021-06-28 18:46:31.513210624                  8.883827
# min              2021-05-01 03:00:00                  3.000000
# 25%              2021-06-01 02:15:00                  7.400000
# 50%              2021-06-27 20:30:00                  8.700000
# 75%              2021-07-25 16:45:00                 10.400000
# max              2021-08-30 18:00:00                 16.100000
# std                              NaN                  2.311117
#
#        air_density_2m:kgm3  ceiling_height_agl:m  clear_sky_energy_1h:J  \
# count          2498.000000           1649.000000           2.498000e+03
# mean              1.216948           3857.221436           1.325876e+06
# min               1.144000             30.400000           0.000000e+00
# 25%               1.202000           1210.000000           2.468912e+05
# ...

# %% [markdown]
# # Plotting

# %%
# Plotting a single feature
feature_name = 'pv_measurement'

fig, axs = plt.subplots(3, 1, figsize=(20, 10), sharex=True)
data_a.frame_without_tuning_data[['date_forecast', feature_name]].set_index('date_forecast').plot(ax=axs[0], title='Train/Test A', color='red')
data_a.tune_data[['date_forecast', feature_name]].set_index('date_forecast').plot(ax=axs[0], title='Train/Test A', color='blue')

data_b.frame_without_tuning_data[['date_forecast', feature_name]].set_index('date_forecast').plot(ax=axs[1], title='Train/Test B', color='red')
data_b.tune_data[['date_forecast', feature_name]].set_index('date_forecast').plot(ax=axs[1], title='Train/Test A', color='blue')

data_c.frame_without_tuning_data[['date_forecast', feature_name]].set_index('date_forecast').plot(ax=axs[2], title='Train/Test C', color='red')
data_c.tune_data[['date_forecast', feature_name]].set_index('date_forecast').plot(ax=axs[2], title='Train/Test A', color='blue')
# Out:
# <Axes: title={'center': 'Train/Test A'}, xlabel='date_forecast'>
