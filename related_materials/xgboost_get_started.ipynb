# %%
import xgboost as xgb

# %%
# read in data
dtrain = xgb.DMatrix('agaricus.txt.train')
dtest = xgb.DMatrix('agaricus.txt.test')

# %%
# specify parameters via map
param = {'max_depth':2, 'eta':1, 'silent':1, 'objective':'binary:logistic' }
num_round = 1000
model = xgb.train(param, dtrain, num_round)
# Out:
# [12:49:41] WARNING: /var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_21wtzqx5vy/croot/xgboost-split_1675457780668/work/src/learner.cc:767:
# Parameters: { "silent" } are not used.

# %%
# make prediction
preds = model.predict(dtest)

# %%
# %matplotlib inline
from matplotlib import pyplot
from matplotlib.pylab import rcParams
rcParams.update({'font.size': 22})
rcParams['figure.figsize'] = 15,10

xgb.plot_importance(model,max_num_features=15)
pyplot.show()

# %%
rcParams['figure.figsize'] = 15,15
xgb.plot_tree(model)
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/xgboost/plotting.py:197, in to_graphviz(booster, fmap, num_trees, rankdir, yes_color, no_color, condition_node_params, leaf_node_params, **kwargs)
#     196 try:
# --> 197     from graphviz import Source
#     198 except ImportError as e:
#
# ModuleNotFoundError: No module named 'graphviz'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# /Users/matsalexander/Library/CloudStorage/OneDrive-NTNU/2-ML/Forelesning4/related_materials/xgboost_get_started.ipynb Cell 6 line 2
#       <a href='vscode-notebook-cell:/Users/matsalexander/Library/CloudStorage/OneDrive-NTNU/2-ML/Forelesning4/related_materials/xgboost_get_started.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> rcParams['figure.figsize'] = 15,15
# ----> <a href='vscode-notebook-cell:/Users/matsalexander/Library/CloudStorage/OneDrive-NTNU/2-ML/Forelesning4/related_materials/xgboost_get_started.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> xgb.plot_tree(model)
#       <a href='vscode-notebook-cell:/Users/matsalexander/Library/CloudStorage/OneDrive-NTNU/2-ML/Forelesning4/related_materials/xgboost_get_started.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a> pyplot.show()
#
# File ~/anaconda3/lib/python3.11/site-packages/xgboost/plotting.py:280, in plot_tree(booster, fmap, num_trees, rankdir, ax, **kwargs)
#     277 if ax is None:
#     278     _, ax = plt.subplots(1, 1)
# --> 280 g = to_graphviz(booster, fmap=fmap, num_trees=num_trees, rankdir=rankdir,
#     281                 **kwargs)
#     283 s = BytesIO()
#     284 s.write(g.pipe(format='png'))
#
# File ~/anaconda3/lib/python3.11/site-packages/xgboost/plotting.py:199, in to_graphviz(booster, fmap, num_trees, rankdir, yes_color, no_color, condition_node_params, leaf_node_params, **kwargs)
#     197     from graphviz import Source
#     198 except ImportError as e:
# --> 199     raise ImportError('You must install graphviz to plot tree') from e
#     200 if isinstance(booster, XGBModel):
#     201     booster = booster.get_booster()
#
# ImportError: You must install graphviz to plot tree
