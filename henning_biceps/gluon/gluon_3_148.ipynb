# %% [markdown]
# <h3> Henning skal teste å fjerne consecutives.</h3>
# <p> yee<p>

# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from autogluon.tabular import TabularDataset, TabularPredictor
import pandas as pd
import numpy as np

# %%
# %autoreload
import sys
sys.path.append('../')
from pipeline import Pipeline
pipin = Pipeline()

# %%
df1_0 = pipin.get_data("A")
df2_0 = pipin.get_data("B")
df3_0 = pipin.get_data("C")

# %%
# remove_consecutive_measurments
df1_0 = pipin.remove_consecutive_measurments(df1_0, 4, 4)
df2_0 = pipin.remove_consecutive_measurments(df2_0, 4, 24)
df3_0 = pipin.remove_consecutive_measurments(df3_0, 4, 24)
print(df1_0.shape, df2_0.shape, df3_0.shape)
# Out:
# (18045, 50) (13958, 50) (11379, 50)

# %%
df1_0 = pipin.get_data("A")
df2_0 = pipin.get_data("B")
df3_0 = pipin.get_data("C")

df1_0.head()
# Out:
#    absolute_humidity_2m:gm3  air_density_2m:kgm3  ceiling_height_agl:m  \
# 0                     7.700              1.22825           1728.949951
# 1                     7.700              1.22350           1689.824951
# 2                     7.875              1.21975           1563.224976
# 3                     8.425              1.21800           1283.425049
# 4                     8.950              1.21800           1003.500000
#
#    clear_sky_energy_1h:J  clear_sky_rad:W  cloud_base_agl:m  dew_or_rime:idx  \
# 0               0.000000             0.00       1728.949951              0.0
# 1               0.000000             0.00       1689.824951              0.0
# 2               0.000000             0.00       1563.224976              0.0
# 3             208.649994             0.75       1283.425049              0.0
# 4           32468.150391            23.10       1003.500000              0.0
#
#    dew_point_2m:K  diffuse_rad:W  diffuse_rad_1h:J  ...  visibility:m  \
# 0      280.299988          0.000          0.000000  ...  40386.476562
# 1      280.299988          0.000          0.000000  ...  33770.648438
# 2      280.649994          0.000          0.000000  ...  13595.500000
# 3      281.674988          0.300        526.775024  ...   2321.850098
# 4      282.500000         11.975      22068.949219  ...  11634.799805
#
#    wind_speed_10m:ms  wind_speed_u_10m:ms  wind_speed_v_10m:ms  \
# 0              3.600                3.575                0.500
# 1              3.350                3.350                0.275
# 2              3.050                2.950                0.750
# 3              2.725                2.600                0.875
# 4              2.550                2.350                0.925
#
#    wind_speed_w_1000hPa:ms  estimated  observed  day_of_year  hour  \
# 0                      0.0        0.0       1.0        153.0  22.0
# 1                      0.0        0.0       1.0        153.0  23.0
# 2                      0.0        0.0       1.0        154.0   0.0
# 3                      0.0        0.0       1.0        154.0   1.0
# 4                      0.0        0.0       1.0        154.0   2.0
#
#    pv_measurement
# 0            0.00
# 1            0.00
# 2            0.00
# 3            0.00
# 4           19.36
#
# [5 rows x 50 columns]

# %%
raise Exception("Stop here")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /Users/matsalexander/Desktop/Forest Gump/henning_biceps/gluon/gluon_3_148.ipynb Cell 8 line 1
# ----> <a href='vscode-notebook-cell:/Users/matsalexander/Desktop/Forest%20Gump/henning_biceps/gluon/gluon_3_148.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> raise Exception("Stop here")
#
# Exception: Stop here

# %%
# remove_consecutive_measurments
df1_0 = pipin.remove_consecutive_measurments(df1_0, 4, 24)
df2_0 = pipin.remove_consecutive_measurments(df2_0, 4, 24)
df3_0 = pipin.remove_consecutive_measurments(df3_0, 4, 24)

#One wind speed should be enough
drop = [
    "wind_speed_w_1000hPa:ms",
    "wind_speed_u_10m:ms",
    "wind_speed_v_10m:ms"
]

df1_0 = df1_0.drop(columns=drop)
df2_0 = df2_0.drop(columns=drop)
df3_0 = df3_0.drop(columns=drop)

# %%
df1_0.head()
# Out:
#    absolute_humidity_2m:gm3  air_density_2m:kgm3  ceiling_height_agl:m  \
# 0                     7.700              1.22825           1728.949951
# 1                     7.700              1.22350           1689.824951
# 2                     7.875              1.21975           1563.224976
# 3                     8.425              1.21800           1283.425049
# 4                     8.950              1.21800           1003.500000
#
#    clear_sky_energy_1h:J  clear_sky_rad:W  cloud_base_agl:m  dew_or_rime:idx  \
# 0               0.000000             0.00       1728.949951              0.0
# 1               0.000000             0.00       1689.824951              0.0
# 2               0.000000             0.00       1563.224976              0.0
# 3             208.649994             0.75       1283.425049              0.0
# 4           32468.150391            23.10       1003.500000              0.0
#
#    dew_point_2m:K  diffuse_rad:W  diffuse_rad_1h:J  ...  \
# 0      280.299988          0.000          0.000000  ...
# 1      280.299988          0.000          0.000000  ...
# 2      280.649994          0.000          0.000000  ...
# 3      281.674988          0.300        526.775024  ...
# 4      282.500000         11.975      22068.949219  ...
#
#    super_cooled_liquid_water:kgm2  t_1000hPa:K  total_cloud_cover:p  \
# 0                             0.0   286.225006           100.000000
# 1                             0.0   286.899994           100.000000
# 2                             0.0   286.950012           100.000000
# 3                             0.0   286.750000           100.000000
# 4                             0.0   286.450012            99.224998
#
#    visibility:m  wind_speed_10m:ms  estimated  observed  day_of_year  hour  \
# 0  40386.476562              3.600        0.0       1.0        153.0  22.0
# 1  33770.648438              3.350        0.0       1.0        153.0  23.0
# 2  13595.500000              3.050        0.0       1.0        154.0   0.0
# 3   2321.850098              2.725        0.0       1.0        154.0   1.0
# 4  11634.799805              2.550        0.0       1.0        154.0   2.0
#
#    pv_measurement
# 0            0.00
# 1            0.00
# 2            0.00
# 3            0.00
# 4           19.36
#
# [5 rows x 47 columns]

# %%
train1 = TabularDataset(df1_0)
train2 = TabularDataset(df2_0)
train3 = TabularDataset(df3_0)

# %%
predictor1 = TabularPredictor(label="pv_measurement", eval_metric='mean_absolute_error').fit(
    train1,
    # time_limit=6000,
    # hyperparameters='extrme', 
    presets="best_quality", 
    # tuning_data = tuning1,
    # use_bag_holdout=True,
    # num_bag_folds= 6,
    # refit_full = True,
    # auto_stack = True,
    # num_bag_sets= 10,
    # set_best_to_refit_full= True,
    # num_stack_levels = 2,
    # verbosity = 3
    
    )
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20231108_155129/"
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20231108_155129/"
# AutoGluon Version:  0.8.2
# Python Version:     3.10.13
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 22.5.0: Thu Jun  8 22:22:20 PDT 2023; root:xnu-8796.121.3~7/RELEASE_ARM64_T6000
# Disk Space Avail:   774.49 GB / 994.66 GB (77.9%)
# Train Data Rows:    20301
# Train Data Columns: 46
# Label Column: pv_measurement
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (5733.42, 0.0, 1058.75674, 1352.40186)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    17550.95 MB
# 	Train Data (Original)  Memory Usage: 4.06 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 3 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Unused Original Features (Count: 1): ['snow_drift:idx']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('float', []) : 1 | ['snow_drift:idx']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 45 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 43 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 		('int', ['bool']) :  2 | ['elevation:m', 'snow_density:kgm3']
# 	0.2s = Fit runtime
# 	45 features in original data used to generate 45 features in processed data.
# 	Train Data (Processed) Memory Usage: 3.86 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.18s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ...
# 	-443.8261	 = Validation score   (-mean_absolute_error)
# 	0.01s	 = Training   runtime
# 	0.4s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ...
# 	-445.2265	 = Validation score   (-mean_absolute_error)
# 	0.01s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/matsalexander/Desktop/Forest Gump/henning_biceps/gluon/gluon_3_148.ipynb Cell 13 line 1
# ----> <a href='vscode-notebook-cell:/Users/matsalexander/Desktop/Forest%20Gump/henning_biceps/gluon/gluon_3_148.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> predictor1 = TabularPredictor(label="pv_measurement", eval_metric='mean_absolute_error').fit(
#       <a href='vscode-notebook-cell:/Users/matsalexander/Desktop/Forest%20Gump/henning_biceps/gluon/gluon_3_148.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a>     train1,
#       <a href='vscode-notebook-cell:/Users/matsalexander/Desktop/Forest%20Gump/henning_biceps/gluon/gluon_3_148.ipynb#X14sZmlsZQ%3D%3D?line=2'>3</a>     # time_limit=6000,
#       <a href='vscode-notebook-cell:/Users/matsalexander/Desktop/Forest%20Gump/henning_biceps/gluon/gluon_3_148.ipynb#X14sZmlsZQ%3D%3D?line=3'>4</a>     # hyperparameters='extrme',
#       <a href='vscode-notebook-cell:/Users/matsalexander/Desktop/Forest%20Gump/henning_biceps/gluon/gluon_3_148.ipynb#X14sZmlsZQ%3D%3D?line=4'>5</a>     presets="best_quality",
#       <a href='vscode-notebook-cell:/Users/matsalexander/Desktop/Forest%20Gump/henning_biceps/gluon/gluon_3_148.ipynb#X14sZmlsZQ%3D%3D?line=5'>6</a>     # tuning_data = tuning1,
#       <a href='vscode-notebook-cell:/Users/matsalexander/Desktop/Forest%20Gump/henning_biceps/gluon/gluon_3_148.ipynb#X14sZmlsZQ%3D%3D?line=6'>7</a>     # use_bag_holdout=True,
#       <a href='vscode-notebook-cell:/Users/matsalexander/Desktop/Forest%20Gump/henning_biceps/gluon/gluon_3_148.ipynb#X14sZmlsZQ%3D%3D?line=7'>8</a>     # num_bag_folds= 6,
#       <a href='vscode-notebook-cell:/Users/matsalexander/Desktop/Forest%20Gump/henning_biceps/gluon/gluon_3_148.ipynb#X14sZmlsZQ%3D%3D?line=8'>9</a>     # refit_full = True,
#      <a href='vscode-notebook-cell:/Users/matsalexander/Desktop/Forest%20Gump/henning_biceps/gluon/gluon_3_148.ipynb#X14sZmlsZQ%3D%3D?line=9'>10</a>     # auto_stack = True,
#      <a href='vscode-notebook-cell:/Users/matsalexander/Desktop/Forest%20Gump/henning_biceps/gluon/gluon_3_148.ipynb#X14sZmlsZQ%3D%3D?line=10'>11</a>     # num_bag_sets= 10,
#      <a href='vscode-notebook-cell:/Users/matsalexander/Desktop/Forest%20Gump/henning_biceps/gluon/gluon_3_148.ipynb#X14sZmlsZQ%3D%3D?line=11'>12</a>     # set_best_to_refit_full= True,
#      <a href='vscode-notebook-cell:/Users/matsalexander/Desktop/Forest%20Gump/henning_biceps/gluon/gluon_3_148.ipynb#X14sZmlsZQ%3D%3D?line=12'>13</a>     # num_stack_levels = 2,
#      <a href='vscode-notebook-cell:/Users/matsalexander/Desktop/Forest%20Gump/henning_biceps/gluon/gluon_3_148.ipynb#X14sZmlsZQ%3D%3D?line=13'>14</a>     # verbosity = 3
#      <a href='vscode-notebook-cell:/Users/matsalexander/Desktop/Forest%20Gump/henning_biceps/gluon/gluon_3_148.ipynb#X14sZmlsZQ%3D%3D?line=14'>15</a>
#      <a href='vscode-notebook-cell:/Users/matsalexander/Desktop/Forest%20Gump/henning_biceps/gluon/gluon_3_148.ipynb#X14sZmlsZQ%3D%3D?line=15'>16</a>     )
#
# File ~/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/core/utils/decorators.py:31, in unpack.<locals>._unpack_inner.<locals>._call(*args, **kwargs)
#      28 @functools.wraps(f)
#      29 def _call(*args, **kwargs):
#      30     gargs, gkwargs = g(*other_args, *args, **kwargs)
# ---> 31     return f(*gargs, **gkwargs)
#
# File ~/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/tabular/predictor/predictor.py:986, in TabularPredictor.fit(self, train_data, tuning_data, time_limit, presets, hyperparameters, feature_metadata, infer_limit, infer_limit_batch_size, fit_weighted_ensemble, calibrate_decision_threshold, num_cpus, num_gpus, **kwargs)
#     984     aux_kwargs["fit_weighted_ensemble"] = False
#     985 self.save(silent=True)  # Save predictor to disk to enable prediction and training after interrupt
# --> 986 self._learner.fit(
#     987     X=train_data,
#     988     X_val=tuning_data,
#     989     X_unlabeled=unlabeled_data,
#     990     holdout_frac=holdout_frac,
#     991     num_bag_folds=num_bag_folds,
#     992     num_bag_sets=num_bag_sets,
#     993     num_stack_levels=num_stack_levels,
#     994     hyperparameters=hyperparameters,
#     995     core_kwargs=core_kwargs,
#     996     aux_kwargs=aux_kwargs,
#     997     time_limit=time_limit,
#     998     infer_limit=infer_limit,
#     999     infer_limit_batch_size=infer_limit_batch_size,
#    1000     verbosity=verbosity,
#    1001     use_bag_holdout=use_bag_holdout,
#    1002 )
#    1003 self._set_post_fit_vars()
#    1005 self._post_fit(
#    1006     keep_only_best=kwargs["keep_only_best"],
#    1007     refit_full=kwargs["refit_full"],
#    (...)
#    1012     infer_limit=infer_limit,
#    1013 )
#
# File ~/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/tabular/learner/abstract_learner.py:159, in AbstractTabularLearner.fit(self, X, X_val, **kwargs)
#     157     raise AssertionError("Learner is already fit.")
#     158 self._validate_fit_input(X=X, X_val=X_val, **kwargs)
# --> 159 return self._fit(X=X, X_val=X_val, **kwargs)
#
# File ~/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/tabular/learner/default_learner.py:157, in DefaultLearner._fit(self, X, X_val, X_unlabeled, holdout_frac, num_bag_folds, num_bag_sets, time_limit, infer_limit, infer_limit_batch_size, verbosity, **trainer_fit_kwargs)
#     154     self.eval_metric = trainer.eval_metric
#     156 self.save()
# --> 157 trainer.fit(
#     158     X=X,
#     159     y=y,
#     160     X_val=X_val,
#     161     y_val=y_val,
#     162     X_unlabeled=X_unlabeled,
#     163     holdout_frac=holdout_frac,
#     164     time_limit=time_limit_trainer,
#     165     infer_limit=infer_limit,
#     166     infer_limit_batch_size=infer_limit_batch_size,
#     167     groups=groups,
#     168     **trainer_fit_kwargs,
#     169 )
#     170 self.save_trainer(trainer=trainer)
#     171 time_end = time.time()
#
# File ~/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/tabular/trainer/auto_trainer.py:114, in AutoTrainer.fit(self, X, y, hyperparameters, X_val, y_val, X_unlabeled, holdout_frac, num_stack_levels, core_kwargs, aux_kwargs, time_limit, infer_limit, infer_limit_batch_size, use_bag_holdout, groups, **kwargs)
#     111 log_str += "}"
#     112 logger.log(20, log_str)
# --> 114 self._train_multi_and_ensemble(
#     115     X=X,
#     116     y=y,
#     117     X_val=X_val,
#     118     y_val=y_val,
#     119     X_unlabeled=X_unlabeled,
#     120     hyperparameters=hyperparameters,
#     121     num_stack_levels=num_stack_levels,
#     122     time_limit=time_limit,
#     123     core_kwargs=core_kwargs,
#     124     aux_kwargs=aux_kwargs,
#     125     infer_limit=infer_limit,
#     126     infer_limit_batch_size=infer_limit_batch_size,
#     127     groups=groups,
#     128 )
#
# File ~/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/core/trainer/abstract_trainer.py:2371, in AbstractTrainer._train_multi_and_ensemble(self, X, y, X_val, y_val, hyperparameters, X_unlabeled, num_stack_levels, time_limit, groups, **kwargs)
#    2369     self._num_rows_val = len(X_val)
#    2370 self._num_cols_train = len(list(X.columns))
# -> 2371 model_names_fit = self.train_multi_levels(
#    2372     X,
#    2373     y,
#    2374     hyperparameters=hyperparameters,
#    2375     X_val=X_val,
#    2376     y_val=y_val,
#    2377     X_unlabeled=X_unlabeled,
#    2378     level_start=1,
#    2379     level_end=num_stack_levels + 1,
#    2380     time_limit=time_limit,
#    2381     **kwargs,
#    2382 )
#    2383 if len(self.get_model_names()) == 0:
#    2384     raise ValueError("AutoGluon did not successfully train any models")
#
# File ~/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/core/trainer/abstract_trainer.py:395, in AbstractTrainer.train_multi_levels(self, X, y, hyperparameters, X_val, y_val, X_unlabeled, base_model_names, core_kwargs, aux_kwargs, level_start, level_end, time_limit, name_suffix, relative_stack, level_time_modifier, infer_limit, infer_limit_batch_size)
#     393         core_kwargs_level["time_limit"] = core_kwargs_level.get("time_limit", time_limit_core)
#     394         aux_kwargs_level["time_limit"] = aux_kwargs_level.get("time_limit", time_limit_aux)
# --> 395     base_model_names, aux_models = self.stack_new_level(
#     396         X=X,
#     397         y=y,
#     398         X_val=X_val,
#     399         y_val=y_val,
#     400         X_unlabeled=X_unlabeled,
#     401         models=hyperparameters,
#     402         level=level,
#     403         base_model_names=base_model_names,
#     404         core_kwargs=core_kwargs_level,
#     405         aux_kwargs=aux_kwargs_level,
#     406         name_suffix=name_suffix,
#     407         infer_limit=infer_limit,
#     408         infer_limit_batch_size=infer_limit_batch_size,
#     409     )
#     410     model_names_fit += base_model_names + aux_models
#     411 if self.model_best is None and len(model_names_fit) != 0:
#
# File ~/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/core/trainer/abstract_trainer.py:539, in AbstractTrainer.stack_new_level(self, X, y, models, X_val, y_val, X_unlabeled, level, base_model_names, core_kwargs, aux_kwargs, name_suffix, infer_limit, infer_limit_batch_size)
#     537     core_kwargs["name_suffix"] = core_kwargs.get("name_suffix", "") + name_suffix
#     538     aux_kwargs["name_suffix"] = aux_kwargs.get("name_suffix", "") + name_suffix
# --> 539 core_models = self.stack_new_level_core(
#     540     X=X,
#     541     y=y,
#     542     X_val=X_val,
#     543     y_val=y_val,
#     544     X_unlabeled=X_unlabeled,
#     545     models=models,
#     546     level=level,
#     547     infer_limit=infer_limit,
#     548     infer_limit_batch_size=infer_limit_batch_size,
#     549     base_model_names=base_model_names,
#     550     **core_kwargs,
#     551 )
#     553 if X_val is None:
#     554     aux_models = self.stack_new_level_aux(
#     555         X=X, y=y, base_model_names=core_models, level=level + 1, infer_limit=infer_limit, infer_limit_batch_size=infer_limit_batch_size, **aux_kwargs
#     556     )
#
# File ~/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/core/trainer/abstract_trainer.py:673, in AbstractTrainer.stack_new_level_core(self, X, y, models, X_val, y_val, X_unlabeled, level, base_model_names, stack_name, ag_args, ag_args_fit, ag_args_ensemble, included_model_types, excluded_model_types, ensemble_type, name_suffix, get_models_func, refit_full, infer_limit, infer_limit_batch_size, **kwargs)
#     670 fit_kwargs = dict(num_classes=self.num_classes)
#     672 # FIXME: TODO: v0.1 X_unlabeled isn't cached so it won't be available during refit_full or fit_extra.
# --> 673 return self._train_multi(
#     674     X=X_init,
#     675     y=y,
#     676     X_val=X_val,
#     677     y_val=y_val,
#     678     X_unlabeled=X_unlabeled,
#     679     models=models,
#     680     level=level,
#     681     stack_name=stack_name,
#     682     compute_score=compute_score,
#     683     fit_kwargs=fit_kwargs,
#     684     **kwargs,
#     685 )
#
# File ~/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/core/trainer/abstract_trainer.py:2321, in AbstractTrainer._train_multi(self, X, y, models, hyperparameter_tune_kwargs, feature_prune_kwargs, k_fold, n_repeats, n_repeat_start, time_limit, **kwargs)
#    2319 if n_repeat_start == 0:
#    2320     time_start = time.time()
# -> 2321     model_names_trained = self._train_multi_initial(
#    2322         X=X,
#    2323         y=y,
#    2324         models=models,
#    2325         k_fold=k_fold,
#    2326         n_repeats=n_repeats_initial,
#    2327         hyperparameter_tune_kwargs=hyperparameter_tune_kwargs,
#    2328         feature_prune_kwargs=feature_prune_kwargs,
#    2329         time_limit=time_limit,
#    2330         **kwargs,
#    2331     )
#    2332     n_repeat_start = n_repeats_initial
#    2333     if time_limit is not None:
#
# File ~/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/core/trainer/abstract_trainer.py:2170, in AbstractTrainer._train_multi_initial(self, X, y, models, k_fold, n_repeats, hyperparameter_tune_kwargs, time_limit, feature_prune_kwargs, **kwargs)
#    2168 else:
#    2169     time_ratio = hpo_time_ratio if hpo_enabled else 1
# -> 2170     models = self._train_multi_fold(
#    2171         models=models,
#    2172         hyperparameter_tune_kwargs=hyperparameter_tune_kwargs,
#    2173         k_fold_start=0,
#    2174         k_fold_end=k_fold,
#    2175         n_repeats=n_repeats,
#    2176         n_repeat_start=0,
#    2177         time_limit=time_limit,
#    2178         time_split=time_split,
#    2179         time_ratio=time_ratio,
#    2180         **fit_args,
#    2181     )
#    2183 multi_fold_time_elapsed = time.time() - multi_fold_time_start
#    2184 if time_limit is not None:
#
# File ~/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/core/trainer/abstract_trainer.py:2278, in AbstractTrainer._train_multi_fold(self, X, y, models, time_limit, time_split, time_ratio, hyperparameter_tune_kwargs, **kwargs)
#    2276         time_start_model = time.time()
#    2277         time_left = time_limit - (time_start_model - time_start)
# -> 2278 model_name_trained_lst = self._train_single_full(
#    2279     X, y, model, time_limit=time_left, hyperparameter_tune_kwargs=hyperparameter_tune_kwargs_model, **kwargs
#    2280 )
#    2282 if self.low_memory:
#    2283     del model
#
# File ~/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/core/trainer/abstract_trainer.py:2051, in AbstractTrainer._train_single_full(self, X, y, model, X_unlabeled, X_val, y_val, X_pseudo, y_pseudo, feature_prune, hyperparameter_tune_kwargs, stack_name, k_fold, k_fold_start, k_fold_end, n_repeats, n_repeat_start, level, time_limit, fit_kwargs, compute_score, total_resources, **kwargs)
#    2047         bagged_model_fit_kwargs = self._get_bagged_model_fit_kwargs(
#    2048             k_fold=k_fold, k_fold_start=k_fold_start, k_fold_end=k_fold_end, n_repeats=n_repeats, n_repeat_start=n_repeat_start
#    2049         )
#    2050         model_fit_kwargs.update(bagged_model_fit_kwargs)
# -> 2051     model_names_trained = self._train_and_save(
#    2052         X=X,
#    2053         y=y,
#    2054         model=model,
#    2055         X_val=X_val,
#    2056         y_val=y_val,
#    2057         X_unlabeled=X_unlabeled,
#    2058         stack_name=stack_name,
#    2059         level=level,
#    2060         compute_score=compute_score,
#    2061         total_resources=total_resources,
#    2062         **model_fit_kwargs,
#    2063     )
#    2064 self.save()
#    2065 return model_names_trained
#
# File ~/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/core/trainer/abstract_trainer.py:1733, in AbstractTrainer._train_and_save(self, X, y, model, X_val, y_val, stack_name, level, compute_score, total_resources, **model_fit_kwargs)
#    1731     model = self._train_single(X_w_pseudo, y_w_pseudo, model, X_val, y_val, **model_fit_kwargs)
#    1732 else:
# -> 1733     model = self._train_single(X, y, model, X_val, y_val, total_resources=total_resources, **model_fit_kwargs)
#    1735 fit_end_time = time.time()
#    1736 if self.weight_evaluation:
#
# File ~/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/core/trainer/abstract_trainer.py:1684, in AbstractTrainer._train_single(self, X, y, model, X_val, y_val, total_resources, **model_fit_kwargs)
#    1679 def _train_single(self, X, y, model: AbstractModel, X_val=None, y_val=None, total_resources=None, **model_fit_kwargs) -> AbstractModel:
#    1680     """
#    1681     Trains model but does not add the trained model to this Trainer.
#    1682     Returns trained model object.
#    1683     """
# -> 1684     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, total_resources=total_resources, **model_fit_kwargs)
#    1685     return model
#
# File ~/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py:829, in AbstractModel.fit(self, **kwargs)
#     827 self.validate_fit_resources(**kwargs)
#     828 self._validate_fit_memory_usage(**kwargs)
# --> 829 out = self._fit(**kwargs)
#     830 if out is None:
#     831     out = self
#
# File ~/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/core/models/ensemble/stacker_ensemble_model.py:169, in StackerEnsembleModel._fit(self, X, y, compute_base_preds, time_limit, **kwargs)
#     167 if time_limit is not None:
#     168     time_limit = time_limit - (time.time() - start_time)
# --> 169 return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#
# File ~/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py:266, in BaggedEnsembleModel._fit(self, X, y, X_val, y_val, X_pseudo, y_pseudo, k_fold, k_fold_start, k_fold_end, n_repeats, n_repeat_start, groups, _skip_oof, **kwargs)
#     264         # Reserve time for final refit model
#     265         kwargs["time_limit"] = kwargs["time_limit"] * folds_to_fit / (folds_to_fit + 1.2)
# --> 266 self._fit_folds(
#     267     X=X,
#     268     y=y,
#     269     model_base=model_base,
#     270     X_pseudo=X_pseudo,
#     271     y_pseudo=y_pseudo,
#     272     k_fold=k_fold,
#     273     k_fold_start=k_fold_start,
#     274     k_fold_end=k_fold_end,
#     275     n_repeats=n_repeats,
#     276     n_repeat_start=n_repeat_start,
#     277     save_folds=save_bag_folds,
#     278     groups=groups,
#     279     **kwargs,
#     280 )
#     281 # FIXME: Cleanup self
#     282 # FIXME: Support `can_refit_full=False` models
#     283 if refit_folds:
#
# File ~/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py:592, in BaggedEnsembleModel._fit_folds(self, X, y, model_base, X_pseudo, y_pseudo, k_fold, k_fold_start, k_fold_end, n_repeats, n_repeat_start, time_limit, sample_weight, save_folds, groups, num_cpus, num_gpus, **kwargs)
#     590 for fold_fit_args in fold_fit_args_list:
#     591     fold_fitting_strategy.schedule_fold_model_fit(**fold_fit_args)
# --> 592 fold_fitting_strategy.after_all_folds_scheduled()
#     594 for model in models:
#     595     # No need to add child times or save child here as this already occurred in the fold_fitting_strategy
#     596     self.add_child(model=model, add_child_times=False)
#
# File ~/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py:508, in ParallelFoldFittingStrategy.after_all_folds_scheduled(self)
#     506 if not self.ray.is_initialized():
#     507     ray_init_args = self._get_ray_init_args()
# --> 508     self.ray.init(**ray_init_args)
#     509 head_node_id = self.ray.get_runtime_context().get_node_id()
#     510 logger.debug(f"Dispatching folds on node {head_node_id}")
#
# File ~/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/ray/_private/client_mode_hook.py:105, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     103     if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     104         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 105 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/ray/_private/worker.py:1555, in init(address, num_cpus, num_gpus, resources, object_store_memory, local_mode, ignore_reinit_error, include_dashboard, dashboard_host, dashboard_port, job_config, configure_logging, logging_level, logging_format, log_to_driver, namespace, runtime_env, storage, **kwargs)
#    1552 else:
#    1553     logger.info(info_str)
# -> 1555 connect(
#    1556     _global_node,
#    1557     _global_node.session_name,
#    1558     mode=driver_mode,
#    1559     log_to_driver=log_to_driver,
#    1560     worker=global_worker,
#    1561     driver_object_store_memory=_driver_object_store_memory,
#    1562     job_id=None,
#    1563     namespace=namespace,
#    1564     job_config=job_config,
#    1565     entrypoint=ray._private.utils.get_entrypoint_name(),
#    1566 )
#    1567 if job_config and job_config.code_search_path:
#    1568     global_worker.set_load_code_from_local(True)
#
# File ~/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/ray/_private/worker.py:2067, in connect(node, session_name, mode, log_to_driver, worker, driver_object_store_memory, job_id, namespace, job_config, runtime_env_hash, startup_token, ray_debugger_external, entrypoint)
#    2065 else:
#    2066     logs_dir = node.get_logs_dir_path()
# -> 2067 worker.core_worker = ray._raylet.CoreWorker(
#    2068     mode,
#    2069     node.plasma_store_socket_name,
#    2070     node.raylet_socket_name,
#    2071     job_id,
#    2072     gcs_options,
#    2073     logs_dir,
#    2074     node.node_ip_address,
#    2075     node.node_manager_port,
#    2076     node.raylet_ip_address,
#    2077     (mode == LOCAL_MODE),
#    2078     driver_name,
#    2079     log_stdout_file_path,
#    2080     log_stderr_file_path,
#    2081     serialized_job_config,
#    2082     node.metrics_agent_port,
#    2083     runtime_env_hash,
#    2084     startup_token,
#    2085     session_name,
#    2086     "" if mode != SCRIPT_MODE else entrypoint,
#    2087 )
#    2089 # Notify raylet that the core worker is ready.
#    2090 worker.core_worker.notify_raylet()
#
# KeyboardInterrupt:

# %%
predictor2 = TabularPredictor(label="pv_measurement", eval_metric='mean_absolute_error').fit(
    train2,

    presets="best_quality", 
    # hyperparameters='very_large', 
    # time_limit=6000,
    # tuning_data = tuning2,
    # use_bag_holdout=True,
    # num_bag_folds= 6,
    # refit_full = True,
    # auto_stack = True,
    # num_bag_sets= 10,
    # set_best_to_refit_full= True,
    # num_stack_levels = 2,
    # verbosity = 3
    
    )

# tuning_data
# num bag holdout 6
# bag_holdout
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20231108_103105"
# Presets specified: ['best_quality']
# /Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/core/utils/utils.py:564: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20231108_103105"
# AutoGluon Version:  0.8.3b20231102
# Python Version:     3.11.4
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 22.4.0: Mon Mar  6 20:59:28 PST 2023; root:xnu-8796.101.5~3/RELEASE_ARM64_T6000
# Disk Space Avail:   252.95 GB / 494.38 GB (51.2%)
# Train Data Rows:    13968
# Train Data Columns: 46
# Label Column: pv_measurement
# Preprocessing data ...
# /Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/core/utils/utils.py:564: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (1152.3, 0.0, 198.77992, 256.1594)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# /Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/tabular/learner/default_learner.py:215: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    6296.31 MB
# 	Train Data (Original)  Memory Usage: 2.79 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 3 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Unused Original Features (Count: 1): ['snow_drift:idx']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('float', []) : 1 | ['snow_drift:idx']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 45 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 43 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 		('int', ['bool']) :  2 | ['elevation:m', 'snow_density:kgm3']
# 	0.1s = Fit runtime
# 	45 features in original data used to generate 45 features in processed data.
# 	Train Data (Processed) Memory Usage: 2.65 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.11s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ...
# 	-75.228	 = Validation score   (-mean_absolute_error)
# 	0.01s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ...
# 	-75.444	 = Validation score   (-mean_absolute_error)
# 	0.01s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-40.5504	 = Validation score   (-mean_absolute_error)
# 	16.76s	 = Training   runtime
# 	24.32s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-43.0029	 = Validation score   (-mean_absolute_error)
# 	25.88s	 = Training   runtime
# 	19.37s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ...
# 	-48.774	 = Validation score   (-mean_absolute_error)
# 	12.26s	 = Training   runtime
# 	0.39s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-43.1554	 = Validation score   (-mean_absolute_error)
# 	162.33s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ...
# 	-48.6972	 = Validation score   (-mean_absolute_error)
# 	2.52s	 = Training   runtime
# 	0.41s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	Warning: Exception caused NeuralNetFastAI_BAG_L1 to fail during training (ImportError)... Skipping this model.
# 		ray::_ray_fit() (pid=14377, ip=127.0.0.1)
# ModuleNotFoundError: No module named 'fastai'
#
# During handling of the above exception, another exception occurred:
#
# ray::_ray_fit() (pid=14377, ip=127.0.0.1)
#   File "/Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 402, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 854, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py", line 208, in _fit
#     try_import_fastai()
#   File "/Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/common/utils/try_import.py", line 123, in try_import_fastai
#     raise ImportError(f"Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]=={__version__}`. ")
# ImportError: Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]==0.8.3b20231102`.
# Fitting model: XGBoost_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 2023-11-08 11:35:07,893	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-08 11:35:07,901	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-08 11:35:07,902	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-08 11:35:07,903	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=14374, ip=127.0.0.1)
# ModuleNotFoundError: No module named 'fastai'
#
# During handling of the above exception, another exception occurred:
#
# ray::_ray_fit() (pid=14374, ip=127.0.0.1)
#   File "/Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 402, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 854, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py", line 208, in _fit
#     try_import_fastai()
#   File "/Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/common/utils/try_import.py", line 123, in try_import_fastai
#     raise ImportError(f"Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]=={__version__}`. ")
# ImportError: Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]==0.8.3b20231102`.
# 2023-11-08 11:35:07,904	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=14375, ip=127.0.0.1)
# ModuleNotFoundError: No module named 'fastai'
#
# During handling of the above exception, another exception occurred:
#
# ray::_ray_fit() (pid=14375, ip=127.0.0.1)
#   File "/Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 402, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 854, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py", line 208, in _fit
#     try_import_fastai()
#   File "/Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/common/utils/try_import.py", line 123, in try_import_fastai
#     raise ImportError(f"Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]=={__version__}`. ")
# ImportError: Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]==0.8.3b20231102`.
# 2023-11-08 11:35:07,905	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-08 11:35:07,906	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	-45.0664	 = Validation score   (-mean_absolute_error)
# 	68.03s	 = Training   runtime
# 	5.88s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-47.1817	 = Validation score   (-mean_absolute_error)
# 	17.79s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-42.462	 = Validation score   (-mean_absolute_error)
# 	77.93s	 = Training   runtime
# 	41.99s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-40.0561	 = Validation score   (-mean_absolute_error)
# 	0.19s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 9 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-41.0539	 = Validation score   (-mean_absolute_error)
# 	2.17s	 = Training   runtime
# 	0.22s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-40.7599	 = Validation score   (-mean_absolute_error)
# 	2.03s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ...
# 	-40.3605	 = Validation score   (-mean_absolute_error)
# 	18.26s	 = Training   runtime
# 	0.39s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-40.3732	 = Validation score   (-mean_absolute_error)
# 	10.39s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ...
# 	-40.1545	 = Validation score   (-mean_absolute_error)
# 	3.17s	 = Training   runtime
# 	0.42s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	Warning: Exception caused NeuralNetFastAI_BAG_L2 to fail during training (ImportError)... Skipping this model.
# 		ray::_ray_fit() (pid=14514, ip=127.0.0.1)
# ModuleNotFoundError: No module named 'fastai'
#
# During handling of the above exception, another exception occurred:
#
# ray::_ray_fit() (pid=14514, ip=127.0.0.1)
#   File "/Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 402, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 854, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py", line 208, in _fit
#     try_import_fastai()
#   File "/Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/common/utils/try_import.py", line 123, in try_import_fastai
#     raise ImportError(f"Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]=={__version__}`. ")
# ImportError: Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]==0.8.3b20231102`.
# Fitting model: XGBoost_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-40.4362	 = Validation score   (-mean_absolute_error)
# 	3.93s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 2023-11-08 11:38:51,333	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-08 11:38:51,334	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-08 11:38:51,335	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-08 11:38:51,340	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-08 11:38:51,341	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-08 11:38:51,341	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-08 11:38:51,342	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	-40.2431	 = Validation score   (-mean_absolute_error)
# 	9.81s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-40.9198	 = Validation score   (-mean_absolute_error)
# 	5.49s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ...
# 	-39.3938	 = Validation score   (-mean_absolute_error)
# 	0.29s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 483.88s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20231108_103105")

# %%
predictor3 = TabularPredictor(label="pv_measurement", eval_metric='mean_absolute_error' ).fit(
    train3,

    presets='best_quality', 
    # hyperparameters='very_large', 
    # time_limit=6000,
    # tuning_data = tuning3,
    # use_bag_holdout=True,
    # num_bag_folds= 6,
    # refit_full = True,
    # auto_stack = True,
    # num_bag_sets= 10,
    # set_best_to_refit_full= True,
    # num_stack_levels = 2,
    # verbosity = 3
    
    )
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20231108_103909"
# Presets specified: ['best_quality']
# /Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/core/utils/utils.py:564: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20231108_103909"
# AutoGluon Version:  0.8.3b20231102
# Python Version:     3.11.4
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 22.4.0: Mon Mar  6 20:59:28 PST 2023; root:xnu-8796.101.5~3/RELEASE_ARM64_T6000
# Disk Space Avail:   249.94 GB / 494.38 GB (50.6%)
# Train Data Rows:    11391
# Train Data Columns: 46
# Label Column: pv_measurement
# Preprocessing data ...
# /Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/core/utils/utils.py:564: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and label-values can't be converted to int).
# 	Label info (max, min, mean, stddev): (999.6, 0.0, 177.83632, 212.52999)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# /Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/tabular/learner/default_learner.py:215: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    5839.96 MB
# 	Train Data (Original)  Memory Usage: 2.28 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 3 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Unused Original Features (Count: 1): ['snow_drift:idx']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('float', []) : 1 | ['snow_drift:idx']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 45 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 43 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 		('int', ['bool']) :  2 | ['elevation:m', 'snow_density:kgm3']
# 	0.1s = Fit runtime
# 	45 features in original data used to generate 45 features in processed data.
# 	Train Data (Processed) Memory Usage: 2.16 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.13s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ...
# 	-60.1803	 = Validation score   (-mean_absolute_error)
# 	0.01s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ...
# 	-60.2328	 = Validation score   (-mean_absolute_error)
# 	0.01s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-35.8052	 = Validation score   (-mean_absolute_error)
# 	15.6s	 = Training   runtime
# 	19.2s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-38.1988	 = Validation score   (-mean_absolute_error)
# 	21.6s	 = Training   runtime
# 	11.31s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ...
# 	-43.5577	 = Validation score   (-mean_absolute_error)
# 	8.78s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-37.9803	 = Validation score   (-mean_absolute_error)
# 	141.74s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ...
# 	-43.2387	 = Validation score   (-mean_absolute_error)
# 	1.85s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	Warning: Exception caused NeuralNetFastAI_BAG_L1 to fail during training (ImportError)... Skipping this model.
# 		ray::_ray_fit() (pid=14646, ip=127.0.0.1)
# ModuleNotFoundError: No module named 'fastai'
#
# During handling of the above exception, another exception occurred:
#
# ray::_ray_fit() (pid=14646, ip=127.0.0.1)
#   File "/Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 402, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 854, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py", line 208, in _fit
#     try_import_fastai()
#   File "/Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/common/utils/try_import.py", line 123, in try_import_fastai
#     raise ImportError(f"Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]=={__version__}`. ")
# ImportError: Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]==0.8.3b20231102`.
# Fitting model: XGBoost_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 2023-11-08 11:42:38,976	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-08 11:42:38,978	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-08 11:42:38,978	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-08 11:42:38,979	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-08 11:42:38,980	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-08 11:42:38,981	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=14643, ip=127.0.0.1)
# ModuleNotFoundError: No module named 'fastai'
#
# During handling of the above exception, another exception occurred:
#
# ray::_ray_fit() (pid=14643, ip=127.0.0.1)
#   File "/Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 402, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 854, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py", line 208, in _fit
#     try_import_fastai()
#   File "/Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/common/utils/try_import.py", line 123, in try_import_fastai
#     raise ImportError(f"Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]=={__version__}`. ")
# ImportError: Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]==0.8.3b20231102`.
# 2023-11-08 11:42:38,982	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	-40.0172	 = Validation score   (-mean_absolute_error)
# 	52.8s	 = Training   runtime
# 	2.89s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-40.9587	 = Validation score   (-mean_absolute_error)
# 	19.01s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-38.0644	 = Validation score   (-mean_absolute_error)
# 	76.85s	 = Training   runtime
# 	22.19s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-35.4126	 = Validation score   (-mean_absolute_error)
# 	0.16s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 9 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-36.6085	 = Validation score   (-mean_absolute_error)
# 	1.97s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-36.2169	 = Validation score   (-mean_absolute_error)
# 	2.46s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ...
# 	-35.6854	 = Validation score   (-mean_absolute_error)
# 	13.68s	 = Training   runtime
# 	0.29s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-36.114	 = Validation score   (-mean_absolute_error)
# 	7.78s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ...
# 	-35.5494	 = Validation score   (-mean_absolute_error)
# 	2.46s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	Warning: Exception caused NeuralNetFastAI_BAG_L2 to fail during training (ImportError)... Skipping this model.
# 		ray::_ray_fit() (pid=14812, ip=127.0.0.1)
# ModuleNotFoundError: No module named 'fastai'
#
# During handling of the above exception, another exception occurred:
#
# ray::_ray_fit() (pid=14812, ip=127.0.0.1)
#   File "/Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 402, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 854, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py", line 208, in _fit
#     try_import_fastai()
#   File "/Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/common/utils/try_import.py", line 123, in try_import_fastai
#     raise ImportError(f"Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]=={__version__}`. ")
# ImportError: Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]==0.8.3b20231102`.
# Fitting model: XGBoost_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-36.1564	 = Validation score   (-mean_absolute_error)
# 	3.76s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 2023-11-08 11:45:58,331	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=14808, ip=127.0.0.1)
# ModuleNotFoundError: No module named 'fastai'
#
# During handling of the above exception, another exception occurred:
#
# ray::_ray_fit() (pid=14808, ip=127.0.0.1)
#   File "/Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 402, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 854, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py", line 208, in _fit
#     try_import_fastai()
#   File "/Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/common/utils/try_import.py", line 123, in try_import_fastai
#     raise ImportError(f"Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]=={__version__}`. ")
# ImportError: Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]==0.8.3b20231102`.
# 2023-11-08 11:45:58,332	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=14810, ip=127.0.0.1)
# ModuleNotFoundError: No module named 'fastai'
#
# During handling of the above exception, another exception occurred:
#
# ray::_ray_fit() (pid=14810, ip=127.0.0.1)
#   File "/Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 402, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 854, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py", line 208, in _fit
#     try_import_fastai()
#   File "/Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/common/utils/try_import.py", line 123, in try_import_fastai
#     raise ImportError(f"Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]=={__version__}`. ")
# ImportError: Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]==0.8.3b20231102`.
# 2023-11-08 11:45:58,333	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=14809, ip=127.0.0.1)
# ModuleNotFoundError: No module named 'fastai'
#
# During handling of the above exception, another exception occurred:
#
# ray::_ray_fit() (pid=14809, ip=127.0.0.1)
#   File "/Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 402, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 854, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py", line 208, in _fit
#     try_import_fastai()
#   File "/Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/common/utils/try_import.py", line 123, in try_import_fastai
#     raise ImportError(f"Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]=={__version__}`. ")
# ImportError: Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]==0.8.3b20231102`.
# 2023-11-08 11:45:58,334	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=14814, ip=127.0.0.1)
# ModuleNotFoundError: No module named 'fastai'
#
# During handling of the above exception, another exception occurred:
#
# ray::_ray_fit() (pid=14814, ip=127.0.0.1)
#   File "/Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 402, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 854, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py", line 208, in _fit
#     try_import_fastai()
#   File "/Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/common/utils/try_import.py", line 123, in try_import_fastai
#     raise ImportError(f"Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]=={__version__}`. ")
# ImportError: Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]==0.8.3b20231102`.
# 2023-11-08 11:45:58,336	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=14815, ip=127.0.0.1)
# ModuleNotFoundError: No module named 'fastai'
#
# During handling of the above exception, another exception occurred:
#
# ray::_ray_fit() (pid=14815, ip=127.0.0.1)
#   File "/Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 402, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 854, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py", line 208, in _fit
#     try_import_fastai()
#   File "/Users/henningdropping/anaconda3/lib/python3.11/site-packages/autogluon/common/utils/try_import.py", line 123, in try_import_fastai
#     raise ImportError(f"Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]=={__version__}`. ")
# ImportError: Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]==0.8.3b20231102`.
# 2023-11-08 11:45:58,337	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	-35.9491	 = Validation score   (-mean_absolute_error)
# 	11.41s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-36.6212	 = Validation score   (-mean_absolute_error)
# 	6.53s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ...
# 	-34.9022	 = Validation score   (-mean_absolute_error)
# 	0.26s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 429.76s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20231108_103909")

# %%
test1 = pipin.get_test_data("A")
test2 = pipin.get_test_data("B")
test3 = pipin.get_test_data("C")

test1 = test1.drop(columns=drop)
test2 = test2.drop(columns=drop)
test3 = test3.drop(columns=drop)

# %%
test_data1 = TabularDataset(test1)
test_data2 = TabularDataset(test2)
test_data3 = TabularDataset(test3)

pred1 = pd.DataFrame(predictor1.predict(test_data1))
pred2 = pd.DataFrame(predictor2.predict(test_data2))
pred3 = pd.DataFrame(predictor3.predict(test_data3))

negatives_pred1 = pred1[pred1["pv_measurement"] < 0]
negatives_pred2 = pred2[pred2["pv_measurement"] < 0]
negatives_pred3 = pred3[pred3["pv_measurement"] < 0]
neg = pd.concat([negatives_pred1, negatives_pred2, negatives_pred3])
neg.shape
# Out:
# (181, 1)

# %%
#from utils import get_unique_filename
pred = pd.concat([pred1, pred2, pred3])
final_prediction = pipin.post_processing(pred, prediction_column="pv_measurement")
final_prediction.to_csv("winner_6.csv")

# %%
diff = pipin.compare_mae(final_prediction)
diff
# Out:
# 60.603437962681795

# %%
# predictor.evaluate(df1, silent=True)
