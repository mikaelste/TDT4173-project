# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from autogluon.tabular import TabularDataset, TabularPredictor
import pandas as pd
import numpy as np

# %%
# %autoreload
import sys
sys.path.append('../')
from pipeline import Pipeline
pipin = Pipeline()

# %%
df1_0 = pipin.get_data("A")
df2_0 = pipin.get_data("B")
df3_0 = pipin.get_data("C")

df1, tuning1 = pipin.split_train_tune(df1_0)
df2, tuning2 = pipin.split_train_tune(df2_0)
df3, tuning3 = pipin.split_train_tune(df3_0)

# %%
train1, tuning1 = TabularDataset(df1), TabularDataset(tuning1)
train2, tuning2 = TabularDataset(df2), TabularDataset(tuning2)
train3, tuning3 = TabularDataset(df3), TabularDataset(tuning3)

# %%
label="pv_measurement"
eval_metric="mean_absolute_error"

# %%
predictor1 = TabularPredictor(label=label, eval_metric=eval_metric).fit(
    train1,
    # time_limit=6000,
    # hyperparameters='extrme', 
    presets='best_quality', 
    tuning_data = tuning1,
    use_bag_holdout=True,
    # refit_full = True,
    # auto_stack = True,
    # num_bag_sets= 10,
    # set_best_to_refit_full= True,
    # num_stack_levels = 2,
    # verbosity = 3
    )
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20231106_225048/"
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20231106_225048/"
# AutoGluon Version:  0.8.2
# Python Version:     3.10.13
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 22.5.0: Thu Jun  8 22:22:20 PDT 2023; root:xnu-8796.121.3~7/RELEASE_ARM64_T6000
# Disk Space Avail:   674.68 GB / 994.66 GB (67.8%)
# Train Data Rows:    31864
# Train Data Columns: 49
# Tuning Data Rows:    31888
# Tuning Data Columns: 49
# Label Column: pv_measurement
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (5733.42, 0.0, 699.40134, 1211.74895)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    11679.96 MB
# 	Train Data (Original)  Memory Usage: 13.52 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 3 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Unused Original Features (Count: 1): ['snow_drift:idx']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('float', []) : 1 | ['snow_drift:idx']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 48 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 46 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 		('int', ['bool']) :  2 | ['elevation:m', 'snow_density:kgm3']
# 	0.9s = Fit runtime
# 	48 features in original data used to generate 48 features in processed data.
# 	Train Data (Processed) Memory Usage: 12.88 MB (0.1% of available memory)
# Data preprocessing and feature engineering runtime = 1.15s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# use_bag_holdout=True, will use tuning_data as holdout (will not be used for early stopping).
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ...
# 	-213.8646	 = Validation score   (-mean_absolute_error)
# 	0.03s	 = Training   runtime
# 	1.9s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ...
# 	-23.5942	 = Validation score   (-mean_absolute_error)
# 	0.02s	 = Training   runtime
# 	1.66s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-51.3959	 = Validation score   (-mean_absolute_error)
# 	114.39s	 = Training   runtime
# 	91.71s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-36.2892	 = Validation score   (-mean_absolute_error)
# 	46.53s	 = Training   runtime
# 	117.7s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ...
# 	-75.0745	 = Validation score   (-mean_absolute_error)
# 	76.07s	 = Training   runtime
# 	2.79s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-63.464	 = Validation score   (-mean_absolute_error)
# 	446.39s	 = Training   runtime
# 	0.36s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ...
# 	-75.0198	 = Validation score   (-mean_absolute_error)
# 	9.27s	 = Training   runtime
# 	1.18s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-161.6312	 = Validation score   (-mean_absolute_error)
# 	134.98s	 = Training   runtime
# 	0.55s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-36.0608	 = Validation score   (-mean_absolute_error)
# 	466.27s	 = Training   runtime
# 	53.79s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-111.9746	 = Validation score   (-mean_absolute_error)
# 	251.99s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-33.314	 = Validation score   (-mean_absolute_error)
# 	134.98s	 = Training   runtime
# 	383.43s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-23.5942	 = Validation score   (-mean_absolute_error)
# 	0.39s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 9 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-47.8855	 = Validation score   (-mean_absolute_error)
# 	26.47s	 = Training   runtime
# 	3.56s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-44.0553	 = Validation score   (-mean_absolute_error)
# 	5.92s	 = Training   runtime
# 	0.71s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ...
# 	-46.6715	 = Validation score   (-mean_absolute_error)
# 	54.27s	 = Training   runtime
# 	1.27s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-47.5199	 = Validation score   (-mean_absolute_error)
# 	26.86s	 = Training   runtime
# 	0.27s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ...
# 	-45.9551	 = Validation score   (-mean_absolute_error)
# 	71.84s	 = Training   runtime
# 	1.84s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-44.7183	 = Validation score   (-mean_absolute_error)
# 	92.97s	 = Training   runtime
# 	0.42s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-45.4782	 = Validation score   (-mean_absolute_error)
# 	5.97s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-47.8183	 = Validation score   (-mean_absolute_error)
# 	61.0s	 = Training   runtime
# 	0.42s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-39.5208	 = Validation score   (-mean_absolute_error)
# 	187.2s	 = Training   runtime
# 	57.88s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ...
# 	-38.1177	 = Validation score   (-mean_absolute_error)
# 	0.52s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 3076.17s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20231106_225048/")

# %%
predictor2 = TabularPredictor(label=label, eval_metric=eval_metric).fit(
    train2,
    # time_limit=6000,

    presets='best_quality', 
    # hyperparameters='very_large', 
    tuning_data = tuning2,
    use_bag_holdout=True,
    # refit_full = True,
    # auto_stack = True,
    # num_bag_sets= 10,
    # set_best_to_refit_full= True,
    # num_stack_levels = 2,
    # verbosity = 3
    )

# tuning_data
# num bag holdout 6
# bag_holdout
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20231106_234204/"
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20231106_234204/"
# AutoGluon Version:  0.8.2
# Python Version:     3.10.13
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 22.5.0: Thu Jun  8 22:22:20 PDT 2023; root:xnu-8796.121.3~7/RELEASE_ARM64_T6000
# Disk Space Avail:   663.37 GB / 994.66 GB (66.7%)
# Train Data Rows:    31018
# Train Data Columns: 49
# Tuning Data Rows:    31044
# Tuning Data Columns: 49
# Label Column: pv_measurement
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (1152.3, 0.0, 97.7652, 194.68285)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    11377.94 MB
# 	Train Data (Original)  Memory Usage: 13.16 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 2 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Unused Original Features (Count: 1): ['wind_speed_w_1000hPa:ms']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('float', []) : 1 | ['wind_speed_w_1000hPa:ms']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 48 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 46 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 		('int', ['bool']) :  2 | ['elevation:m', 'snow_density:kgm3']
# 	0.4s = Fit runtime
# 	48 features in original data used to generate 48 features in processed data.
# 	Train Data (Processed) Memory Usage: 12.54 MB (0.1% of available memory)
# Data preprocessing and feature engineering runtime = 0.56s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# use_bag_holdout=True, will use tuning_data as holdout (will not be used for early stopping).
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ...
# 	-45.1848	 = Validation score   (-mean_absolute_error)
# 	0.03s	 = Training   runtime
# 	1.93s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ...
# 	-3.7575	 = Validation score   (-mean_absolute_error)
# 	0.02s	 = Training   runtime
# 	2.06s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-10.1697	 = Validation score   (-mean_absolute_error)
# 	63.79s	 = Training   runtime
# 	77.01s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-6.7576	 = Validation score   (-mean_absolute_error)
# 	105.42s	 = Training   runtime
# 	134.91s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ...
# 	-13.7929	 = Validation score   (-mean_absolute_error)
# 	140.05s	 = Training   runtime
# 	1.25s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-11.8161	 = Validation score   (-mean_absolute_error)
# 	856.92s	 = Training   runtime
# 	0.78s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ...
# 	-14.5219	 = Validation score   (-mean_absolute_error)
# 	46.84s	 = Training   runtime
# 	7.29s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	Warning: Exception caused NeuralNetFastAI_BAG_L1 to fail during training... Skipping this model.
# 		ray::_ray_fit() (pid=52171, ip=127.0.0.1)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 402, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 829, in fit
#     out = self._fit(**kwargs)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py", line 327, in _fit
#     self.model.fit_one_cycle(epochs, params["lr"], cbs=callbacks)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/callback/schedule.py", line 119, in fit_one_cycle
#     self.fit(n_epoch, cbs=ParamScheduler(scheds)+L(cbs), reset_opt=reset_opt, wd=wd, start_epoch=start_epoch)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/learner.py", line 264, in fit
#     self._with_events(self._do_fit, 'fit', CancelFitException, self._end_cleanup)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/learner.py", line 201, in _with_events
#     self(f'after_{event_type}');  final()
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/learner.py", line 172, in __call__
#     def __call__(self, event_name): L(event_name).map(self._call_one)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastcore/foundation.py", line 156, in map
#     def map(self, f, *args, **kwargs): return self._new(map_ex(self, f, *args, gen=False, **kwargs))
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastcore/basics.py", line 840, in map_ex
#     return list(res)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastcore/basics.py", line 825, in __call__
#     return self.func(*fargs, **kwargs)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/learner.py", line 176, in _call_one
#     for cb in self.cbs.sorted('order'): cb(event_name)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/callback/core.py", line 62, in __call__
#     except Exception as e: raise modify_exception(e, f'Exception occured in `{self.__class__.__name__}` when calling event `{event_name}`:\n\t{e.args[0]}', replace=True)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/callback/core.py", line 60, in __call__
#     try: res = getcallable(self, event_name)()
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/callbacks.py", line 107, in after_fit
#     self.learn.load(f"{self.fname}", with_opt=self.with_opt)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/learner.py", line 420, in load
#     load_model(file, self.model, self.opt, device=device, **kwargs)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/learner.py", line 51, in load_model
#     state = torch.load(file, map_location=device, **torch_load_kwargs)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/torch/serialization.py", line 771, in load
#     with _open_file_like(f, 'rb') as opened_file:
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/torch/serialization.py", line 270, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/torch/serialization.py", line 251, in __init__
#     super(_open_file, self).__init__(open(name, mode))
# FileNotFoundError: [Errno 2] No such file or directory: '/var/folders/b0/slnc__2x31jczblnsfgfmjw00000gn/T/tmp2x1brbjl/models/model.pth'
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/core/trainer/abstract_trainer.py", line 1733, in _train_and_save
#     model = self._train_single(X, y, model, X_val, y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/core/trainer/abstract_trainer.py", line 1684, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 829, in fit
#     out = self._fit(**kwargs)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/core/models/ensemble/stacker_ensemble_model.py", line 169, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 266, in _fit
#     self._fit_folds(
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 592, in _fit_folds
#     fold_fitting_strategy.after_all_folds_scheduled()
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 581, in after_all_folds_scheduled
#     raise processed_exception
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 541, in after_all_folds_scheduled
#     fold_model, pred_proba, time_start_fit, time_end_fit, predict_time, predict_1_time = self.ray.get(finished)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 105, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/ray/_private/worker.py", line 2380, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(FileNotFoundError): ray::_ray_fit() (pid=52171, ip=127.0.0.1)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 402, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 829, in fit
#     out = self._fit(**kwargs)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py", line 327, in _fit
#     self.model.fit_one_cycle(epochs, params["lr"], cbs=callbacks)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/callback/schedule.py", line 119, in fit_one_cycle
#     self.fit(n_epoch, cbs=ParamScheduler(scheds)+L(cbs), reset_opt=reset_opt, wd=wd, start_epoch=start_epoch)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/learner.py", line 264, in fit
#     self._with_events(self._do_fit, 'fit', CancelFitException, self._end_cleanup)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/learner.py", line 201, in _with_events
#     self(f'after_{event_type}');  final()
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/learner.py", line 172, in __call__
#     def __call__(self, event_name): L(event_name).map(self._call_one)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastcore/foundation.py", line 156, in map
#     def map(self, f, *args, **kwargs): return self._new(map_ex(self, f, *args, gen=False, **kwargs))
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastcore/basics.py", line 840, in map_ex
#     return list(res)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastcore/basics.py", line 825, in __call__
#     return self.func(*fargs, **kwargs)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/learner.py", line 176, in _call_one
#     for cb in self.cbs.sorted('order'): cb(event_name)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/callback/core.py", line 62, in __call__
#     except Exception as e: raise modify_exception(e, f'Exception occured in `{self.__class__.__name__}` when calling event `{event_name}`:\n\t{e.args[0]}', replace=True)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/callback/core.py", line 60, in __call__
#     try: res = getcallable(self, event_name)()
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/callbacks.py", line 107, in after_fit
#     self.learn.load(f"{self.fname}", with_opt=self.with_opt)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/learner.py", line 420, in load
#     load_model(file, self.model, self.opt, device=device, **kwargs)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/learner.py", line 51, in load_model
#     state = torch.load(file, map_location=device, **torch_load_kwargs)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/torch/serialization.py", line 771, in load
#     with _open_file_like(f, 'rb') as opened_file:
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/torch/serialization.py", line 270, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/torch/serialization.py", line 251, in __init__
#     super(_open_file, self).__init__(open(name, mode))
# FileNotFoundError: [Errno 2] No such file or directory: '/var/folders/b0/slnc__2x31jczblnsfgfmjw00000gn/T/tmp2x1brbjl/models/model.pth'
# Fitting model: XGBoost_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 2023-11-07 01:08:37,837	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-07 01:08:37,852	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-07 01:08:37,853	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-07 01:08:37,859	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-07 01:08:37,861	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-07 01:08:37,862	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	-6.7037	 = Validation score   (-mean_absolute_error)
# 	392.35s	 = Training   runtime
# 	79.02s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-24.0759	 = Validation score   (-mean_absolute_error)
# 	189.63s	 = Training   runtime
# 	0.45s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-6.0528	 = Validation score   (-mean_absolute_error)
# 	339.37s	 = Training   runtime
# 	487.29s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-3.7575	 = Validation score   (-mean_absolute_error)
# 	0.83s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 9 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-9.3696	 = Validation score   (-mean_absolute_error)
# 	14.85s	 = Training   runtime
# 	3.08s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-8.1427	 = Validation score   (-mean_absolute_error)
# 	8.58s	 = Training   runtime
# 	1.03s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ...
# 	-8.1201	 = Validation score   (-mean_absolute_error)
# 	102.96s	 = Training   runtime
# 	4.09s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-8.5399	 = Validation score   (-mean_absolute_error)
# 	48.95s	 = Training   runtime
# 	0.44s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ...
# 	-7.8353	 = Validation score   (-mean_absolute_error)
# 	20.47s	 = Training   runtime
# 	4.13s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	Warning: Exception caused NeuralNetFastAI_BAG_L2 to fail during training... Skipping this model.
# 		ray::_ray_fit() (pid=52619, ip=127.0.0.1)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 402, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 829, in fit
#     out = self._fit(**kwargs)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py", line 327, in _fit
#     self.model.fit_one_cycle(epochs, params["lr"], cbs=callbacks)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/callback/schedule.py", line 119, in fit_one_cycle
#     self.fit(n_epoch, cbs=ParamScheduler(scheds)+L(cbs), reset_opt=reset_opt, wd=wd, start_epoch=start_epoch)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/learner.py", line 264, in fit
#     self._with_events(self._do_fit, 'fit', CancelFitException, self._end_cleanup)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/learner.py", line 201, in _with_events
#     self(f'after_{event_type}');  final()
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/learner.py", line 172, in __call__
#     def __call__(self, event_name): L(event_name).map(self._call_one)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastcore/foundation.py", line 156, in map
#     def map(self, f, *args, **kwargs): return self._new(map_ex(self, f, *args, gen=False, **kwargs))
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastcore/basics.py", line 840, in map_ex
#     return list(res)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastcore/basics.py", line 825, in __call__
#     return self.func(*fargs, **kwargs)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/learner.py", line 176, in _call_one
#     for cb in self.cbs.sorted('order'): cb(event_name)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/callback/core.py", line 62, in __call__
#     except Exception as e: raise modify_exception(e, f'Exception occured in `{self.__class__.__name__}` when calling event `{event_name}`:\n\t{e.args[0]}', replace=True)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/callback/core.py", line 60, in __call__
#     try: res = getcallable(self, event_name)()
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/callbacks.py", line 107, in after_fit
#     self.learn.load(f"{self.fname}", with_opt=self.with_opt)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/learner.py", line 420, in load
#     load_model(file, self.model, self.opt, device=device, **kwargs)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/learner.py", line 51, in load_model
#     state = torch.load(file, map_location=device, **torch_load_kwargs)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/torch/serialization.py", line 771, in load
#     with _open_file_like(f, 'rb') as opened_file:
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/torch/serialization.py", line 270, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/torch/serialization.py", line 251, in __init__
#     super(_open_file, self).__init__(open(name, mode))
# FileNotFoundError: [Errno 2] No such file or directory: '/var/folders/b0/slnc__2x31jczblnsfgfmjw00000gn/T/tmpkd2r_j9_/models/model.pth'
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/core/trainer/abstract_trainer.py", line 1733, in _train_and_save
#     model = self._train_single(X, y, model, X_val, y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/core/trainer/abstract_trainer.py", line 1684, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 829, in fit
#     out = self._fit(**kwargs)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/core/models/ensemble/stacker_ensemble_model.py", line 169, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 266, in _fit
#     self._fit_folds(
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 592, in _fit_folds
#     fold_fitting_strategy.after_all_folds_scheduled()
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 581, in after_all_folds_scheduled
#     raise processed_exception
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 541, in after_all_folds_scheduled
#     fold_model, pred_proba, time_start_fit, time_end_fit, predict_time, predict_1_time = self.ray.get(finished)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 105, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/ray/_private/worker.py", line 2380, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(FileNotFoundError): ray::_ray_fit() (pid=52619, ip=127.0.0.1)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 402, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 829, in fit
#     out = self._fit(**kwargs)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py", line 327, in _fit
#     self.model.fit_one_cycle(epochs, params["lr"], cbs=callbacks)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/callback/schedule.py", line 119, in fit_one_cycle
#     self.fit(n_epoch, cbs=ParamScheduler(scheds)+L(cbs), reset_opt=reset_opt, wd=wd, start_epoch=start_epoch)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/learner.py", line 264, in fit
#     self._with_events(self._do_fit, 'fit', CancelFitException, self._end_cleanup)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/learner.py", line 201, in _with_events
#     self(f'after_{event_type}');  final()
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/learner.py", line 172, in __call__
#     def __call__(self, event_name): L(event_name).map(self._call_one)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastcore/foundation.py", line 156, in map
#     def map(self, f, *args, **kwargs): return self._new(map_ex(self, f, *args, gen=False, **kwargs))
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastcore/basics.py", line 840, in map_ex
#     return list(res)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastcore/basics.py", line 825, in __call__
#     return self.func(*fargs, **kwargs)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/learner.py", line 176, in _call_one
#     for cb in self.cbs.sorted('order'): cb(event_name)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/callback/core.py", line 62, in __call__
#     except Exception as e: raise modify_exception(e, f'Exception occured in `{self.__class__.__name__}` when calling event `{event_name}`:\n\t{e.args[0]}', replace=True)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/callback/core.py", line 60, in __call__
#     try: res = getcallable(self, event_name)()
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/callbacks.py", line 107, in after_fit
#     self.learn.load(f"{self.fname}", with_opt=self.with_opt)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/learner.py", line 420, in load
#     load_model(file, self.model, self.opt, device=device, **kwargs)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/learner.py", line 51, in load_model
#     state = torch.load(file, map_location=device, **torch_load_kwargs)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/torch/serialization.py", line 771, in load
#     with _open_file_like(f, 'rb') as opened_file:
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/torch/serialization.py", line 270, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/torch/serialization.py", line 251, in __init__
#     super(_open_file, self).__init__(open(name, mode))
# FileNotFoundError: [Errno 2] No such file or directory: '/var/folders/b0/slnc__2x31jczblnsfgfmjw00000gn/T/tmpkd2r_j9_/models/model.pth'
# Fitting model: XGBoost_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 2023-11-07 01:38:57,887	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-07 01:38:57,894	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-07 01:38:57,900	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-07 01:38:57,904	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-07 01:38:57,906	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-07 01:38:57,907	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-07 01:38:57,908	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	-8.247	 = Validation score   (-mean_absolute_error)
# 	9.04s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-10.4735	 = Validation score   (-mean_absolute_error)
# 	152.87s	 = Training   runtime
# 	1.19s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-7.9326	 = Validation score   (-mean_absolute_error)
# 	368.27s	 = Training   runtime
# 	139.94s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ...
# 	-7.2644	 = Validation score   (-mean_absolute_error)
# 	1.23s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 4173.24s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20231106_234204/")

# %%
predictor3 = TabularPredictor(label=label, eval_metric=eval_metric).fit(
    train3,
    # time_limit=6000,
    presets='best_quality', 
    tuning_data = tuning3,
    use_bag_holdout=True,
    # hyperparameters='very_large', 
    # refit_full = True,
    # auto_stack = True,
    # num_bag_sets= 10,
    # set_best_to_refit_full= True,
    # num_stack_levels = 2,
    # verbosity = 3
    )
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20231107_005137/"
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20231107_005137/"
# AutoGluon Version:  0.8.2
# Python Version:     3.10.13
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 22.5.0: Thu Jun  8 22:22:20 PDT 2023; root:xnu-8796.121.3~7/RELEASE_ARM64_T6000
# Disk Space Avail:   650.74 GB / 994.66 GB (65.4%)
# Train Data Rows:    24606
# Train Data Columns: 49
# Tuning Data Rows:    24630
# Tuning Data Columns: 49
# Label Column: pv_measurement
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and label-values can't be converted to int).
# 	Label info (max, min, mean, stddev): (999.6, 0.0, 81.53085, 168.85)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    11681.66 MB
# 	Train Data (Original)  Memory Usage: 10.44 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 3 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Unused Original Features (Count: 1): ['snow_drift:idx']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('float', []) : 1 | ['snow_drift:idx']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 48 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 46 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 		('int', ['bool']) :  2 | ['elevation:m', 'snow_density:kgm3']
# 	1.5s = Fit runtime
# 	48 features in original data used to generate 48 features in processed data.
# 	Train Data (Processed) Memory Usage: 9.95 MB (0.1% of available memory)
# Data preprocessing and feature engineering runtime = 1.54s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# use_bag_holdout=True, will use tuning_data as holdout (will not be used for early stopping).
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ...
# 	-24.8066	 = Validation score   (-mean_absolute_error)
# 	0.08s	 = Training   runtime
# 	1.43s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ...
# 	-2.706	 = Validation score   (-mean_absolute_error)
# 	0.09s	 = Training   runtime
# 	1.25s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-5.7202	 = Validation score   (-mean_absolute_error)
# 	67.39s	 = Training   runtime
# 	123.66s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-4.791	 = Validation score   (-mean_absolute_error)
# 	65.06s	 = Training   runtime
# 	148.25s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ...
# 	-9.3495	 = Validation score   (-mean_absolute_error)
# 	32.86s	 = Training   runtime
# 	1.47s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-6.5755	 = Validation score   (-mean_absolute_error)
# 	568.21s	 = Training   runtime
# 	0.39s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ...
# 	-9.3472	 = Validation score   (-mean_absolute_error)
# 	6.29s	 = Training   runtime
# 	0.81s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.1073	 = Validation score   (-mean_absolute_error)
# 	46.04s	 = Training   runtime
# 	0.34s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-4.9137	 = Validation score   (-mean_absolute_error)
# 	204.75s	 = Training   runtime
# 	94.24s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-14.5379	 = Validation score   (-mean_absolute_error)
# 	94.11s	 = Training   runtime
# 	0.22s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-4.6474	 = Validation score   (-mean_absolute_error)
# 	119.15s	 = Training   runtime
# 	279.12s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-2.706	 = Validation score   (-mean_absolute_error)
# 	0.26s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 9 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-7.1297	 = Validation score   (-mean_absolute_error)
# 	3.27s	 = Training   runtime
# 	0.45s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-6.5922	 = Validation score   (-mean_absolute_error)
# 	1.28s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ...
# 	-6.4642	 = Validation score   (-mean_absolute_error)
# 	16.37s	 = Training   runtime
# 	0.57s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-6.8236	 = Validation score   (-mean_absolute_error)
# 	15.09s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ...
# 	-6.38	 = Validation score   (-mean_absolute_error)
# 	2.68s	 = Training   runtime
# 	0.57s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-6.5362	 = Validation score   (-mean_absolute_error)
# 	14.19s	 = Training   runtime
# 	0.24s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-6.6922	 = Validation score   (-mean_absolute_error)
# 	8.18s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-7.0384	 = Validation score   (-mean_absolute_error)
# 	41.26s	 = Training   runtime
# 	0.38s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-6.0521	 = Validation score   (-mean_absolute_error)
# 	91.08s	 = Training   runtime
# 	23.74s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ...
# 	-5.6879	 = Validation score   (-mean_absolute_error)
# 	0.33s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 2029.31s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20231107_005137/")

# %%
test1 = pipin.get_test_data("A")
test2 = pipin.get_test_data("B")
test3 = pipin.get_test_data("C")

# %%
test_data1 = TabularDataset(test1)
test_data2 = TabularDataset(test2)
test_data3 = TabularDataset(test3)

pred1 = pd.DataFrame(predictor1.predict(test_data1))
pred2 = pd.DataFrame(predictor2.predict(test_data2))
pred3 = pd.DataFrame(predictor3.predict(test_data3))

negatives_pred1 = pred1[pred1["pv_measurement"] < 0]
negatives_pred2 = pred2[pred2["pv_measurement"] < 0]
negatives_pred3 = pred3[pred3["pv_measurement"] < 0]
neg = pd.concat([negatives_pred1, negatives_pred2, negatives_pred3])
neg.shape
# Out:
# (0, 1)

# %%
from utils import get_unique_filename
pred = pd.concat([pred1, pred2, pred3])
final_prediction = pipin.post_processing(pred, prediction_column="pv_measurement")
final_prediction.to_csv(get_unique_filename('gluon_3_tuned'))

# %%
diff = pipin.compare_mae(final_prediction)
diff
# Out:
# 149.3343120804446

# %%
# predictor1.evaluate(df1, silent=True)
# Out:
# {'mean_absolute_error': -0.0003879492771304323,
#  'root_mean_squared_error': -0.0017087086938725178,
#  'mean_squared_error': -2.9196854005155256e-06,
#  'r2': 0.9999999999980115,
#  'pearsonr': 0.9999999999991402,
#  'median_absolute_error': -9.155273446026513e-07}
