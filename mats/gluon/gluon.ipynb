# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from autogluon.tabular import TabularDataset, TabularPredictor
import pandas as pd
import numpy as np

# %%
# %autoreload
import sys
sys.path.append('../')
from pipeline import Pipin
pipin = Pipin()
# Out:
# Current working directory: /Users/matsalexander/Desktop/Forest Gump/mats/gluon

# %%
df1 = pipin.get_data("A")
df2 = pipin.get_data("B")
df3 = pipin.get_data("C")

# %%
train1 = TabularDataset(df1)
train2 = TabularDataset(df2)
train3 = TabularDataset(df3)

# %%
predictor = TabularPredictor(label="pv_measurement").fit(train1)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20231103_155513/"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20231103_155513/"
# AutoGluon Version:  0.8.2
# Python Version:     3.10.13
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 22.5.0: Thu Jun  8 22:22:20 PDT 2023; root:xnu-8796.121.3~7/RELEASE_ARM64_T6000
# Disk Space Avail:   791.32 GB / 994.66 GB (79.6%)
# Train Data Rows:    21282
# Train Data Columns: 51
# Label Column: pv_measurement
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (5733.42, 0.0, 1009.90843, 1339.42288)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    18130.78 MB
# 	Train Data (Original)  Memory Usage: 4.85 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 5 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting DatetimeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Useless Original Features (Count: 2): ['elevation:m', 'snow_drift:idx']
# 		These features carry no predictive signal and should be manually investigated.
# 		This is typically a feature which has the same value for all rows.
# 		These features do not need to be present at inference time.
# 	Types of features in original data (raw dtype, special dtypes):
# 		('datetime', []) :  2 | ['time', 'date_calc']
# 		('float', [])    : 43 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 		('int', [])      :  4 | ['is_estimated:idx', 'day_of_year', 'hour', 'month']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])                : 39 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 		('int', [])                  :  3 | ['day_of_year', 'hour', 'month']
# 		('int', ['bool'])            :  5 | ['is_day:idx', 'is_in_shadow:idx', 'snow_density:kgm3', 'wind_speed_w_1000hPa:ms', 'is_estimated:idx']
# 		('int', ['datetime_as_int']) :  9 | ['time', 'time.year', 'time.day', 'time.dayofweek', 'date_calc', ...]
# 	0.2s = Fit runtime
# 	49 features in original data used to generate 56 features in processed data.
# 	Train Data (Processed) Memory Usage: 5.47 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.25s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.1, Train Rows: 19153, Val Rows: 2129
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif ...
# 	-663.6815	 = Validation score   (-root_mean_squared_error)
# 	0.54s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: KNeighborsDist ...
# 	-510.6418	 = Validation score   (-root_mean_squared_error)
# 	0.03s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: LightGBMXT ...
# [1000]	valid_set's rmse: 465.129
# [2000]	valid_set's rmse: 445.259
# [3000]	valid_set's rmse: 438.393
# [4000]	valid_set's rmse: 432.069
# [5000]	valid_set's rmse: 429.45
# [6000]	valid_set's rmse: 427.923
# [7000]	valid_set's rmse: 426.36
# [8000]	valid_set's rmse: 425.19
# [9000]	valid_set's rmse: 424.391
# [10000]	valid_set's rmse: 424.108
# 	-424.0967	 = Validation score   (-root_mean_squared_error)
# 	64.16s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: LightGBM ...
# [1000]	valid_set's rmse: 460.106
# [2000]	valid_set's rmse: 450.608
# [3000]	valid_set's rmse: 447.069
# [4000]	valid_set's rmse: 445.576
# [5000]	valid_set's rmse: 444.689
# [6000]	valid_set's rmse: 444.149
# [7000]	valid_set's rmse: 443.657
# [8000]	valid_set's rmse: 443.476
# [9000]	valid_set's rmse: 443.319
# [10000]	valid_set's rmse: 443.281
# 	-443.2765	 = Validation score   (-root_mean_squared_error)
# 	58.35s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: RandomForestMSE ...
# 	-531.9688	 = Validation score   (-root_mean_squared_error)
# 	13.94s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: CatBoost ...
# 	-447.6923	 = Validation score   (-root_mean_squared_error)
# 	74.66s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: ExtraTreesMSE ...
# 	-520.9169	 = Validation score   (-root_mean_squared_error)
# 	3.49s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# 	-492.8484	 = Validation score   (-root_mean_squared_error)
# 	16.77s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: XGBoost ...
# 	-464.5693	 = Validation score   (-root_mean_squared_error)
# 	39.65s	 = Training   runtime
# 	0.32s	 = Validation runtime
# Fitting model: NeuralNetTorch ...
# 	-496.0105	 = Validation score   (-root_mean_squared_error)
# 	19.1s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBMLarge ...
# [1000]	valid_set's rmse: 456.138
# [2000]	valid_set's rmse: 452.536
# [3000]	valid_set's rmse: 451.913
# [4000]	valid_set's rmse: 451.685
# [5000]	valid_set's rmse: 451.61
# [6000]	valid_set's rmse: 451.583
# [7000]	valid_set's rmse: 451.575
# [8000]	valid_set's rmse: 451.573
# [9000]	valid_set's rmse: 451.571
# [10000]	valid_set's rmse: 451.571
# 	-451.5711	 = Validation score   (-root_mean_squared_error)
# 	290.98s	 = Training   runtime
# 	0.72s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-404.6778	 = Validation score   (-root_mean_squared_error)
# 	0.13s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 586.47s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20231103_155513/")

# %%
predictor2 = TabularPredictor(label="pv_measurement").fit(train2)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20231103_160515/"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20231103_160515/"
# AutoGluon Version:  0.8.2
# Python Version:     3.10.13
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 22.5.0: Thu Jun  8 22:22:20 PDT 2023; root:xnu-8796.121.3~7/RELEASE_ARM64_T6000
# Disk Space Avail:   790.26 GB / 994.66 GB (79.4%)
# Train Data Rows:    14757
# Train Data Columns: 51
# Label Column: pv_measurement
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (1152.3, -0.0, 188.17893, 253.18265)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    15623.51 MB
# 	Train Data (Original)  Memory Usage: 3.36 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 5 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting DatetimeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Useless Original Features (Count: 2): ['elevation:m', 'snow_drift:idx']
# 		These features carry no predictive signal and should be manually investigated.
# 		This is typically a feature which has the same value for all rows.
# 		These features do not need to be present at inference time.
# 	Types of features in original data (raw dtype, special dtypes):
# 		('datetime', []) :  2 | ['time', 'date_calc']
# 		('float', [])    : 43 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 		('int', [])      :  4 | ['is_estimated:idx', 'day_of_year', 'hour', 'month']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])                : 39 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 		('int', [])                  :  3 | ['day_of_year', 'hour', 'month']
# 		('int', ['bool'])            :  5 | ['is_day:idx', 'is_in_shadow:idx', 'snow_density:kgm3', 'wind_speed_w_1000hPa:ms', 'is_estimated:idx']
# 		('int', ['datetime_as_int']) :  9 | ['time', 'time.year', 'time.day', 'time.dayofweek', 'date_calc', ...]
# 	0.2s = Fit runtime
# 	49 features in original data used to generate 56 features in processed data.
# 	Train Data (Processed) Memory Usage: 3.79 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.22s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.1, Train Rows: 13281, Val Rows: 1476
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif ...
# 	-104.9241	 = Validation score   (-root_mean_squared_error)
# 	0.01s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: KNeighborsDist ...
# 	-79.1337	 = Validation score   (-root_mean_squared_error)
# 	0.01s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: LightGBMXT ...
# [1000]	valid_set's rmse: 71.5104
# [2000]	valid_set's rmse: 69.2496
# [3000]	valid_set's rmse: 68.5869
# [4000]	valid_set's rmse: 68.0754
# [5000]	valid_set's rmse: 67.7746
# [6000]	valid_set's rmse: 67.6428
# [7000]	valid_set's rmse: 67.5378
# [8000]	valid_set's rmse: 67.4511
# [9000]	valid_set's rmse: 67.4164
# [10000]	valid_set's rmse: 67.2909
# 	-67.2872	 = Validation score   (-root_mean_squared_error)
# 	68.31s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: LightGBM ...
# [1000]	valid_set's rmse: 74.4439
# [2000]	valid_set's rmse: 73.3697
# [3000]	valid_set's rmse: 73.0204
# [4000]	valid_set's rmse: 72.8835
# [5000]	valid_set's rmse: 72.8263
# [6000]	valid_set's rmse: 72.7736
# [7000]	valid_set's rmse: 72.7459
# [8000]	valid_set's rmse: 72.7274
# [9000]	valid_set's rmse: 72.7229
# [10000]	valid_set's rmse: 72.7196
# 	-72.7195	 = Validation score   (-root_mean_squared_error)
# 	62.79s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Fitting model: RandomForestMSE ...
# 	-82.0518	 = Validation score   (-root_mean_squared_error)
# 	8.18s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: CatBoost ...
# 	-71.3683	 = Validation score   (-root_mean_squared_error)
# 	69.83s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: ExtraTreesMSE ...
# 	-79.6772	 = Validation score   (-root_mean_squared_error)
# 	3.39s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# 	-76.661	 = Validation score   (-root_mean_squared_error)
# 	10.36s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: XGBoost ...
# 	-75.6402	 = Validation score   (-root_mean_squared_error)
# 	25.42s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetTorch ...
# 	-78.4854	 = Validation score   (-root_mean_squared_error)
# 	19.66s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBMLarge ...
# [1000]	valid_set's rmse: 72.8009
# [2000]	valid_set's rmse: 72.4846
# [3000]	valid_set's rmse: 72.4524
# [4000]	valid_set's rmse: 72.4444
# [5000]	valid_set's rmse: 72.4428
# [6000]	valid_set's rmse: 72.4424
# [7000]	valid_set's rmse: 72.4423
# [8000]	valid_set's rmse: 72.4422
# [9000]	valid_set's rmse: 72.4422
# [10000]	valid_set's rmse: 72.4422
# 	-72.4422	 = Validation score   (-root_mean_squared_error)
# 	260.77s	 = Training   runtime
# 	0.59s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-63.1836	 = Validation score   (-root_mean_squared_error)
# 	0.12s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 532.86s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20231103_160515/")

# %%
predictor3 = TabularPredictor(label="pv_measurement").fit(train3)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20231103_161408/"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20231103_161408/"
# AutoGluon Version:  0.8.2
# Python Version:     3.10.13
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 22.5.0: Thu Jun  8 22:22:20 PDT 2023; root:xnu-8796.121.3~7/RELEASE_ARM64_T6000
# Disk Space Avail:   789.47 GB / 994.66 GB (79.4%)
# Train Data Rows:    11993
# Train Data Columns: 51
# Label Column: pv_measurement
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and label-values can't be converted to int).
# 	Label info (max, min, mean, stddev): (999.6, -0.0, 168.90835, 210.73645)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    15010.92 MB
# 	Train Data (Original)  Memory Usage: 2.73 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 4 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting DatetimeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Useless Original Features (Count: 2): ['elevation:m', 'snow_drift:idx']
# 		These features carry no predictive signal and should be manually investigated.
# 		This is typically a feature which has the same value for all rows.
# 		These features do not need to be present at inference time.
# 	Types of features in original data (raw dtype, special dtypes):
# 		('datetime', []) :  2 | ['time', 'date_calc']
# 		('float', [])    : 43 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 		('int', [])      :  4 | ['is_estimated:idx', 'day_of_year', 'hour', 'month']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])                : 40 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 		('int', [])                  :  3 | ['day_of_year', 'hour', 'month']
# 		('int', ['bool'])            :  4 | ['is_day:idx', 'is_in_shadow:idx', 'snow_density:kgm3', 'is_estimated:idx']
# 		('int', ['datetime_as_int']) :  9 | ['time', 'time.year', 'time.day', 'time.dayofweek', 'date_calc', ...]
# 	0.2s = Fit runtime
# 	49 features in original data used to generate 56 features in processed data.
# 	Train Data (Processed) Memory Usage: 3.12 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.2s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.1, Train Rows: 10793, Val Rows: 1200
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif ...
# 	-99.4201	 = Validation score   (-root_mean_squared_error)
# 	0.01s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: KNeighborsDist ...
# 	-75.0663	 = Validation score   (-root_mean_squared_error)
# 	0.01s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: LightGBMXT ...
# [1000]	valid_set's rmse: 58.8059
# [2000]	valid_set's rmse: 57.5958
# [3000]	valid_set's rmse: 56.9751
# [4000]	valid_set's rmse: 56.6684
# [5000]	valid_set's rmse: 56.5887
# [6000]	valid_set's rmse: 56.5278
# [7000]	valid_set's rmse: 56.5002
# [8000]	valid_set's rmse: 56.4893
# [9000]	valid_set's rmse: 56.4515
# [10000]	valid_set's rmse: 56.42
# 	-56.4168	 = Validation score   (-root_mean_squared_error)
# 	59.85s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: LightGBM ...
# [1000]	valid_set's rmse: 59.9473
# [2000]	valid_set's rmse: 59.2962
# [3000]	valid_set's rmse: 59.1973
# 	-59.1846	 = Validation score   (-root_mean_squared_error)
# 	20.91s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: RandomForestMSE ...
# 	-68.5309	 = Validation score   (-root_mean_squared_error)
# 	6.09s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: CatBoost ...
# 	-59.4696	 = Validation score   (-root_mean_squared_error)
# 	54.85s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: ExtraTreesMSE ...
# 	-66.8385	 = Validation score   (-root_mean_squared_error)
# 	1.65s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# 	-62.954	 = Validation score   (-root_mean_squared_error)
# 	7.77s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: XGBoost ...
# 	-61.837	 = Validation score   (-root_mean_squared_error)
# 	9.57s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetTorch ...
# 	-63.2064	 = Validation score   (-root_mean_squared_error)
# 	9.67s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBMLarge ...
# [1000]	valid_set's rmse: 60.8671
# [2000]	valid_set's rmse: 60.7102
# [3000]	valid_set's rmse: 60.6914
# [4000]	valid_set's rmse: 60.6888
# [5000]	valid_set's rmse: 60.6884
# [6000]	valid_set's rmse: 60.6883
# [7000]	valid_set's rmse: 60.6883
# [8000]	valid_set's rmse: 60.6883
# [9000]	valid_set's rmse: 60.6883
# [10000]	valid_set's rmse: 60.6883
# 	-60.6883	 = Validation score   (-root_mean_squared_error)
# 	239.03s	 = Training   runtime
# 	0.37s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-53.5522	 = Validation score   (-root_mean_squared_error)
# 	0.12s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 412.22s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20231103_161408/")

# %%
test1 = pipin.get_test_data("A")
test2 = pipin.get_test_data("B")
test3 = pipin.get_test_data("C")

# %%
test_data1 = TabularDataset(test1)
test_data2 = TabularDataset(test2)
test_data3 = TabularDataset(test3)

pred1 = pd.DataFrame(predictor.predict(test_data1))
pred2 = pd.DataFrame(predictor2.predict(test_data2))
pred3 = pd.DataFrame(predictor3.predict(test_data3))
negatives_pred1 = pred1[pred1["pv_measurement"] < 0]
negatives_pred2 = pred2[pred2["pv_measurement"] < 0]
negatives_pred3 = pred3[pred3["pv_measurement"] < 0]
neg = pd.concat([negatives_pred1, negatives_pred2, negatives_pred3])
neg.shape
# Out:
# (84, 1)

# %%
from utils import get_unique_filename
pred = pd.concat([pred1, pred2, pred3])
final_prediction = pipin.post_processing(pred, prediction_column="pv_measurement")
final_prediction.to_csv(get_unique_filename('gluon'))

# %%
test_data1
# Out:
#                    time  visibility:m  fresh_snow_24h:cm  wind_speed_u_10m:ms  \
# 0   2023-05-01 00:00:00  29907.500000                0.0                2.100
# 1   2023-05-01 01:00:00  29519.074219                0.0                1.925
# 2   2023-05-01 02:00:00  31009.125000                0.0                1.750
# 3   2023-05-01 03:00:00  34552.500000                0.0                1.450
# 4   2023-05-01 04:00:00  35483.875000                0.0                1.300
# ..                  ...           ...                ...                  ...
# 715 2023-07-03 19:00:00  44056.375000                0.0                2.075
# 716 2023-07-03 20:00:00  44017.175781                0.0                2.100
# 717 2023-07-03 21:00:00  43302.050781                0.0                2.150
# 718 2023-07-03 22:00:00  40505.851562                0.0                1.800
# 719 2023-07-03 23:00:00  39665.523438                0.0                1.600
#
#      absolute_humidity_2m:gm3  pressure_100m:hPa  fresh_snow_6h:cm  \
# 0                       4.325        1000.549988               0.0
# 1                       4.275        1000.049988               0.0
# 2                       4.150         999.500000               0.0
# 3                       4.025         998.974976               0.0
# 4                       3.900         998.549988               0.0
# ..                        ...                ...               ...
# 715                     8.350         979.599976               0.0
# 716                     8.525         980.025024               0.0
# 717                     8.825         980.349976               0.0
# 718                     9.025         980.700012               0.0
# 719                     9.050         981.000000               0.0
#
#      sfc_pressure:hPa  pressure_50m:hPa  snow_melt_10min:mm  ...  \
# 0         1013.099976       1006.799988                 0.0  ...
# 1         1012.599976       1006.299988                 0.0  ...
# 2         1012.049988       1005.799988                 0.0  ...
# 3         1011.525024       1005.224976                 0.0  ...
# 4         1011.049988       1004.750000                 0.0  ...
# ..                ...               ...                 ...  ...
# 715        991.325012        985.424988                 0.0  ...
# 716        991.799988        985.900024                 0.0  ...
# 717        992.150024        986.250000                 0.0  ...
# 718        992.525024        986.599976                 0.0  ...
# 719        992.825012        986.900024                 0.0  ...
#
#      snow_density:kgm3  dew_or_rime:idx  is_day:idx  is_in_shadow:idx  \
# 0                  NaN              0.0         0.0               1.0
# 1                  NaN              0.0         0.0               1.0
# 2                  NaN              0.0         0.0               1.0
# 3                  NaN              0.0         1.0               0.0
# 4                  NaN              0.0         1.0               0.0
# ..                 ...              ...         ...               ...
# 715                NaN              0.0         1.0               0.0
# 716                NaN              0.0         1.0               0.0
# 717                NaN              0.0         0.0               1.0
# 718                NaN              0.0         0.0               1.0
# 719                NaN              0.0         0.0               1.0
#
#      precip_type_5min:idx  snow_drift:idx  day_of_year  hour  month  \
# 0                     0.0             0.0          121     0      5
# 1                     0.0             0.0          121     1      5
# 2                     0.0             0.0          121     2      5
# 3                     0.0             0.0          121     3      5
# 4                     0.0             0.0          121     4      5
# ..                    ...             ...          ...   ...    ...
# 715                   0.0             0.0          184    19      7
# 716                   0.0             0.0          184    20      7
# 717                   0.0             0.0          184    21      7
# 718                   0.0             0.0          184    22      7
# 719                   0.0             0.0          184    23      7
#
#      is_estimated:idx
# 0                   1
# 1                   1
# 2                   1
# 3                   1
# 4                   1
# ..                ...
# 715                 1
# 716                 1
# 717                 1
# 718                 1
# 719                 1
#
# [720 rows x 51 columns]

# %%
predictor.evaluate(df1, silent=True)
# Out:
# {'root_mean_squared_error': -141.59062992788995,
#  'mean_squared_error': -20047.906483376682,
#  'mean_absolute_error': -59.25292336122937,
#  'r2': 0.988824833399717,
#  'pearsonr': 0.9945011969990492,
#  'median_absolute_error': -21.811315155029263}

# %%
predictor.leaderboard(df1, silent=True)
# Out:
#                   model  score_test   score_val  pred_time_test  \
# 0              LightGBM -140.398294 -443.276476        2.817896
# 1   WeightedEnsemble_L2 -141.590630 -404.677841        5.675743
# 2         LightGBMLarge -142.826155 -451.571088        7.800392
# 3               XGBoost -146.937332 -464.569281        2.799421
# 4            LightGBMXT -147.893303 -424.096660        2.474003
# 5        KNeighborsDist -161.489862 -510.641821        0.283721
# 6              CatBoost -168.614217 -447.692294        0.068065
# 7         ExtraTreesMSE -245.067410 -520.916883        0.279151
# 8       RandomForestMSE -248.921414 -531.968795        0.296161
# 9        NeuralNetTorch -426.368487 -496.010534        0.089367
# 10      NeuralNetFastAI -434.956210 -492.848400        0.161763
# 11       KNeighborsUnif -487.477806 -663.681498        0.309999
#
#     pred_time_val    fit_time  pred_time_test_marginal  \
# 0        0.276061   58.354545                 2.817896
# 1        0.685816  141.766530                 0.010756
# 2        0.720509  290.978878                 7.800392
# 3        0.320391   39.649945                 2.799421
# 4        0.307207   64.164883                 2.474003
# 5        0.082173    0.025133                 0.283721
# 6        0.006550   74.664945                 0.068065
# 7        0.040906    3.490199                 0.279151
# 8        0.040851   13.939986                 0.296161
# 9        0.020143   19.096033                 0.089367
# 10       0.017622   16.767762                 0.161763
# 11       0.231822    0.540051                 0.309999
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 0.276061          58.354545            1       True
# 1                 0.000232           0.125936            2       True
# 2                 0.720509         290.978878            1       True
# 3                 0.320391          39.649945            1       True
# 4                 0.307207          64.164883            1       True
# 5                 0.082173           0.025133            1       True
# 6                 0.006550          74.664945            1       True
# 7                 0.040906           3.490199            1       True
# 8                 0.040851          13.939986            1       True
# 9                 0.020143          19.096033            1       True
# 10                0.017622          16.767762            1       True
# 11                0.231822           0.540051            1       True
#
#     fit_order
# 0           4
# 1          12
# 2          11
# 3           9
# 4           3
# 5           2
# 6           6
# 7           7
# 8           5
# 9          10
# 10          8
# 11          1
