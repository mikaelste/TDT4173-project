# %% [markdown]
# <h3> tester kombinasjoner av remove</h3>
# <p><p>

# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from autogluon.tabular import TabularDataset, TabularPredictor
import pandas as pd
import numpy as np

# %%
# %autoreload
import sys
sys.path.append('../')
from pipeline import Pipeline
pipin = Pipeline()

# %%
df1_0 = pipin.get_data("A")
df2_0 = pipin.get_data("B")
df3_0 = pipin.get_data("C")

# %%
threshold1 = 3
threshold2 = 12
threshold3 = 24

# %%
# remove_consecutive_measurments
# 6/6 er henning sin beste
df1_0 = pipin.remove_consecutive_measurments_new_new(df1_0, 3, 12, 21) #tipper oslo
df2_0 = pipin.remove_consecutive_measurments_new_new(df2_0, 3, 12, 24) #tipper Trondheim
df3_0 = pipin.remove_consecutive_measurments_new_new(df3_0, 3, 12, 24) #tipper Trondheim

# %%
df1_0 = pipin.drop_columns(df1_0)
df2_0 = pipin.drop_columns(df2_0)
df3_0 = pipin.drop_columns(df3_0)
print(df1_0.shape, df2_0.shape, df3_0.shape)
# Out:
# (33850, 47) (25667, 47) (20905, 47)

# %%
df1_0.head()
# Out:
#    absolute_humidity_2m:gm3  air_density_2m:kgm3  ceiling_height_agl:m  \
# 0                     7.700              1.22825           1728.949951
# 1                     7.700              1.22350           1689.824951
# 2                     7.875              1.21975           1563.224976
# 3                     8.425              1.21800           1283.425049
# 4                     8.950              1.21800           1003.500000
#
#    clear_sky_energy_1h:J  clear_sky_rad:W  cloud_base_agl:m  dew_or_rime:idx  \
# 0               0.000000             0.00       1728.949951              0.0
# 1               0.000000             0.00       1689.824951              0.0
# 2               0.000000             0.00       1563.224976              0.0
# 3             208.649994             0.75       1283.425049              0.0
# 4           32468.150391            23.10       1003.500000              0.0
#
#    dew_point_2m:K  diffuse_rad:W  diffuse_rad_1h:J  ...  \
# 0      280.299988          0.000          0.000000  ...
# 1      280.299988          0.000          0.000000  ...
# 2      280.649994          0.000          0.000000  ...
# 3      281.674988          0.300        526.775024  ...
# 4      282.500000         11.975      22068.949219  ...
#
#    super_cooled_liquid_water:kgm2  t_1000hPa:K  total_cloud_cover:p  \
# 0                             0.0   286.225006           100.000000
# 1                             0.0   286.899994           100.000000
# 2                             0.0   286.950012           100.000000
# 3                             0.0   286.750000           100.000000
# 4                             0.0   286.450012            99.224998
#
#    visibility:m  wind_speed_10m:ms  estimated  observed  day_of_year  hour  \
# 0  40386.476562              3.600        0.0       1.0        153.0  22.0
# 1  33770.648438              3.350        0.0       1.0        153.0  23.0
# 2  13595.500000              3.050        0.0       1.0        154.0   0.0
# 3   2321.850098              2.725        0.0       1.0        154.0   1.0
# 4  11634.799805              2.550        0.0       1.0        154.0   2.0
#
#    pv_measurement
# 0            0.00
# 1            0.00
# 2            0.00
# 3            0.00
# 4           19.36
#
# [5 rows x 47 columns]

# %%
train1 = TabularDataset(df1_0)
train2 = TabularDataset(df2_0)
train3 = TabularDataset(df3_0)

# %%
predictor1 = TabularPredictor(label="pv_measurement", eval_metric='mean_absolute_error').fit(
    train1,
    # time_limit=60*60*1.5,
    # hyperparameters='extrme', 
    presets='best_quality',
    # tuning_data = tuning1,
    # use_bag_holdout=True,
    # num_bag_folds= 6,
    # refit_full = True,
    # auto_stack = True,
    # num_bag_sets= 10,
    # set_best_to_refit_full= True,
    # num_stack_levels = 2,
    # verbosity = 3
    )
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20231109_100545/"
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=20
# Beginning AutoGluon training ... Time limit = 5400.0s
# AutoGluon will save models to "AutogluonModels/ag-20231109_100545/"
# AutoGluon Version:  0.8.2
# Python Version:     3.10.13
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 22.5.0: Thu Jun  8 22:22:20 PDT 2023; root:xnu-8796.121.3~7/RELEASE_ARM64_T6000
# Disk Space Avail:   795.88 GB / 994.66 GB (80.0%)
# Train Data Rows:    33850
# Train Data Columns: 46
# Label Column: pv_measurement
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (5733.42, 0.0, 634.97254, 1168.75397)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    20097.72 MB
# 	Train Data (Original)  Memory Usage: 6.77 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 3 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Unused Original Features (Count: 1): ['snow_drift:idx']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('float', []) : 1 | ['snow_drift:idx']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 45 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 43 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 		('int', ['bool']) :  2 | ['elevation:m', 'snow_density:kgm3']
# 	0.2s = Fit runtime
# 	45 features in original data used to generate 45 features in processed data.
# 	Train Data (Processed) Memory Usage: 6.43 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.19s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 3598.97s of the 5399.8s of remaining time.
# 	-266.17	 = Validation score   (-mean_absolute_error)
# 	0.02s	 = Training   runtime
# 	0.65s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 3598.11s of the 5398.95s of remaining time.
# 	-267.0048	 = Validation score   (-mean_absolute_error)
# 	0.02s	 = Training   runtime
# 	0.64s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 3597.41s of the 5398.24s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-156.7365	 = Validation score   (-mean_absolute_error)
# 	23.7s	 = Training   runtime
# 	60.75s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 3563.08s of the 5363.92s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-163.7932	 = Validation score   (-mean_absolute_error)
# 	44.79s	 = Training   runtime
# 	57.82s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 3509.61s of the 5310.45s of remaining time.
# 	-181.4357	 = Validation score   (-mean_absolute_error)
# 	17.52s	 = Training   runtime
# 	0.8s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 3491.07s of the 5291.9s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-172.1032	 = Validation score   (-mean_absolute_error)
# 	2980.25s	 = Training   runtime
# 	0.73s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 509.41s of the 2310.25s of remaining time.
# 	-182.0047	 = Validation score   (-mean_absolute_error)
# 	3.79s	 = Training   runtime
# 	0.97s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 504.39s of the 2305.23s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-186.9634	 = Validation score   (-mean_absolute_error)
# 	320.07s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 176.95s of the 1977.78s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-173.5312	 = Validation score   (-mean_absolute_error)
# 	113.36s	 = Training   runtime
# 	53.87s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 55.01s of the 1855.85s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-173.0334	 = Validation score   (-mean_absolute_error)
# 	44.77s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 8.71s of the 1809.54s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-163.188	 = Validation score   (-mean_absolute_error)
# 	7.75s	 = Training   runtime
# 	2.2s	 = Validation runtime
# Completed 1/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 1799.59s of remaining time.
# 	-153.8658	 = Validation score   (-mean_absolute_error)
# 	0.4s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 9 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 1799.19s of the 1799.18s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-157.4021	 = Validation score   (-mean_absolute_error)
# 	3.33s	 = Training   runtime
# 	0.53s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 1794.05s of the 1794.04s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-154.7362	 = Validation score   (-mean_absolute_error)
# 	2.52s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ... Training model for up to 1789.71s of the 1789.7s of remaining time.
# 	-154.3604	 = Validation score   (-mean_absolute_error)
# 	31.0s	 = Training   runtime
# 	1.05s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 1757.41s of the 1757.4s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-154.658	 = Validation score   (-mean_absolute_error)
# 	7.07s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ... Training model for up to 1748.89s of the 1748.88s of remaining time.
# 	-153.6992	 = Validation score   (-mean_absolute_error)
# 	4.7s	 = Training   runtime
# 	1.01s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 1742.95s of the 1742.94s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-154.6001	 = Validation score   (-mean_absolute_error)
# 	17.35s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 1724.11s of the 1724.1s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-153.7107	 = Validation score   (-mean_absolute_error)
# 	3.94s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 1718.47s of the 1718.46s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-154.2812	 = Validation score   (-mean_absolute_error)
# 	26.31s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 1690.59s of the 1690.58s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-155.8739	 = Validation score   (-mean_absolute_error)
# 	4.87s	 = Training   runtime
# 	0.58s	 = Validation runtime
# Repeating k-fold bagging: 2/20
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 1684.05s of the 1684.04s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-156.6877	 = Validation score   (-mean_absolute_error)
# 	6.74s	 = Training   runtime
# 	1.07s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 1678.83s of the 1678.82s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-154.3787	 = Validation score   (-mean_absolute_error)
# 	5.04s	 = Training   runtime
# 	0.44s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 1674.48s of the 1674.47s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-154.1963	 = Validation score   (-mean_absolute_error)
# 	16.28s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 1663.6s of the 1663.6s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-153.84	 = Validation score   (-mean_absolute_error)
# 	34.68s	 = Training   runtime
# 	0.52s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 1644.78s of the 1644.78s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-153.2362	 = Validation score   (-mean_absolute_error)
# 	6.5s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 1640.51s of the 1640.5s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-153.3659	 = Validation score   (-mean_absolute_error)
# 	46.73s	 = Training   runtime
# 	0.47s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 1618.43s of the 1618.42s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-154.6931	 = Validation score   (-mean_absolute_error)
# 	11.22s	 = Training   runtime
# 	1.24s	 = Validation runtime
# Repeating k-fold bagging: 3/20
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 1610.28s of the 1610.27s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-156.324	 = Validation score   (-mean_absolute_error)
# 	9.02s	 = Training   runtime
# 	1.6s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 1606.45s of the 1606.44s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-154.3108	 = Validation score   (-mean_absolute_error)
# 	7.41s	 = Training   runtime
# 	0.64s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 1602.31s of the 1602.3s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-154.0668	 = Validation score   (-mean_absolute_error)
# 	24.33s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 1592.55s of the 1592.55s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-153.3567	 = Validation score   (-mean_absolute_error)
# 	51.99s	 = Training   runtime
# 	0.77s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 1573.7s of the 1573.69s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-153.2117	 = Validation score   (-mean_absolute_error)
# 	9.86s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 1568.63s of the 1568.62s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-152.992	 = Validation score   (-mean_absolute_error)
# 	69.07s	 = Training   runtime
# 	0.71s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 1544.48s of the 1544.47s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-154.4873	 = Validation score   (-mean_absolute_error)
# 	17.09s	 = Training   runtime
# 	1.83s	 = Validation runtime
# Repeating k-fold bagging: 4/20
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 1536.74s of the 1536.73s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-156.238	 = Validation score   (-mean_absolute_error)
# 	11.68s	 = Training   runtime
# 	2.13s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 1532.35s of the 1532.34s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-154.2603	 = Validation score   (-mean_absolute_error)
# 	9.03s	 = Training   runtime
# 	0.85s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 1529.34s of the 1529.34s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-153.9414	 = Validation score   (-mean_absolute_error)
# 	33.83s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 1518.09s of the 1518.08s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-153.0587	 = Validation score   (-mean_absolute_error)
# 	70.58s	 = Training   runtime
# 	1.02s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 1497.85s of the 1497.84s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-153.2216	 = Validation score   (-mean_absolute_error)
# 	13.31s	 = Training   runtime
# 	0.4s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 1492.54s of the 1492.53s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-152.8249	 = Validation score   (-mean_absolute_error)
# 	91.18s	 = Training   runtime
# 	0.94s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 1468.83s of the 1468.83s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-154.4824	 = Validation score   (-mean_absolute_error)
# 	21.63s	 = Training   runtime
# 	2.39s	 = Validation runtime
# Repeating k-fold bagging: 5/20
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 1462.58s of the 1462.57s of remaining time.
# 	Fitting 8 child models (S5F1 - S5F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-156.14	 = Validation score   (-mean_absolute_error)
# 	14.91s	 = Training   runtime
# 	2.69s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 1457.57s of the 1457.56s of remaining time.
# 	Fitting 8 child models (S5F1 - S5F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-154.2313	 = Validation score   (-mean_absolute_error)
# 	11.46s	 = Training   runtime
# 	1.06s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 1453.35s of the 1453.35s of remaining time.
# 	Fitting 8 child models (S5F1 - S5F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-153.8814	 = Validation score   (-mean_absolute_error)
# 	44.05s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 1441.48s of the 1441.47s of remaining time.
# 	Fitting 8 child models (S5F1 - S5F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-152.9506	 = Validation score   (-mean_absolute_error)
# 	87.89s	 = Training   runtime
# 	1.28s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 1422.58s of the 1422.57s of remaining time.
# 	Fitting 8 child models (S5F1 - S5F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-153.2377	 = Validation score   (-mean_absolute_error)
# 	16.81s	 = Training   runtime
# 	0.49s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 1417.37s of the 1417.36s of remaining time.
# 	Fitting 8 child models (S5F1 - S5F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-152.687	 = Validation score   (-mean_absolute_error)
# 	113.8s	 = Training   runtime
# 	1.17s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 1392.98s of the 1392.97s of remaining time.
# 	Fitting 8 child models (S5F1 - S5F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-154.4153	 = Validation score   (-mean_absolute_error)
# 	27.04s	 = Training   runtime
# 	2.99s	 = Validation runtime
# Repeating k-fold bagging: 6/20
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 1385.82s of the 1385.81s of remaining time.
# 	Fitting 8 child models (S6F1 - S6F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-156.0848	 = Validation score   (-mean_absolute_error)
# 	16.87s	 = Training   runtime
# 	3.23s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 1382.19s of the 1382.18s of remaining time.
# 	Fitting 8 child models (S6F1 - S6F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-154.2245	 = Validation score   (-mean_absolute_error)
# 	13.94s	 = Training   runtime
# 	1.28s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 1377.97s of the 1377.96s of remaining time.
# 	Fitting 8 child models (S6F1 - S6F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-153.8711	 = Validation score   (-mean_absolute_error)
# 	52.9s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 1367.43s of the 1367.42s of remaining time.
# 	Fitting 8 child models (S6F1 - S6F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-152.7987	 = Validation score   (-mean_absolute_error)
# 	106.27s	 = Training   runtime
# 	1.54s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 1347.34s of the 1347.33s of remaining time.
# 	Fitting 8 child models (S6F1 - S6F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-153.2046	 = Validation score   (-mean_absolute_error)
# 	20.53s	 = Training   runtime
# 	0.59s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 1342.0s of the 1341.99s of remaining time.
# 	Fitting 8 child models (S6F1 - S6F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-152.6723	 = Validation score   (-mean_absolute_error)
# 	136.12s	 = Training   runtime
# 	1.4s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 1318.16s of the 1318.15s of remaining time.
# 	Fitting 8 child models (S6F1 - S6F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-154.3919	 = Validation score   (-mean_absolute_error)
# 	32.55s	 = Training   runtime
# 	3.59s	 = Validation runtime
# Repeating k-fold bagging: 7/20
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 1310.96s of the 1310.96s of remaining time.
# 	Fitting 8 child models (S7F1 - S7F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-156.0694	 = Validation score   (-mean_absolute_error)
# 	18.96s	 = Training   runtime
# 	3.76s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 1307.32s of the 1307.31s of remaining time.
# 	Fitting 8 child models (S7F1 - S7F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-154.1701	 = Validation score   (-mean_absolute_error)
# 	16.48s	 = Training   runtime
# 	1.48s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 1303.17s of the 1303.16s of remaining time.
# 	Fitting 8 child models (S7F1 - S7F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-153.82	 = Validation score   (-mean_absolute_error)
# 	65.13s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 1289.27s of the 1289.26s of remaining time.
# 	Fitting 8 child models (S7F1 - S7F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-152.7808	 = Validation score   (-mean_absolute_error)
# 	123.76s	 = Training   runtime
# 	1.8s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 1270.14s of the 1270.13s of remaining time.
# 	Fitting 8 child models (S7F1 - S7F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-153.1119	 = Validation score   (-mean_absolute_error)
# 	24.17s	 = Training   runtime
# 	0.69s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 1264.65s of the 1264.64s of remaining time.
# 	Fitting 8 child models (S7F1 - S7F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-152.6755	 = Validation score   (-mean_absolute_error)
# 	155.64s	 = Training   runtime
# 	1.64s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 1243.7s of the 1243.69s of remaining time.
# 	Fitting 8 child models (S7F1 - S7F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-154.3102	 = Validation score   (-mean_absolute_error)
# 	37.61s	 = Training   runtime
# 	4.15s	 = Validation runtime
# Repeating k-fold bagging: 8/20
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 1236.68s of the 1236.68s of remaining time.
# 	Fitting 8 child models (S8F1 - S8F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-156.0648	 = Validation score   (-mean_absolute_error)
# 	21.83s	 = Training   runtime
# 	4.22s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 1231.87s of the 1231.87s of remaining time.
# 	Fitting 8 child models (S8F1 - S8F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-154.1848	 = Validation score   (-mean_absolute_error)
# 	18.0s	 = Training   runtime
# 	1.7s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 1228.78s of the 1228.77s of remaining time.
# 	Fitting 8 child models (S8F1 - S8F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-153.8319	 = Validation score   (-mean_absolute_error)
# 	74.14s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 1218.1s of the 1218.09s of remaining time.
# 	Fitting 8 child models (S8F1 - S8F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-152.751	 = Validation score   (-mean_absolute_error)
# 	140.94s	 = Training   runtime
# 	2.05s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 1199.42s of the 1199.41s of remaining time.
# 	Fitting 8 child models (S8F1 - S8F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-153.086	 = Validation score   (-mean_absolute_error)
# 	27.66s	 = Training   runtime
# 	0.79s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 1194.17s of the 1194.16s of remaining time.
# 	Fitting 8 child models (S8F1 - S8F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-152.5868	 = Validation score   (-mean_absolute_error)
# 	180.3s	 = Training   runtime
# 	1.87s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 1167.66s of the 1167.66s of remaining time.
# 	Fitting 8 child models (S8F1 - S8F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-154.3304	 = Validation score   (-mean_absolute_error)
# 	42.32s	 = Training   runtime
# 	4.75s	 = Validation runtime
# Repeating k-fold bagging: 9/20
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 1161.3s of the 1161.3s of remaining time.
# 	Fitting 8 child models (S9F1 - S9F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-156.0632	 = Validation score   (-mean_absolute_error)
# 	24.12s	 = Training   runtime
# 	4.78s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 1157.32s of the 1157.32s of remaining time.
# 	Fitting 8 child models (S9F1 - S9F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-154.1528	 = Validation score   (-mean_absolute_error)
# 	20.68s	 = Training   runtime
# 	1.92s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 1152.68s of the 1152.68s of remaining time.
# 	Fitting 8 child models (S9F1 - S9F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-153.7983	 = Validation score   (-mean_absolute_error)
# 	88.61s	 = Training   runtime
# 	0.19s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 1136.5s of the 1136.49s of remaining time.
# 	Fitting 8 child models (S9F1 - S9F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-152.6909	 = Validation score   (-mean_absolute_error)
# 	158.33s	 = Training   runtime
# 	2.3s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 1117.45s of the 1117.44s of remaining time.
# 	Fitting 8 child models (S9F1 - S9F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-153.0586	 = Validation score   (-mean_absolute_error)
# 	31.2s	 = Training   runtime
# 	0.9s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 1112.05s of the 1112.04s of remaining time.
# 	Fitting 8 child models (S9F1 - S9F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-152.5646	 = Validation score   (-mean_absolute_error)
# 	207.24s	 = Training   runtime
# 	2.11s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 1083.37s of the 1083.36s of remaining time.
# 	Fitting 8 child models (S9F1 - S9F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-154.2922	 = Validation score   (-mean_absolute_error)
# 	46.96s	 = Training   runtime
# 	5.34s	 = Validation runtime
# Repeating k-fold bagging: 10/20
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 1077.09s of the 1077.08s of remaining time.
# 	Fitting 8 child models (S10F1 - S10F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-156.0275	 = Validation score   (-mean_absolute_error)
# 	27.56s	 = Training   runtime
# 	5.4s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 1071.81s of the 1071.8s of remaining time.
# 	Fitting 8 child models (S10F1 - S10F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-154.1523	 = Validation score   (-mean_absolute_error)
# 	22.3s	 = Training   runtime
# 	2.13s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 1068.68s of the 1068.67s of remaining time.
# 	Fitting 8 child models (S10F1 - S10F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-153.7593	 = Validation score   (-mean_absolute_error)
# 	99.3s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 1056.22s of the 1056.21s of remaining time.
# 	Fitting 8 child models (S10F1 - S10F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-152.6407	 = Validation score   (-mean_absolute_error)
# 	175.54s	 = Training   runtime
# 	2.55s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 1037.36s of the 1037.35s of remaining time.
# 	Fitting 8 child models (S10F1 - S10F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-153.0557	 = Validation score   (-mean_absolute_error)
# 	34.69s	 = Training   runtime
# 	1.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 1032.07s of the 1032.06s of remaining time.
# 	Fitting 8 child models (S10F1 - S10F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-152.5202	 = Validation score   (-mean_absolute_error)
# 	232.8s	 = Training   runtime
# 	2.34s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 1004.87s of the 1004.86s of remaining time.
# 	Fitting 8 child models (S10F1 - S10F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-154.2792	 = Validation score   (-mean_absolute_error)
# 	52.21s	 = Training   runtime
# 	5.95s	 = Validation runtime
# Repeating k-fold bagging: 11/20
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 997.8s of the 997.79s of remaining time.
# 	Fitting 8 child models (S11F1 - S11F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-155.9945	 = Validation score   (-mean_absolute_error)
# 	30.59s	 = Training   runtime
# 	5.88s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 992.72s of the 992.71s of remaining time.
# 	Fitting 8 child models (S11F1 - S11F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-154.154	 = Validation score   (-mean_absolute_error)
# 	23.87s	 = Training   runtime
# 	2.34s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 989.51s of the 989.5s of remaining time.
# 	Fitting 8 child models (S11F1 - S11F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-153.762	 = Validation score   (-mean_absolute_error)
# 	111.0s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 976.12s of the 976.11s of remaining time.
# 	Fitting 8 child models (S11F1 - S11F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-152.6435	 = Validation score   (-mean_absolute_error)
# 	192.94s	 = Training   runtime
# 	2.81s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 957.28s of the 957.27s of remaining time.
# 	Fitting 8 child models (S11F1 - S11F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-153.0392	 = Validation score   (-mean_absolute_error)
# 	38.67s	 = Training   runtime
# 	1.1s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 951.61s of the 951.6s of remaining time.
# 	Fitting 8 child models (S11F1 - S11F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-152.521	 = Validation score   (-mean_absolute_error)
# 	253.54s	 = Training   runtime
# 	2.58s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 929.34s of the 929.34s of remaining time.
# 	Fitting 8 child models (S11F1 - S11F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-154.3037	 = Validation score   (-mean_absolute_error)
# 	57.96s	 = Training   runtime
# 	6.55s	 = Validation runtime
# Repeating k-fold bagging: 12/20
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 921.72s of the 921.71s of remaining time.
# 	Fitting 8 child models (S12F1 - S12F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-155.9535	 = Validation score   (-mean_absolute_error)
# 	33.52s	 = Training   runtime
# 	6.39s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 917.08s of the 917.07s of remaining time.
# 	Fitting 8 child models (S12F1 - S12F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-154.1089	 = Validation score   (-mean_absolute_error)
# 	25.64s	 = Training   runtime
# 	2.58s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 913.71s of the 913.71s of remaining time.
# 	Fitting 8 child models (S12F1 - S12F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-153.7791	 = Validation score   (-mean_absolute_error)
# 	118.39s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 904.75s of the 904.75s of remaining time.
# 	Fitting 8 child models (S12F1 - S12F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-152.5731	 = Validation score   (-mean_absolute_error)
# 	211.35s	 = Training   runtime
# 	3.08s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 884.53s of the 884.52s of remaining time.
# 	Fitting 8 child models (S12F1 - S12F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-153.0447	 = Validation score   (-mean_absolute_error)
# 	42.31s	 = Training   runtime
# 	1.2s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 879.09s of the 879.08s of remaining time.
# 	Fitting 8 child models (S12F1 - S12F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-152.5025	 = Validation score   (-mean_absolute_error)
# 	274.16s	 = Training   runtime
# 	2.81s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 856.87s of the 856.86s of remaining time.
# 	Fitting 8 child models (S12F1 - S12F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-154.2422	 = Validation score   (-mean_absolute_error)
# 	64.16s	 = Training   runtime
# 	7.17s	 = Validation runtime
# Repeating k-fold bagging: 13/20
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 848.84s of the 848.83s of remaining time.
# 	Fitting 8 child models (S13F1 - S13F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-155.9531	 = Validation score   (-mean_absolute_error)
# 	35.79s	 = Training   runtime
# 	6.94s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 844.94s of the 844.93s of remaining time.
# 	Fitting 8 child models (S13F1 - S13F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-154.1227	 = Validation score   (-mean_absolute_error)
# 	28.03s	 = Training   runtime
# 	2.8s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 840.65s of the 840.64s of remaining time.
# 	Fitting 8 child models (S13F1 - S13F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-153.7824	 = Validation score   (-mean_absolute_error)
# 	131.23s	 = Training   runtime
# 	0.27s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 826.09s of the 826.08s of remaining time.
# 	Fitting 8 child models (S13F1 - S13F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-152.5569	 = Validation score   (-mean_absolute_error)
# 	228.72s	 = Training   runtime
# 	3.33s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 807.19s of the 807.18s of remaining time.
# 	Fitting 8 child models (S13F1 - S13F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-153.0373	 = Validation score   (-mean_absolute_error)
# 	45.89s	 = Training   runtime
# 	1.3s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 801.74s of the 801.73s of remaining time.
# 	Fitting 8 child models (S13F1 - S13F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-152.4677	 = Validation score   (-mean_absolute_error)
# 	296.76s	 = Training   runtime
# 	3.03s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 777.6s of the 777.59s of remaining time.
# 	Fitting 8 child models (S13F1 - S13F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-154.1701	 = Validation score   (-mean_absolute_error)
# 	68.72s	 = Training   runtime
# 	7.73s	 = Validation runtime
# Repeating k-fold bagging: 14/20
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 771.18s of the 771.17s of remaining time.
# 	Fitting 8 child models (S14F1 - S14F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-155.9454	 = Validation score   (-mean_absolute_error)
# 	38.08s	 = Training   runtime
# 	7.49s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 767.21s of the 767.2s of remaining time.
# 	Fitting 8 child models (S14F1 - S14F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-154.1114	 = Validation score   (-mean_absolute_error)
# 	30.46s	 = Training   runtime
# 	3.01s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 762.89s of the 762.88s of remaining time.
# 	Fitting 8 child models (S14F1 - S14F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-153.7631	 = Validation score   (-mean_absolute_error)
# 	141.7s	 = Training   runtime
# 	0.29s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 750.72s of the 750.72s of remaining time.
# 	Fitting 8 child models (S14F1 - S14F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-152.5454	 = Validation score   (-mean_absolute_error)
# 	247.11s	 = Training   runtime
# 	3.59s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 730.63s of the 730.62s of remaining time.
# 	Fitting 8 child models (S14F1 - S14F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-153.0291	 = Validation score   (-mean_absolute_error)
# 	49.36s	 = Training   runtime
# 	1.4s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 725.34s of the 725.33s of remaining time.
# 	Fitting 8 child models (S14F1 - S14F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-152.4487	 = Validation score   (-mean_absolute_error)
# 	318.87s	 = Training   runtime
# 	3.27s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 701.55s of the 701.54s of remaining time.
# 	Fitting 8 child models (S14F1 - S14F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-154.1748	 = Validation score   (-mean_absolute_error)
# 	73.42s	 = Training   runtime
# 	8.33s	 = Validation runtime
# Repeating k-fold bagging: 15/20
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 695.15s of the 695.15s of remaining time.
# 	Fitting 8 child models (S15F1 - S15F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-155.9335	 = Validation score   (-mean_absolute_error)
# 	41.26s	 = Training   runtime
# 	8.0s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 690.1s of the 690.09s of remaining time.
# 	Fitting 8 child models (S15F1 - S15F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-154.0936	 = Validation score   (-mean_absolute_error)
# 	32.96s	 = Training   runtime
# 	3.22s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 685.83s of the 685.82s of remaining time.
# 	Fitting 8 child models (S15F1 - S15F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-153.7673	 = Validation score   (-mean_absolute_error)
# 	149.56s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 676.34s of the 676.33s of remaining time.
# 	Fitting 8 child models (S15F1 - S15F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-152.5148	 = Validation score   (-mean_absolute_error)
# 	264.33s	 = Training   runtime
# 	3.83s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 657.49s of the 657.48s of remaining time.
# 	Fitting 8 child models (S15F1 - S15F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-153.0096	 = Validation score   (-mean_absolute_error)
# 	53.12s	 = Training   runtime
# 	1.5s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 651.97s of the 651.97s of remaining time.
# 	Fitting 8 child models (S15F1 - S15F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-152.4484	 = Validation score   (-mean_absolute_error)
# 	337.85s	 = Training   runtime
# 	3.5s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 631.31s of the 631.3s of remaining time.
# 	Fitting 8 child models (S15F1 - S15F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-154.1318	 = Validation score   (-mean_absolute_error)
# 	78.55s	 = Training   runtime
# 	8.94s	 = Validation runtime
# Repeating k-fold bagging: 16/20
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 624.37s of the 624.36s of remaining time.
# 	Fitting 8 child models (S16F1 - S16F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-155.9138	 = Validation score   (-mean_absolute_error)
# 	44.55s	 = Training   runtime
# 	8.56s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 619.26s of the 619.25s of remaining time.
# 	Fitting 8 child models (S16F1 - S16F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-154.0794	 = Validation score   (-mean_absolute_error)
# 	35.39s	 = Training   runtime
# 	3.44s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 614.99s of the 614.98s of remaining time.
# 	Fitting 8 child models (S16F1 - S16F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-153.7582	 = Validation score   (-mean_absolute_error)
# 	159.77s	 = Training   runtime
# 	0.33s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 603.12s of the 603.11s of remaining time.
# 	Fitting 8 child models (S16F1 - S16F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-152.5025	 = Validation score   (-mean_absolute_error)
# 	282.98s	 = Training   runtime
# 	4.09s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 582.74s of the 582.73s of remaining time.
# 	Fitting 8 child models (S16F1 - S16F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-152.9979	 = Validation score   (-mean_absolute_error)
# 	56.58s	 = Training   runtime
# 	1.6s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 577.27s of the 577.26s of remaining time.
# 	Fitting 8 child models (S16F1 - S16F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-152.4671	 = Validation score   (-mean_absolute_error)
# 	357.52s	 = Training   runtime
# 	3.73s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 555.89s of the 555.88s of remaining time.
# 	Fitting 8 child models (S16F1 - S16F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-154.1185	 = Validation score   (-mean_absolute_error)
# 	83.19s	 = Training   runtime
# 	9.53s	 = Validation runtime
# Repeating k-fold bagging: 17/20
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 549.42s of the 549.41s of remaining time.
# 	Fitting 8 child models (S17F1 - S17F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-155.9206	 = Validation score   (-mean_absolute_error)
# 	46.57s	 = Training   runtime
# 	9.01s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 545.76s of the 545.75s of remaining time.
# 	Fitting 8 child models (S17F1 - S17F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-154.0699	 = Validation score   (-mean_absolute_error)
# 	36.97s	 = Training   runtime
# 	3.65s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 542.58s of the 542.57s of remaining time.
# 	Fitting 8 child models (S17F1 - S17F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-153.7475	 = Validation score   (-mean_absolute_error)
# 	171.8s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 528.84s of the 528.84s of remaining time.
# 	Fitting 8 child models (S17F1 - S17F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-152.5087	 = Validation score   (-mean_absolute_error)
# 	300.58s	 = Training   runtime
# 	4.35s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 509.76s of the 509.75s of remaining time.
# 	Fitting 8 child models (S17F1 - S17F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-152.9597	 = Validation score   (-mean_absolute_error)
# 	60.15s	 = Training   runtime
# 	1.71s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 504.21s of the 504.19s of remaining time.
# 	Fitting 8 child models (S17F1 - S17F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-152.4825	 = Validation score   (-mean_absolute_error)
# 	376.53s	 = Training   runtime
# 	3.96s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 483.55s of the 483.54s of remaining time.
# 	Fitting 8 child models (S17F1 - S17F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-154.0896	 = Validation score   (-mean_absolute_error)
# 	87.89s	 = Training   runtime
# 	10.14s	 = Validation runtime
# Repeating k-fold bagging: 18/20
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 477.19s of the 477.18s of remaining time.
# 	Fitting 8 child models (S18F1 - S18F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-155.8807	 = Validation score   (-mean_absolute_error)
# 	48.99s	 = Training   runtime
# 	9.58s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 473.03s of the 473.02s of remaining time.
# 	Fitting 8 child models (S18F1 - S18F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-154.0249	 = Validation score   (-mean_absolute_error)
# 	38.76s	 = Training   runtime
# 	3.88s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 469.6s of the 469.59s of remaining time.
# 	Fitting 8 child models (S18F1 - S18F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-153.7476	 = Validation score   (-mean_absolute_error)
# 	179.17s	 = Training   runtime
# 	0.37s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 460.61s of the 460.61s of remaining time.
# 	Fitting 8 child models (S18F1 - S18F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-152.5011	 = Validation score   (-mean_absolute_error)
# 	318.88s	 = Training   runtime
# 	4.61s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 440.61s of the 440.6s of remaining time.
# 	Fitting 8 child models (S18F1 - S18F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-152.9475	 = Validation score   (-mean_absolute_error)
# 	63.1s	 = Training   runtime
# 	1.81s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 436.11s of the 436.1s of remaining time.
# 	Fitting 8 child models (S18F1 - S18F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-152.4327	 = Validation score   (-mean_absolute_error)
# 	404.39s	 = Training   runtime
# 	4.2s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 406.67s of the 406.66s of remaining time.
# 	Fitting 8 child models (S18F1 - S18F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-154.0264	 = Validation score   (-mean_absolute_error)
# 	92.71s	 = Training   runtime
# 	10.77s	 = Validation runtime
# Repeating k-fold bagging: 19/20
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 400.12s of the 400.11s of remaining time.
# 	Fitting 8 child models (S19F1 - S19F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-155.8737	 = Validation score   (-mean_absolute_error)
# 	52.23s	 = Training   runtime
# 	10.11s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 395.06s of the 395.05s of remaining time.
# 	Fitting 8 child models (S19F1 - S19F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-154.0068	 = Validation score   (-mean_absolute_error)
# 	41.44s	 = Training   runtime
# 	4.12s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 390.67s of the 390.66s of remaining time.
# 	Fitting 8 child models (S19F1 - S19F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-153.7273	 = Validation score   (-mean_absolute_error)
# 	194.35s	 = Training   runtime
# 	0.39s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 373.74s of the 373.73s of remaining time.
# 	Fitting 8 child models (S19F1 - S19F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-152.5041	 = Validation score   (-mean_absolute_error)
# 	336.1s	 = Training   runtime
# 	4.86s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 354.99s of the 354.98s of remaining time.
# 	Fitting 8 child models (S19F1 - S19F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-152.9276	 = Validation score   (-mean_absolute_error)
# 	66.99s	 = Training   runtime
# 	1.91s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 349.34s of the 349.33s of remaining time.
# 	Fitting 8 child models (S19F1 - S19F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-152.4214	 = Validation score   (-mean_absolute_error)
# 	427.64s	 = Training   runtime
# 	4.43s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 324.53s of the 324.52s of remaining time.
# 	Fitting 8 child models (S19F1 - S19F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-153.9929	 = Validation score   (-mean_absolute_error)
# 	97.45s	 = Training   runtime
# 	11.35s	 = Validation runtime
# Repeating k-fold bagging: 20/20
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 318.0s of the 317.99s of remaining time.
# 	Fitting 8 child models (S20F1 - S20F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-155.8878	 = Validation score   (-mean_absolute_error)
# 	55.74s	 = Training   runtime
# 	10.65s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 312.65s of the 312.64s of remaining time.
# 	Fitting 8 child models (S20F1 - S20F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-154.0116	 = Validation score   (-mean_absolute_error)
# 	43.14s	 = Training   runtime
# 	4.34s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 309.4s of the 309.39s of remaining time.
# 	Fitting 8 child models (S20F1 - S20F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-153.7315	 = Validation score   (-mean_absolute_error)
# 	201.93s	 = Training   runtime
# 	0.41s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 300.24s of the 300.23s of remaining time.
# 	Fitting 8 child models (S20F1 - S20F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-152.4706	 = Validation score   (-mean_absolute_error)
# 	353.27s	 = Training   runtime
# 	5.12s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 281.55s of the 281.54s of remaining time.
# 	Fitting 8 child models (S20F1 - S20F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-152.9207	 = Validation score   (-mean_absolute_error)
# 	70.42s	 = Training   runtime
# 	2.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 276.2s of the 276.19s of remaining time.
# 	Fitting 8 child models (S20F1 - S20F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-152.4392	 = Validation score   (-mean_absolute_error)
# 	447.8s	 = Training   runtime
# 	4.66s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 254.47s of the 254.46s of remaining time.
# 	Fitting 8 child models (S20F1 - S20F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-153.9942	 = Validation score   (-mean_absolute_error)
# 	103.39s	 = Training   runtime
# 	11.95s	 = Validation runtime
# Completed 20/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the 246.7s of remaining time.
# 	-150.5523	 = Validation score   (-mean_absolute_error)
# 	0.3s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 5153.61s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20231109_100545/")

# %%
test1 = pipin.get_test_data("A")
test_data1 = TabularDataset(test1)


pred1 = pd.DataFrame(predictor1.predict(test_data1))

# %%
predictor2 = TabularPredictor(label="pv_measurement", eval_metric='mean_absolute_error').fit(
    train2,

    presets='best_quality', 
    # hyperparameters='very_large', 
    # time_limit=60*60*1.5
    # tuning_data = tuning2,
    # use_bag_holdout=True,
    # num_bag_folds= 6,
    # refit_full = True,
    # auto_stack = True,
    # num_bag_sets= 10,
    # set_best_to_refit_full= True,
    # num_stack_levels = 2,
    # verbosity = 3
    )

# tuning_data
# num bag holdout 6
# bag_holdout
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20231109_113150/"
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=20
# Beginning AutoGluon training ... Time limit = 5400.0s
# AutoGluon will save models to "AutogluonModels/ag-20231109_113150/"
# AutoGluon Version:  0.8.2
# Python Version:     3.10.13
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 22.5.0: Thu Jun  8 22:22:20 PDT 2023; root:xnu-8796.121.3~7/RELEASE_ARM64_T6000
# Disk Space Avail:   792.10 GB / 994.66 GB (79.6%)
# Train Data Rows:    25667
# Train Data Columns: 46
# Label Column: pv_measurement
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (1152.3, 0.0, 108.0757, 213.23738)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    18991.99 MB
# 	Train Data (Original)  Memory Usage: 5.13 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 2 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 46 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 44 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 		('int', ['bool']) :  2 | ['elevation:m', 'snow_density:kgm3']
# 	0.1s = Fit runtime
# 	46 features in original data used to generate 46 features in processed data.
# 	Train Data (Processed) Memory Usage: 4.98 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.11s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 3599.03s of the 5399.89s of remaining time.
# 	-40.945	 = Validation score   (-mean_absolute_error)
# 	0.02s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 3598.62s of the 5399.48s of remaining time.
# 	-41.0654	 = Validation score   (-mean_absolute_error)
# 	0.02s	 = Training   runtime
# 	0.39s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 3598.18s of the 5399.04s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.4561	 = Validation score   (-mean_absolute_error)
# 	20.92s	 = Training   runtime
# 	42.72s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 3568.85s of the 5369.71s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-24.0126	 = Validation score   (-mean_absolute_error)
# 	28.42s	 = Training   runtime
# 	16.94s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 3532.99s of the 5333.85s of remaining time.
# 	-26.7819	 = Validation score   (-mean_absolute_error)
# 	14.87s	 = Training   runtime
# 	0.67s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 3517.24s of the 5318.1s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-24.5788	 = Validation score   (-mean_absolute_error)
# 	200.61s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 3315.16s of the 5116.02s of remaining time.
# 	-26.4656	 = Validation score   (-mean_absolute_error)
# 	2.59s	 = Training   runtime
# 	0.72s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 3311.63s of the 5112.49s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-27.7891	 = Validation score   (-mean_absolute_error)
# 	13.43s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 3296.74s of the 5097.6s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-24.9408	 = Validation score   (-mean_absolute_error)
# 	91.64s	 = Training   runtime
# 	41.05s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 3197.19s of the 4998.05s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-25.5741	 = Validation score   (-mean_absolute_error)
# 	34.96s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 3160.39s of the 4961.25s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-23.3324	 = Validation score   (-mean_absolute_error)
# 	80.13s	 = Training   runtime
# 	123.54s	 = Validation runtime
# Repeating k-fold bagging: 2/20
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 3058.39s of the 4859.26s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.9341	 = Validation score   (-mean_absolute_error)
# 	41.12s	 = Training   runtime
# 	86.24s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 3030.01s of the 4830.87s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-23.4143	 = Validation score   (-mean_absolute_error)
# 	52.96s	 = Training   runtime
# 	33.89s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 3000.35s of the 4801.21s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-24.0906	 = Validation score   (-mean_absolute_error)
# 	398.36s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 2801.03s of the 4601.89s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-27.3037	 = Validation score   (-mean_absolute_error)
# 	26.71s	 = Training   runtime
# 	0.42s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 2786.13s of the 4586.99s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-24.3706	 = Validation score   (-mean_absolute_error)
# 	183.24s	 = Training   runtime
# 	78.4s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 2687.23s of the 4488.09s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-25.098	 = Validation score   (-mean_absolute_error)
# 	73.33s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 2647.25s of the 4448.11s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.9862	 = Validation score   (-mean_absolute_error)
# 	161.21s	 = Training   runtime
# 	209.64s	 = Validation runtime
# Repeating k-fold bagging: 3/20
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 2544.3s of the 4345.16s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.7149	 = Validation score   (-mean_absolute_error)
# 	60.2s	 = Training   runtime
# 	134.15s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 2516.46s of the 4317.33s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-23.1493	 = Validation score   (-mean_absolute_error)
# 	81.34s	 = Training   runtime
# 	56.93s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 2480.11s of the 4280.97s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-23.8672	 = Validation score   (-mean_absolute_error)
# 	603.36s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 2273.5s of the 4074.36s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-27.1061	 = Validation score   (-mean_absolute_error)
# 	40.33s	 = Training   runtime
# 	0.63s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 2258.2s of the 4059.06s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-24.1025	 = Validation score   (-mean_absolute_error)
# 	275.78s	 = Training   runtime
# 	108.92s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 2158.88s of the 3959.74s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-24.7931	 = Validation score   (-mean_absolute_error)
# 	119.63s	 = Training   runtime
# 	0.42s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 2110.94s of the 3911.8s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.8104	 = Validation score   (-mean_absolute_error)
# 	240.62s	 = Training   runtime
# 	258.77s	 = Validation runtime
# Repeating k-fold bagging: 4/20
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 2017.19s of the 3818.05s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.6318	 = Validation score   (-mean_absolute_error)
# 	80.73s	 = Training   runtime
# 	176.86s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 1988.16s of the 3789.02s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-23.0598	 = Validation score   (-mean_absolute_error)
# 	108.46s	 = Training   runtime
# 	72.07s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 1954.64s of the 3755.51s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-23.768	 = Validation score   (-mean_absolute_error)
# 	807.06s	 = Training   runtime
# 	0.41s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 1749.5s of the 3550.36s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-26.9773	 = Validation score   (-mean_absolute_error)
# 	53.81s	 = Training   runtime
# 	0.83s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 1734.36s of the 3535.22s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-24.0198	 = Validation score   (-mean_absolute_error)
# 	367.95s	 = Training   runtime
# 	147.54s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 1634.79s of the 3435.65s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-24.7306	 = Validation score   (-mean_absolute_error)
# 	156.76s	 = Training   runtime
# 	0.56s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 1595.97s of the 3396.84s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.7477	 = Validation score   (-mean_absolute_error)
# 	320.72s	 = Training   runtime
# 	312.98s	 = Validation runtime
# Repeating k-fold bagging: 5/20
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 1499.22s of the 3300.09s of remaining time.
# 	Fitting 8 child models (S5F1 - S5F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.5849	 = Validation score   (-mean_absolute_error)
# 	100.99s	 = Training   runtime
# 	222.15s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 1470.2s of the 3271.06s of remaining time.
# 	Fitting 8 child models (S5F1 - S5F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.9958	 = Validation score   (-mean_absolute_error)
# 	137.42s	 = Training   runtime
# 	92.82s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 1433.18s of the 3234.04s of remaining time.
# 	Fitting 8 child models (S5F1 - S5F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-23.7282	 = Validation score   (-mean_absolute_error)
# 	1013.79s	 = Training   runtime
# 	0.52s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 1224.89s of the 3025.76s of remaining time.
# 	Fitting 8 child models (S5F1 - S5F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-26.9211	 = Validation score   (-mean_absolute_error)
# 	68.42s	 = Training   runtime
# 	1.06s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 1208.81s of the 3009.68s of remaining time.
# 	Fitting 8 child models (S5F1 - S5F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-23.9558	 = Validation score   (-mean_absolute_error)
# 	460.09s	 = Training   runtime
# 	184.37s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 1109.04s of the 2909.9s of remaining time.
# 	Fitting 8 child models (S5F1 - S5F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-24.7511	 = Validation score   (-mean_absolute_error)
# 	186.68s	 = Training   runtime
# 	0.7s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 1077.35s of the 2878.21s of remaining time.
# 	Fitting 8 child models (S5F1 - S5F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.7167	 = Validation score   (-mean_absolute_error)
# 	402.81s	 = Training   runtime
# 	419.89s	 = Validation runtime
# Repeating k-fold bagging: 6/20
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 973.6s of the 2774.46s of remaining time.
# 	Fitting 8 child models (S6F1 - S6F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.5434	 = Validation score   (-mean_absolute_error)
# 	120.4s	 = Training   runtime
# 	268.25s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 945.55s of the 2746.41s of remaining time.
# 	Fitting 8 child models (S6F1 - S6F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.9479	 = Validation score   (-mean_absolute_error)
# 	165.54s	 = Training   runtime
# 	113.78s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 909.58s of the 2710.45s of remaining time.
# 	Fitting 8 child models (S6F1 - S6F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-23.7835	 = Validation score   (-mean_absolute_error)
# 	2085.79s	 = Training   runtime
# 	0.66s	 = Validation runtime
# Completed 6/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 1636.81s of remaining time.
# 	-21.5434	 = Validation score   (-mean_absolute_error)
# 	0.22s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 9 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 1636.57s of the 1636.57s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.8257	 = Validation score   (-mean_absolute_error)
# 	3.26s	 = Training   runtime
# 	0.5s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 1468.05s of the 1468.04s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.1097	 = Validation score   (-mean_absolute_error)
# 	2.32s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ... Training model for up to 1463.83s of the 1463.83s of remaining time.
# 	-21.7627	 = Validation score   (-mean_absolute_error)
# 	1468.06s	 = Training   runtime
# 	0.72s	 = Validation runtime
# Completed 1/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the -5.2s of remaining time.
# 	-21.6896	 = Validation score   (-mean_absolute_error)
# 	0.12s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 5405.33s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20231109_113150/")

# %%
predictor3 = TabularPredictor(label="pv_measurement", eval_metric='mean_absolute_error' ).fit(
    train3,

    presets='best_quality', 
    # time_limit=60*60*1.5
    # hyperparameters='very_large', 
    # tuning_data = tuning3,
    # use_bag_holdout=True,
    # num_bag_folds= 6,
    # refit_full = True,
    # auto_stack = True,
    # num_bag_sets= 10,
    # set_best_to_refit_full= True,
    # num_stack_levels = 2,
    # verbosity = 3
    )
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20231109_130156/"
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=20
# Beginning AutoGluon training ... Time limit = 5400.0s
# AutoGluon will save models to "AutogluonModels/ag-20231109_130156/"
# AutoGluon Version:  0.8.2
# Python Version:     3.10.13
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 22.5.0: Thu Jun  8 22:22:20 PDT 2023; root:xnu-8796.121.3~7/RELEASE_ARM64_T6000
# Disk Space Avail:   782.84 GB / 994.66 GB (78.7%)
# Train Data Rows:    20905
# Train Data Columns: 46
# Label Column: pv_measurement
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and label-values can't be converted to int).
# 	Label info (max, min, mean, stddev): (999.6, 0.0, 96.74745, 180.17896)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    17625.91 MB
# 	Train Data (Original)  Memory Usage: 4.18 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 3 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Unused Original Features (Count: 1): ['snow_drift:idx']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('float', []) : 1 | ['snow_drift:idx']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 45 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 43 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 		('int', ['bool']) :  2 | ['elevation:m', 'snow_density:kgm3']
# 	0.2s = Fit runtime
# 	45 features in original data used to generate 45 features in processed data.
# 	Train Data (Processed) Memory Usage: 3.97 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.2s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 3598.97s of the 5399.8s of remaining time.
# 	-32.3099	 = Validation score   (-mean_absolute_error)
# 	0.02s	 = Training   runtime
# 	0.24s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 3598.67s of the 5399.5s of remaining time.
# 	-32.3392	 = Validation score   (-mean_absolute_error)
# 	0.02s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 3598.33s of the 5399.16s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.9083	 = Validation score   (-mean_absolute_error)
# 	19.64s	 = Training   runtime
# 	34.11s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 3570.96s of the 5371.79s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.1397	 = Validation score   (-mean_absolute_error)
# 	26.6s	 = Training   runtime
# 	28.07s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 3536.28s of the 5337.11s of remaining time.
# 	-23.528	 = Validation score   (-mean_absolute_error)
# 	9.73s	 = Training   runtime
# 	0.5s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 3525.84s of the 5326.68s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.6178	 = Validation score   (-mean_absolute_error)
# 	188.66s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 3335.6s of the 5136.43s of remaining time.
# 	-23.3046	 = Validation score   (-mean_absolute_error)
# 	2.04s	 = Training   runtime
# 	0.56s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 3332.79s of the 5133.63s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-23.7997	 = Validation score   (-mean_absolute_error)
# 	11.74s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 3319.57s of the 5120.4s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.1726	 = Validation score   (-mean_absolute_error)
# 	86.29s	 = Training   runtime
# 	22.91s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 3227.65s of the 5028.48s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.1942	 = Validation score   (-mean_absolute_error)
# 	25.41s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 3200.56s of the 5001.39s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-20.7619	 = Validation score   (-mean_absolute_error)
# 	81.72s	 = Training   runtime
# 	83.29s	 = Validation runtime
# Repeating k-fold bagging: 2/20
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 3099.46s of the 4900.29s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.4348	 = Validation score   (-mean_absolute_error)
# 	37.89s	 = Training   runtime
# 	71.49s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 3073.51s of the 4874.35s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-20.6465	 = Validation score   (-mean_absolute_error)
# 	53.59s	 = Training   runtime
# 	60.04s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 3038.33s of the 4839.16s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.1752	 = Validation score   (-mean_absolute_error)
# 	379.22s	 = Training   runtime
# 	0.19s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 2846.09s of the 4646.92s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-23.3909	 = Validation score   (-mean_absolute_error)
# 	22.88s	 = Training   runtime
# 	0.39s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 2833.42s of the 4634.25s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.6453	 = Validation score   (-mean_absolute_error)
# 	172.58s	 = Training   runtime
# 	50.08s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 2741.34s of the 4542.17s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.8067	 = Validation score   (-mean_absolute_error)
# 	52.43s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 2712.54s of the 4513.38s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-20.4507	 = Validation score   (-mean_absolute_error)
# 	163.75s	 = Training   runtime
# 	184.97s	 = Validation runtime
# Repeating k-fold bagging: 3/20
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 2609.76s of the 4410.59s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.2689	 = Validation score   (-mean_absolute_error)
# 	55.46s	 = Training   runtime
# 	111.8s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 2584.1s of the 4384.93s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-20.4797	 = Validation score   (-mean_absolute_error)
# 	80.26s	 = Training   runtime
# 	83.3s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 2550.15s of the 4350.98s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.0218	 = Validation score   (-mean_absolute_error)
# 	566.51s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 2361.32s of the 4162.15s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-23.2523	 = Validation score   (-mean_absolute_error)
# 	35.07s	 = Training   runtime
# 	0.57s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 2347.5s of the 4148.33s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.3994	 = Validation score   (-mean_absolute_error)
# 	257.65s	 = Training   runtime
# 	78.99s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 2256.53s of the 4057.37s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.735	 = Validation score   (-mean_absolute_error)
# 	75.52s	 = Training   runtime
# 	0.37s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 2231.91s of the 4032.74s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-20.3746	 = Validation score   (-mean_absolute_error)
# 	243.66s	 = Training   runtime
# 	281.58s	 = Validation runtime
# Repeating k-fold bagging: 4/20
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 2133.19s of the 3934.02s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.2077	 = Validation score   (-mean_absolute_error)
# 	73.52s	 = Training   runtime
# 	149.67s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 2107.44s of the 3908.27s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-20.3945	 = Validation score   (-mean_absolute_error)
# 	107.0s	 = Training   runtime
# 	115.56s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 2072.53s of the 3873.36s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-20.9541	 = Validation score   (-mean_absolute_error)
# 	752.75s	 = Training   runtime
# 	0.38s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 1884.85s of the 3685.68s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-23.1838	 = Validation score   (-mean_absolute_error)
# 	46.46s	 = Training   runtime
# 	0.75s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 1871.96s of the 3672.8s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.2626	 = Validation score   (-mean_absolute_error)
# 	342.94s	 = Training   runtime
# 	100.27s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 1781.03s of the 3581.87s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.7326	 = Validation score   (-mean_absolute_error)
# 	93.87s	 = Training   runtime
# 	0.49s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 1761.16s of the 3561.99s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-20.3113	 = Validation score   (-mean_absolute_error)
# 	325.68s	 = Training   runtime
# 	364.85s	 = Validation runtime
# Repeating k-fold bagging: 5/20
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 1659.52s of the 3460.35s of remaining time.
# 	Fitting 8 child models (S5F1 - S5F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.1547	 = Validation score   (-mean_absolute_error)
# 	91.35s	 = Training   runtime
# 	188.62s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 1634.11s of the 3434.94s of remaining time.
# 	Fitting 8 child models (S5F1 - S5F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-20.3534	 = Validation score   (-mean_absolute_error)
# 	133.77s	 = Training   runtime
# 	144.99s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 1599.03s of the 3399.86s of remaining time.
# 	Fitting 8 child models (S5F1 - S5F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-20.9233	 = Validation score   (-mean_absolute_error)
# 	939.75s	 = Training   runtime
# 	0.47s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 1410.52s of the 3211.35s of remaining time.
# 	Fitting 8 child models (S5F1 - S5F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-23.1237	 = Validation score   (-mean_absolute_error)
# 	57.68s	 = Training   runtime
# 	0.94s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 1397.82s of the 3198.65s of remaining time.
# 	Fitting 8 child models (S5F1 - S5F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.2023	 = Validation score   (-mean_absolute_error)
# 	428.74s	 = Training   runtime
# 	127.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 1306.33s of the 3107.17s of remaining time.
# 	Fitting 8 child models (S5F1 - S5F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.642	 = Validation score   (-mean_absolute_error)
# 	118.82s	 = Training   runtime
# 	0.61s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 1279.58s of the 3080.41s of remaining time.
# 	Fitting 8 child models (S5F1 - S5F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-20.2879	 = Validation score   (-mean_absolute_error)
# 	408.3s	 = Training   runtime
# 	465.48s	 = Validation runtime
# Repeating k-fold bagging: 6/20
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 1175.87s of the 2976.7s of remaining time.
# 	Fitting 8 child models (S6F1 - S6F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.1549	 = Validation score   (-mean_absolute_error)
# 	110.43s	 = Training   runtime
# 	229.08s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 1148.6s of the 2949.43s of remaining time.
# 	Fitting 8 child models (S6F1 - S6F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-20.3327	 = Validation score   (-mean_absolute_error)
# 	163.18s	 = Training   runtime
# 	190.82s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 1110.41s of the 2911.24s of remaining time.
# 	Fitting 8 child models (S6F1 - S6F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-20.8866	 = Validation score   (-mean_absolute_error)
# 	1131.31s	 = Training   runtime
# 	0.56s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 917.4s of the 2718.23s of remaining time.
# 	Fitting 8 child models (S6F1 - S6F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-23.104	 = Validation score   (-mean_absolute_error)
# 	69.69s	 = Training   runtime
# 	1.14s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 903.84s of the 2704.67s of remaining time.
# 	Fitting 8 child models (S6F1 - S6F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.1887	 = Validation score   (-mean_absolute_error)
# 	515.02s	 = Training   runtime
# 	151.92s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 811.13s of the 2611.96s of remaining time.
# 	Fitting 8 child models (S6F1 - S6F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.632	 = Validation score   (-mean_absolute_error)
# 	144.63s	 = Training   runtime
# 	0.74s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 783.78s of the 2584.61s of remaining time.
# 	Fitting 8 child models (S6F1 - S6F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-20.2878	 = Validation score   (-mean_absolute_error)
# 	491.68s	 = Training   runtime
# 	555.54s	 = Validation runtime
# Repeating k-fold bagging: 7/20
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 680.38s of the 2481.22s of remaining time.
# 	Fitting 8 child models (S7F1 - S7F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.1752	 = Validation score   (-mean_absolute_error)
# 	128.71s	 = Training   runtime
# 	266.92s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 654.53s of the 2455.36s of remaining time.
# 	Fitting 8 child models (S7F1 - S7F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-20.3082	 = Validation score   (-mean_absolute_error)
# 	190.25s	 = Training   runtime
# 	229.49s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 618.5s of the 2419.34s of remaining time.
# 	Fitting 8 child models (S7F1 - S7F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-20.8861	 = Validation score   (-mean_absolute_error)
# 	1319.39s	 = Training   runtime
# 	0.66s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 428.65s of the 2229.48s of remaining time.
# 	Fitting 8 child models (S7F1 - S7F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-23.0821	 = Validation score   (-mean_absolute_error)
# 	82.19s	 = Training   runtime
# 	1.33s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 414.54s of the 2215.38s of remaining time.
# 	Fitting 8 child models (S7F1 - S7F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.1374	 = Validation score   (-mean_absolute_error)
# 	600.52s	 = Training   runtime
# 	175.28s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 322.99s of the 2123.82s of remaining time.
# 	Fitting 8 child models (S7F1 - S7F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.6219	 = Validation score   (-mean_absolute_error)
# 	174.55s	 = Training   runtime
# 	0.86s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 291.48s of the 2092.31s of remaining time.
# 	Fitting 8 child models (S7F1 - S7F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-20.2932	 = Validation score   (-mean_absolute_error)
# 	571.71s	 = Training   runtime
# 	667.13s	 = Validation runtime
# Completed 7/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 1990.63s of remaining time.
# 	-19.116	 = Validation score   (-mean_absolute_error)
# 	0.27s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 9 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 1990.35s of the 1990.35s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-20.2101	 = Validation score   (-mean_absolute_error)
# 	1.85s	 = Training   runtime
# 	0.34s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 1986.91s of the 1986.9s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.6816	 = Validation score   (-mean_absolute_error)
# 	1.49s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ... Training model for up to 1983.79s of the 1983.78s of remaining time.
# 	-19.3071	 = Validation score   (-mean_absolute_error)
# 	14.85s	 = Training   runtime
# 	0.54s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 1968.19s of the 1968.19s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.854	 = Validation score   (-mean_absolute_error)
# 	6.99s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ... Training model for up to 1959.84s of the 1959.83s of remaining time.
# 	-19.1877	 = Validation score   (-mean_absolute_error)
# 	2.49s	 = Training   runtime
# 	0.57s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 1956.53s of the 1956.52s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.3508	 = Validation score   (-mean_absolute_error)
# 	11.22s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 1943.66s of the 1943.66s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.5579	 = Validation score   (-mean_absolute_error)
# 	3.55s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 1938.31s of the 1938.3s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.8616	 = Validation score   (-mean_absolute_error)
# 	15.55s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 1921.1s of the 1921.09s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.7666	 = Validation score   (-mean_absolute_error)
# 	5.34s	 = Training   runtime
# 	0.43s	 = Validation runtime
# Repeating k-fold bagging: 2/20
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 1913.88s of the 1913.88s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-20.0822	 = Validation score   (-mean_absolute_error)
# 	5.73s	 = Training   runtime
# 	0.79s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 1908.12s of the 1908.11s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.5309	 = Validation score   (-mean_absolute_error)
# 	2.97s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 1905.14s of the 1905.13s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.7213	 = Validation score   (-mean_absolute_error)
# 	19.01s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 1891.35s of the 1891.35s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.1854	 = Validation score   (-mean_absolute_error)
# 	22.45s	 = Training   runtime
# 	0.38s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 1878.66s of the 1878.66s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.3576	 = Validation score   (-mean_absolute_error)
# 	7.42s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 1873.09s of the 1873.09s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.6796	 = Validation score   (-mean_absolute_error)
# 	32.93s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 1854.05s of the 1854.04s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.5702	 = Validation score   (-mean_absolute_error)
# 	10.98s	 = Training   runtime
# 	0.87s	 = Validation runtime
# Repeating k-fold bagging: 3/20
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 1846.57s of the 1846.56s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-20.037	 = Validation score   (-mean_absolute_error)
# 	8.62s	 = Training   runtime
# 	1.21s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 1841.95s of the 1841.94s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.4927	 = Validation score   (-mean_absolute_error)
# 	4.91s	 = Training   runtime
# 	0.47s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 1838.51s of the 1838.5s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.6644	 = Validation score   (-mean_absolute_error)
# 	28.95s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 1826.98s of the 1826.97s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.138	 = Validation score   (-mean_absolute_error)
# 	33.81s	 = Training   runtime
# 	0.57s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 1814.22s of the 1814.21s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.3167	 = Validation score   (-mean_absolute_error)
# 	10.7s	 = Training   runtime
# 	0.19s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 1809.15s of the 1809.14s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.6125	 = Validation score   (-mean_absolute_error)
# 	48.83s	 = Training   runtime
# 	0.52s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 1791.71s of the 1791.7s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.509	 = Validation score   (-mean_absolute_error)
# 	15.89s	 = Training   runtime
# 	1.34s	 = Validation runtime
# Repeating k-fold bagging: 4/20
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 1785.16s of the 1785.15s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.9945	 = Validation score   (-mean_absolute_error)
# 	11.6s	 = Training   runtime
# 	1.59s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 1780.44s of the 1780.43s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.4435	 = Validation score   (-mean_absolute_error)
# 	7.46s	 = Training   runtime
# 	0.62s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 1776.21s of the 1776.2s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.6567	 = Validation score   (-mean_absolute_error)
# 	37.69s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 1765.77s of the 1765.77s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.0726	 = Validation score   (-mean_absolute_error)
# 	46.44s	 = Training   runtime
# 	0.76s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 1751.55s of the 1751.55s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.2833	 = Validation score   (-mean_absolute_error)
# 	14.22s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 1746.22s of the 1746.21s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.5837	 = Validation score   (-mean_absolute_error)
# 	64.25s	 = Training   runtime
# 	0.69s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 1729.2s of the 1729.19s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.4596	 = Validation score   (-mean_absolute_error)
# 	20.47s	 = Training   runtime
# 	1.75s	 = Validation runtime
# Repeating k-fold bagging: 5/20
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 1723.08s of the 1723.07s of remaining time.
# 	Fitting 8 child models (S5F1 - S5F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.9695	 = Validation score   (-mean_absolute_error)
# 	14.26s	 = Training   runtime
# 	1.95s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 1718.68s of the 1718.67s of remaining time.
# 	Fitting 8 child models (S5F1 - S5F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.4304	 = Validation score   (-mean_absolute_error)
# 	9.06s	 = Training   runtime
# 	0.79s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 1715.6s of the 1715.6s of remaining time.
# 	Fitting 8 child models (S5F1 - S5F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.6392	 = Validation score   (-mean_absolute_error)
# 	45.87s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 1705.65s of the 1705.64s of remaining time.
# 	Fitting 8 child models (S5F1 - S5F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.0367	 = Validation score   (-mean_absolute_error)
# 	57.83s	 = Training   runtime
# 	0.94s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 1692.73s of the 1692.72s of remaining time.
# 	Fitting 8 child models (S5F1 - S5F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.266	 = Validation score   (-mean_absolute_error)
# 	17.81s	 = Training   runtime
# 	0.32s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 1687.28s of the 1687.28s of remaining time.
# 	Fitting 8 child models (S5F1 - S5F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.5646	 = Validation score   (-mean_absolute_error)
# 	79.29s	 = Training   runtime
# 	0.87s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 1670.66s of the 1670.65s of remaining time.
# 	Fitting 8 child models (S5F1 - S5F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.4415	 = Validation score   (-mean_absolute_error)
# 	25.26s	 = Training   runtime
# 	2.19s	 = Validation runtime
# Repeating k-fold bagging: 6/20
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 1664.2s of the 1664.2s of remaining time.
# 	Fitting 8 child models (S6F1 - S6F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.9644	 = Validation score   (-mean_absolute_error)
# 	17.02s	 = Training   runtime
# 	2.27s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 1659.71s of the 1659.71s of remaining time.
# 	Fitting 8 child models (S6F1 - S6F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.4235	 = Validation score   (-mean_absolute_error)
# 	11.75s	 = Training   runtime
# 	0.95s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 1655.32s of the 1655.31s of remaining time.
# 	Fitting 8 child models (S6F1 - S6F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.6386	 = Validation score   (-mean_absolute_error)
# 	57.73s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 1641.8s of the 1641.79s of remaining time.
# 	Fitting 8 child models (S6F1 - S6F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.0146	 = Validation score   (-mean_absolute_error)
# 	68.99s	 = Training   runtime
# 	1.13s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 1629.17s of the 1629.16s of remaining time.
# 	Fitting 8 child models (S6F1 - S6F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.2649	 = Validation score   (-mean_absolute_error)
# 	21.32s	 = Training   runtime
# 	0.38s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 1623.91s of the 1623.9s of remaining time.
# 	Fitting 8 child models (S6F1 - S6F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.5642	 = Validation score   (-mean_absolute_error)
# 	96.66s	 = Training   runtime
# 	1.04s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 1604.89s of the 1604.88s of remaining time.
# 	Fitting 8 child models (S6F1 - S6F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.4265	 = Validation score   (-mean_absolute_error)
# 	30.01s	 = Training   runtime
# 	2.6s	 = Validation runtime
# Repeating k-fold bagging: 7/20
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 1598.35s of the 1598.34s of remaining time.
# 	Fitting 8 child models (S7F1 - S7F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.9461	 = Validation score   (-mean_absolute_error)
# 	19.77s	 = Training   runtime
# 	2.66s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 1593.76s of the 1593.75s of remaining time.
# 	Fitting 8 child models (S7F1 - S7F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.4136	 = Validation score   (-mean_absolute_error)
# 	13.3s	 = Training   runtime
# 	1.1s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 1590.65s of the 1590.64s of remaining time.
# 	Fitting 8 child models (S7F1 - S7F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.6325	 = Validation score   (-mean_absolute_error)
# 	66.13s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 1580.56s of the 1580.56s of remaining time.
# 	Fitting 8 child models (S7F1 - S7F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-18.999	 = Validation score   (-mean_absolute_error)
# 	81.33s	 = Training   runtime
# 	1.31s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 1566.56s of the 1566.56s of remaining time.
# 	Fitting 8 child models (S7F1 - S7F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.2518	 = Validation score   (-mean_absolute_error)
# 	24.77s	 = Training   runtime
# 	0.45s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 1561.31s of the 1561.31s of remaining time.
# 	Fitting 8 child models (S7F1 - S7F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.5374	 = Validation score   (-mean_absolute_error)
# 	113.97s	 = Training   runtime
# 	1.22s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 1542.31s of the 1542.31s of remaining time.
# 	Fitting 8 child models (S7F1 - S7F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.4037	 = Validation score   (-mean_absolute_error)
# 	34.67s	 = Training   runtime
# 	3.04s	 = Validation runtime
# Repeating k-fold bagging: 8/20
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 1535.9s of the 1535.89s of remaining time.
# 	Fitting 8 child models (S8F1 - S8F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.9428	 = Validation score   (-mean_absolute_error)
# 	22.5s	 = Training   runtime
# 	3.02s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 1531.49s of the 1531.48s of remaining time.
# 	Fitting 8 child models (S8F1 - S8F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.4078	 = Validation score   (-mean_absolute_error)
# 	14.88s	 = Training   runtime
# 	1.26s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 1528.51s of the 1528.5s of remaining time.
# 	Fitting 8 child models (S8F1 - S8F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.6257	 = Validation score   (-mean_absolute_error)
# 	79.59s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 1513.35s of the 1513.34s of remaining time.
# 	Fitting 8 child models (S8F1 - S8F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-18.9898	 = Validation score   (-mean_absolute_error)
# 	92.52s	 = Training   runtime
# 	1.5s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 1500.68s of the 1500.67s of remaining time.
# 	Fitting 8 child models (S8F1 - S8F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.2448	 = Validation score   (-mean_absolute_error)
# 	28.54s	 = Training   runtime
# 	0.51s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 1495.18s of the 1495.18s of remaining time.
# 	Fitting 8 child models (S8F1 - S8F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.5296	 = Validation score   (-mean_absolute_error)
# 	129.23s	 = Training   runtime
# 	1.39s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 1478.36s of the 1478.36s of remaining time.
# 	Fitting 8 child models (S8F1 - S8F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.3825	 = Validation score   (-mean_absolute_error)
# 	39.73s	 = Training   runtime
# 	3.49s	 = Validation runtime
# Repeating k-fold bagging: 9/20
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 1471.61s of the 1471.6s of remaining time.
# 	Fitting 8 child models (S9F1 - S9F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.9387	 = Validation score   (-mean_absolute_error)
# 	24.22s	 = Training   runtime
# 	3.34s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 1468.17s of the 1468.17s of remaining time.
# 	Fitting 8 child models (S9F1 - S9F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.4069	 = Validation score   (-mean_absolute_error)
# 	16.58s	 = Training   runtime
# 	1.42s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 1464.88s of the 1464.87s of remaining time.
# 	Fitting 8 child models (S9F1 - S9F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.6211	 = Validation score   (-mean_absolute_error)
# 	90.11s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 1452.73s of the 1452.73s of remaining time.
# 	Fitting 8 child models (S9F1 - S9F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-18.983	 = Validation score   (-mean_absolute_error)
# 	103.85s	 = Training   runtime
# 	1.68s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 1439.97s of the 1439.96s of remaining time.
# 	Fitting 8 child models (S9F1 - S9F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.2352	 = Validation score   (-mean_absolute_error)
# 	31.28s	 = Training   runtime
# 	0.57s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 1435.51s of the 1435.5s of remaining time.
# 	Fitting 8 child models (S9F1 - S9F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.5318	 = Validation score   (-mean_absolute_error)
# 	144.11s	 = Training   runtime
# 	1.56s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 1418.98s of the 1418.98s of remaining time.
# 	Fitting 8 child models (S9F1 - S9F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.3804	 = Validation score   (-mean_absolute_error)
# 	44.44s	 = Training   runtime
# 	3.95s	 = Validation runtime
# Repeating k-fold bagging: 10/20
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 1412.56s of the 1412.55s of remaining time.
# 	Fitting 8 child models (S10F1 - S10F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.9405	 = Validation score   (-mean_absolute_error)
# 	25.85s	 = Training   runtime
# 	3.69s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 1409.26s of the 1409.26s of remaining time.
# 	Fitting 8 child models (S10F1 - S10F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.4152	 = Validation score   (-mean_absolute_error)
# 	19.0s	 = Training   runtime
# 	1.56s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 1405.24s of the 1405.23s of remaining time.
# 	Fitting 8 child models (S10F1 - S10F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.6234	 = Validation score   (-mean_absolute_error)
# 	100.05s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 1393.53s of the 1393.52s of remaining time.
# 	Fitting 8 child models (S10F1 - S10F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-18.9795	 = Validation score   (-mean_absolute_error)
# 	115.17s	 = Training   runtime
# 	1.87s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 1380.73s of the 1380.72s of remaining time.
# 	Fitting 8 child models (S10F1 - S10F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.2254	 = Validation score   (-mean_absolute_error)
# 	34.71s	 = Training   runtime
# 	0.64s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 1375.61s of the 1375.6s of remaining time.
# 	Fitting 8 child models (S10F1 - S10F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.5201	 = Validation score   (-mean_absolute_error)
# 	159.45s	 = Training   runtime
# 	1.73s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 1358.56s of the 1358.55s of remaining time.
# 	Fitting 8 child models (S10F1 - S10F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.3918	 = Validation score   (-mean_absolute_error)
# 	50.25s	 = Training   runtime
# 	4.42s	 = Validation runtime
# Repeating k-fold bagging: 11/20
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 1350.99s of the 1350.99s of remaining time.
# 	Fitting 8 child models (S11F1 - S11F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.9393	 = Validation score   (-mean_absolute_error)
# 	28.04s	 = Training   runtime
# 	4.08s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 1347.06s of the 1347.06s of remaining time.
# 	Fitting 8 child models (S11F1 - S11F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.4119	 = Validation score   (-mean_absolute_error)
# 	21.45s	 = Training   runtime
# 	1.71s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 1342.84s of the 1342.83s of remaining time.
# 	Fitting 8 child models (S11F1 - S11F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.6212	 = Validation score   (-mean_absolute_error)
# 	108.74s	 = Training   runtime
# 	0.19s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 1332.49s of the 1332.48s of remaining time.
# 	Fitting 8 child models (S11F1 - S11F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-18.9769	 = Validation score   (-mean_absolute_error)
# 	126.38s	 = Training   runtime
# 	2.05s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 1319.82s of the 1319.82s of remaining time.
# 	Fitting 8 child models (S11F1 - S11F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.2197	 = Validation score   (-mean_absolute_error)
# 	38.33s	 = Training   runtime
# 	0.7s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 1314.38s of the 1314.37s of remaining time.
# 	Fitting 8 child models (S11F1 - S11F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.5082	 = Validation score   (-mean_absolute_error)
# 	175.43s	 = Training   runtime
# 	1.91s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 1296.86s of the 1296.85s of remaining time.
# 	Fitting 8 child models (S11F1 - S11F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.3791	 = Validation score   (-mean_absolute_error)
# 	56.07s	 = Training   runtime
# 	4.88s	 = Validation runtime
# Repeating k-fold bagging: 12/20
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 1289.24s of the 1289.24s of remaining time.
# 	Fitting 8 child models (S12F1 - S12F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.9392	 = Validation score   (-mean_absolute_error)
# 	29.81s	 = Training   runtime
# 	4.45s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 1285.81s of the 1285.81s of remaining time.
# 	Fitting 8 child models (S12F1 - S12F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.4015	 = Validation score   (-mean_absolute_error)
# 	24.05s	 = Training   runtime
# 	1.86s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 1281.58s of the 1281.57s of remaining time.
# 	Fitting 8 child models (S12F1 - S12F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.6192	 = Validation score   (-mean_absolute_error)
# 	117.12s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 1271.61s of the 1271.6s of remaining time.
# 	Fitting 8 child models (S12F1 - S12F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-18.9744	 = Validation score   (-mean_absolute_error)
# 	138.82s	 = Training   runtime
# 	2.24s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 1257.52s of the 1257.51s of remaining time.
# 	Fitting 8 child models (S12F1 - S12F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.2065	 = Validation score   (-mean_absolute_error)
# 	42.39s	 = Training   runtime
# 	0.76s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 1251.77s of the 1251.76s of remaining time.
# 	Fitting 8 child models (S12F1 - S12F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.5133	 = Validation score   (-mean_absolute_error)
# 	189.94s	 = Training   runtime
# 	2.09s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 1235.71s of the 1235.7s of remaining time.
# 	Fitting 8 child models (S12F1 - S12F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.3713	 = Validation score   (-mean_absolute_error)
# 	62.09s	 = Training   runtime
# 	5.32s	 = Validation runtime
# Repeating k-fold bagging: 13/20
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 1227.83s of the 1227.82s of remaining time.
# 	Fitting 8 child models (S13F1 - S13F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.934	 = Validation score   (-mean_absolute_error)
# 	31.71s	 = Training   runtime
# 	4.83s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 1224.23s of the 1224.22s of remaining time.
# 	Fitting 8 child models (S13F1 - S13F8) | Fitting with ParallelLocalFoldFittingStrategy
# ...
# 	Fitting 8 child models (S13F1 - S13F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.3625	 = Validation score   (-mean_absolute_error)
# 	67.37s	 = Training   runtime
# 	5.83s	 = Validation runtime
# Repeating k-fold bagging: 14/20
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 1169.09s of the 1169.08s of remaining time.
# 	Fitting 8 child models (S14F1 - S14F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.929	 = Validation score   (-mean_absolute_error)
# 	35.41s	 = Training   runtime
# 	5.27s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 1163.5s of the 1163.49s of remaining time.
# 	Fitting 8 child models (S14F1 - S14F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.399	 = Validation score   (-mean_absolute_error)
# 	27.32s	 = Training   runtime
# 	2.16s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 1160.11s of the 1160.1s of remaining time.
# 	Fitting 8 child models (S14F1 - S14F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.6145	 = Validation score   (-mean_absolute_error)
# 	135.81s	 = Training   runtime
# 	0.24s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 1148.12s of the 1148.12s of remaining time.
# 	Fitting 8 child models (S14F1 - S14F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-18.9761	 = Validation score   (-mean_absolute_error)
# 	162.29s	 = Training   runtime
# 	2.61s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 1134.21s of the 1134.2s of remaining time.
# 	Fitting 8 child models (S14F1 - S14F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.2	 = Validation score   (-mean_absolute_error)
# 	49.1s	 = Training   runtime
# 	0.88s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 1129.04s of the 1129.04s of remaining time.
# 	Fitting 8 child models (S14F1 - S14F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.501	 = Validation score   (-mean_absolute_error)
# 	224.66s	 = Training   runtime
# 	2.43s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 1107.93s of the 1107.92s of remaining time.
# 	Fitting 8 child models (S14F1 - S14F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.3511	 = Validation score   (-mean_absolute_error)
# 	73.07s	 = Training   runtime
# 	6.31s	 = Validation runtime
# Repeating k-fold bagging: 15/20
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 1100.4s of the 1100.4s of remaining time.
# 	Fitting 8 child models (S15F1 - S15F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.9284	 = Validation score   (-mean_absolute_error)
# 	37.46s	 = Training   runtime
# 	5.67s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 1096.71s of the 1096.7s of remaining time.
# 	Fitting 8 child models (S15F1 - S15F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.3995	 = Validation score   (-mean_absolute_error)
# 	29.81s	 = Training   runtime
# 	2.3s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 1092.54s of the 1092.54s of remaining time.
# 	Fitting 8 child models (S15F1 - S15F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.614	 = Validation score   (-mean_absolute_error)
# 	144.78s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 1081.88s of the 1081.87s of remaining time.
# 	Fitting 8 child models (S15F1 - S15F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-18.9761	 = Validation score   (-mean_absolute_error)
# 	173.73s	 = Training   runtime
# 	2.79s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 1068.94s of the 1068.93s of remaining time.
# 	Fitting 8 child models (S15F1 - S15F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.2056	 = Validation score   (-mean_absolute_error)
# 	52.64s	 = Training   runtime
# 	0.94s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 1063.64s of the 1063.63s of remaining time.
# 	Fitting 8 child models (S15F1 - S15F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.5033	 = Validation score   (-mean_absolute_error)
# 	241.95s	 = Training   runtime
# 	2.61s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 1044.66s of the 1044.65s of remaining time.
# 	Fitting 8 child models (S15F1 - S15F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.3579	 = Validation score   (-mean_absolute_error)
# 	77.64s	 = Training   runtime
# 	6.72s	 = Validation runtime
# Repeating k-fold bagging: 16/20
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 1038.37s of the 1038.36s of remaining time.
# 	Fitting 8 child models (S16F1 - S16F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.9264	 = Validation score   (-mean_absolute_error)
# 	39.91s	 = Training   runtime
# 	6.03s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 1034.32s of the 1034.31s of remaining time.
# 	Fitting 8 child models (S16F1 - S16F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.4007	 = Validation score   (-mean_absolute_error)
# 	32.4s	 = Training   runtime
# 	2.46s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 1029.91s of the 1029.91s of remaining time.
# 	Fitting 8 child models (S16F1 - S16F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.6157	 = Validation score   (-mean_absolute_error)
# 	154.4s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 1018.65s of the 1018.65s of remaining time.
# 	Fitting 8 child models (S16F1 - S16F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-18.9738	 = Validation score   (-mean_absolute_error)
# 	184.92s	 = Training   runtime
# 	2.97s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 1005.92s of the 1005.91s of remaining time.
# 	Fitting 8 child models (S16F1 - S16F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.2062	 = Validation score   (-mean_absolute_error)
# 	56.17s	 = Training   runtime
# 	1.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 1000.6s of the 1000.59s of remaining time.
# 	Fitting 8 child models (S16F1 - S16F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.5048	 = Validation score   (-mean_absolute_error)
# 	256.11s	 = Training   runtime
# 	2.78s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 984.77s of the 984.77s of remaining time.
# 	Fitting 8 child models (S16F1 - S16F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.3549	 = Validation score   (-mean_absolute_error)
# 	82.38s	 = Training   runtime
# 	7.16s	 = Validation runtime
# Repeating k-fold bagging: 17/20
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 978.25s of the 978.24s of remaining time.
# 	Fitting 8 child models (S17F1 - S17F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.9253	 = Validation score   (-mean_absolute_error)
# 	41.52s	 = Training   runtime
# 	6.36s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 975.02s of the 975.01s of remaining time.
# 	Fitting 8 child models (S17F1 - S17F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.3974	 = Validation score   (-mean_absolute_error)
# 	34.86s	 = Training   runtime
# 	2.62s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 970.93s of the 970.92s of remaining time.
# 	Fitting 8 child models (S17F1 - S17F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.6161	 = Validation score   (-mean_absolute_error)
# 	162.08s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 961.3s of the 961.29s of remaining time.
# 	Fitting 8 child models (S17F1 - S17F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-18.9739	 = Validation score   (-mean_absolute_error)
# 	196.28s	 = Training   runtime
# 	3.15s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 948.42s of the 948.42s of remaining time.
# 	Fitting 8 child models (S17F1 - S17F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.2042	 = Validation score   (-mean_absolute_error)
# 	59.87s	 = Training   runtime
# 	1.07s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 942.94s of the 942.94s of remaining time.
# 	Fitting 8 child models (S17F1 - S17F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.5026	 = Validation score   (-mean_absolute_error)
# 	271.08s	 = Training   runtime
# 	2.96s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 926.32s of the 926.31s of remaining time.
# 	Fitting 8 child models (S17F1 - S17F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.3527	 = Validation score   (-mean_absolute_error)
# 	88.39s	 = Training   runtime
# 	7.63s	 = Validation runtime
# Repeating k-fold bagging: 18/20
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 918.47s of the 918.46s of remaining time.
# 	Fitting 8 child models (S18F1 - S18F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.9264	 = Validation score   (-mean_absolute_error)
# 	43.13s	 = Training   runtime
# 	6.67s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 915.26s of the 915.25s of remaining time.
# 	Fitting 8 child models (S18F1 - S18F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.3959	 = Validation score   (-mean_absolute_error)
# 	36.3s	 = Training   runtime
# 	2.76s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 912.12s of the 912.12s of remaining time.
# 	Fitting 8 child models (S18F1 - S18F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.6133	 = Validation score   (-mean_absolute_error)
# 	172.19s	 = Training   runtime
# 	0.32s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 900.31s of the 900.31s of remaining time.
# 	Fitting 8 child models (S18F1 - S18F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-18.9716	 = Validation score   (-mean_absolute_error)
# 	207.58s	 = Training   runtime
# 	3.34s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 887.51s of the 887.51s of remaining time.
# 	Fitting 8 child models (S18F1 - S18F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.2024	 = Validation score   (-mean_absolute_error)
# 	63.33s	 = Training   runtime
# 	1.13s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 882.29s of the 882.29s of remaining time.
# 	Fitting 8 child models (S18F1 - S18F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.5059	 = Validation score   (-mean_absolute_error)
# 	286.23s	 = Training   runtime
# 	3.13s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 865.48s of the 865.47s of remaining time.
# 	Fitting 8 child models (S18F1 - S18F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.3561	 = Validation score   (-mean_absolute_error)
# 	93.16s	 = Training   runtime
# 	8.07s	 = Validation runtime
# Repeating k-fold bagging: 19/20
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 859.07s of the 859.06s of remaining time.
# 	Fitting 8 child models (S19F1 - S19F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.9228	 = Validation score   (-mean_absolute_error)
# 	44.66s	 = Training   runtime
# 	7.0s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 855.86s of the 855.85s of remaining time.
# 	Fitting 8 child models (S19F1 - S19F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.3885	 = Validation score   (-mean_absolute_error)
# 	37.87s	 = Training   runtime
# 	2.91s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 852.59s of the 852.58s of remaining time.
# 	Fitting 8 child models (S19F1 - S19F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.6106	 = Validation score   (-mean_absolute_error)
# 	182.04s	 = Training   runtime
# 	0.33s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 841.15s of the 841.15s of remaining time.
# 	Fitting 8 child models (S19F1 - S19F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-18.9732	 = Validation score   (-mean_absolute_error)
# 	218.95s	 = Training   runtime
# 	3.52s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 828.34s of the 828.33s of remaining time.
# 	Fitting 8 child models (S19F1 - S19F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.2052	 = Validation score   (-mean_absolute_error)
# 	66.62s	 = Training   runtime
# 	1.19s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 823.24s of the 823.24s of remaining time.
# 	Fitting 8 child models (S19F1 - S19F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.5049	 = Validation score   (-mean_absolute_error)
# 	301.21s	 = Training   runtime
# 	3.3s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 806.45s of the 806.44s of remaining time.
# 	Fitting 8 child models (S19F1 - S19F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.3512	 = Validation score   (-mean_absolute_error)
# 	97.76s	 = Training   runtime
# 	8.49s	 = Validation runtime
# Repeating k-fold bagging: 20/20
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 800.13s of the 800.13s of remaining time.
# 	Fitting 8 child models (S20F1 - S20F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.9243	 = Validation score   (-mean_absolute_error)
# 	47.23s	 = Training   runtime
# 	7.29s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 795.88s of the 795.87s of remaining time.
# 	Fitting 8 child models (S20F1 - S20F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.3878	 = Validation score   (-mean_absolute_error)
# 	39.55s	 = Training   runtime
# 	3.06s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 792.47s of the 792.46s of remaining time.
# 	Fitting 8 child models (S20F1 - S20F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.6109	 = Validation score   (-mean_absolute_error)
# 	190.56s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 782.32s of the 782.32s of remaining time.
# 	Fitting 8 child models (S20F1 - S20F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-18.9692	 = Validation score   (-mean_absolute_error)
# 	230.19s	 = Training   runtime
# 	3.7s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 769.56s of the 769.55s of remaining time.
# 	Fitting 8 child models (S20F1 - S20F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.2074	 = Validation score   (-mean_absolute_error)
# 	70.01s	 = Training   runtime
# 	1.25s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 764.38s of the 764.38s of remaining time.
# 	Fitting 8 child models (S20F1 - S20F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.5046	 = Validation score   (-mean_absolute_error)
# 	316.43s	 = Training   runtime
# 	3.48s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 747.47s of the 747.46s of remaining time.
# 	Fitting 8 child models (S20F1 - S20F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-19.3526	 = Validation score   (-mean_absolute_error)
# 	102.79s	 = Training   runtime
# 	8.97s	 = Validation runtime
# Completed 20/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the 740.63s of remaining time.
# 	-18.8343	 = Validation score   (-mean_absolute_error)
# 	0.44s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 4659.82s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20231109_130156/")

# %%
test1 = pipin.get_test_data("A")
test2 = pipin.get_test_data("B")
test3 = pipin.get_test_data("C")

# %%
test_data1 = TabularDataset(test1)
test_data2 = TabularDataset(test2)
test_data3 = TabularDataset(test3)

# pred1 = pd.DataFrame(predictor1.predict(test_data1))
pred2 = pd.DataFrame(predictor2.predict(test_data2))
pred3 = pd.DataFrame(predictor3.predict(test_data3))

negatives_pred1 = pred1[pred1["pv_measurement"] < 0]
negatives_pred2 = pred2[pred2["pv_measurement"] < 0]
negatives_pred3 = pred3[pred3["pv_measurement"] < 0]
neg = pd.concat([negatives_pred1, negatives_pred2, negatives_pred3])
neg.shape
# Out:
# (168, 1)

# %%
from utils import get_unique_filename
pred = pd.concat([pred1, pred2, pred3])
final_prediction = pipin.post_processing(pred, prediction_column="pv_measurement")
file_name = f"gluon_3_remove_consecutive_measurements_{threshold1}_{threshold2}_{threshold3}"
final_prediction.to_csv(get_unique_filename(file_name))

# %%
diff = pipin.compare_mae(final_prediction)
diff
# Out:
# 17.83717034574026

# %%
# predictor.evaluate(df1, silent=True)
