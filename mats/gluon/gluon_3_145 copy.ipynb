# %% [markdown]
# <h3> tester ny consecutives function.</h3>
# <p>ny ga 145.44.<p>

# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from autogluon.tabular import TabularDataset, TabularPredictor
import pandas as pd
import numpy as np

# %%
# %autoreload
import sys
sys.path.append('../')
from pipeline import Pipeline
pipin = Pipeline()
# Out:
# Current working directory: /Users/matsalexander/Desktop/Forest Gump/mats/gluon

# %%
df1_0 = pipin.get_data("A")
df2_0 = pipin.get_data("B")
df3_0 = pipin.get_data("C")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/matsalexander/Desktop/Forest Gump/mats/gluon/gluon_3_145 copy.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/Users/matsalexander/Desktop/Forest%20Gump/mats/gluon/gluon_3_145%20copy.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> df1_0 = pipin.get_data("A")
#       <a href='vscode-notebook-cell:/Users/matsalexander/Desktop/Forest%20Gump/mats/gluon/gluon_3_145%20copy.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> df2_0 = pipin.get_data("B")
#       <a href='vscode-notebook-cell:/Users/matsalexander/Desktop/Forest%20Gump/mats/gluon/gluon_3_145%20copy.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> df3_0 = pipin.get_data("C")
#
# File ~/Desktop/Forest Gump/mats/gluon/../pipeline.py:97, in Pipeline.get_data(self, location, keeptime)
#      95 def get_data(self, location: str, keeptime=False) -> pd.DataFrame:
#      96     train, targets = self.get_training_data_by_location(location)
# ---> 97     return self.handle_data(train, targets, keeptime=keeptime)
#
# File ~/Desktop/Forest Gump/mats/gluon/../pipeline.py:126, in Pipeline.handle_data(self, df, targets, keeptime)
#     123     df.rename(columns={"time": "date_forecast"}, inplace=True)
#     125 # denne var ikke med i 148 3 modeller med gluon.
# --> 126 df = self.absolute_values(df)
#     127 return df
#
# File ~/Desktop/Forest Gump/mats/gluon/../pipeline.py:208, in Pipeline.absolute_values(self, df)
#     207 def absolute_values(self, df: pd.DataFrame):
# --> 208     columns = list(df.columns)
#     209     columns.remove("date_forecast")
#     210     print("columns", columns)
#
# AttributeError: 'NoneType' object has no attribute 'columns'

# %%
# remove_consecutive_measurments
df1_0 = pipin.remove_consecutive_measurments(df1_0, 3, 12)
df2_0 = pipin.remove_consecutive_measurments(df2_0, 3, 12)
df3_0 = pipin.remove_consecutive_measurments(df3_0, 3, 12)
# Out:
# ---------------------------------------------------------------------------
# SettingWithCopyError                      Traceback (most recent call last)
# /var/folders/b0/slnc__2x31jczblnsfgfmjw00000gn/T/ipykernel_72009/2924262346.py in ?()
#       1 # remove_consecutive_measurments
# ----> 2 df1_0 = pipin.remove_consecutive_measurments(df1_0, 3, 12)
#       3 df2_0 = pipin.remove_consecutive_measurments(df2_0, 3, 12)
#       4 df3_0 = pipin.remove_consecutive_measurments(df3_0, 3, 12)
#
# ~/Desktop/Forest Gump/mats/gluon/../pipeline.py in ?(self, df, consecutive_threshold, consecutive_threshold_zero, return_removed_rows)
#     224
#     225         removed_rows = df.copy().loc[mask]
#     226         df = df.loc[~mask]
#     227         # if "consecutive_count" in df.columns:
# --> 228         df.drop(["consecutive_count"], axis=1, inplace=True)
#     229
#     230         if return_removed_rows:
#     231             return df, removed_rows
#
# ~/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/pandas/util/_decorators.py in ?(*args, **kwargs)
#     327                     msg.format(arguments=_format_argument_list(allow_args)),
#     328                     FutureWarning,
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#
# ~/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/pandas/core/frame.py in ?(self, labels, axis, index, columns, level, inplace, errors)
#    5395                 weight  250.0   150.0
#    5396         falcon  speed   320.0   250.0
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#    5402             index=index,
#
# ~/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/pandas/util/_decorators.py in ?(*args, **kwargs)
#     327                     msg.format(arguments=_format_argument_list(allow_args)),
#     328                     FutureWarning,
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#
# ~/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, labels, axis, index, columns, level, inplace, errors)
#    4504             if labels is not None:
#    4505                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4506
#    4507         if inplace:
# -> 4508             self._update_inplace(obj)
#    4509         else:
#    4510             return obj
#
# ~/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, result, verify_is_copy)
#    4610         # decision that we may revisit in the future.
#    4611         self._reset_cache()
#    4612         self._clear_item_cache()
#    4613         self._mgr = result._mgr
# -> 4614         self._maybe_update_cacher(verify_is_copy=verify_is_copy, inplace=True)
#
# ~/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, clear, verify_is_copy, inplace)
#    3763             Provide is_copy checks.
#    3764         """
#    3765
#    3766         if verify_is_copy:
# -> 3767             self._check_setitem_copy(t="referent")
#    3768
#    3769         if clear:
#    3770             self._clear_item_cache()
#
# ~/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, t, force)
#    4207                 "indexing.html#returning-a-view-versus-a-copy"
#    4208             )
#    4209
#    4210         if value == "raise":
# -> 4211             raise SettingWithCopyError(t)
#    4212         elif value == "warn":
#    4213             warnings.warn(t, SettingWithCopyWarning, stacklevel=find_stack_level())
#
# SettingWithCopyError:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df1_0.head()
# Out:
#    absolute_humidity_2m:gm3  air_density_2m:kgm3  ceiling_height_agl:m  \
# 0                     7.700              1.22825           1728.949951
# 1                     7.700              1.22350           1689.824951
# 2                     7.875              1.21975           1563.224976
# 3                     8.425              1.21800           1283.425049
# 4                     8.950              1.21800           1003.500000
#
#    clear_sky_energy_1h:J  clear_sky_rad:W  cloud_base_agl:m  dew_or_rime:idx  \
# 0               0.000000             0.00       1728.949951              0.0
# 1               0.000000             0.00       1689.824951              0.0
# 2               0.000000             0.00       1563.224976              0.0
# 3             208.649994             0.75       1283.425049              0.0
# 4           32468.150391            23.10       1003.500000              0.0
#
#    dew_point_2m:K  diffuse_rad:W  diffuse_rad_1h:J  ...  wind_speed_10m:ms  \
# 0      280.299988          0.000          0.000000  ...              3.600
# 1      280.299988          0.000          0.000000  ...              3.350
# 2      280.649994          0.000          0.000000  ...              3.050
# 3      281.674988          0.300        526.775024  ...              2.725
# 4      282.500000         11.975      22068.949219  ...              2.550
#
#    wind_speed_u_10m:ms  wind_speed_v_10m:ms  wind_speed_w_1000hPa:ms  \
# 0                3.575                0.500                      0.0
# 1                3.350                0.275                      0.0
# 2                2.950                0.750                      0.0
# 3                2.600                0.875                      0.0
# 4                2.350                0.925                      0.0
#
#    estimated  observed  day_of_year  hour  pv_measurement  consecutive_count
# 0        0.0       1.0        153.0  22.0            0.00                  4
# 1        0.0       1.0        153.0  23.0            0.00                  4
# 2        0.0       1.0        154.0   0.0            0.00                  4
# 3        0.0       1.0        154.0   1.0            0.00                  4
# 4        0.0       1.0        154.0   2.0           19.36                  1
#
# [5 rows x 51 columns]

# %%
train1 = TabularDataset(df1_0)
train2 = TabularDataset(df2_0)
train3 = TabularDataset(df3_0)

# %%
predictor1 = TabularPredictor(label="pv_measurement", eval_metric='mean_absolute_error').fit(
    train1,
    # time_limit=6000,
    # hyperparameters='extrme', 
    presets='best_quality', 
    # tuning_data = tuning1,
    # use_bag_holdout=True,
    # num_bag_folds= 6,
    # refit_full = True,
    # auto_stack = True,
    # num_bag_sets= 10,
    # set_best_to_refit_full= True,
    # num_stack_levels = 2,
    # verbosity = 3
    )
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20231108_080511/"
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20231108_080511/"
# AutoGluon Version:  0.8.2
# Python Version:     3.10.13
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 22.5.0: Thu Jun  8 22:22:20 PDT 2023; root:xnu-8796.121.3~7/RELEASE_ARM64_T6000
# Disk Space Avail:   660.06 GB / 994.66 GB (66.4%)
# Train Data Rows:    23231
# Train Data Columns: 50
# Label Column: pv_measurement
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (5733.42, 0.0, 925.2215, 1312.19479)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    15717.94 MB
# 	Train Data (Original)  Memory Usage: 5.11 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 3 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Unused Original Features (Count: 1): ['snow_drift:idx']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('float', []) : 1 | ['snow_drift:idx']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 48 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 		('int', [])   :  1 | ['consecutive_count']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 46 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 		('int', [])       :  1 | ['consecutive_count']
# 		('int', ['bool']) :  2 | ['elevation:m', 'snow_density:kgm3']
# 	0.6s = Fit runtime
# 	49 features in original data used to generate 49 features in processed data.
# 	Train Data (Processed) Memory Usage: 4.88 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.67s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ...
# 	-387.0076	 = Validation score   (-mean_absolute_error)
# 	0.03s	 = Training   runtime
# 	0.66s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ...
# 	-388.2399	 = Validation score   (-mean_absolute_error)
# 	0.03s	 = Training   runtime
# 	0.64s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-223.0788	 = Validation score   (-mean_absolute_error)
# 	74.54s	 = Training   runtime
# 	53.28s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-234.0356	 = Validation score   (-mean_absolute_error)
# 	57.04s	 = Training   runtime
# 	59.76s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ...
# 	-265.3719	 = Validation score   (-mean_absolute_error)
# 	24.19s	 = Training   runtime
# 	0.9s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-240.3565	 = Validation score   (-mean_absolute_error)
# 	446.24s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ...
# 	-264.8291	 = Validation score   (-mean_absolute_error)
# 	7.89s	 = Training   runtime
# 	0.83s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-263.7155	 = Validation score   (-mean_absolute_error)
# 	28.12s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-249.0936	 = Validation score   (-mean_absolute_error)
# 	118.5s	 = Training   runtime
# 	14.72s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-251.1274	 = Validation score   (-mean_absolute_error)
# 	77.4s	 = Training   runtime
# 	0.24s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-230.3507	 = Validation score   (-mean_absolute_error)
# 	198.56s	 = Training   runtime
# 	199.99s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-219.5208	 = Validation score   (-mean_absolute_error)
# 	0.25s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 9 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-221.199	 = Validation score   (-mean_absolute_error)
# 	4.15s	 = Training   runtime
# 	0.51s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-218.125	 = Validation score   (-mean_absolute_error)
# 	2.31s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ...
# 	-217.8156	 = Validation score   (-mean_absolute_error)
# 	34.48s	 = Training   runtime
# 	1.13s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-219.2669	 = Validation score   (-mean_absolute_error)
# 	16.0s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ...
# 	-216.6709	 = Validation score   (-mean_absolute_error)
# 	6.56s	 = Training   runtime
# 	0.94s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-216.7687	 = Validation score   (-mean_absolute_error)
# 	27.6s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-218.0131	 = Validation score   (-mean_absolute_error)
# 	8.15s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-217.3359	 = Validation score   (-mean_absolute_error)
# 	18.32s	 = Training   runtime
# 	0.42s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-219.589	 = Validation score   (-mean_absolute_error)
# 	12.27s	 = Training   runtime
# 	0.69s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ...
# 	-212.63	 = Validation score   (-mean_absolute_error)
# 	0.24s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 1255.91s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20231108_080511/")

# %%
test1 = pipin.get_test_data("A")
test_data1 = TabularDataset(test1)
pred1 = pd.DataFrame(predictor1.predict(test_data1))

# %%
predictor2 = TabularPredictor(label="pv_measurement", eval_metric='mean_absolute_error').fit(
    train2,

    presets='best_quality', 
    # hyperparameters='very_large', 
    # time_limit=6000,
    # tuning_data = tuning2,
    # use_bag_holdout=True,
    # num_bag_folds= 6,
    # refit_full = True,
    # auto_stack = True,
    # num_bag_sets= 10,
    # set_best_to_refit_full= True,
    # num_stack_levels = 2,
    # verbosity = 3
    )

# tuning_data
# num bag holdout 6
# bag_holdout
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20231108_082607/"
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20231108_082607/"
# AutoGluon Version:  0.8.2
# Python Version:     3.10.13
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 22.5.0: Thu Jun  8 22:22:20 PDT 2023; root:xnu-8796.121.3~7/RELEASE_ARM64_T6000
# Disk Space Avail:   652.11 GB / 994.66 GB (65.6%)
# Train Data Rows:    15792
# Train Data Columns: 50
# Label Column: pv_measurement
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (1152.3, 0.0, 175.40234, 249.06867)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    16534.06 MB
# 	Train Data (Original)  Memory Usage: 3.47 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 3 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Unused Original Features (Count: 1): ['snow_drift:idx']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('float', []) : 1 | ['snow_drift:idx']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 48 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 		('int', [])   :  1 | ['consecutive_count']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 46 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 		('int', [])       :  1 | ['consecutive_count']
# 		('int', ['bool']) :  2 | ['elevation:m', 'snow_density:kgm3']
# 	0.3s = Fit runtime
# 	49 features in original data used to generate 49 features in processed data.
# 	Train Data (Processed) Memory Usage: 3.32 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.35s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ...
# 	-65.8501	 = Validation score   (-mean_absolute_error)
# 	0.01s	 = Training   runtime
# 	0.33s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ...
# 	-66.0355	 = Validation score   (-mean_absolute_error)
# 	0.01s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-35.0178	 = Validation score   (-mean_absolute_error)
# 	41.92s	 = Training   runtime
# 	35.18s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-37.4011	 = Validation score   (-mean_absolute_error)
# 	68.57s	 = Training   runtime
# 	54.96s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ...
# 	-42.9136	 = Validation score   (-mean_absolute_error)
# 	19.33s	 = Training   runtime
# 	0.63s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-38.2149	 = Validation score   (-mean_absolute_error)
# 	290.26s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ...
# 	-42.4651	 = Validation score   (-mean_absolute_error)
# 	6.2s	 = Training   runtime
# 	0.53s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-42.3342	 = Validation score   (-mean_absolute_error)
# 	15.64s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-39.6798	 = Validation score   (-mean_absolute_error)
# 	144.47s	 = Training   runtime
# 	15.71s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-41.0233	 = Validation score   (-mean_absolute_error)
# 	52.78s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-36.9147	 = Validation score   (-mean_absolute_error)
# 	1116.34s	 = Training   runtime
# 	294.12s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-34.6975	 = Validation score   (-mean_absolute_error)
# 	0.23s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 9 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-35.6195	 = Validation score   (-mean_absolute_error)
# 	4.81s	 = Training   runtime
# 	0.49s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-34.9553	 = Validation score   (-mean_absolute_error)
# 	3.92s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ...
# 	-34.7686	 = Validation score   (-mean_absolute_error)
# 	40.57s	 = Training   runtime
# 	0.96s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-35.1448	 = Validation score   (-mean_absolute_error)
# 	20.08s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ...
# 	-34.3764	 = Validation score   (-mean_absolute_error)
# 	6.21s	 = Training   runtime
# 	0.78s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-34.8302	 = Validation score   (-mean_absolute_error)
# 	21.81s	 = Training   runtime
# 	0.19s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-34.7317	 = Validation score   (-mean_absolute_error)
# 	3.48s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-35.0708	 = Validation score   (-mean_absolute_error)
# 	19.98s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-35.068	 = Validation score   (-mean_absolute_error)
# 	21.56s	 = Training   runtime
# 	1.13s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ...
# 	-33.9962	 = Validation score   (-mean_absolute_error)
# 	0.18s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 1984.63s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20231108_082607/")

# %%
predictor3 = TabularPredictor(label="pv_measurement", eval_metric='mean_absolute_error' ).fit(
    train3,

    presets='best_quality', 
    # hyperparameters='very_large', 
    # time_limit=6000,
    # tuning_data = tuning3,
    # use_bag_holdout=True,
    # num_bag_folds= 6,
    # refit_full = True,
    # auto_stack = True,
    # num_bag_sets= 10,
    # set_best_to_refit_full= True,
    # num_stack_levels = 2,
    # verbosity = 3
    )
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20231108_085912/"
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20231108_085912/"
# AutoGluon Version:  0.8.2
# Python Version:     3.10.13
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 22.5.0: Thu Jun  8 22:22:20 PDT 2023; root:xnu-8796.121.3~7/RELEASE_ARM64_T6000
# Disk Space Avail:   646.37 GB / 994.66 GB (65.0%)
# Train Data Rows:    13084
# Train Data Columns: 50
# Label Column: pv_measurement
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and label-values can't be converted to int).
# 	Label info (max, min, mean, stddev): (999.6, 0.0, 154.46153, 207.24859)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    16100.72 MB
# 	Train Data (Original)  Memory Usage: 2.88 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 3 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Unused Original Features (Count: 1): ['snow_drift:idx']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('float', []) : 1 | ['snow_drift:idx']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 48 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 		('int', [])   :  1 | ['consecutive_count']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 46 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 		('int', [])       :  1 | ['consecutive_count']
# 		('int', ['bool']) :  2 | ['elevation:m', 'snow_density:kgm3']
# 	0.3s = Fit runtime
# 	49 features in original data used to generate 49 features in processed data.
# 	Train Data (Processed) Memory Usage: 2.75 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.33s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ...
# 	-50.6947	 = Validation score   (-mean_absolute_error)
# 	0.02s	 = Training   runtime
# 	0.27s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ...
# 	-50.7606	 = Validation score   (-mean_absolute_error)
# 	0.03s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-30.5495	 = Validation score   (-mean_absolute_error)
# 	63.37s	 = Training   runtime
# 	35.7s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-32.6506	 = Validation score   (-mean_absolute_error)
# 	62.25s	 = Training   runtime
# 	44.02s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ...
# 	-36.6478	 = Validation score   (-mean_absolute_error)
# 	13.71s	 = Training   runtime
# 	0.46s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-32.5603	 = Validation score   (-mean_absolute_error)
# 	494.41s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ...
# 	-36.17	 = Validation score   (-mean_absolute_error)
# 	5.1s	 = Training   runtime
# 	0.5s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-36.0199	 = Validation score   (-mean_absolute_error)
# 	46.55s	 = Training   runtime
# 	0.56s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-33.791	 = Validation score   (-mean_absolute_error)
# 	186.41s	 = Training   runtime
# 	13.77s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-34.2445	 = Validation score   (-mean_absolute_error)
# 	57.62s	 = Training   runtime
# 	0.44s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-32.311	 = Validation score   (-mean_absolute_error)
# 	131.94s	 = Training   runtime
# 	92.5s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-30.1345	 = Validation score   (-mean_absolute_error)
# 	0.22s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 9 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-31.1379	 = Validation score   (-mean_absolute_error)
# 	3.79s	 = Training   runtime
# 	0.38s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-30.8559	 = Validation score   (-mean_absolute_error)
# 	4.89s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ...
# 	-30.2509	 = Validation score   (-mean_absolute_error)
# 	22.68s	 = Training   runtime
# 	0.45s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-30.8051	 = Validation score   (-mean_absolute_error)
# 	32.82s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ...
# 	-30.2377	 = Validation score   (-mean_absolute_error)
# 	5.69s	 = Training   runtime
# 	0.45s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-30.7683	 = Validation score   (-mean_absolute_error)
# 	27.78s	 = Training   runtime
# 	0.47s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-30.6335	 = Validation score   (-mean_absolute_error)
# 	9.42s	 = Training   runtime
# 	0.27s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-30.8103	 = Validation score   (-mean_absolute_error)
# 	27.69s	 = Training   runtime
# 	0.54s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-31.0356	 = Validation score   (-mean_absolute_error)
# 	16.25s	 = Training   runtime
# 	1.04s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ...
# 	-29.8596	 = Validation score   (-mean_absolute_error)
# 	0.19s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 1304.77s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20231108_085912/")

# %%
test1 = pipin.get_test_data("A")
test2 = pipin.get_test_data("B")
test3 = pipin.get_test_data("C")

# %%
test_data1 = TabularDataset(test1)
test_data2 = TabularDataset(test2)
test_data3 = TabularDataset(test3)

pred1 = pd.DataFrame(predictor1.predict(test_data1))
pred2 = pd.DataFrame(predictor2.predict(test_data2))
pred3 = pd.DataFrame(predictor3.predict(test_data3))

negatives_pred1 = pred1[pred1["pv_measurement"] < 0]
negatives_pred2 = pred2[pred2["pv_measurement"] < 0]
negatives_pred3 = pred3[pred3["pv_measurement"] < 0]
neg = pd.concat([negatives_pred1, negatives_pred2, negatives_pred3])
neg.shape
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/features/generators/abstract.py:338, in AbstractFeatureGenerator.transform(self, X)
#     335     if list(X.columns) != self.features_in:
#     336         # It comes at a cost when making a copy of the DataFrame,
#     337         # therefore, try avoid copying by checking the expected features first.
# --> 338         X = X[self.features_in]
#     339 except KeyError:
#
# File ~/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/pandas/core/frame.py:3813, in DataFrame.__getitem__(self, key)
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#
# File ~/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/pandas/core/indexes/base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#
# File ~/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/pandas/core/indexes/base.py:6133, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6132 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6133 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['consecutive_count'] not in index"
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /Users/matsalexander/Desktop/Forest Gump/mats/gluon/gluon_3_145 copy.ipynb Cell 13 line 5
#       <a href='vscode-notebook-cell:/Users/matsalexander/Desktop/Forest%20Gump/mats/gluon/gluon_3_145%20copy.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a> test_data2 = TabularDataset(test2)
#       <a href='vscode-notebook-cell:/Users/matsalexander/Desktop/Forest%20Gump/mats/gluon/gluon_3_145%20copy.ipynb#X15sZmlsZQ%3D%3D?line=2'>3</a> test_data3 = TabularDataset(test3)
# ----> <a href='vscode-notebook-cell:/Users/matsalexander/Desktop/Forest%20Gump/mats/gluon/gluon_3_145%20copy.ipynb#X15sZmlsZQ%3D%3D?line=4'>5</a> pred1 = pd.DataFrame(predictor1.predict(test_data1))
#       <a href='vscode-notebook-cell:/Users/matsalexander/Desktop/Forest%20Gump/mats/gluon/gluon_3_145%20copy.ipynb#X15sZmlsZQ%3D%3D?line=5'>6</a> pred2 = pd.DataFrame(predictor2.predict(test_data2))
#       <a href='vscode-notebook-cell:/Users/matsalexander/Desktop/Forest%20Gump/mats/gluon/gluon_3_145%20copy.ipynb#X15sZmlsZQ%3D%3D?line=6'>7</a> pred3 = pd.DataFrame(predictor3.predict(test_data3))
#
# File ~/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/tabular/predictor/predictor.py:1579, in TabularPredictor.predict(self, data, model, as_pandas, transform_features, decision_threshold)
#    1577 if decision_threshold is None:
#    1578     decision_threshold = self.decision_threshold
# -> 1579 return self._learner.predict(X=data, model=model, as_pandas=as_pandas, transform_features=transform_features, decision_threshold=decision_threshold)
#
# File ~/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/tabular/learner/abstract_learner.py:208, in AbstractTabularLearner.predict(self, X, model, as_pandas, inverse_transform, transform_features, decision_threshold)
#     206     decision_threshold = 0.5
#     207 X_index = copy.deepcopy(X.index) if as_pandas else None
# --> 208 y_pred_proba = self.predict_proba(
#     209     X=X, model=model, as_pandas=False, as_multiclass=False, inverse_transform=False, transform_features=transform_features
#     210 )
#     211 problem_type = self.label_cleaner.problem_type_transform or self.problem_type
#     212 y_pred = get_pred_from_proba(y_pred_proba=y_pred_proba, problem_type=problem_type, decision_threshold=decision_threshold)
#
# File ~/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/tabular/learner/abstract_learner.py:188, in AbstractTabularLearner.predict_proba(self, X, model, as_pandas, as_multiclass, inverse_transform, transform_features)
#     186 else:
#     187     if transform_features:
# --> 188         X = self.transform_features(X)
#     189     y_pred_proba = self.load_trainer().predict_proba(X, model=model)
#     190 y_pred_proba = self._post_process_predict_proba(
#     191     y_pred_proba=y_pred_proba, as_pandas=as_pandas, index=X_index, as_multiclass=as_multiclass, inverse_transform=inverse_transform
#     192 )
#
# File ~/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/tabular/learner/abstract_learner.py:462, in AbstractTabularLearner.transform_features(self, X)
#     460 def transform_features(self, X):
#     461     for feature_generator in self.feature_generators:
# --> 462         X = feature_generator.transform(X)
#     463     return X
#
# File ~/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/features/generators/abstract.py:344, in AbstractFeatureGenerator.transform(self, X)
#     342         if col not in X.columns:
#     343             missing_cols.append(col)
# --> 344     raise KeyError(
#     345         f"{len(missing_cols)} required columns are missing from the provided dataset to transform using {self.__class__.__name__}. "
#     346         f"{len(missing_cols)} missing columns: {missing_cols} | "
#     347         f"{len(list(X.columns))} available columns: {list(X.columns)}"
#     348     )
#     349 if self._pre_astype_generator:
#     350     X = self._pre_astype_generator.transform(X)
#
# KeyError: "1 required columns are missing from the provided dataset to transform using AutoMLPipelineFeatureGenerator. 1 missing columns: ['consecutive_count'] | 49 available columns: ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', 'cloud_base_agl:m', 'dew_or_rime:idx', 'dew_point_2m:K', 'diffuse_rad:W', 'diffuse_rad_1h:J', 'direct_rad:W', 'direct_rad_1h:J', 'effective_cloud_cover:p', 'elevation:m', 'fresh_snow_12h:cm', 'fresh_snow_1h:cm', 'fresh_snow_24h:cm', 'fresh_snow_3h:cm', 'fresh_snow_6h:cm', 'is_day:idx', 'is_in_shadow:idx', 'msl_pressure:hPa', 'precip_5min:mm', 'precip_type_5min:idx', 'pressure_100m:hPa', 'pressure_50m:hPa', 'prob_rime:p', 'rain_water:kgm2', 'relative_humidity_1000hPa:p', 'sfc_pressure:hPa', 'snow_density:kgm3', 'snow_depth:cm', 'snow_drift:idx', 'snow_melt_10min:mm', 'snow_water:kgm2', 'sun_azimuth:d', 'sun_elevation:d', 'super_cooled_liquid_water:kgm2', 't_1000hPa:K', 'total_cloud_cover:p', 'visibility:m', 'wind_speed_10m:ms', 'wind_speed_u_10m:ms', 'wind_speed_v_10m:ms', 'wind_speed_w_1000hPa:ms', 'estimated', 'observed', 'day_of_year', 'hour']"

# %%
from utils import get_unique_filename
pred = pd.concat([pred1, pred2, pred3])
final_prediction = pipin.post_processing(pred, prediction_column="pv_measurement")
final_prediction.to_csv(get_unique_filename('gluon_3_3_12'))

# %%
diff = pipin.compare_mae(final_prediction)
diff
# Out:
# 36.15299865835177

# %%
# predictor.evaluate(df1, silent=True)
