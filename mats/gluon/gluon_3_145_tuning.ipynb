# %% [markdown]
# <h3> tester tuning.</h3>
# <p>Henning fikk 144.9. Uten<p>

# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from autogluon.tabular import TabularDataset, TabularPredictor
import pandas as pd
import numpy as np

# %%
# %autoreload
import sys
sys.path.append('../')
from pipeline_tuning import Pipeline
pipin = Pipeline()
# Out:
# Current working directory: /Users/matsalexander/Desktop/Forest Gump/mats/gluon

# %%
df1_0 = pipin.get_data("A", keeptime=True)
df2_0 = pipin.get_data("B", keeptime=True)
df3_0 = pipin.get_data("C", keeptime=True)

# %%
# remove_consecutive_measurments
# 6/24
df1_0 = pipin.remove_consecutive_measurments(df1_0, 4, 24)
df2_0 = pipin.remove_consecutive_measurments(df2_0, 4, 24)
df3_0 = pipin.remove_consecutive_measurments(df3_0, 4, 24)

# %%
print(df1_0.columns[-1])
# Out:
# pv_measurement

# %%
# tuning
# split_train_summer_2021 test this
train1, tune_estimated1 = pipin.split_train_tune(df1_0)
train2, tune_estimated2 = pipin.split_train_tune(df2_0)
train3, tune_estimated3 = pipin.split_train_tune(df3_0)

# %%
train1
# Out:
#             date_forecast  absolute_humidity_2m:gm3  air_density_2m:kgm3  \
# 0     2019-06-02 22:00:00                     7.700              1.22825
# 1     2019-06-02 23:00:00                     7.700              1.22350
# 2     2019-06-03 00:00:00                     7.875              1.21975
# 3     2019-06-03 01:00:00                     8.425              1.21800
# 4     2019-06-03 02:00:00                     8.950              1.21800
# ...                   ...                       ...                  ...
# 31840 2023-01-29 06:00:00                     5.125              1.26000
# 31841 2023-01-29 07:00:00                     5.200              1.25800
# 31842 2023-01-29 08:00:00                     5.175              1.25575
# 31843 2023-01-29 09:00:00                     5.175              1.25300
# 31844 2023-01-29 10:00:00                     5.300              1.24975
#
#        ceiling_height_agl:m  clear_sky_energy_1h:J  clear_sky_rad:W  \
# ...

# %%
# what percent of the data is used for tuning?
train1, tune_summer1 = pipin.split_train_summer_2021(train1.copy())
train2, tune_summer2 = pipin.split_train_summer_2021(train2.copy())
train3, tune_summer3 = pipin.split_train_summer_2021(train3.copy())

# %%
train1
# Out:
#             date_forecast  absolute_humidity_2m:gm3  air_density_2m:kgm3  \
# 0     2019-06-02 22:00:00                     7.700              1.22825
# 1     2019-06-02 23:00:00                     7.700              1.22350
# 2     2019-06-03 00:00:00                     7.875              1.21975
# 3     2019-06-03 01:00:00                     8.425              1.21800
# 4     2019-06-03 02:00:00                     8.950              1.21800
# ...                   ...                       ...                  ...
# 31840 2023-01-29 06:00:00                     5.125              1.26000
# 31841 2023-01-29 07:00:00                     5.200              1.25800
# 31842 2023-01-29 08:00:00                     5.175              1.25575
# 31843 2023-01-29 09:00:00                     5.175              1.25300
# 31844 2023-01-29 10:00:00                     5.300              1.24975
#
#        ceiling_height_agl:m  clear_sky_energy_1h:J  clear_sky_rad:W  \
# ...

# %%
xx = train1["pv_measurement"]
xx
# Out:
# 0         0.00
# 1         0.00
# 2         0.00
# 3         0.00
# 4        19.36
#          ...
# 31840     0.00
# 31841     0.00
# 31842     0.88
# 31843    52.80
# 31844    66.22
# Name: pv_measurement, Length: 30285, dtype: float64

# %%
from sklearn.model_selection import train_test_split
train1, tune_random1, _, __ = train_test_split(train1.copy(), train1.copy()["pv_measurement"], test_size=0.1, random_state=42)
train2, tune_random2, _, __ = train_test_split(train2.copy(), train2.copy()["pv_measurement"], test_size=0.1, random_state=42)
train3, tune_random3, _, __ = train_test_split(train3.copy(), train3.copy()["pv_measurement"], test_size=0.1, random_state=42)

# %%
tune1 = pd.concat([tune_random1, tune_estimated1, tune_summer1])
tune2 = pd.concat([tune_random2, tune_estimated2, tune_summer2])
tune3 = pd.concat([tune_random3, tune_estimated3, tune_summer3])

tune1_0_percent = tune1.shape[0] / (tune1.shape[0] + train1.shape[0])
tune1_0_percent
# Out:
# 0.19877711799635486

# %%
tune1 = tune1.drop(columns=["date_forecast"])
tune2 = tune2.drop(columns=["date_forecast"])
tune3 = tune3.drop(columns=["date_forecast"])
train1 = train1.drop(columns=["date_forecast"])
train2 = train2.drop(columns=["date_forecast"])
train3 = train3.drop(columns=["date_forecast"])

# %%
dfs = [tune1, tune2, tune3, train1, train2, train3]
for dff in dfs:
    print("date_forecast in columns", dff.columns)
    if "date_forecast" in dff.columns or "time" in dff.columns:
        raise Exception("stop")
# Out:
# date_forecast in columns Index(['absolute_humidity_2m:gm3', 'air_density_2m:kgm3',
#        'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W',
#        'cloud_base_agl:m', 'dew_or_rime:idx', 'dew_point_2m:K',
#        'diffuse_rad:W', 'diffuse_rad_1h:J', 'direct_rad:W', 'direct_rad_1h:J',
#        'effective_cloud_cover:p', 'elevation:m', 'fresh_snow_12h:cm',
#        'fresh_snow_1h:cm', 'fresh_snow_24h:cm', 'fresh_snow_3h:cm',
#        'fresh_snow_6h:cm', 'is_day:idx', 'is_in_shadow:idx',
#        'msl_pressure:hPa', 'precip_5min:mm', 'precip_type_5min:idx',
#        'pressure_100m:hPa', 'pressure_50m:hPa', 'prob_rime:p',
#        'rain_water:kgm2', 'relative_humidity_1000hPa:p', 'sfc_pressure:hPa',
#        'snow_density:kgm3', 'snow_depth:cm', 'snow_drift:idx',
#        'snow_melt_10min:mm', 'snow_water:kgm2', 'sun_azimuth:d',
#        'sun_elevation:d', 'super_cooled_liquid_water:kgm2', 't_1000hPa:K',
# ...

# %%
train1 = TabularDataset(train1)
train2 = TabularDataset(train2)
train3 = TabularDataset(train3)

# %%
tuning1 = TabularDataset(tune1)
tuning2 = TabularDataset(tune2)
tuning3 = TabularDataset(tune3)

# %%
test1 = pipin.get_test_data("A")
test_data1 = TabularDataset(test1)
test_data1
# Out:
#      absolute_humidity_2m:gm3  air_density_2m:kgm3  ceiling_height_agl:m  \
# 0                       4.325              1.28675            912.700012
# 1                       4.275              1.28600           1482.099976
# 2                       4.150              1.28375           1791.300049
# 3                       4.025              1.28200           2312.875000
# 4                       3.900              1.28100           2198.299805
# ..                        ...                  ...                   ...
# 715                     8.350              1.19725           3638.899902
# 716                     8.525              1.20050           3552.100098
# 717                     8.825              1.20450           2315.000000
# 718                     9.025              1.20700           2202.800049
# 719                     9.050              1.20775           2015.675049
#
#      clear_sky_energy_1h:J  clear_sky_rad:W  cloud_base_agl:m  \
# ...

# %%
predictor1 = TabularPredictor(label="pv_measurement", eval_metric='mean_absolute_error').fit(
    train1,
    # time_limit=6000,
    # hyperparameters='extrme', 
    presets='best_quality',
    tuning_data = tuning1,
    use_bag_holdout=True,
    # num_bag_folds= 6,
    # refit_full = True,
    # auto_stack = True,
    # num_bag_sets= 10,
    # set_best_to_refit_full= True,
    # num_stack_levels = 2,
    # verbosity = 3
    )
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20231108_115828/"
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20231108_115828/"
# AutoGluon Version:  0.8.2
# Python Version:     3.10.13
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 22.5.0: Thu Jun  8 22:22:20 PDT 2023; root:xnu-8796.121.3~7/RELEASE_ARM64_T6000
# Disk Space Avail:   623.91 GB / 994.66 GB (62.7%)
# Train Data Rows:    27256
# Train Data Columns: 49
# Tuning Data Rows:    6762
# Tuning Data Columns: 49
# Label Column: pv_measurement
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (5651.8, 0.0, 595.2049, 1123.56535)
# ...

# %%
test1 = pipin.get_test_data("A")
test_data1 = TabularDataset(test1)
pred1 = pd.DataFrame(predictor1.predict(test_data1))
test_data1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/matsalexander/Desktop/Forest Gump/mats/gluon/gluon_3_145_tuning.ipynb Cell 20 line 1
# ----> <a href='vscode-notebook-cell:/Users/matsalexander/Desktop/Forest%20Gump/mats/gluon/gluon_3_145_tuning.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> test1 = pipin.get_test_data("A")
#       <a href='vscode-notebook-cell:/Users/matsalexander/Desktop/Forest%20Gump/mats/gluon/gluon_3_145_tuning.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a> test_data1 = TabularDataset(test1)
#       <a href='vscode-notebook-cell:/Users/matsalexander/Desktop/Forest%20Gump/mats/gluon/gluon_3_145_tuning.ipynb#X15sZmlsZQ%3D%3D?line=2'>3</a> # pred1 = pd.DataFrame(predictor1.predict(test_data1))
#
# File ~/Desktop/Forest Gump/mats/gluon/../pipeline_tuning.py:101, in Pipeline.get_test_data(self, location)
#      99 def get_test_data(self, location: str) -> pd.DataFrame:
# ...

# %%
predictor2 = TabularPredictor(label="pv_measurement", eval_metric='mean_absolute_error').fit(
    train2,

    presets='best_quality', 
    # hyperparameters='very_large', 
    # time_limit=6000,
    tuning_data = tuning2,
    use_bag_holdout=True,
    # num_bag_folds= 6,
    # refit_full = True,
    # auto_stack = True,
    # num_bag_sets= 10,
    # set_best_to_refit_full= True,
    # num_stack_levels = 2,
    # verbosity = 3
    )

# tuning_data
# num bag holdout 6
# bag_holdout
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20231108_114819/"
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20231108_114819/"
# AutoGluon Version:  0.8.2
# Python Version:     3.10.13
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 22.5.0: Thu Jun  8 22:22:20 PDT 2023; root:xnu-8796.121.3~7/RELEASE_ARM64_T6000
# Disk Space Avail:   625.45 GB / 994.66 GB (62.9%)
# Train Data Rows:    20321
# Train Data Columns: 49
# Tuning Data Rows:    5395
# Tuning Data Columns: 49
# Label Column: pv_measurement
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (1152.3, 0.0, 97.67397, 200.97769)
# ...

# %%
predictor3 = TabularPredictor(label="pv_measurement", eval_metric='mean_absolute_error' ).fit(
    train3,

    presets='best_quality', 
    # hyperparameters='very_large', 
    # time_limit=6000,
    tuning_data = tuning3,
    use_bag_holdout=True,
    # num_bag_folds= 6,
    # refit_full = True,
    # auto_stack = True,
    # num_bag_sets= 10,
    # set_best_to_refit_full= True,
    # num_stack_levels = 2,
    # verbosity = 3
    )
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20231108_094616/"
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20231108_094616/"
# AutoGluon Version:  0.8.2
# Python Version:     3.10.13
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 22.5.0: Thu Jun  8 22:22:20 PDT 2023; root:xnu-8796.121.3~7/RELEASE_ARM64_T6000
# Disk Space Avail:   632.85 GB / 994.66 GB (63.6%)
# Train Data Rows:    21093
# Train Data Columns: 49
# Tuning Data Rows:    1421
# Tuning Data Columns: 49
# Label Column: pv_measurement
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and label-values can't be converted to int).
# 	Label info (max, min, mean, stddev): (999.6, 0.0, 96.01356, 179.58944)
# ...

# %%
test1 = pipin.get_test_data("A")
test2 = pipin.get_test_data("B")
test3 = pipin.get_test_data("C")

# %%
test_data1 = TabularDataset(test1)
test_data2 = TabularDataset(test2)
test_data3 = TabularDataset(test3)

pred1 = pd.DataFrame(predictor1.predict(test_data1))
pred2 = pd.DataFrame(predictor2.predict(test_data2))
pred3 = pd.DataFrame(predictor3.predict(test_data3))

negatives_pred1 = pred1[pred1["pv_measurement"] < 0]
negatives_pred2 = pred2[pred2["pv_measurement"] < 0]
negatives_pred3 = pred3[pred3["pv_measurement"] < 0]
neg = pd.concat([negatives_pred1, negatives_pred2, negatives_pred3])
neg.shape
# Out:
# (0, 1)

# %%
from utils import get_unique_filename
pred = pd.concat([pred1, pred2, pred3])
final_prediction = pipin.post_processing(pred, prediction_column="pv_measurement")
final_prediction.to_csv(get_unique_filename('gluon_3_same_as_145'))

# %%
diff = pipin.compare_mae(final_prediction)
diff
# Out:
# 146.10734352930925

# %%
# predictor.evaluate(df1, silent=True)
