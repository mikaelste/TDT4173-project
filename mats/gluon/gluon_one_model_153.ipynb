# min             0.000000          0.000000           0.000000
# 25%             0.000000          0.000000           0.000000
# 50%             0.000000          0.000000           0.000000
# 75%             0.000000          0.000000           0.000000
# max             0.125000          0.125000           0.125000
#
#        fresh_snow_3h:cm  fresh_snow_6h:cm  is_day:idx  is_in_shadow:idx  \
# count        720.000000        720.000000  720.000000        720.000000
# mean           0.000347          0.000347    0.793750          0.225347
# std            0.006583          0.006583    0.385538          0.405328
# min            0.000000          0.000000    0.000000          0.000000
# 25%            0.000000          0.000000    1.000000          0.000000
# 50%            0.000000          0.000000    1.000000          0.000000
# 75%            0.000000          0.000000    1.000000          0.000000
# max            0.125000          0.125000    1.000000          1.000000
#
#        msl_pressure:hPa  precip_5min:mm  precip_type_5min:idx  \
# count        720.000000      720.000000            720.000000
# mean        1016.797241        0.007476              0.063889
# std            9.731263        0.031335              0.230456
# min          986.025024        0.000000              0.000000
# 25%         1011.549988        0.000000              0.000000
# 50%         1020.437500        0.000000              0.000000
# 75%         1023.849976        0.000000              0.000000
# max         1029.500000        0.287500              1.000000
#
#        pressure_100m:hPa  pressure_50m:hPa  prob_rime:p  rain_water:kgm2  \
# count         720.000000        720.000000        720.0       720.000000
# mean         1003.811279       1009.852600          0.0         0.013333
# std             9.620932          9.717662          0.0         0.052354
# min           973.799988        979.625000          0.0         0.000000
# 25%           998.418747       1004.437515          0.0         0.000000
# 50%          1007.475006       1013.562500          0.0         0.000000
# 75%          1010.924988       1017.000000          0.0         0.000000
# max          1016.325012       1022.500000          0.0         0.525000
#
#        relative_humidity_1000hPa:p  sfc_pressure:hPa  snow_density:kgm3  \
# count                   720.000000        720.000000                0.0
# mean                     70.750069       1015.920654                NaN
# std                      15.531467          9.817863                NaN
# min                      24.824999        985.450012                NaN
# 25%                      60.368752       1010.487503                NaN
# 50%                      73.550003       1019.662506                NaN
# 75%                      83.275002       1023.031265                NaN
# max                      97.000000       1028.699951                NaN
#
#        snow_depth:cm  snow_drift:idx  snow_melt_10min:mm  snow_water:kgm2  \
# count          720.0           720.0               720.0       720.000000
# mean             0.0             0.0                 0.0         0.061146
# std              0.0             0.0                 0.0         0.201748
# min              0.0             0.0                 0.0         0.000000
# 25%              0.0             0.0                 0.0         0.000000
# 50%              0.0             0.0                 0.0         0.000000
# 75%              0.0             0.0                 0.0         0.000000
# max              0.0             0.0                 0.0         2.900000
#
#        sun_azimuth:d  sun_elevation:d  super_cooled_liquid_water:kgm2  \
# count     720.000000       720.000000                      720.000000
# mean      179.181381        21.730387                        0.063924
# std       103.971336        16.930809                        0.108792
# min        13.441751         0.020750                        0.000000
# 25%        89.981750         4.640813                        0.000000
# 50%       180.960999        19.800626                        0.000000
# 75%       271.244804        38.861813                        0.100000
# max       348.118500        49.903500                        0.600000
#
#        t_1000hPa:K  total_cloud_cover:p  visibility:m  wind_speed_10m:ms  \
# count   720.000000           720.000000    720.000000         720.000000
# mean    284.723358            69.309792  33599.617188           3.075139
# std       5.811303            37.675526  15615.333008           1.795147
# min     273.799988             0.000000   2104.725098           0.100000
# 25%     279.849976            38.918751  19721.299805           1.593750
# 50%     284.774994            91.625000  36758.650391           2.950000
# 75%     288.174995           100.000000  46096.938477           4.206250
# max     301.950012           100.000000  63868.226562           9.075000
#
#        wind_speed_u_10m:ms  wind_speed_v_10m:ms  wind_speed_w_1000hPa:ms  \
# count           720.000000           720.000000                    720.0
# mean              2.606146             1.224549                      0.0
# std               1.896068             0.872396                      0.0
# min               0.000000             0.000000                      0.0
# 25%               0.925000             0.500000                      0.0
# 50%               2.400000             1.075000                      0.0
# 75%               3.800000             1.750000                      0.0
# max               9.050000             4.300000                      0.0
#
#        estimated  observed  day_of_year        hour
# count      720.0     720.0   720.000000  720.000000
# mean         1.0       0.0   156.433333   11.500000
# std          0.0       0.0    16.983703    6.926999
# min          1.0       0.0   121.000000    0.000000
# 25%          1.0       0.0   143.000000    5.750000
# 50%          1.0       0.0   154.500000   11.500000
# 75%          1.0       0.0   170.000000   17.250000
# max          1.0       0.0   184.000000   23.000000

# %%
# train, tune = TabularDataset(df), TabularDataset(df_tune)
train = TabularDataset(df0)

# %%
label="pv_measurement"
eval_metric="mean_absolute_error"

# %%
predictor1 = TabularPredictor(label=label, eval_metric=eval_metric).fit(
    train,
    presets='best_quality', 
    # tuning_data = tune,
    # use_bag_holdout=True,
    )
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20231107_092121/"
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20231107_092121/"
# AutoGluon Version:  0.8.2
# Python Version:     3.10.13
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 22.5.0: Thu Jun  8 22:22:20 PDT 2023; root:xnu-8796.121.3~7/RELEASE_ARM64_T6000
# Disk Space Avail:   592.05 GB / 994.66 GB (59.5%)
# Train Data Rows:    93024
# Train Data Columns: 52
# Label Column: pv_measurement
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (5733.42, 0.0, 287.01965, 766.40778)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    10315.45 MB
# 	Train Data (Original)  Memory Usage: 21.95 MB (0.2% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 4 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 49 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 		('int', [])   :  3 | ['A', 'B', 'C']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 48 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 		('int', ['bool']) :  4 | ['snow_density:kgm3', 'A', 'B', 'C']
# 	1.3s = Fit runtime
# 	52 features in original data used to generate 52 features in processed data.
# 	Train Data (Processed) Memory Usage: 19.72 MB (0.2% of available memory)
# Data preprocessing and feature engineering runtime = 1.51s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ...
# 	-289.8916	 = Validation score   (-mean_absolute_error)
# 	0.18s	 = Training   runtime
# 	20.8s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ...
# 	-375.461	 = Validation score   (-mean_absolute_error)
# 	0.24s	 = Training   runtime
# 	19.15s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-70.0286	 = Validation score   (-mean_absolute_error)
# 	152.83s	 = Training   runtime
# 	211.17s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-73.3271	 = Validation score   (-mean_absolute_error)
# 	225.78s	 = Training   runtime
# 	321.11s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ...
# 	-83.3312	 = Validation score   (-mean_absolute_error)
# 	161.51s	 = Training   runtime
# 	7.37s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-79.027	 = Validation score   (-mean_absolute_error)
# 	1796.64s	 = Training   runtime
# 	0.94s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ...
# 	-83.4553	 = Validation score   (-mean_absolute_error)
# 	15.67s	 = Training   runtime
# 	4.72s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	Warning: Exception caused NeuralNetFastAI_BAG_L1 to fail during training... Skipping this model.
# 		ray::_ray_fit() (pid=59103, ip=127.0.0.1)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 402, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 829, in fit
#     out = self._fit(**kwargs)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py", line 327, in _fit
#     self.model.fit_one_cycle(epochs, params["lr"], cbs=callbacks)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/callback/schedule.py", line 119, in fit_one_cycle
#     self.fit(n_epoch, cbs=ParamScheduler(scheds)+L(cbs), reset_opt=reset_opt, wd=wd, start_epoch=start_epoch)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/learner.py", line 264, in fit
#     self._with_events(self._do_fit, 'fit', CancelFitException, self._end_cleanup)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/learner.py", line 201, in _with_events
#     self(f'after_{event_type}');  final()
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/learner.py", line 172, in __call__
#     def __call__(self, event_name): L(event_name).map(self._call_one)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastcore/foundation.py", line 156, in map
#     def map(self, f, *args, **kwargs): return self._new(map_ex(self, f, *args, gen=False, **kwargs))
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastcore/basics.py", line 840, in map_ex
#     return list(res)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastcore/basics.py", line 825, in __call__
#     return self.func(*fargs, **kwargs)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/learner.py", line 176, in _call_one
#     for cb in self.cbs.sorted('order'): cb(event_name)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/callback/core.py", line 62, in __call__
#     except Exception as e: raise modify_exception(e, f'Exception occured in `{self.__class__.__name__}` when calling event `{event_name}`:\n\t{e.args[0]}', replace=True)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/callback/core.py", line 60, in __call__
#     try: res = getcallable(self, event_name)()
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/callbacks.py", line 107, in after_fit
#     self.learn.load(f"{self.fname}", with_opt=self.with_opt)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/learner.py", line 420, in load
#     load_model(file, self.model, self.opt, device=device, **kwargs)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/learner.py", line 51, in load_model
#     state = torch.load(file, map_location=device, **torch_load_kwargs)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/torch/serialization.py", line 771, in load
#     with _open_file_like(f, 'rb') as opened_file:
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/torch/serialization.py", line 270, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/torch/serialization.py", line 251, in __init__
#     super(_open_file, self).__init__(open(name, mode))
# FileNotFoundError: [Errno 2] No such file or directory: '/var/folders/b0/slnc__2x31jczblnsfgfmjw00000gn/T/tmpx_q8p4_o/models/model.pth'
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/core/trainer/abstract_trainer.py", line 1733, in _train_and_save
#     model = self._train_single(X, y, model, X_val, y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/core/trainer/abstract_trainer.py", line 1684, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 829, in fit
#     out = self._fit(**kwargs)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/core/models/ensemble/stacker_ensemble_model.py", line 169, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 266, in _fit
#     self._fit_folds(
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 592, in _fit_folds
#     fold_fitting_strategy.after_all_folds_scheduled()
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 581, in after_all_folds_scheduled
#     raise processed_exception
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 541, in after_all_folds_scheduled
#     fold_model, pred_proba, time_start_fit, time_end_fit, predict_time, predict_1_time = self.ray.get(finished)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 105, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/ray/_private/worker.py", line 2380, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(FileNotFoundError): ray::_ray_fit() (pid=59103, ip=127.0.0.1)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 402, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 829, in fit
#     out = self._fit(**kwargs)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py", line 327, in _fit
#     self.model.fit_one_cycle(epochs, params["lr"], cbs=callbacks)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/callback/schedule.py", line 119, in fit_one_cycle
#     self.fit(n_epoch, cbs=ParamScheduler(scheds)+L(cbs), reset_opt=reset_opt, wd=wd, start_epoch=start_epoch)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/learner.py", line 264, in fit
#     self._with_events(self._do_fit, 'fit', CancelFitException, self._end_cleanup)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/learner.py", line 201, in _with_events
#     self(f'after_{event_type}');  final()
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/learner.py", line 172, in __call__
#     def __call__(self, event_name): L(event_name).map(self._call_one)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastcore/foundation.py", line 156, in map
#     def map(self, f, *args, **kwargs): return self._new(map_ex(self, f, *args, gen=False, **kwargs))
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastcore/basics.py", line 840, in map_ex
#     return list(res)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastcore/basics.py", line 825, in __call__
#     return self.func(*fargs, **kwargs)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/learner.py", line 176, in _call_one
#     for cb in self.cbs.sorted('order'): cb(event_name)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/callback/core.py", line 62, in __call__
#     except Exception as e: raise modify_exception(e, f'Exception occured in `{self.__class__.__name__}` when calling event `{event_name}`:\n\t{e.args[0]}', replace=True)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/callback/core.py", line 60, in __call__
#     try: res = getcallable(self, event_name)()
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/autogluon/tabular/models/fastainn/callbacks.py", line 107, in after_fit
#     self.learn.load(f"{self.fname}", with_opt=self.with_opt)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/learner.py", line 420, in load
#     load_model(file, self.model, self.opt, device=device, **kwargs)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/fastai/learner.py", line 51, in load_model
#     state = torch.load(file, map_location=device, **torch_load_kwargs)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/torch/serialization.py", line 771, in load
#     with _open_file_like(f, 'rb') as opened_file:
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/torch/serialization.py", line 270, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#   File "/Users/matsalexander/.pyenv/versions/3.10.13/envs/gluon/lib/python3.10/site-packages/torch/serialization.py", line 251, in __init__
#     super(_open_file, self).__init__(open(name, mode))
# FileNotFoundError: [Errno 2] No such file or directory: '/var/folders/b0/slnc__2x31jczblnsfgfmjw00000gn/T/tmpx_q8p4_o/models/model.pth'
# Fitting model: XGBoost_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 2023-11-07 11:05:24,680	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-07 11:05:24,707	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-07 11:05:24,720	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-07 11:05:24,764	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-07 11:05:24,776	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-07 11:05:24,778	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-07 11:05:24,778	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	-82.4633	 = Validation score   (-mean_absolute_error)
# 	1557.25s	 = Training   runtime
# 	58.57s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-82.8569	 = Validation score   (-mean_absolute_error)
# 	506.93s	 = Training   runtime
# 	1.83s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-68.3093	 = Validation score   (-mean_absolute_error)
# 	363.59s	 = Training   runtime
# 	601.17s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-66.8715	 = Validation score   (-mean_absolute_error)
# 	0.67s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 9 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-61.0915	 = Validation score   (-mean_absolute_error)
# 	161.6s	 = Training   runtime
# 	238.37s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-60.9309	 = Validation score   (-mean_absolute_error)
# 	19.14s	 = Training   runtime
# 	2.86s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ...
# 	-59.8732	 = Validation score   (-mean_absolute_error)
# 	203.12s	 = Training   runtime
# 	3.62s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-61.4276	 = Validation score   (-mean_absolute_error)
# 	164.94s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ...
# 	-61.1315	 = Validation score   (-mean_absolute_error)
# 	15.17s	 = Training   runtime
# 	2.57s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-64.0526	 = Validation score   (-mean_absolute_error)
# 	52.52s	 = Training   runtime
# 	0.68s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-60.9315	 = Validation score   (-mean_absolute_error)
# 	11.53s	 = Training   runtime
# 	0.47s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-66.6342	 = Validation score   (-mean_absolute_error)
# 	41.49s	 = Training   runtime
# 	0.55s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-58.7859	 = Validation score   (-mean_absolute_error)
# 	138.15s	 = Training   runtime
# 	262.88s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ...
# 	-58.1552	 = Validation score   (-mean_absolute_error)
# 	0.51s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 6043.86s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20231107_092121/")

# %%
test_data = pipin.get_combined_data(test_data=True)
test_data = TabularDataset(test_data)
test_data.shape
# Out:
# (2160, 52)

# %%
pred = pd.DataFrame(predictor1.predict(test_data))
negatives_pred = pred[pred["pv_measurement"] < 0]
negatives_pred.shape
# Out:
# (81, 1)

# %%
from utils import get_unique_filename
final_prediction = pipin.post_processing(pred, prediction_column="pv_measurement")
final_prediction.to_csv(get_unique_filename('big_gluon_with_pipe_no_add'))

# %%
diff = pipin.compare_mae(final_prediction)
diff
# Out:
# 55.01258566397478

# %%
# predictor1.evaluate(train, silent=True)
