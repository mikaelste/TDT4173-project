# %% [markdown]
# <h3> Nå tester jeg ute time since calc. Jeg legger til abs av alle verdier. Uten abs av verider fikk modellen 148.04</h3>
# <p> Jeg har ikke med hotencode estimated <p>

# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from autogluon.tabular import TabularDataset, TabularPredictor
import pandas as pd
import numpy as np

# %%
# %autoreload
import sys
sys.path.append('../')
from pipeline import Pipeline
pipin = Pipeline()
# Out:
# Current working directory: /Users/matsalexander/Desktop/Forest Gump/mats/gluon

# %%
df1_0 = pipin.get_data("A")
df2_0 = pipin.get_data("B")
df3_0 = pipin.get_data("C")

# %%
df1_0.head()
# Out:
#    absolute_humidity_2m:gm3  air_density_2m:kgm3  ceiling_height_agl:m  \
# 0                     7.700              1.22825           1728.949951
# 1                     7.700              1.22350           1689.824951
# 2                     7.875              1.21975           1563.224976
# 3                     8.425              1.21800           1283.425049
# 4                     8.950              1.21800           1003.500000
#
#    clear_sky_energy_1h:J  clear_sky_rad:W  cloud_base_agl:m  dew_or_rime:idx  \
# 0               0.000000             0.00       1728.949951              0.0
# 1               0.000000             0.00       1689.824951              0.0
# 2               0.000000             0.00       1563.224976              0.0
# 3             208.649994             0.75       1283.425049              0.0
# 4           32468.150391            23.10       1003.500000              0.0
#
#    dew_point_2m:K  diffuse_rad:W  diffuse_rad_1h:J  ...  total_cloud_cover:p  \
# 0      280.299988          0.000          0.000000  ...           100.000000
# 1      280.299988          0.000          0.000000  ...           100.000000
# 2      280.649994          0.000          0.000000  ...           100.000000
# 3      281.674988          0.300        526.775024  ...           100.000000
# 4      282.500000         11.975      22068.949219  ...            99.224998
#
#    visibility:m  wind_speed_10m:ms  wind_speed_u_10m:ms  wind_speed_v_10m:ms  \
# 0  40386.476562              3.600                3.575                0.500
# 1  33770.648438              3.350                3.350                0.275
# 2  13595.500000              3.050                2.950                0.750
# 3   2321.850098              2.725                2.600                0.875
# 4  11634.799805              2.550                2.350                0.925
#
#    wind_speed_w_1000hPa:ms  calculated_ago  day_of_year  hour  pv_measurement
# 0                      0.0             0.0        153.0  22.0            0.00
# 1                      0.0             0.0        153.0  23.0            0.00
# 2                      0.0             0.0        154.0   0.0            0.00
# 3                      0.0             0.0        154.0   1.0            0.00
# 4                      0.0             0.0        154.0   2.0           19.36
#
# [5 rows x 49 columns]

# %%
train1 = TabularDataset(df1_0)
train2 = TabularDataset(df2_0)
train3 = TabularDataset(df3_0)

# %%
predictor1 = TabularPredictor(label="pv_measurement", eval_metric='mean_absolute_error').fit(
    train1,
    # time_limit=6000,
    # hyperparameters='extrme', 
    presets='best_quality', 
    # tuning_data = tuning1,
    # use_bag_holdout=True,
    # num_bag_folds= 6,
    # refit_full = True,
    # auto_stack = True,
    # num_bag_sets= 10,
    # set_best_to_refit_full= True,
    # num_stack_levels = 2,
    # verbosity = 3
    )
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20231107_080659/"
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20231107_080659/"
# AutoGluon Version:  0.8.2
# Python Version:     3.10.13
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 22.5.0: Thu Jun  8 22:22:20 PDT 2023; root:xnu-8796.121.3~7/RELEASE_ARM64_T6000
# Disk Space Avail:   641.52 GB / 994.66 GB (64.5%)
# Train Data Rows:    34085
# Train Data Columns: 48
# Label Column: pv_measurement
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (5733.42, 0.0, 630.59471, 1165.90242)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    12633.14 MB
# 	Train Data (Original)  Memory Usage: 6.95 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 3 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Unused Original Features (Count: 1): ['snow_drift:idx']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('float', []) : 1 | ['snow_drift:idx']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 47 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 45 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 		('int', ['bool']) :  2 | ['elevation:m', 'snow_density:kgm3']
# 	0.3s = Fit runtime
# 	47 features in original data used to generate 47 features in processed data.
# 	Train Data (Processed) Memory Usage: 6.61 MB (0.1% of available memory)
# Data preprocessing and feature engineering runtime = 0.33s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ...
# 	-266.2614	 = Validation score   (-mean_absolute_error)
# 	0.03s	 = Training   runtime
# 	1.81s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ...
# 	-266.9746	 = Validation score   (-mean_absolute_error)
# 	0.02s	 = Training   runtime
# 	2.07s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-155.1945	 = Validation score   (-mean_absolute_error)
# 	138.69s	 = Training   runtime
# 	109.47s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-163.313	 = Validation score   (-mean_absolute_error)
# 	119.45s	 = Training   runtime
# 	150.75s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ...
# 	-181.3585	 = Validation score   (-mean_absolute_error)
# 	63.73s	 = Training   runtime
# 	1.4s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-169.4752	 = Validation score   (-mean_absolute_error)
# 	613.02s	 = Training   runtime
# 	1.15s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ...
# 	-181.6923	 = Validation score   (-mean_absolute_error)
# 	33.35s	 = Training   runtime
# 	1.29s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-186.1052	 = Validation score   (-mean_absolute_error)
# 	79.85s	 = Training   runtime
# 	0.88s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-172.6131	 = Validation score   (-mean_absolute_error)
# 	443.63s	 = Training   runtime
# 	162.53s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-171.9788	 = Validation score   (-mean_absolute_error)
# 	123.84s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-159.6999	 = Validation score   (-mean_absolute_error)
# 	315.6s	 = Training   runtime
# 	493.8s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-152.4869	 = Validation score   (-mean_absolute_error)
# 	0.37s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 9 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-154.9774	 = Validation score   (-mean_absolute_error)
# 	6.39s	 = Training   runtime
# 	0.88s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-151.9846	 = Validation score   (-mean_absolute_error)
# 	5.07s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ...
# 	-151.2219	 = Validation score   (-mean_absolute_error)
# 	118.15s	 = Training   runtime
# 	1.71s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-152.17	 = Validation score   (-mean_absolute_error)
# 	34.62s	 = Training   runtime
# 	0.44s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ...
# 	-150.4988	 = Validation score   (-mean_absolute_error)
# 	25.89s	 = Training   runtime
# 	1.5s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-152.4954	 = Validation score   (-mean_absolute_error)
# 	49.92s	 = Training   runtime
# 	0.42s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-151.317	 = Validation score   (-mean_absolute_error)
# 	8.37s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-152.0597	 = Validation score   (-mean_absolute_error)
# 	136.86s	 = Training   runtime
# 	0.41s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-153.0817	 = Validation score   (-mean_absolute_error)
# 	10.66s	 = Training   runtime
# 	0.9s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ...
# 	-148.2303	 = Validation score   (-mean_absolute_error)
# 	0.35s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 2564.45s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20231107_080659/")

# %%
predictor2 = TabularPredictor(label="pv_measurement", eval_metric='mean_absolute_error').fit(
    train2,

    presets='best_quality', 
    # hyperparameters='very_large', 
    # time_limit=6000,
    # tuning_data = tuning2,
    # use_bag_holdout=True,
    # num_bag_folds= 6,
    # refit_full = True,
    # auto_stack = True,
    # num_bag_sets= 10,
    # set_best_to_refit_full= True,
    # num_stack_levels = 2,
    # verbosity = 3
    )

# tuning_data
# num bag holdout 6
# bag_holdout
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20231107_084944/"
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20231107_084944/"
# AutoGluon Version:  0.8.2
# Python Version:     3.10.13
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 22.5.0: Thu Jun  8 22:22:20 PDT 2023; root:xnu-8796.121.3~7/RELEASE_ARM64_T6000
# Disk Space Avail:   629.49 GB / 994.66 GB (63.3%)
# Train Data Rows:    32844
# Train Data Columns: 48
# Label Column: pv_measurement
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (1152.3, 0.0, 96.82478, 193.94649)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    11985.81 MB
# 	Train Data (Original)  Memory Usage: 6.7 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 2 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 48 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 46 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 		('int', ['bool']) :  2 | ['elevation:m', 'snow_density:kgm3']
# 	0.2s = Fit runtime
# 	48 features in original data used to generate 48 features in processed data.
# 	Train Data (Processed) Memory Usage: 6.5 MB (0.1% of available memory)
# Data preprocessing and feature engineering runtime = 0.28s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ...
# 	-52.0534	 = Validation score   (-mean_absolute_error)
# 	0.03s	 = Training   runtime
# 	1.25s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ...
# 	-51.9553	 = Validation score   (-mean_absolute_error)
# 	0.02s	 = Training   runtime
# 	1.07s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-26.8696	 = Validation score   (-mean_absolute_error)
# 	73.11s	 = Training   runtime
# 	77.31s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-26.6901	 = Validation score   (-mean_absolute_error)
# 	102.16s	 = Training   runtime
# 	112.95s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ...
# 	-30.9234	 = Validation score   (-mean_absolute_error)
# 	99.84s	 = Training   runtime
# 	1.95s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-28.2864	 = Validation score   (-mean_absolute_error)
# 	477.53s	 = Training   runtime
# 	0.43s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ...
# 	-32.9348	 = Validation score   (-mean_absolute_error)
# 	22.05s	 = Training   runtime
# 	1.33s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-36.8061	 = Validation score   (-mean_absolute_error)
# 	141.55s	 = Training   runtime
# 	0.64s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-29.4005	 = Validation score   (-mean_absolute_error)
# 	364.32s	 = Training   runtime
# 	88.67s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-31.2787	 = Validation score   (-mean_absolute_error)
# 	129.51s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-25.0699	 = Validation score   (-mean_absolute_error)
# 	423.42s	 = Training   runtime
# 	905.55s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-24.8929	 = Validation score   (-mean_absolute_error)
# 	0.48s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 9 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.9515	 = Validation score   (-mean_absolute_error)
# 	16.52s	 = Training   runtime
# 	4.65s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.6152	 = Validation score   (-mean_absolute_error)
# 	31.91s	 = Training   runtime
# 	1.86s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ...
# 	-21.4205	 = Validation score   (-mean_absolute_error)
# 	141.6s	 = Training   runtime
# 	1.75s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.8217	 = Validation score   (-mean_absolute_error)
# 	94.06s	 = Training   runtime
# 	0.22s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ...
# 	-21.4985	 = Validation score   (-mean_absolute_error)
# 	17.91s	 = Training   runtime
# 	2.46s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.2654	 = Validation score   (-mean_absolute_error)
# 	113.19s	 = Training   runtime
# 	0.99s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.1964	 = Validation score   (-mean_absolute_error)
# 	12.11s	 = Training   runtime
# 	0.44s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-22.1299	 = Validation score   (-mean_absolute_error)
# 	152.84s	 = Training   runtime
# 	1.07s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-21.9544	 = Validation score   (-mean_absolute_error)
# 	183.28s	 = Training   runtime
# 	50.92s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ...
# 	-21.1501	 = Validation score   (-mean_absolute_error)
# 	0.31s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 2962.01s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20231107_084944/")

# %%
predictor3 = TabularPredictor(label="pv_measurement", eval_metric='mean_absolute_error' ).fit(
    train3,

    presets='best_quality', 
    # hyperparameters='very_large', 
    # time_limit=6000,
    # tuning_data = tuning3,
    # use_bag_holdout=True,
    # num_bag_folds= 6,
    # refit_full = True,
    # auto_stack = True,
    # num_bag_sets= 10,
    # set_best_to_refit_full= True,
    # num_stack_levels = 2,
    # verbosity = 3
    )
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20231107_093906/"
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20231107_093906/"
# AutoGluon Version:  0.8.2
# Python Version:     3.10.13
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 22.5.0: Thu Jun  8 22:22:20 PDT 2023; root:xnu-8796.121.3~7/RELEASE_ARM64_T6000
# Disk Space Avail:   585.12 GB / 994.66 GB (58.8%)
# Train Data Rows:    26095
# Train Data Columns: 48
# Label Column: pv_measurement
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and label-values can't be converted to int).
# 	Label info (max, min, mean, stddev): (999.6, 0.0, 77.63106, 165.81688)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    11636.14 MB
# 	Train Data (Original)  Memory Usage: 5.32 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 3 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Unused Original Features (Count: 1): ['snow_drift:idx']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('float', []) : 1 | ['snow_drift:idx']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 47 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 45 | ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', ...]
# 		('int', ['bool']) :  2 | ['elevation:m', 'snow_density:kgm3']
# 	0.4s = Fit runtime
# 	47 features in original data used to generate 47 features in processed data.
# 	Train Data (Processed) Memory Usage: 5.06 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.43s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ...
# 	-29.115	 = Validation score   (-mean_absolute_error)
# 	0.07s	 = Training   runtime
# 	2.05s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ...
# 	-29.0904	 = Validation score   (-mean_absolute_error)
# 	0.02s	 = Training   runtime
# 	1.6s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-16.58	 = Validation score   (-mean_absolute_error)
# 	121.34s	 = Training   runtime
# 	57.53s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-17.4667	 = Validation score   (-mean_absolute_error)
# 	1298.7s	 = Training   runtime
# 	2307.53s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ...
# 	-19.7163	 = Validation score   (-mean_absolute_error)
# 	42.37s	 = Training   runtime
# 	0.8s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-18.2547	 = Validation score   (-mean_absolute_error)
# 	1748.14s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ...
# 	-19.8594	 = Validation score   (-mean_absolute_error)
# 	14.66s	 = Training   runtime
# 	1.18s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-20.1655	 = Validation score   (-mean_absolute_error)
# 	158.3s	 = Training   runtime
# 	0.43s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-18.4136	 = Validation score   (-mean_absolute_error)
# 	158.36s	 = Training   runtime
# 	43.73s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-18.3407	 = Validation score   (-mean_absolute_error)
# 	186.85s	 = Training   runtime
# 	0.57s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-17.1374	 = Validation score   (-mean_absolute_error)
# 	239.56s	 = Training   runtime
# 	192.4s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-16.2049	 = Validation score   (-mean_absolute_error)
# 	0.29s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 9 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-16.6867	 = Validation score   (-mean_absolute_error)
# 	7.16s	 = Training   runtime
# 	1.13s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-16.4211	 = Validation score   (-mean_absolute_error)
# 	5.56s	 = Training   runtime
# 	0.58s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ...
# 	-16.04	 = Validation score   (-mean_absolute_error)
# 	59.91s	 = Training   runtime
# 	0.77s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-16.5526	 = Validation score   (-mean_absolute_error)
# 	29.9s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ...
# 	-16.0141	 = Validation score   (-mean_absolute_error)
# 	8.87s	 = Training   runtime
# 	0.79s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-16.2215	 = Validation score   (-mean_absolute_error)
# 	103.26s	 = Training   runtime
# 	0.53s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-16.2774	 = Validation score   (-mean_absolute_error)
# 	12.49s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-16.3684	 = Validation score   (-mean_absolute_error)
# 	64.34s	 = Training   runtime
# 	0.65s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-16.3211	 = Validation score   (-mean_absolute_error)
# 	20.44s	 = Training   runtime
# 	2.3s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ...
# 	-15.8063	 = Validation score   (-mean_absolute_error)
# 	0.25s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 4412.73s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20231107_093906/")

# %%
test1 = pipin.get_test_data("A")
test2 = pipin.get_test_data("B")
test3 = pipin.get_test_data("C")

# %%
test_data1 = TabularDataset(test1)
test_data2 = TabularDataset(test2)
test_data3 = TabularDataset(test3)

pred1 = pd.DataFrame(predictor1.predict(test_data1))
pred2 = pd.DataFrame(predictor2.predict(test_data2))
pred3 = pd.DataFrame(predictor3.predict(test_data3))

negatives_pred1 = pred1[pred1["pv_measurement"] < 0]
negatives_pred2 = pred2[pred2["pv_measurement"] < 0]
negatives_pred3 = pred3[pred3["pv_measurement"] < 0]
neg = pd.concat([negatives_pred1, negatives_pred2, negatives_pred3])
neg.shape
# Out:
# (55, 1)

# %%
from utils import get_unique_filename
pred = pd.concat([pred1, pred2, pred3])
final_prediction = pipin.post_processing(pred, prediction_column="pv_measurement")
final_prediction.to_csv(get_unique_filename('gluon_3_calc'))

# %%
diff = pipin.compare_mae(final_prediction)
diff
# Out:
# 59.95888593656395

# %%
# predictor.evaluate(df1, silent=True)
